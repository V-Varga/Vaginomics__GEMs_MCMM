% %% [markdown]
% # <span style="color:rgb(213,80,0)">README RAVEN GEMs</span>
%
% Author: Vi Varga
%
%
% Work Period: August 2025
%
% ## Description
%
% This MATLAB Live script can create the GEMs that were used for the MCMMs used in the `MCMMs__README_Tracking.ipynb` Jupyter Notebook.
%
%
% All GEMs in this project were created using the \[RAVEN Toolbox\](https://github.com/SysBioChalmers/RAVEN).
%
% ## Setup
%
% The MATLAB environment was set up for the RAVEN Toolbox's use according to the instructions on the Wiki, here: [https://github.com/SysBioChalmers/RAVEN/wiki](https://github.com/SysBioChalmers/RAVEN/wiki)
%
%
% Notes on RAVEN Toolbox files:
%
% -  All files are stored locally at: `C:\\Users\\viragv\\AppData\\Roaming\\MathWorks\\'MATLAB Add-Ons'\\Collections\\'RAVEN Toolbox'\\`
% -  `Within the above directory, files related to the [tutorials](https://github.com/SysBioChalmers/RAVEN/wiki/Tutorials) are found in the `tutorial` directory`

% %%
% testing GEM creation with RAVEN
%cd('C:\Users\viragv\AppData\Roaming\MathWorks\'MATLAB Add-Ons'\Collections\'RAVEN Toolbox'\tutorial\')
%tutorial5 % example model reconstruction from KEGG data
%tutorial6 % example model reconstruction from KEGG & MetaCyc data

% %% [markdown]
% ## Data wrangling
%
% The primary project working directory for this project is: C:/Users/viragv/Documents/ChalmersG/Courses/FKBT190\_Adv\_Biosci\_Tech/MCMMs\_Vaginomics/
%
% -  The Data/ subdirectory contains all protein FASTAs and GEMS
% -  The Results/ subdirectory contains the MCMMs
%
% Based on `tutorial6`, the RAVEN Toolbox requires protein FASTA files for the organisms of interest in order to generate the GEMs. These were downloaded from the NCBI as follows:
%
% -  *Trichomonas vaginalis*: [https://www.ncbi.nlm.nih.gov/datasets/genome/GCF\_026262505.1/](https://www.ncbi.nlm.nih.gov/datasets/genome/GCF_026262505.1/)
% -  *Prevotella bivia*: [https://www.ncbi.nlm.nih.gov/datasets/genome/GCF\_000262545.1/](https://www.ncbi.nlm.nih.gov/datasets/genome/GCF_000262545.1/)
% -  *Gardnerella vaginalis*: [https://www.ncbi.nlm.nih.gov/datasets/genome/GCF\_001042655.1/](https://www.ncbi.nlm.nih.gov/datasets/genome/GCF_001042655.1/)
% -  *Lactobacillus iners*: [https://www.ncbi.nlm.nih.gov/datasets/taxonomy/147802/](https://www.ncbi.nlm.nih.gov/datasets/taxonomy/147802/)
% -  *Lactobacillus crispatus*: [https://www.ncbi.nlm.nih.gov/datasets/taxonomy/47770/](https://www.ncbi.nlm.nih.gov/datasets/taxonomy/47770/)
% -  Note: A human GEM was not generated, as the SysBio Human\-GEM is available from GitHub: [https://github.com/SysBioChalmers/Human\-GEM](https://github.com/SysBioChalmers/Human-GEM)
%
% For all protein FASTA datasets, I used the GCF dataset version (GCF is RefSeq; GCA is GenBank).
%
%
% The FASTA headers were cleaned up for ease of use in GEM generation with the `assignFASTAheaders_GEMs.py` script, like so:
%
%
% `# gardnerella vaginalis`
%
%
% `python assignFASTAheaders_GEMs.py Data/gardnerella_vaginalis_GCF_001042655-1_prots.faa Data/GEM_EncodingSummary.txt`
%
%
% `# lactobacillus crispatus`
%
%
% `python assignFASTAheaders_GEMs.py Data/lactobacillus_crispatus_GCF_009769205-1_prots.faa Data/GEM_EncodingSummary.txt`
%
%
% `# lactobacillus iners`
%
%
% `python assignFASTAheaders_GEMs.py Data/lactobacillus_iners_GCF_011058775-1_prots.faa Data/GEM_EncodingSummary.txt`
%
%
% `# prevotella bivia`
%
%
% `python assignFASTAheaders_GEMs.py Data/prevotella_bivia_GCF_000262545-1_prots.faa Data/GEM_EncodingSummary.txt`
%
%
% `# trichomonas vaginalis`
%
%
% `python assignFASTAheaders_GEMs.py Data/trichomonas_vaginalis_GCF_026262505-1_prots.faa Data/GEM_EncodingSummary.txt`

% %%
%% Environment setup

% set the working directory with
%cd('C:\Users\viragv\Documents\ChalmersG\Courses\FKBT190_Adv_Biosci_Tech\MCMMs_Vaginomics\Data\');
% check that this worked correctly with
%disp(pwd);
% add the script directory to teh PATH
addpath('C:\Users\viragv\Documents\ChalmersG\Courses\FKBT190_Adv_Biosci_Tech\MCMMs_Vaginomics\Scripts\');
% load KEGG database to use for gap-filling
modelKEGG = getModelFromKEGG()
% Out:
% Importing the global KEGG model from C:/Users/viragv/AppData/Roaming/MathWorks/MATLAB Add-Ons/Collections/RAVEN Toolbox/external/kegg/keggModel.mat... COMPLETE
% modelKEGG = struct with fields:
%              id: 'KEGG'
%            name: 'Automatically generated from KEGG database'
%            rxns: {11588x1 cell}
%        rxnNames: {11588x1 cell}
%         eccodes: {11588x1 cell}
%      subSystems: {11588x1 cell}
%      rxnMiriams: {11588x1 cell}
%        rxnNotes: {11588x1 cell}
%               S: [9560x11588 double]
%            mets: {9560x1 cell}
%             rev: [11588x1 double]
%              ub: [11588x1 double]
%              lb: [11588x1 double]
%               c: [11588x1 double]
%               b: [9560x1 double]
%           genes: {6543571x1 cell}
%      rxnGeneMat: [11588x6543571 double]
%        metNames: {9560x1 cell}
%     metFormulas: {9560x1 cell}
%          inchis: {9560x1 cell}
%      metMiriams: {9560x1 cell}
%           comps: {'s'}
%       compNames: {'System'}
%        metComps: [9560x1 double]
%      annotation: [1x1 struct]

% %%
%clear; % clear environment variables
%clc % clear the command window

% %% [markdown]
% ## Small helper functions
%
% Minor cleaning functions used throughout the script:

% %%
% grRules continues to cause problems
function model = ensureGrRules(model)
    % Ensure model has grRules and matches rxns length
    if ~isfield(model,'grRules') || numel(model.grRules) ~= numel(model.rxns)
        model.grRules = repmat({''}, numel(model.rxns), 1);
        fprintf('Patched grRules to match %d rxns\n', numel(model.rxns));
    end
end

% ensuring reversibility
function model = ensureRevField(model)
    if ~isfield(model, 'rev')
        % infer reversibility from bounds
        model.rev = model.lb < 0;
        fprintf('Created rev field with %d reversible reactions\n', sum(model.rev));
    else
        fprintf('Model already has rev field\n');
    end
end

% check for dead-end metabolites
function deadMets = quickDeadEnds(model)
    deadMets = {};
    for i = 1:numel(model.mets)
        involved = find(model.S(i,:)); % reactions involving this metabolite
        if isempty(involved)
            deadMets{end+1} = model.mets{i};
        end
    end
    deadMets = deadMets(:);
end

% %% [markdown]
% ## GEM generation with RAVEN
%
% Below, I'll generate and quality\-check draft GEMs for the organisms of interest.
%
% ## Draft Lactobacillus crispatus GEM

% %%
%   Reconstruct a combined draft GEM from KEGG and MetaCyc pathway databases.
%   Based on RAVEN Toolbox tutorial6

%Before reconstruction, a FASTA file with protein sequences of the target
%organism needs to be prepared.
%This was doen by downloading sequences from the NCBI & processing them
%with the assignFASTAheaders_GEMs.py script, as described above.

%Generate the two draft models from KEGG database. The first one is
%reconstructed from the genome information annotated by KEGG. Since KEGG
%provides genome annotations for over 5000 organisms, their GEMs can thus
%be generated without providing protein sequences while only using the
%organismID. The organisms with KEGG annotation and their associated ids
%(e.g. 'lcr' for Lactobacillus crispatus) can be found from here:
%https://www.kegg.jp/kegg/catalog/org_list.html.
%Generate a draft model using KEGG annotation and exclude incomplete
%reactions and reactions with undefined stoichiometry
LcrispatusKEGGAnnotation=getKEGGModelForOrganism('lcr','','','',1,0,0);
% Out:
% *** The model reconstruction from KEGG based on the annotation available for KEGG Species lcr ***
% Importing the global KEGG model from C:/Users/viragv/AppData/Roaming/MathWorks/MATLAB Add-Ons/Collections/RAVEN Toolbox/external/kegg/keggModel.mat... COMPLETE
% Importing the KEGG phylogenetic distance matrix from C:/Users/viragv/AppData/Roaming/MathWorks/MATLAB Add-Ons/Collections/RAVEN Toolbox/external/kegg/keggPhylDist.mat... COMPLETE
% Pruning the model from non-lcr genes... COMPLETE
% Removing non-spontaneous reactions without GPR rules... COMPLETE
% Fixing gene names in the model... COMPLETE
% Constructing GPR associations and annotations for the model... COMPLETE
% *** Model reconstruction complete ***

% %%
%Generate the second KEGG-based draft model based on sequence homology to
%KEGG Ortholog sequence clusters while excluding incomplete reactions and
%the ones with undefined stoichiometry. Type "help getKEGGModelForOrganism"
%to see the detailed instructions for the choice of different parameters.
%The default values for homology search are used because they have been
%optimized for the best performance.
LcrispatusKEGGHomology=getKEGGModelForOrganism('LcrispatusKEGGHMMs','lactobacillus_crispatus_GCF_009769205-1_prots_edit.fasta','prok90_kegg105','',1,0,0);
% Out:
% *** The model reconstruction from KEGG based on the protein homology search against KEGG Orthology specific HMMs ***
% NOTE: Found prok90_kegg105 directory with pre-trained HMMs, it will therefore be used during reconstruction
% Importing the global KEGG model from C:/Users/viragv/AppData/Roaming/MathWorks/MATLAB Add-Ons/Collections/RAVEN Toolbox/external/kegg/keggModel.mat... COMPLETE
% Removing non-spontaneous reactions without GPR rules... COMPLETE
% Fixing gene names in the model... COMPLETE
% Importing the KEGG phylogenetic distance matrix from C:/Users/viragv/AppData/Roaming/MathWorks/MATLAB Add-Ons/Collections/RAVEN Toolbox/external/kegg/keggPhylDist.mat... COMPLETE
% Generating the KEGG Orthology specific multi-FASTA files... COMPLETE
% Performing clustering and multiple alignment for KEGG Orthology specific protein sets... COMPLETE
% Training the KEGG Orthology specific HMMs... COMPLETE
% Querying the user-specified FASTA file against the KEGG Orthology specific HMMs... COMPLETE
% Parsing the HMM search results... COMPLETE
% Removing gene, KEGG Orthology associations below minScoreRatioKO, minScoreRatioG... COMPLETE
% Adding gene annotations to the model... COMPLETE
% Removing non-spontaneous reactions which after HMM search no longer have GPR rules... COMPLETE
% Constructing GPR rules and finalizing the model... COMPLETE
% *** Model reconstruction complete ***

% %%
%De novo reconstruction from MetaCyc should take about 10 minutes, while
%both reconstructions from KEGG may take up to 50-60 minutes in overall
%depending on the computer hardware and the system used. Given that KEGG
%and MetaCyc databases are formulated in different ways; KEGG relies on
%sequence-based annotation, while MetaCyc collects only experimentally
%verified pathways. Therefore, integration of MetaCyc- and KEGG-based draft
%models could have a better coverage of the metbolism for the target
%organism.

%At first, the two KEGG-based models can be directly merged
LcrispatusKEGGDraftModel=mergeModels({LcrispatusKEGGAnnotation LcrispatusKEGGHomology});

disp(numel(LcrispatusKEGGHomology.rxns)+numel(LcrispatusKEGGAnnotation.rxns));
% Out:
%         1353

% %%
disp(numel(LcrispatusKEGGDraftModel.rxns));
% Out:
%         1353

% %%
%By checking the reaction number, it can be seen that reaction number in
%the merged model equals adding up the reaction numbers in homology and
%annotation KEGG draft models. And there are duplicated reactions in this
%merged model.

% %%
%Merge the duplicated reactions into one and combine multiple iso-enzymes
%into a single grRules. The expandModel and contractModel functions are
%utilised, see their instructions for details.
LcrispatusKEGGDraftModel=expandModel(LcrispatusKEGGDraftModel);
LcrispatusKEGGDraftModel=contractModel(LcrispatusKEGGDraftModel);

% %% [markdown]
% At this point, a draft GEM has been created for *L. crispatus*, merging the information from MetaCyc and KEGG. While it needs to be improved, I'll save it for now in Excel format to avoid having to recreate it each time.

% %%
exportToExcelFormat(LcrispatusKEGGDraftModel, 'Lcrispatus_draftGEM_v1.xlsx');
save('Lcrispatus_draftGEM_v1.mat', 'LcrispatusKEGGDraftModel');

% %% [markdown]
% ## Sanity checks
%
% The merged GEM likely has compatibility issues between the MetaCyc and KEGG reactions, so I need to clean those up:

% %%
%LcrispatusCombinedDraftModel = load('Lcrispatus_draftGEM_v1.mat');
LcrispatusCleanDraftModel = cleanGrRulesGenes(LcrispatusKEGGDraftModel);
LcrispatusCleanDraftModel = mergeDuplicateMetNames(LcrispatusCleanDraftModel);
LcrispatusCleanDraftModel = fixSubsystemsField(LcrispatusCleanDraftModel);

% %% [markdown]
% The preliminary model should now be ready for export.

% %%
exportModel(LcrispatusCleanDraftModel, 'Lcrispatus_draftGEM_v2.xml');
% Out:
% WARNING: No objective function found. This might be intended, but results in FBCv2 non-compliant SBML file when exported
% WARNING: The composition for the following metabolites could not be parsed:
%     C01977
%     C04157
%     C04432
%     C17324
%     C19722
%     C19723
%     C20451
%     C20650
%     C21582
%     C20751
% WARNING: The following InChI strings are associated to more than one unique metabolite name:
%     1S/C10H20O7P2/c1-9(2)5-4-6-10(3)7-8-16-19(14,15)17-18(11,12)13/h5,7H,4,6,8H2,1-3H3,(H,14,15)(H2,11,12,13)/b10-7+
% Document written

% %%
exportToExcelFormat(LcrispatusCleanDraftModel, 'Lcrispatus_draftGEM_v2.xlsx');
save('Lcrispatus_draftGEM_v2.mat', 'LcrispatusCleanDraftModel');

% %% [markdown]
% Saved in SBML standard GEM format.
%
% ## Quality checks & improvements
%
% First, import the saved model:

% %%
% Load the model from SBML (.xml)
%LcrispatusCleanDraftModel = importModel('Lcrispatus_draftGEM_v2.xml');

% %% [markdown]
% Now start quality checks:

% %%
%Check out if the newly generated LcrispatusCombinedDraftModel could grow
sol=solveLP(LcrispatusCleanDraftModel);
disp(sol.f);
% Out:
%      0

% %%
%The results indicate that this new model is non-functional
% ie., biomass = 0, which means there is no growth

% %% [markdown]
% A solution of 0 likely means that this model as it exists is non\-functional. This is most likely due to one of the following:
%
% -  The biomass reaction is incomplete, contains blocked metabolites, or requires compounds that the model cannot synthesize
% -  The constraints prevent flux to biomass even though the model could grow.
%
% Possible solutions/things to check include:
%
% -  Perform **gap filling** to see if missing reactions block biomass precursors.
% -  Run **metabolite producibility analysis** to identify which biomass components are unreachable.
% -  Verify transport/exchange reactions for essential nutrients.
% -  Are uptake rates for carbon, nitrogen, phosphorus, sulfur set correctly?
% -  Is oxygen (or other electron acceptors) available if the organism is aerobic?
% -  Are you using the right biomass reaction for the organism and strain?
% ## Looking for a biomass reaction
%
% Need to check whether a biomas reaction was generated:

% %%
% Look for metabolites whose names include the substring "biomass"
% (case-insensitive because we apply 'lower' before searching).
bioMets = find(contains(lower(LcrispatusCleanDraftModel.metNames), 'biomass'));

% If no biomass-like metabolites are found, raise a warning.
if isempty(bioMets)
    warning('No metabolites with "biomass" in the name were found.');
else
    % Otherwise, search for reactions that involve these biomass metabolites.
    % The stoichiometric matrix S has rows = metabolites, columns = reactions.
    % We check which reactions (columns) have nonzero entries in rows that
    % correspond to the biomass metabolites.
    [rxnIdx, ~] = find(LcrispatusCleanDraftModel.S(bioMets,:) ~= 0);

    % Remove duplicate reaction indices (since a metabolite could appear in
    % multiple positions, or multiple biomass metabolites may map to the same reaction).
    rxnIdx = unique(rxnIdx);

    % Display the identified potential biomass reactions
    disp('Potential biomass reactions:');
    % Display reaction indices, reaction IDs, and human-readable reaction names side by side
    disp([rxnIdx, LcrispatusCleanDraftModel.rxns(rxnIdx)', LcrispatusCleanDraftModel.rxnNames(rxnIdx)']);
end
% Out:
% Warning: No metabolites with "biomass" in the name were found.

% %% [markdown]
% ## Adding a biomass reaction
%
% Initial explorations showed that the current preliminary GEM draft doesn't have a biomass reaction. Hence, biomass will always be 0 until this is added. The following code was generated by ChatGPT; it seeds a biomass reaction from common building blocks like amino acids and nucleotides.

% %%
[LcrispatusBiomassDraftModel, biomassRxnID] = addPseudoBiomass_debug_all( ...
    LcrispatusCleanDraftModel, ...                  % Input model
    'BIOMASS_ps', ...                               % ID for new biomass reaction
    [], ...                                         % Use default precursor list
    true, ...                                       % Enable debug printing to console
    'Lcrispatus_biomass_debug.txt', ...             % Save debug log to file
    'Lcrispatus_biomass_metabolites.csv' ...        % Export metabolites to CSV
);
% Out:
% Precursor "L-alanine" → 3 matches found
%     Match: "UDP-N-acetylmuramoyl-L-alanine:D-glutamate ligase(ADP-forming)" (ID: R02783)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "D-Glutamate" (ID: C00217)
%         Metabolite: "UDP-N-acetylmuramoyl-L-alanine" (ID: C01212)
%     Match: "L-Alanine:tRNA(Ala) ligase (AMP-forming)" (ID: R03038)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "L-Alanine" (ID: C00041)
%         Metabolite: "tRNA(Ala)" (ID: C01635)
%     Match: "UDP-N-acetylmuramate:L-alanine ligase (ADP-forming)" (ID: R03193)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "L-Alanine" (ID: C00041)
%         Metabolite: "UDP-N-acetylmuramate" (ID: C01050)
% Precursor "L-arginine" → 3 matches found
%     Match: "L-Arginine iminohydrolase" (ID: R00552)
%         Metabolite: "H2O" (ID: C00001)
%         Metabolite: "L-Arginine" (ID: C00062)
%     Match: "L-Arginine:tRNA(Arg) ligase (AMP-forming)" (ID: R03646)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "L-Arginine" (ID: C00062)
%         Metabolite: "tRNA(Arg)" (ID: C01636)
%     Match: "L-arginine carboxy-lyase (agmatine-forming)" (ID: R00566)
%         Metabolite: "L-Arginine" (ID: C00062)
% Precursor "L-aspartate" → 9 matches found
%     Match: "ATP:L-aspartate 4-phosphotransferase" (ID: R00480)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "L-Aspartate" (ID: C00049)
%     Match: "L-aspartate:ammonia ligase (AMP-forming)" (ID: R00483)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "Ammonia" (ID: C00014)
%         Metabolite: "L-Aspartate" (ID: C00049)
%     Match: "L-aspartate:L-glutamine amido-ligase (AMP-forming)" (ID: R00578)
%         Metabolite: "H2O" (ID: C00001)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "L-Aspartate" (ID: C00049)
%         Metabolite: "L-Glutamine" (ID: C00064)
%     Match: "IMP:L-aspartate ligase (GDP-forming)" (ID: R01135)
%         Metabolite: "GTP" (ID: C00044)
%         Metabolite: "L-Aspartate" (ID: C00049)
%         Metabolite: "IMP" (ID: C00130)
%     Match: "carbamoyl-phosphate:L-aspartate carbamoyltransferase" (ID: R01397)
%         Metabolite: "L-Aspartate" (ID: C00049)
%         Metabolite: "Carbamoyl phosphate" (ID: C00169)
%     Match: "L-Aspartate-4-semialdehyde:NADP+ oxidoreductase (phosphorylating)" (ID: R02291)
%         Metabolite: "NADP+" (ID: C00006)
%         Metabolite: "Orthophosphate" (ID: C00009)
%         Metabolite: "L-Aspartate 4-semialdehyde" (ID: C00441)
%     Match: "L-Aspartate:tRNA(Asp) ligase (AMP-forming)" (ID: R05577)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "L-Aspartate" (ID: C00049)
%         Metabolite: "tRNA(Asp)" (ID: C01638)
%     Match: "L-aspartate-4-semialdehyde hydro-lyase [adding pyruvate and cyclizing; (2S,4S)-4-hydroxy-2,3,4,5-tetrahydrodipicolinate-forming]" (ID: R10147)
%         Metabolite: "Pyruvate" (ID: C00022)
%         Metabolite: "L-Aspartate 4-semialdehyde" (ID: C00441)
%     Match: "L-aspartate ammonia-lyase (fumarate-forming)" (ID: R00490)
%         Metabolite: "L-Aspartate" (ID: C00049)
% Precursor "L-cysteine" → 8 matches found
%     Match: "L-cysteine hydrogen-sulfide-lyase (deaminating; pyruvate-forming)" (ID: R00782_EXP_1)
%         Metabolite: "H2O" (ID: C00001)
%         Metabolite: "L-Cysteine" (ID: C00097)
%     Match: "N-[(R)-4'-Phosphopantothenoyl]-L-cysteine carboxy-lyase" (ID: R03269)
%         Metabolite: "(R)-4'-Phosphopantothenoyl-L-cysteine" (ID: C04352)
%     Match: "L-Cysteine:tRNA(Cys) ligase (AMP-forming)" (ID: R03650)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "L-Cysteine" (ID: C00097)
%         Metabolite: "tRNA(Cys)" (ID: C01639)
%     Match: "(R)-4'-phosphopantothenate:L-cysteine ligase" (ID: R04231)
%         Metabolite: "CTP" (ID: C00063)
%         Metabolite: "L-Cysteine" (ID: C00097)
%         Metabolite: "D-4'-Phosphopantothenate" (ID: C03492)
%     Match: "L-cysteine:[enzyme]-cysteine sulfurtransferase" (ID: R07460)
%         Metabolite: "L-Cysteine" (ID: C00097)
%         Metabolite: "[Enzyme]-cysteine" (ID: C15811)
%     Match: "[enzyme]-S-sulfanyl-L-cysteine:adenylyl-[sulfur-carrier protein] sulfurtransferase" (ID: R07461)
%         Metabolite: "Reduced acceptor" (ID: C00030)
%         Metabolite: "[Enzyme]-S-sulfanylcysteine" (ID: C15812)
%         Metabolite: "Adenylyl-[sulfur-carrier protein]" (ID: C15813)
%     Match: "L-cysteine:sulfur-acceptor sulfurtransferase" (ID: R11528)
%         Metabolite: "L-Cysteine" (ID: C00097)
%         Metabolite: "[Protein]-L-cysteine" (ID: C02743)
%     Match: "L-cysteine-S-conjugate thiol-lyase (deaminating; 2-aminoprop-2-enoate-forming)" (ID: R12188_EXP_1)
%         Metabolite: "H2O" (ID: C00001)
%         Metabolite: "L-Cysteine-S-conjugate" (ID: C02882)
% Precursor "L-glutamate" → 9 matches found
%     Match: "L-Glutamate:ammonia ligase (ADP-forming)" (ID: R00253)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "Ammonia" (ID: C00014)
%         Metabolite: "L-Glutamate" (ID: C00025)
%     Match: "Tetrahydrofolate:L-glutamate gamma-ligase (ADP-forming)" (ID: R00942)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "L-Glutamate" (ID: C00025)
%         Metabolite: "Tetrahydrofolate" (ID: C00101)
%     Match: "7,8-dihydropteroate:L-glutamate ligase (ADP-forming)" (ID: R02237)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "L-Glutamate" (ID: C00025)
%         Metabolite: "Dihydropteroate" (ID: C00921)
%     Match: "L-Glutamate:tRNA(Gln) ligase (AMP-forming)" (ID: R03651)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "L-Glutamate" (ID: C00025)
%         Metabolite: "tRNA(Gln)" (ID: C01640)
%     Match: "5-Methyltetrahydropteroyltri-L-glutamate:L-homocysteine S-methyltransferase" (ID: R04405)
%         Metabolite: "L-Homocysteine" (ID: C00155)
%         Metabolite: "5-Methyltetrahydropteroyltri-L-glutamate" (ID: C04489)
%     Match: "L-glutamate:tRNA(Glu) ligase (AMP-forming)" (ID: R05578)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "L-Glutamate" (ID: C00025)
%         Metabolite: "tRNA(Glu)" (ID: C01641)
%     Match: "5-methyltetrahydropteroyltri-L-glutamate:L-selenohomocysteine Se-methyltransferase" (ID: R09365)
%         Metabolite: "5-Methyltetrahydropteroyltri-L-glutamate" (ID: C04489)
%         Metabolite: "Selenohomocysteine" (ID: C05698)
%     Match: "L-glutamate:coenzyme F420-0 ligase (GDP-forming)" (ID: R09399)
%         Metabolite: "L-Glutamate" (ID: C00025)
%         Metabolite: "GTP" (ID: C00044)
%         Metabolite: "Coenzyme F420-0" (ID: C19153)
%     Match: "L-glutamate:coenzyme F420-1 ligase (GDP-forming)" (ID: R09400)
%         Metabolite: "L-Glutamate" (ID: C00025)
%         Metabolite: "GTP" (ID: C00044)
%         Metabolite: "Coenzyme F420-1" (ID: C19152)
% Precursor "L-glutamine" → 11 matches found
%     Match: "L-glutamine amidohydrolase" (ID: R00256)
%         Metabolite: "H2O" (ID: C00001)
%         Metabolite: "L-Glutamine" (ID: C00064)
%     Match: "UTP:L-glutamine amido-ligase (ADP-forming)" (ID: R00573)
%         Metabolite: "H2O" (ID: C00001)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "L-Glutamine" (ID: C00064)
%         Metabolite: "UTP" (ID: C00075)
%     Match: "HCO3-:L-glutamine amido-ligase (ADP-forming, carbamate-phosphorylating)" (ID: R00575)
%         Metabolite: "H2O" (ID: C00001)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "L-Glutamine" (ID: C00064)
%         Metabolite: "HCO3-" (ID: C00288)
%     Match: "L-aspartate:L-glutamine amido-ligase (AMP-forming)" (ID: R00578)
%         Metabolite: "H2O" (ID: C00001)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "L-Aspartate" (ID: C00049)
%         Metabolite: "L-Glutamine" (ID: C00064)
%     Match: "L-glutamine:D-fructose-6-phosphate isomerase (deaminating);" (ID: R00768)
%         Metabolite: "L-Glutamine" (ID: C00064)
%         Metabolite: "D-Fructose 6-phosphate" (ID: C00085)
%     Match: "Xanthosine-5'-phosphate:L-glutamine amido-ligase (AMP-forming)" (ID: R01231)
%         Metabolite: "H2O" (ID: C00001)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "L-Glutamine" (ID: C00064)
%         Metabolite: "Xanthosine 5'-phosphate" (ID: C00655)
%     Match: "Glu-tRNA(Gln):L-glutamine amido-ligase(ADP-forming)" (ID: R03905)
%         Metabolite: "ADP" (ID: C00008)
%         Metabolite: "Orthophosphate" (ID: C00009)
%         Metabolite: "L-Glutamate" (ID: C00025)
%         Metabolite: "Glutaminyl-tRNA" (ID: C02282)
%     Match: "Asp-tRNA(Asn):L-glutamine amido-ligase (ADP-forming)" (ID: R04212)
%         Metabolite: "ADP" (ID: C00008)
%         Metabolite: "Orthophosphate" (ID: C00009)
%         Metabolite: "L-Glutamate" (ID: C00025)
%         Metabolite: "L-Asparaginyl-tRNA(Asn)" (ID: C03402)
%     Match: "beta-D-GlcNAc-(1->4)-Mur2Ac(oyl-L-Ala-gamma-D-Glu-L-Lys-D-Ala-D-Ala)-diphospho-ditrans,octacis-undecaprenol:L-glutamine amidoligase (ADP-forming)" (ID: R05030)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "Ammonia" (ID: C00014)
%         Metabolite: "Undecaprenyl-diphospho-N-acetylmuramoyl-(N-acetylglucosamine)-L-alanyl-gamma-D-glutamyl-L-lysyl-D-alanyl-D-alanine" (ID: C05893)
%     Match: "6-thioxanthine 5'-monophosphate:L-glutamine amido-ligase (AMP-forming)" (ID: R08244)
%         Metabolite: "H2O" (ID: C00001)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "L-Glutamine" (ID: C00064)
%         Metabolite: "6-Thioxanthine 5'-monophosphate" (ID: C16618)
%     Match: "S-adenosyl-L-methionine:[protein]-L-glutamine (N5-glutamine)-methyltransferase" (ID: R10806)
%         Metabolite: "S-Adenosyl-L-methionine" (ID: C00019)
%         Metabolite: "Protein glutamine" (ID: C02583)
% Precursor "L-glycine" → no matches found
% Precursor "L-histidine" → 5 matches found
%     Match: "protein-Npi-phospho-L-histidine:sugar phosphotransferase" (ID: R00811)
%         Metabolite: "Sucrose" (ID: C00089)
%         Metabolite: "Protein N(pi)-phospho-L-histidine" (ID: C04261)
%     Match: "L-Histidine:tRNA(His) ligase (AMP-forming)" (ID: R03655)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "L-Histidine" (ID: C00135)
%         Metabolite: "tRNA(His)" (ID: C01643)
%     Match: "protein-Npi-phospho-L-histidine:N,N'-diacetylchitobiose 6'-O-phosphotransferase" (ID: R11170)
%         Metabolite: "Chitobiose" (ID: C01674)
%         Metabolite: "Protein N(pi)-phospho-L-histidine" (ID: C04261)
%     Match: "protein-Npi-phospho-L-histidine:D-galactose 6-O-phosphotransferase" (ID: R11171)
%         Metabolite: "D-Galactose" (ID: C00124)
%         Metabolite: "Protein N(pi)-phospho-L-histidine" (ID: C04261)
%     Match: "protein-Npi-phospho-L-histidine:cellobiose 6'-O-phosphotransferase" (ID: R11172)
%         Metabolite: "Cellobiose" (ID: C00185)
%         Metabolite: "Protein N(pi)-phospho-L-histidine" (ID: C04261)
% Precursor "L-isoleucine" → 1 matches found
%     Match: "L-Isoleucine:tRNA(Ile) ligase (AMP-forming)" (ID: R03656)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "L-Isoleucine" (ID: C00407)
%         Metabolite: "tRNA(Ile)" (ID: C01644)
% Precursor "L-leucine" → 1 matches found
%     Match: "L-Leucine:tRNA(Leu) ligase (AMP-forming)" (ID: R03657)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "L-Leucine" (ID: C00123)
%         Metabolite: "tRNA(Leu)" (ID: C01645)
% Precursor "L-lysine" → 5 matches found
%     Match: "meso-2,6-diaminoheptanedioate carboxy-lyase (L-lysine-forming)" (ID: R00451)
%         Metabolite: "meso-2,6-Diaminoheptanedioate" (ID: C00680)
%     Match: "L-lysine:tRNALys ligase (AMP-forming)" (ID: R03658)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "L-Lysine" (ID: C00047)
%         Metabolite: "tRNA(Lys)" (ID: C01646)
%     Match: "UDP-N-acetylmuramoyl-L-alanyl-D-glutamyl-L-lysine:alanyl-D-alanine ligase (ADP-forming)" (ID: R04573)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "D-Alanyl-D-alanine" (ID: C00993)
%         Metabolite: "UDP-N-acetylmuramoyl-L-alanyl-gamma-D-glutamyl-L-lysine" (ID: C05892)
%     Match: "L-lysine:[tRNA(Ile2)]-cytidine34 ligase (AMP-forming)" (ID: R09597)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "L-Lysine" (ID: C00047)
%         Metabolite: "[tRNA(Ile2)]-cytidine34" (ID: C19722)
%     Match: "UDP-N-acetylmuramoyl-L-alanyl-D-glutamate:L-lysine gamma-ligase (ADP-forming);" (ID: R02786)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "L-Lysine" (ID: C00047)
%         Metabolite: "UDP-N-acetylmuramoyl-L-alanyl-D-glutamate" (ID: C00692)
% Precursor "L-methionine" → 7 matches found
%     Match: "ATP:L-methionine S-adenosyltransferase" (ID: R00177)
%         Metabolite: "Orthophosphate" (ID: C00009)
%         Metabolite: "Diphosphate" (ID: C00013)
%         Metabolite: "S-Adenosyl-L-methionine" (ID: C00019)
%     Match: "S-adenosyl-L-methionine:tRNA guanine N1-methyltransferase;" (ID: R00597)
%         Metabolite: "S-Adenosyl-L-methionine" (ID: C00019)
%         Metabolite: "tRNA guanine" (ID: C01977)
%     Match: "S-Adenosyl-L-methionine:L-homocysteine S-methyltransferase" (ID: R00650)
%         Metabolite: "S-Adenosyl-L-methionine" (ID: C00019)
%         Metabolite: "L-Homocysteine" (ID: C00155)
%     Match: "L-methionine:oxidized-thioredoxin S-oxidoreductase" (ID: R02025)
%         Metabolite: "H2O" (ID: C00001)
%         Metabolite: "L-Methionine" (ID: C00073)
%         Metabolite: "Thioredoxin disulfide" (ID: C00343)
%     Match: "L-Methionine:tRNAMet ligase (AMP-forming)" (ID: R03659)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "L-Methionine" (ID: C00073)
%         Metabolite: "tRNA(Met)" (ID: C01647)
%     Match: "Protein-glycine,dihydroflavodoxin:S-adenosyl-L-methionine oxidoreductase (S-adenosyl-L-methionine cleaving)" (ID: R04710)
%         Metabolite: "S-Adenosyl-L-methionine" (ID: C00019)
%         Metabolite: "Dihydroflavodoxin" (ID: C05196)
%         Metabolite: "Protein glycine" (ID: C05197)
%     Match: "S-adenosyl-L-methionine:[protein]-L-glutamine (N5-glutamine)-methyltransferase" (ID: R10806)
%         Metabolite: "S-Adenosyl-L-methionine" (ID: C00019)
%         Metabolite: "Protein glutamine" (ID: C02583)
% Precursor "L-phenylalanine" → 1 matches found
%     Match: "L-Phenylalanine:tRNA(Ala) ligase (AMP-forming)" (ID: R03660)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "L-Phenylalanine" (ID: C00079)
%         Metabolite: "tRNA(Phe)" (ID: C01648)
% Precursor "L-proline" → 1 matches found
%     Match: "L-proline:tRNA(Pro) ligase (AMP-forming)" (ID: R03661)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "L-Proline" (ID: C00148)
%         Metabolite: "tRNA(Pro)" (ID: C01649)
% Precursor "L-serine" → 5 matches found
%     Match: "L-serine ammonia-lyase" (ID: R00220_EXP_1)
%         Metabolite: "L-Serine" (ID: C00065)
%     Match: "Phsophatidyl-L-serine carboxy-lyase" (ID: R02055)
%         Metabolite: "Phosphatidylserine" (ID: C02737)
%     Match: "L-Serine:tRNA(Ser) ligase (AMP-forming)" (ID: R03662)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "L-Serine" (ID: C00065)
%         Metabolite: "tRNA(Ser)" (ID: C01650)
%     Match: "L-serine:tRNASec ligase (AMP-forming)" (ID: R08218)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "L-Serine" (ID: C00065)
%         Metabolite: "tRNA(Sec)" (ID: C16636)
%     Match: "O-phospho-L-serine phosphohydrolase" (ID: R00582)
%         Metabolite: "H2O" (ID: C00001)
%         Metabolite: "O-Phospho-L-serine" (ID: C01005)
% Precursor "L-threonine" → 3 matches found
%     Match: "O-phospho-L-homoserine phosphate-lyase (adding water;L-threonine-forming)" (ID: R01466)
%         Metabolite: "H2O" (ID: C00001)
%         Metabolite: "O-Phospho-L-homoserine" (ID: C01102)
%     Match: "L-Threonine:tRNA(Thr) ligase (AMP-forming)" (ID: R03663)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "L-Threonine" (ID: C00188)
%         Metabolite: "tRNA(Thr)" (ID: C01651)
%     Match: "O-Phospho-4-hydroxy-L-threonine phospho-lyase (adding water)" (ID: R05086)
%         Metabolite: "H2O" (ID: C00001)
%         Metabolite: "O-Phospho-4-hydroxy-L-threonine" (ID: C06055)
% Precursor "L-tryptophan" → 1 matches found
%     Match: "L-Tryptophan -tRNA(Trp) ligase (AMP-forming)" (ID: R03664)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "L-Tryptophan" (ID: C00078)
%         Metabolite: "tRNA(Trp)" (ID: C01652)
% Precursor "L-tyrosine" → 1 matches found
%     Match: "L-Tyrosine:tRNA(Tyr) ligase (AMP-forming)" (ID: R02918)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "L-Tyrosine" (ID: C00082)
%         Metabolite: "tRNA(Tyr)" (ID: C00787)
% Precursor "L-valine" → 1 matches found
%     Match: "L-Valine:tRNAVal ligase (AMP-forming)" (ID: R03665)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "L-Valine" (ID: C00183)
%         Metabolite: "tRNA(Val)" (ID: C01653)
% Precursor "ATP" → 77 matches found
%     Match: "ATP:NAD+ 2'-phosphotransferase" (ID: R00104)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "NAD+" (ID: C00003)
%     Match: "ATP:AMP phosphotransferase" (ID: R00127)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "AMP" (ID: C00020)
%     Match: "ATP:dephospho-CoA 3'-phosphotransferase" (ID: R00130)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "Dephospho-CoA" (ID: C00882)
%     Match: "ATP:nicotinamide-nucleotide adenylyltransferase" (ID: R00137)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "Nicotinamide D-ribonucleotide" (ID: C00455)
%     Match: "ATP:carbamate phosphotransferase" (ID: R00150)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "Ammonia" (ID: C00014)
%         Metabolite: "HCO3-" (ID: C00288)
%     Match: "ATP:UMP phosphotransferase" (ID: R00158)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "UMP" (ID: C00105)
%     Match: "ATP:FMN adenylyltransferase" (ID: R00161)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "FMN" (ID: C00061)
%     Match: "ATP:pyridoxal 5'-phosphotransferase" (ID: R00174)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "Pyridoxal" (ID: C00250)
%     Match: "ATP:L-methionine S-adenosyltransferase" (ID: R00177)
%         Metabolite: "Orthophosphate" (ID: C00009)
%         Metabolite: "Diphosphate" (ID: C00013)
%         Metabolite: "S-Adenosyl-L-methionine" (ID: C00019)
%     Match: "ATP:pyruvate,water phosphotransferase" (ID: R00199)
%         Metabolite: "H2O" (ID: C00001)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "Pyruvate" (ID: C00022)
%     Match: "ATP:pyruvate 2-O-phosphotransferase" (ID: R00200)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "Pyruvate" (ID: C00022)
%     Match: "ATP:acetate phosphotransferase" (ID: R00315)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "Acetate" (ID: C00033)
%     Match: "ATP:GMP phosphotransferase" (ID: R00332_EXP_1)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "GMP" (ID: C00144)
%     Match: "ATP:oxaloacetate carboxy-lyase (transphosphorylating;phosphoenolpyruvate-forming)" (ID: R00341)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "Oxaloacetate" (ID: C00036)
%     Match: "ATP:GTP 3'-diphosphotransferase" (ID: R00429)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "GTP" (ID: C00044)
%     Match: "ATP:L-aspartate 4-phosphotransferase" (ID: R00480)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "L-Aspartate" (ID: C00049)
%     Match: "ATP:CMP phosphotransferase" (ID: R00512)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "CMP" (ID: C00055)
%     Match: "ATP:cytidine 5'-phosphotransferase" (ID: R00513)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "Cytidine" (ID: C00475)
%     Match: "ATP:riboflavin 5'-phosphotransferase" (ID: R00549)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "Riboflavin" (ID: C00255)
%     Match: "ATP:thiamine diphosphotransferase" (ID: R00619)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "Thiamine" (ID: C00378)
%     Match: "ATP:D-fructose-6-phosphate 1-phosphotransferase" (ID: R00756)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "D-Fructose 6-phosphate" (ID: C00085)
%     Match: "ATP:D-fructose 6-phosphotransferase" (ID: R00760)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "D-Fructose" (ID: C00095)
%     Match: "ATP:glycerol 3-phosphotransferase" (ID: R00847)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "Glycerol" (ID: C00116)
%     Match: "ATP:D-fructose 6-phosphotransferase" (ID: R00867)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "D-Fructose" (ID: C00095)
%     Match: "ATP:uridine 5'-phosphotransferase" (ID: R00964)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "Uridine" (ID: C00299)
%     Match: "ATP:D-ribose-5-phosphate diphosphotransferase" (ID: R01049)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "D-Ribose 5-phosphate" (ID: C00117)
%     Match: "ATP:D-ribose 5-phosphotransferase" (ID: R01051)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "D-Ribose" (ID: C00121)
%     Match: "ATP:alpha-D-galactose 1-phosphotransferase" (ID: R01092)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "alpha-D-Galactose" (ID: C00984)
%     Match: "ATP:(R)-5-diphosphomevalonate carboxy-lyase (adding ATP; isopentenyl-diphosphate-forming);" (ID: R01121)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "(R)-5-Diphosphomevalonate" (ID: C01143)
%     Match: "dATP:pyruvate 2-O-phosphotransferase" (ID: R01138)
%         Metabolite: "Pyruvate" (ID: C00022)
%         Metabolite: "dATP" (ID: C00131)
%     Match: "ATP:propanoate phosphotransferase" (ID: R01353)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "Propanoate" (ID: C00163)
%     Match: "ATP:carbamate phosphotransferase" (ID: R01395)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "Carbamate" (ID: C01563)
%     Match: "ATP:3-phospho-D-glycerate 1-phosphotransferase" (ID: R01512)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "3-Phospho-D-glycerate" (ID: C00197)
%     Match: "ATP:dAMP phosphotransferase" (ID: R01547)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "dAMP" (ID: C00360)
%     Match: "ATP:thymidine 5'-phosphotransferase" (ID: R01567)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "Thymidine" (ID: C00214)
%     Match: "ATP:dCMP phosphotransferase" (ID: R01665)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "dCMP" (ID: C00239)
%     Match: "ATP:D-gluconate 6-phosphotransferase" (ID: R01737)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "D-Gluconic acid" (ID: C00257)
%     Match: "ATP:L-homoserine O-phosphotransferase" (ID: R01771)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "L-Homoserine" (ID: C00263)
%     Match: "ATP:pyridoxine 5'-phosphotransferase" (ID: R01909)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "Pyridoxine" (ID: C00314)
%     Match: "ATP:D-glucosamine 6-phosphotransferase" (ID: R01961)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "D-Glucosamine" (ID: C00329)
%     Match: "ATP:deoxyguanosine 5'-phosphotransferase" (ID: R01967)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "Deoxyguanosine" (ID: C00330)
%     Match: "ATP:D-fructose-1-phosphate 6-phosphotransferase" (ID: R02071)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "D-Fructose 1-phosphate" (ID: C01094)
%     Match: "ATP:deoxyadenosine 5'-phosphotransferase" (ID: R02089)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "Deoxyadenosine" (ID: C00559)
%     Match: "ATP:dGMP phosphotransferase" (ID: R02090_EXP_1)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "dGMP" (ID: C00362)
%     Match: "ATP:dTMP phosphotransferase" (ID: R02094)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "dTMP" (ID: C00364)
%     Match: "ATP:dUMP phosphotransferase" (ID: R02098)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "dUMP" (ID: C00365)
%     Match: "ATP:deoxyuridine 5'-phosphotransferase" (ID: R02099)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "Deoxyuridine" (ID: C00526)
%     Match: "ATP:1,2-diacylglycerol 3-phosphotransferase" (ID: R02240)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "1,2-Diacyl-sn-glycerol" (ID: C00641)
%     Match: "ATP:(R)-mevalonate 5-phosphotransferase" (ID: R02245)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "(R)-Mevalonate" (ID: C00418)
%     Match: "ATP:pyridoxal 5'-phosphotransferase" (ID: R02493)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "Pyridoxamine" (ID: C00534)
%     Match: "ATP:2-deoxy-D-ribose 5-phosphotransferase" (ID: R02750)
%         Metabolite: "ADP" (ID: C00008)
%         Metabolite: "2-Deoxy-D-ribose 5-phosphate" (ID: C00673)
%     Match: "ATP:pantothenate 4'-phosphotransferase" (ID: R02971)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "Pantetheine" (ID: C00831)
%     Match: "ATP:nicotinamide-nucleotide adenylyltransferase" (ID: R03005)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "Nicotinate D-ribonucleotide" (ID: C01185)
%     Match: "ATP:pantothenate 4'-phosphotransferase" (ID: R03018)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "Pantothenate" (ID: C00864)
%     Match: "ATP:pantetheine-4'-phosphate adenylyltransferase" (ID: R03035)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "Pantetheine 4'-phosphate" (ID: C01134)
%     Match: "ATP:D-tagatose-6-phosphate 1-phosphotransferase" (ID: R03236)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "D-Tagatose 6-phosphate" (ID: C01097)
%     Match: "ATP:(R)-5-phosphomevalonate phosphotransferase" (ID: R03245)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "(R)-5-Phosphomevalonate" (ID: C01107)
%     Match: "ATP:4-amino-5-hydroxymethyl-2-methylpyrimidine 5-phosphotransferase" (ID: R03471)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "4-Amino-5-hydroxymethyl-2-methylpyrimidine" (ID: C01279)
%     Match: "ATP:D-fructose 6-phosphotransferase" (ID: R03920)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "beta-D-Fructose" (ID: C02336)
%     Match: "ATP:pantothenate 4'-phosphotransferase" (ID: R04391)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "N-((R)-Pantothenoyl)-L-cysteine" (ID: C04079)
%     Match: "ATP:4-amino-2-methyl-5-phosphomethylpyrimidine phosphotransferase" (ID: R04509)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "4-Amino-2-methyl-5-(phosphooxymethyl)pyrimidine" (ID: C04556)
%     Match: "ATP:L-selenomethione S-adenosyltransferase" (ID: R04771)
%         Metabolite: "H2O" (ID: C00001)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "L-Selenomethionine" (ID: C05335)
%     Match: "ATP:D-fructose-6-phosphate 1-phosphotransferase" (ID: R04779)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "beta-D-Fructose 6-phosphate" (ID: C05345)
%     Match: "ATP:5-fluorouridine 5'-phosphotransferase" (ID: R08232)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "5-Fluorouridine" (ID: C16633)
%     Match: "ATP:5-fluorodeoxyuridine 5'-phosphotransferase" (ID: R08233)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "5-Fluorodeoxyuridine" (ID: C11736)
%     Match: "ATP:(R)-glycerate 2-phosphotransferase" (ID: R08572)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "D-Glycerate" (ID: C00258)
%     Match: "CTP,CTP,ATP:tRNA cytidylyl,cytidylyl,adenylyltransferase" (ID: R09382)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "CTP" (ID: C00063)
%         Metabolite: "tRNA precursor" (ID: C02211)
%     Match: "ATP:tRNA adenylyltransferase" (ID: R09386)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "tRNA with a 3' CC end" (ID: C19080)
%     Match: "ATP:3'-dephospho-CoA 5-triphospho-alpha-D-ribosyltransferase" (ID: R09675)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "Dephospho-CoA" (ID: C00882)
%     Match: "ATP:L-threonyl,bicarbonate adenylyltransferase" (ID: R10463)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "H+" (ID: C00080)
%         Metabolite: "L-Threonine" (ID: C00188)
%         Metabolite: "HCO3-" (ID: C00288)
%     Match: "ATP:HCO3- phosphotransferase" (ID: R10948)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "HCO3-" (ID: C00288)
%     Match: "ATP:formate 2'-oxidoreductase" (ID: R11634)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "Formate" (ID: C00058)
%     Match: "ATP:pyruvate,phosphate phosphotransferase" (ID: R00206)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "Orthophosphate" (ID: C00009)
%         Metabolite: "Pyruvate" (ID: C00022)
%     Match: "ATP:D-glucose 6-phosphotransferase" (ID: R00299)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "D-Glucose" (ID: C00031)
%     Match: "ATP:beta-D-glucose 6-phosphotransferase" (ID: R01600)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "beta-D-Glucose" (ID: C00221)
%     Match: "ATP:alpha-D-glucose 6-phosphotransferase" (ID: R01786)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "alpha-D-Glucose" (ID: C00267)
%     Match: "ATP:methylphosphonate 5-triphosphoribosyltransferase" (ID: R10185)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "Methylphosphonate" (ID: C20396)
% Precursor "GTP" → 9 matches found
%     Match: "GTP 7,8-8,9-dihydrolase (diphosphate-forming)" (ID: R00425)
%         Metabolite: "H2O" (ID: C00001)
%         Metabolite: "GTP" (ID: C00044)
%     Match: "ATP:GTP 3'-diphosphotransferase" (ID: R00429)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "GTP" (ID: C00044)
%     Match: "GTP:pyruvate 2-O-phosphotransferase" (ID: R00430)
%         Metabolite: "Pyruvate" (ID: C00022)
%         Metabolite: "GTP" (ID: C00044)
%     Match: "GTP:cytidine 5'-phosphotransferase" (ID: R00517)
%         Metabolite: "GTP" (ID: C00044)
%         Metabolite: "Cytidine" (ID: C00475)
%     Match: "GTP:uridine 5'-phosphotransferase" (ID: R00968)
%         Metabolite: "GTP" (ID: C00044)
%         Metabolite: "Uridine" (ID: C00299)
%     Match: "dGTP:pyruvate 2-O-phosphotransferase" (ID: R01858)
%         Metabolite: "Pyruvate" (ID: C00022)
%         Metabolite: "dGTP" (ID: C00286)
%     Match: "GTP:formate 2'-oxidoreductase" (ID: R11633)
%         Metabolite: "GTP" (ID: C00044)
%         Metabolite: "Formate" (ID: C00058)
%     Match: "GTP 7,8-8,9-dihydrolase" (ID: R00424)
%         Metabolite: "H2O" (ID: C00001)
%         Metabolite: "GTP" (ID: C00044)
%     Match: "GTP 8,9-hydrolase" (ID: R00428)
%         Metabolite: "H2O" (ID: C00001)
%         Metabolite: "GTP" (ID: C00044)
% Precursor "CTP" → 7 matches found
%     Match: "CTP:sn-glycerol-3-phosphate cytidylyltransferase" (ID: R00856)
%         Metabolite: "CTP" (ID: C00063)
%         Metabolite: "sn-Glycerol 3-phosphate" (ID: C00093)
%     Match: "CTP:phosphatidate cytidyltransferase" (ID: R01799)
%         Metabolite: "CTP" (ID: C00063)
%         Metabolite: "Phosphatidate" (ID: C00416)
%     Match: "CTP:D-tagatose 6-phosphate 1-phosphotransferase" (ID: R03237)
%         Metabolite: "CTP" (ID: C00063)
%         Metabolite: "D-Tagatose 6-phosphate" (ID: C01097)
%     Match: "CTP,CTP,ATP:tRNA cytidylyl,cytidylyl,adenylyltransferase" (ID: R09382)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "CTP" (ID: C00063)
%         Metabolite: "tRNA precursor" (ID: C02211)
%     Match: "CTP:tRNA cytidylyltransferase" (ID: R09383)
%         Metabolite: "CTP" (ID: C00063)
%         Metabolite: "tRNA precursor" (ID: C02211)
%     Match: "CTP:tRNA cytidylyltransferase" (ID: R09384)
%         Metabolite: "CTP" (ID: C00063)
%         Metabolite: "tRNA with a 3' cytidine" (ID: C19078)
%     Match: "CTP:formate 2'-oxidoreductase" (ID: R11636)
%         Metabolite: "Formate" (ID: C00058)
%         Metabolite: "CTP" (ID: C00063)
% Precursor "UTP" → 7 matches found
%     Match: "UTP:alpha-D-glucose-1-phosphate uridylyltransferase" (ID: R00289)
%         Metabolite: "UTP" (ID: C00075)
%         Metabolite: "D-Glucose 1-phosphate" (ID: C00103)
%     Match: "UTP:N-acetyl-alpha-D-glucosamine-1-phosphate uridylyltransferase" (ID: R00416)
%         Metabolite: "UTP" (ID: C00075)
%         Metabolite: "N-Acetyl-alpha-D-glucosamine 1-phosphate" (ID: C04501)
%     Match: "UTP:ammonia ligase (ADP-forming)" (ID: R00571)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "Ammonia" (ID: C00014)
%         Metabolite: "UTP" (ID: C00075)
%     Match: "UTP:L-glutamine amido-ligase (ADP-forming)" (ID: R00573)
%         Metabolite: "H2O" (ID: C00001)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "L-Glutamine" (ID: C00064)
%         Metabolite: "UTP" (ID: C00075)
%     Match: "dUTP nucleotidohydrolase" (ID: R02100)
%         Metabolite: "H2O" (ID: C00001)
%         Metabolite: "dUTP" (ID: C00460)
%     Match: "UTP:D-tagatose 6-phosphate 1-phosphotransferase" (ID: R03238)
%         Metabolite: "UTP" (ID: C00075)
%         Metabolite: "D-Tagatose 6-phosphate" (ID: C01097)
%     Match: "UTP:formate 2'-oxidoreductase" (ID: R11635)
%         Metabolite: "Formate" (ID: C00058)
%         Metabolite: "UTP" (ID: C00075)
% Precursor "NAD" → 103 matches found
%     Match: "ATP:NAD+ 2'-phosphotransferase" (ID: R00104)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "NAD+" (ID: C00003)
%     Match: "deamido-NAD+:ammonia ligase (AMP-forming)" (ID: R00189)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "Ammonia" (ID: C00014)
%         Metabolite: "Deamino-NAD+" (ID: C00857)
%     Match: "acetaldehyde:NAD+ oxidoreductase (CoA-acetylating)" (ID: R00228)
%         Metabolite: "NAD+" (ID: C00003)
%         Metabolite: "CoA" (ID: C00010)
%         Metabolite: "Acetaldehyde" (ID: C00084)
%     Match: "(S)-Lactate:NAD+ oxidoreductase" (ID: R00703)
%         Metabolite: "NAD+" (ID: C00003)
%         Metabolite: "(S)-Lactate" (ID: C00186)
%     Match: "(R)-Lactate:NAD+ oxidoreductase" (ID: R00704)
%         Metabolite: "NAD+" (ID: C00003)
%         Metabolite: "(R)-Lactate" (ID: C00256)
%     Match: "succinate-semialdehyde:NAD+ oxidoreductase" (ID: R00713)
%         Metabolite: "H2O" (ID: C00001)
%         Metabolite: "NAD+" (ID: C00003)
%         Metabolite: "Succinate semialdehyde" (ID: C00232)
%     Match: "succinate-semialdehyde:NADP+ oxidoreductase" (ID: R00714)
%         Metabolite: "H2O" (ID: C00001)
%         Metabolite: "NADP+" (ID: C00006)
%         Metabolite: "Succinate semialdehyde" (ID: C00232)
%     Match: "ethanol:NAD+ oxidoreductase" (ID: R00754)
%         Metabolite: "NAD+" (ID: C00003)
%         Metabolite: "Ethanol" (ID: C00469)
%     Match: "D-glucose-6-phosphate:NADP+ 1-oxidoreductase" (ID: R00835)
%         Metabolite: "NADP+" (ID: C00006)
%         Metabolite: "D-Glucose 6-phosphate" (ID: C00092)
%     Match: "sn-Glycerol-3-phosphate:NAD+ 2-oxidoreductase" (ID: R00842)
%         Metabolite: "NAD+" (ID: C00003)
%         Metabolite: "sn-Glycerol 3-phosphate" (ID: C00093)
%     Match: "sn-Glycerol-3-phosphate:NADP+ 2-oxidoreductase" (ID: R00844)
%         Metabolite: "NADP+" (ID: C00006)
%         Metabolite: "sn-Glycerol 3-phosphate" (ID: C00093)
%     Match: "5,6,7,8-tetrahydrofolate:NAD+ oxidoreductase" (ID: R00936)
%         Metabolite: "NAD+" (ID: C00003)
%         Metabolite: "Tetrahydrofolate" (ID: C00101)
%     Match: "5,6,7,8-tetrahydrofolate:NAD+ oxidoreductase" (ID: R00937)
%         Metabolite: "NAD+" (ID: C00003)
%         Metabolite: "Tetrahydrofolate" (ID: C00101)
%     Match: "5,6,7,8-tetrahydrofolate:NADP+ oxidoreductase" (ID: R00939)
%         Metabolite: "NADP+" (ID: C00006)
%         Metabolite: "Tetrahydrofolate" (ID: C00101)
%     Match: "5,6,7,8-tetrahydrofolate:NADP+ oxidoreductase" (ID: R00940)
%         Metabolite: "NADP+" (ID: C00006)
%         Metabolite: "Tetrahydrofolate" (ID: C00101)
%     Match: "2-hydroxybutyrate:NAD+ oxidoreductase" (ID: R01000)
%         Metabolite: "NAD+" (ID: C00003)
%         Metabolite: "2-Hydroxybutanoic acid" (ID: C05984)
%     Match: "D-glyceraldehyde-3-phosphate:NAD+ oxidoreductase (phosphorylating)" (ID: R01061)
%         Metabolite: "NAD+" (ID: C00003)
%         Metabolite: "Orthophosphate" (ID: C00009)
%         Metabolite: "D-Glyceraldehyde 3-phosphate" (ID: C00118)
%     Match: "IMP:NAD+ oxidoreductase" (ID: R01130)
%         Metabolite: "H2O" (ID: C00001)
%         Metabolite: "NAD+" (ID: C00003)
%         Metabolite: "IMP" (ID: C00130)
%     Match: "inosine-5'-phosphate:NADP+ oxidoreductase (aminating);" (ID: R01134)
%         Metabolite: "NADP+" (ID: C00006)
%         Metabolite: "Ammonia" (ID: C00014)
%         Metabolite: "IMP" (ID: C00130)
%     Match: "butanal:NAD+ oxidoreductase (CoA-acylating)" (ID: R01172)
%         Metabolite: "NAD+" (ID: C00003)
%         Metabolite: "CoA" (ID: C00010)
%         Metabolite: "Butanal" (ID: C01412)
%     Match: "5,10-methylenetetrahydrofolate:NADP+ oxidoreductase" (ID: R01220)
%         Metabolite: "NADP+" (ID: C00006)
%         Metabolite: "5,10-Methylenetetrahydrofolate" (ID: C00143)
%     Match: "6-phospho-D-gluconate:NADP+ 2-oxidoreductase (decarboxylating)" (ID: R01528)
%         Metabolite: "NADP+" (ID: C00006)
%         Metabolite: "6-Phospho-D-gluconate" (ID: C00345)
%     Match: "L-Homoserine:NAD+ oxidoreductase" (ID: R01773)
%         Metabolite: "NAD+" (ID: C00003)
%         Metabolite: "L-Homoserine" (ID: C00263)
%     Match: "L-homoserine:NADP+ oxidoreductase" (ID: R01775)
%         Metabolite: "NADP+" (ID: C00006)
%         Metabolite: "L-Homoserine" (ID: C00263)
%     Match: "NADPH:oxidized-thioredoxin oxidoreductase" (ID: R02016)
%         Metabolite: "NADP+" (ID: C00006)
%         Metabolite: "Thioredoxin" (ID: C00342)
%     Match: "(R)-Mevalonate:NAD+ oxidoreductase (CoA-acetylating)" (ID: R02081)
%         Metabolite: "NAD+" (ID: C00003)
%         Metabolite: "CoA" (ID: C00010)
%         Metabolite: "(R)-Mevalonate" (ID: C00418)
%     Match: "dihydrofolate:NAD+ oxidoreductase" (ID: R02235)
%         Metabolite: "NAD+" (ID: C00003)
%         Metabolite: "Dihydrofolate" (ID: C00415)
%     Match: "dihydrofolate:NADP+ oxidoreductase" (ID: R02236)
%         Metabolite: "NADP+" (ID: C00006)
%         Metabolite: "Dihydrofolate" (ID: C00415)
%     Match: "L-Aspartate-4-semialdehyde:NADP+ oxidoreductase (phosphorylating)" (ID: R02291)
%         Metabolite: "NADP+" (ID: C00006)
%         Metabolite: "Orthophosphate" (ID: C00009)
%         Metabolite: "L-Aspartate 4-semialdehyde" (ID: C00441)
%     Match: "glutarate-semialdehyde:NAD+ oxidoreductase" (ID: R02401)
%         Metabolite: "H2O" (ID: C00001)
%         Metabolite: "NAD+" (ID: C00003)
%         Metabolite: "5-Oxopentanoate" (ID: C03273)
%     Match: "D-Mannitol-1-phosphate:NAD+ 5-oxidoreductase" (ID: R02703)
%         Metabolite: "NAD+" (ID: C00003)
%         Metabolite: "D-Mannitol 1-phosphate" (ID: C00644)
%     Match: "beta-D-glucose-6-phosphate:NADP+ 1-oxoreductase" (ID: R02736)
%         Metabolite: "NADP+" (ID: C00006)
%         Metabolite: "beta-D-Glucose 6-phosphate" (ID: C01172)
%     Match: "dTDP-beta-L-rhamnose:NADP+ 4-oxidoreductase;" (ID: R02777)
%         Metabolite: "NADP+" (ID: C00006)
%         Metabolite: "dTDP-L-rhamnose" (ID: C03319)
%     Match: "3-Mercaptolactate:NAD+ oxidoreductase" (ID: R03104)
%         Metabolite: "NAD+" (ID: C00003)
%         Metabolite: "3-Mercaptolactate" (ID: C05823)
%     Match: "UDP-N-acetylmuramate:NADP+ oxidoreductase" (ID: R03191)
%         Metabolite: "NAD+" (ID: C00003)
%         Metabolite: "UDP-N-acetylmuramate" (ID: C01050)
%     Match: "UDP-N-acetylmuramate:NADP+ oxidoreductase" (ID: R03192)
%         Metabolite: "NADP+" (ID: C00006)
%         Metabolite: "UDP-N-acetylmuramate" (ID: C01050)
%     Match: "5-amino-6-(5-phosphoribitylamino)uracil:NADP+ 1'-oxidoreductase" (ID: R03458)
%         Metabolite: "NADP+" (ID: C00006)
%         Metabolite: "5-Amino-6-(5'-phospho-D-ribitylamino)uracil" (ID: C04454)
%     Match: "hydrogen selenide:NADP+ oxidoreductase" (ID: R03596)
%         Metabolite: "H2O" (ID: C00001)
%         Metabolite: "NADP+" (ID: C00006)
%         Metabolite: "Hydrogen selenide" (ID: C01528)
%     Match: "2,3,4,5-tetrahydrodipicolinate:NAD+ 4-oxidoreductase" (ID: R04198)
%         Metabolite: "H2O" (ID: C00001)
%         Metabolite: "NAD+" (ID: C00003)
%         Metabolite: "2,3,4,5-Tetrahydrodipicolinate" (ID: C03972)
%     Match: "2,3,4,5-tetrahydrodipicolinate:NADP+ 4-oxidoreductase" (ID: R04199)
%         Metabolite: "H2O" (ID: C00001)
%         Metabolite: "NADP+" (ID: C00006)
%         Metabolite: "2,3,4,5-Tetrahydrodipicolinate" (ID: C03972)
%     Match: "(3R)-3-hydroxybutanoyl-[acyl-carrier protein]:NADP+ oxidoreductase" (ID: R04533)
%         Metabolite: "NADP+" (ID: C00006)
%         Metabolite: "(3R)-3-Hydroxybutanoyl-[acyl-carrier protein]" (ID: C04618)
%     Match: "(3R)-3-hydroxydecanoyl-[acyl-carrier-protein]:NADP+ oxidoreductase" (ID: R04534)
%         Metabolite: "NADP+" (ID: C00006)
%         Metabolite: "(3R)-3-Hydroxydecanoyl-[acyl-carrier protein]" (ID: C04619)
%     Match: "(3R)-3-hydroxyoctanoyl-[acyl-carrier-protein]:NADP+ oxidoreductase" (ID: R04536)
%         Metabolite: "NADP+" (ID: C00006)
%         Metabolite: "(3R)-3-Hydroxyoctanoyl-[acyl-carrier protein]" (ID: C04620)
%     Match: "(3R)-3-hydroxypalmitoyl-[acyl-carrier-protein]:NADP+ oxidoreductase" (ID: R04543)
%         Metabolite: "NADP+" (ID: C00006)
%         Metabolite: "(3R)-3-Hydroxypalmitoyl-[acyl-carrier protein]" (ID: C04633)
%     Match: "(3R)-3-hydroxytetradecanoyl-[acyl-carrier-protein]:NADP+ oxidoreductase" (ID: R04566)
%         Metabolite: "NADP+" (ID: C00006)
%         Metabolite: "(3R)-3-Hydroxytetradecanoyl-[acyl-carrier protein]" (ID: C04688)
%     Match: "3,4-dihydroxyphenylethyleneglycol:NAD+ oxidoreductase" (ID: R04880)
%         Metabolite: "NAD+" (ID: C00003)
%         Metabolite: "3,4-Dihydroxyphenylethyleneglycol" (ID: C05576)
%     Match: "(3R)-3-hydroxyhexanoyl-[acyl-carrier-protein]:NADP+ oxidoreductase" (ID: R04953)
%         Metabolite: "NADP+" (ID: C00006)
%         Metabolite: "(3R)-3-Hydroxyhexanoyl-[acyl-carrier protein]" (ID: C05747)
%     Match: "(3R)-3-hydroxydodecanoyl-[acyl-carrier-protein]:NADP+ oxidoreductase" (ID: R04964)
%         Metabolite: "NADP+" (ID: C00006)
%         Metabolite: "(3R)-3-Hydroxydodecanoyl-[acyl-carrier protein]" (ID: C05757)
%     Match: "trans-3-Chloro-2-propene-1-ol:NAD+ oxidoreductase" (ID: R05233)
%         Metabolite: "NAD+" (ID: C00003)
%         Metabolite: "trans-3-Chloro-2-propene-1-ol" (ID: C06611)
%     Match: "cis-3-chloro-2-propene-1-ol:NAD+ oxidoreductase" (ID: R05234)
%         Metabolite: "NAD+" (ID: C00003)
%         Metabolite: "cis-3-Chloro-2-propene-1-ol" (ID: C06612)
%     Match: "FMNH2:NAD+ oxidoreductase" (ID: R05705)
%         Metabolite: "NAD+" (ID: C00003)
%         Metabolite: "Reduced FMN" (ID: C01847)
%     Match: "1-hydroxymethylnaphthalene:NAD+ oxidoreductase" (ID: R06917)
%         Metabolite: "NAD+" (ID: C00003)
%         Metabolite: "1-Hydroxymethylnaphthalene" (ID: C14089)
%     Match: "(2-naphthyl)methanol:NAD+ oxidoreductase" (ID: R06927)
%         Metabolite: "NAD+" (ID: C00003)
%         Metabolite: "(2-Naphthyl)methanol" (ID: C02909)
%     Match: "6-thioinosine 5'-monophosphate:NAD+ oxidoreductase" (ID: R08240)
%         Metabolite: "H2O" (ID: C00001)
%         Metabolite: "NAD+" (ID: C00003)
%         Metabolite: "6-Thioinosine-5'-monophosphate" (ID: C04646)
%     Match: "2-dehydro-L-idonate:NADP+ 5-oxidoreductase" (ID: R08878)
%         Metabolite: "NADP+" (ID: C00006)
%         Metabolite: "2-Dehydro-L-idonate" (ID: C15673)
%     Match: "methaneselenol:NADP+ oxidoreductase" (ID: R09372)
%         Metabolite: "NADPH" (ID: C00005)
%         Metabolite: "H+" (ID: C00080)
%         Metabolite: "Methylselenic acid" (ID: C18902)
%     Match: "FADH2:NAD+ oxidoreductase" (ID: R09748)
%         Metabolite: "NAD+" (ID: C00003)
%         Metabolite: "FADH2" (ID: C01352)
%     Match: "reduced-riboflavin:NAD+ oxidoreductase" (ID: R09750)
%         Metabolite: "NAD+" (ID: C00003)
%         Metabolite: "Reduced riboflavin" (ID: C01007)
%     Match: "scyllo-inositol:NADP+ oxidoreductase" (ID: R09954)
%         Metabolite: "NADP+" (ID: C00006)
%         Metabolite: "scyllo-Inositol" (ID: C06153)
%     Match: "3-hydroxyglutaryl-[acp]-methyl-ester:NADP+ oxidoreductase" (ID: R10116)
%         Metabolite: "NADPH" (ID: C00005)
%         Metabolite: "H+" (ID: C00080)
%         Metabolite: "3-Ketoglutaryl-[acp] methyl ester" (ID: C20372)
%     Match: "3-hydroxypimeloyl-[acp]-methyl-ester:NADP+ oxidoreductase" (ID: R10120)
%         Metabolite: "NADPH" (ID: C00005)
%         Metabolite: "H+" (ID: C00080)
%         Metabolite: "3-Ketopimeloyl-[acp] methyl ester" (ID: C20376)
%     Match: "6-phospho-D-gluconate:NAD+ 2-oxidoreductase (decarboxylating)" (ID: R10221)
%         Metabolite: "NAD+" (ID: C00003)
%         Metabolite: "6-Phospho-D-gluconate" (ID: C00345)
%     Match: "beta-D-glucose-6-phosphate:NAD+ 1-oxidoreductase" (ID: R10907)
%         Metabolite: "NAD+" (ID: C00003)
%         Metabolite: "beta-D-Glucose 6-phosphate" (ID: C01172)
%     Match: "tetrahydrobiopterin:NADP+ oxidoreductase (7,8-dihydrobiopterin-forming)" (ID: R11765)
%         Metabolite: "NADP+" (ID: C00006)
%         Metabolite: "Tetrahydrobiopterin" (ID: C00272)
%     Match: "liquiritigenin,[reduced NADPH---hemoprotein reductase]:oxygen oxidoreductase (licodione-forming)" (ID: R07198)
%         Metabolite: "Oxygen" (ID: C00007)
%         Metabolite: "[Reduced NADPH---hemoprotein reductase]" (ID: C03024)
%         Metabolite: "Liquiritigenin" (ID: C09762)
%     Match: "glutathione:NAD+ oxidoreductase" (ID: R00094)
%         Metabolite: "NAD+" (ID: C00003)
%         Metabolite: "Glutathione" (ID: C00051)
%     Match: "glutathione:NADP+ oxidoreductase" (ID: R00115)
%         Metabolite: "NADP+" (ID: C00006)
%         Metabolite: "Glutathione" (ID: C00051)
%     Match: "pyruvate:NAD+ 2-oxidoreductase (CoA-acetylating);" (ID: R00209)
%         Metabolite: "NAD+" (ID: C00003)
%         Metabolite: "CoA" (ID: C00010)
%         Metabolite: "Pyruvate" (ID: C00022)
%     Match: "glycolate:NADP+ oxidoreductase" (ID: R00465)
%         Metabolite: "NADP+" (ID: C00006)
%         Metabolite: "Glycolate" (ID: C00160)
%     Match: "Glycolate:NAD+ oxidoreductase" (ID: R00717)
%         Metabolite: "NAD+" (ID: C00003)
%         Metabolite: "Glycolate" (ID: C00160)
%     Match: "glycine:NAD+ 2-oxidoreductase (tetrahydrofolate-methylene-adding);" (ID: R01221)
%         Metabolite: "NAD+" (ID: C00003)
%         Metabolite: "Glycine" (ID: C00037)
%         Metabolite: "Tetrahydrofolate" (ID: C00101)
%     Match: "(R)-3-Hydroxybutanoate:NAD+ oxidoreductase" (ID: R01361)
%         Metabolite: "NAD+" (ID: C00003)
%         Metabolite: "(R)-3-Hydroxybutanoate" (ID: C01089)
%     Match: "D-Glycerate:NAD+ 2-oxidoreductase" (ID: R01388)
%         Metabolite: "NAD+" (ID: C00003)
%         Metabolite: "D-Glycerate" (ID: C00258)
%     Match: "D-glycerate:NADP+ 2-oxidoreductase" (ID: R01392)
%         Metabolite: "NADP+" (ID: C00006)
%         Metabolite: "D-Glycerate" (ID: C00258)
%     Match: "D-xylose:NAD+ 1-oxidoreductase" (ID: R01429)
%         Metabolite: "NAD+" (ID: C00003)
%         Metabolite: "D-Xylose" (ID: C00181)
%     Match: "D-xylose:NADP+ 1-oxidoreductase" (ID: R01430)
%         Metabolite: "NADP+" (ID: C00006)
%         Metabolite: "D-Xylose" (ID: C00181)
%     Match: "3-Phospho-D-glycerate:NAD+ 2-oxidoreductase" (ID: R01513)
%         Metabolite: "NAD+" (ID: C00003)
%         Metabolite: "3-Phospho-D-glycerate" (ID: C00197)
%     Match: "beta-D-Glucose:NAD+ 1-oxoreductase" (ID: R01520)
%         Metabolite: "NAD+" (ID: C00003)
%         Metabolite: "beta-D-Glucose" (ID: C00221)
%     Match: "beta-D-Glucose:NADP+ 1-oxoreductase" (ID: R01521)
%         Metabolite: "NADP+" (ID: C00006)
%         Metabolite: "beta-D-Glucose" (ID: C00221)
%     Match: "Dihydrolipoamide:NAD+ oxidoreductase" (ID: R01698)
%         Metabolite: "NAD+" (ID: C00003)
%         Metabolite: "Dihydrolipoamide" (ID: C00579)
%     Match: "Pyridoxine:NADP+ 4-oxidoreductase" (ID: R01708)
%         Metabolite: "NADP+" (ID: C00006)
%         Metabolite: "Pyridoxine" (ID: C00314)
%     Match: "D-gluconate:NADP+ 2-oxidoreductase" (ID: R01739)
%         Metabolite: "NADP+" (ID: C00006)
%         Metabolite: "D-Gluconic acid" (ID: C00257)
%     Match: "(S)-dihydroorotate:NAD+ oxidoreductase" (ID: R01869)
%         Metabolite: "NAD+" (ID: C00003)
%         Metabolite: "(S)-Dihydroorotate" (ID: C00337)
%     Match: "rubredoxin:NAD+ oxidoreductase" (ID: R02000)
%         Metabolite: "NAD+" (ID: C00003)
%         Metabolite: "H+" (ID: C00080)
%         Metabolite: "Reduced rubredoxin" (ID: C00340)
%     Match: "(S)-lactaldehyde:NADP+ oxidoreductase" (ID: R02260)
%         Metabolite: "NADP+" (ID: C00006)
%         Metabolite: "(S)-Lactaldehyde" (ID: C00424)
%     Match: "(R)-Acetoin:NAD+ oxidoreductase" (ID: R02855)
%         Metabolite: "NADH" (ID: C00004)
%         Metabolite: "H+" (ID: C00080)
%         Metabolite: "Diacetyl" (ID: C00741)
%     Match: "(R,R)-Butane-2,3-diol:NAD+ oxidoreductase" (ID: R02946)
% ...
%         Metabolite: "NADP+" (ID: C00006)
%         Metabolite: "L-Allothreonine" (ID: C05519)
%     Match: "L-allo-threonine:NADP+ 3-oxidoreductase (decarboxylating)" (ID: R10852)
%         Metabolite: "NADP+" (ID: C00006)
%         Metabolite: "L-Allothreonine" (ID: C05519)
%     Match: "NADPH:demethylphylloquinone oxidoreductase" (ID: R11061)
%         Metabolite: "NADPH" (ID: C00005)
%         Metabolite: "H+" (ID: C00080)
%         Metabolite: "2-Phytyl-1,4-naphthoquinone" (ID: C13309)
%     Match: "(R)-lactate:NAD+,ferredoxin oxidoreductase" (ID: R13049)
%         Metabolite: "NAD+" (ID: C00003)
%         Metabolite: "(R)-Lactate" (ID: C00256)
%         Metabolite: "Reduced ferredoxin" (ID: C00138)
%     Match: "(S)-lactate:NAD+,ferredoxin oxidoreductase" (ID: R13050)
%         Metabolite: "NAD+" (ID: C00003)
%         Metabolite: "(S)-Lactate" (ID: C00186)
%         Metabolite: "Reduced ferredoxin" (ID: C00138)
%     Match: "propanoate:NAD+ oxidoreductase" (ID: R13136)
%         Metabolite: "NAD+" (ID: C00003)
%         Metabolite: "Propanoate" (ID: C00163)
% Precursor "NADP" → 46 matches found
%     Match: "succinate-semialdehyde:NADP+ oxidoreductase" (ID: R00714)
%         Metabolite: "H2O" (ID: C00001)
%         Metabolite: "NADP+" (ID: C00006)
%         Metabolite: "Succinate semialdehyde" (ID: C00232)
%     Match: "D-glucose-6-phosphate:NADP+ 1-oxidoreductase" (ID: R00835)
%         Metabolite: "NADP+" (ID: C00006)
%         Metabolite: "D-Glucose 6-phosphate" (ID: C00092)
%     Match: "sn-Glycerol-3-phosphate:NADP+ 2-oxidoreductase" (ID: R00844)
%         Metabolite: "NADP+" (ID: C00006)
%         Metabolite: "sn-Glycerol 3-phosphate" (ID: C00093)
%     Match: "5,6,7,8-tetrahydrofolate:NADP+ oxidoreductase" (ID: R00939)
%         Metabolite: "NADP+" (ID: C00006)
%         Metabolite: "Tetrahydrofolate" (ID: C00101)
%     Match: "5,6,7,8-tetrahydrofolate:NADP+ oxidoreductase" (ID: R00940)
%         Metabolite: "NADP+" (ID: C00006)
%         Metabolite: "Tetrahydrofolate" (ID: C00101)
%     Match: "inosine-5'-phosphate:NADP+ oxidoreductase (aminating);" (ID: R01134)
%         Metabolite: "NADP+" (ID: C00006)
%         Metabolite: "Ammonia" (ID: C00014)
%         Metabolite: "IMP" (ID: C00130)
%     Match: "5,10-methylenetetrahydrofolate:NADP+ oxidoreductase" (ID: R01220)
%         Metabolite: "NADP+" (ID: C00006)
%         Metabolite: "5,10-Methylenetetrahydrofolate" (ID: C00143)
%     Match: "6-phospho-D-gluconate:NADP+ 2-oxidoreductase (decarboxylating)" (ID: R01528)
%         Metabolite: "NADP+" (ID: C00006)
%         Metabolite: "6-Phospho-D-gluconate" (ID: C00345)
%     Match: "L-homoserine:NADP+ oxidoreductase" (ID: R01775)
%         Metabolite: "NADP+" (ID: C00006)
%         Metabolite: "L-Homoserine" (ID: C00263)
%     Match: "NADPH:oxidized-thioredoxin oxidoreductase" (ID: R02016)
%         Metabolite: "NADP+" (ID: C00006)
%         Metabolite: "Thioredoxin" (ID: C00342)
%     Match: "dihydrofolate:NADP+ oxidoreductase" (ID: R02236)
%         Metabolite: "NADP+" (ID: C00006)
%         Metabolite: "Dihydrofolate" (ID: C00415)
%     Match: "L-Aspartate-4-semialdehyde:NADP+ oxidoreductase (phosphorylating)" (ID: R02291)
%         Metabolite: "NADP+" (ID: C00006)
%         Metabolite: "Orthophosphate" (ID: C00009)
%         Metabolite: "L-Aspartate 4-semialdehyde" (ID: C00441)
%     Match: "beta-D-glucose-6-phosphate:NADP+ 1-oxoreductase" (ID: R02736)
%         Metabolite: "NADP+" (ID: C00006)
%         Metabolite: "beta-D-Glucose 6-phosphate" (ID: C01172)
%     Match: "dTDP-beta-L-rhamnose:NADP+ 4-oxidoreductase;" (ID: R02777)
%         Metabolite: "NADP+" (ID: C00006)
%         Metabolite: "dTDP-L-rhamnose" (ID: C03319)
%     Match: "UDP-N-acetylmuramate:NADP+ oxidoreductase" (ID: R03191)
%         Metabolite: "NAD+" (ID: C00003)
%         Metabolite: "UDP-N-acetylmuramate" (ID: C01050)
%     Match: "UDP-N-acetylmuramate:NADP+ oxidoreductase" (ID: R03192)
%         Metabolite: "NADP+" (ID: C00006)
%         Metabolite: "UDP-N-acetylmuramate" (ID: C01050)
%     Match: "5-amino-6-(5-phosphoribitylamino)uracil:NADP+ 1'-oxidoreductase" (ID: R03458)
%         Metabolite: "NADP+" (ID: C00006)
%         Metabolite: "5-Amino-6-(5'-phospho-D-ribitylamino)uracil" (ID: C04454)
%     Match: "hydrogen selenide:NADP+ oxidoreductase" (ID: R03596)
%         Metabolite: "H2O" (ID: C00001)
%         Metabolite: "NADP+" (ID: C00006)
%         Metabolite: "Hydrogen selenide" (ID: C01528)
%     Match: "2,3,4,5-tetrahydrodipicolinate:NADP+ 4-oxidoreductase" (ID: R04199)
%         Metabolite: "H2O" (ID: C00001)
%         Metabolite: "NADP+" (ID: C00006)
%         Metabolite: "2,3,4,5-Tetrahydrodipicolinate" (ID: C03972)
%     Match: "(3R)-3-hydroxybutanoyl-[acyl-carrier protein]:NADP+ oxidoreductase" (ID: R04533)
%         Metabolite: "NADP+" (ID: C00006)
%         Metabolite: "(3R)-3-Hydroxybutanoyl-[acyl-carrier protein]" (ID: C04618)
%     Match: "(3R)-3-hydroxydecanoyl-[acyl-carrier-protein]:NADP+ oxidoreductase" (ID: R04534)
%         Metabolite: "NADP+" (ID: C00006)
%         Metabolite: "(3R)-3-Hydroxydecanoyl-[acyl-carrier protein]" (ID: C04619)
%     Match: "(3R)-3-hydroxyoctanoyl-[acyl-carrier-protein]:NADP+ oxidoreductase" (ID: R04536)
%         Metabolite: "NADP+" (ID: C00006)
%         Metabolite: "(3R)-3-Hydroxyoctanoyl-[acyl-carrier protein]" (ID: C04620)
%     Match: "(3R)-3-hydroxypalmitoyl-[acyl-carrier-protein]:NADP+ oxidoreductase" (ID: R04543)
%         Metabolite: "NADP+" (ID: C00006)
%         Metabolite: "(3R)-3-Hydroxypalmitoyl-[acyl-carrier protein]" (ID: C04633)
%     Match: "(3R)-3-hydroxytetradecanoyl-[acyl-carrier-protein]:NADP+ oxidoreductase" (ID: R04566)
%         Metabolite: "NADP+" (ID: C00006)
%         Metabolite: "(3R)-3-Hydroxytetradecanoyl-[acyl-carrier protein]" (ID: C04688)
%     Match: "(3R)-3-hydroxyhexanoyl-[acyl-carrier-protein]:NADP+ oxidoreductase" (ID: R04953)
%         Metabolite: "NADP+" (ID: C00006)
%         Metabolite: "(3R)-3-Hydroxyhexanoyl-[acyl-carrier protein]" (ID: C05747)
%     Match: "(3R)-3-hydroxydodecanoyl-[acyl-carrier-protein]:NADP+ oxidoreductase" (ID: R04964)
%         Metabolite: "NADP+" (ID: C00006)
%         Metabolite: "(3R)-3-Hydroxydodecanoyl-[acyl-carrier protein]" (ID: C05757)
%     Match: "2-dehydro-L-idonate:NADP+ 5-oxidoreductase" (ID: R08878)
%         Metabolite: "NADP+" (ID: C00006)
%         Metabolite: "2-Dehydro-L-idonate" (ID: C15673)
%     Match: "methaneselenol:NADP+ oxidoreductase" (ID: R09372)
%         Metabolite: "NADPH" (ID: C00005)
%         Metabolite: "H+" (ID: C00080)
%         Metabolite: "Methylselenic acid" (ID: C18902)
%     Match: "scyllo-inositol:NADP+ oxidoreductase" (ID: R09954)
%         Metabolite: "NADP+" (ID: C00006)
%         Metabolite: "scyllo-Inositol" (ID: C06153)
%     Match: "3-hydroxyglutaryl-[acp]-methyl-ester:NADP+ oxidoreductase" (ID: R10116)
%         Metabolite: "NADPH" (ID: C00005)
%         Metabolite: "H+" (ID: C00080)
%         Metabolite: "3-Ketoglutaryl-[acp] methyl ester" (ID: C20372)
%     Match: "3-hydroxypimeloyl-[acp]-methyl-ester:NADP+ oxidoreductase" (ID: R10120)
%         Metabolite: "NADPH" (ID: C00005)
%         Metabolite: "H+" (ID: C00080)
%         Metabolite: "3-Ketopimeloyl-[acp] methyl ester" (ID: C20376)
%     Match: "tetrahydrobiopterin:NADP+ oxidoreductase (7,8-dihydrobiopterin-forming)" (ID: R11765)
%         Metabolite: "NADP+" (ID: C00006)
%         Metabolite: "Tetrahydrobiopterin" (ID: C00272)
%     Match: "liquiritigenin,[reduced NADPH---hemoprotein reductase]:oxygen oxidoreductase (licodione-forming)" (ID: R07198)
%         Metabolite: "Oxygen" (ID: C00007)
%         Metabolite: "[Reduced NADPH---hemoprotein reductase]" (ID: C03024)
%         Metabolite: "Liquiritigenin" (ID: C09762)
%     Match: "glutathione:NADP+ oxidoreductase" (ID: R00115)
%         Metabolite: "NADP+" (ID: C00006)
%         Metabolite: "Glutathione" (ID: C00051)
%     Match: "glycolate:NADP+ oxidoreductase" (ID: R00465)
%         Metabolite: "NADP+" (ID: C00006)
%         Metabolite: "Glycolate" (ID: C00160)
%     Match: "D-glycerate:NADP+ 2-oxidoreductase" (ID: R01392)
%         Metabolite: "NADP+" (ID: C00006)
%         Metabolite: "D-Glycerate" (ID: C00258)
%     Match: "D-xylose:NADP+ 1-oxidoreductase" (ID: R01430)
%         Metabolite: "NADP+" (ID: C00006)
%         Metabolite: "D-Xylose" (ID: C00181)
%     Match: "beta-D-Glucose:NADP+ 1-oxoreductase" (ID: R01521)
%         Metabolite: "NADP+" (ID: C00006)
%         Metabolite: "beta-D-Glucose" (ID: C00221)
%     Match: "Pyridoxine:NADP+ 4-oxidoreductase" (ID: R01708)
%         Metabolite: "NADP+" (ID: C00006)
%         Metabolite: "Pyridoxine" (ID: C00314)
%     Match: "D-gluconate:NADP+ 2-oxidoreductase" (ID: R01739)
%         Metabolite: "NADP+" (ID: C00006)
%         Metabolite: "D-Gluconic acid" (ID: C00257)
%     Match: "(S)-lactaldehyde:NADP+ oxidoreductase" (ID: R02260)
%         Metabolite: "NADP+" (ID: C00006)
%         Metabolite: "(S)-Lactaldehyde" (ID: C00424)
%     Match: "FMNH2:NADP+ oxidoreductase" (ID: R05706)
%         Metabolite: "NADP+" (ID: C00006)
%         Metabolite: "Reduced FMN" (ID: C01847)
%     Match: "3-hydroxypropionate:NADP+ oxidoreductase" (ID: R09289)
%         Metabolite: "NADP+" (ID: C00006)
%         Metabolite: "3-Hydroxypropanoate" (ID: C01013)
%     Match: "L-allo-threonine:NADP+ 3-oxidoreductase" (ID: R10851)
%         Metabolite: "NADP+" (ID: C00006)
%         Metabolite: "L-Allothreonine" (ID: C05519)
%     Match: "L-allo-threonine:NADP+ 3-oxidoreductase (decarboxylating)" (ID: R10852)
%         Metabolite: "NADP+" (ID: C00006)
%         Metabolite: "L-Allothreonine" (ID: C05519)
%     Match: "NADPH:demethylphylloquinone oxidoreductase" (ID: R11061)
%         Metabolite: "NADPH" (ID: C00005)
%         Metabolite: "H+" (ID: C00080)
%         Metabolite: "2-Phytyl-1,4-naphthoquinone" (ID: C13309)
% Precursor "FAD" → 1 matches found
%     Match: "FADH2:NAD+ oxidoreductase" (ID: R09748)
%         Metabolite: "NAD+" (ID: C00003)
%         Metabolite: "FADH2" (ID: C01352)
% Precursor "CoA" → 28 matches found
%     Match: "ATP:dephospho-CoA 3'-phosphotransferase" (ID: R00130)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "Dephospho-CoA" (ID: C00882)
%     Match: "acetaldehyde:NAD+ oxidoreductase (CoA-acetylating)" (ID: R00228)
%         Metabolite: "NAD+" (ID: C00003)
%         Metabolite: "CoA" (ID: C00010)
%         Metabolite: "Acetaldehyde" (ID: C00084)
%     Match: "acetyl-CoA:phosphate acetyltransferase" (ID: R00230)
%         Metabolite: "Orthophosphate" (ID: C00009)
%         Metabolite: "Acetyl-CoA" (ID: C00024)
%     Match: "acetyl-CoA:acetyl-CoA C-acetyltransferase" (ID: R00238)
%         Metabolite: "Acetyl-CoA" (ID: C00024)
%     Match: "propanoyl-CoA:phosphate propanoyltransferase" (ID: R00921)
%         Metabolite: "Orthophosphate" (ID: C00009)
%         Metabolite: "Propanoyl-CoA" (ID: C00100)
%     Match: "butanal:NAD+ oxidoreductase (CoA-acylating)" (ID: R01172)
%         Metabolite: "NAD+" (ID: C00003)
%         Metabolite: "CoA" (ID: C00010)
%         Metabolite: "Butanal" (ID: C01412)
%     Match: "butanoyl-CoA:acetyl-CoA C-butanoyltransferase" (ID: R01177)
%         Metabolite: "Acetyl-CoA" (ID: C00024)
%         Metabolite: "Butanoyl-CoA" (ID: C00136)
%     Match: "palmitoyl-CoA hydrolase" (ID: R01274)
%         Metabolite: "H2O" (ID: C00001)
%         Metabolite: "Palmitoyl-CoA" (ID: C00154)
%     Match: "CoA:apo-[acyl-carrier-protein] pantetheinephosphotransferase" (ID: R01625)
%         Metabolite: "CoA" (ID: C00010)
%         Metabolite: "Apo-[acyl-carrier-protein]" (ID: C03688)
%     Match: "Malonyl-CoA:[acyl-carrier-protein] S-malonyltransferase" (ID: R01626)
%         Metabolite: "Malonyl-CoA" (ID: C00083)
%         Metabolite: "Acyl-carrier protein" (ID: C00229)
%     Match: "acetyl-CoA:acetoacetyl-CoA C-acetyltransferase (thioester-hydrolysing, carboxymethyl-forming)" (ID: R01978)
%         Metabolite: "CoA" (ID: C00010)
%         Metabolite: "(S)-3-Hydroxy-3-methylglutaryl-CoA" (ID: C00356)
%     Match: "(R)-Mevalonate:NAD+ oxidoreductase (CoA-acetylating)" (ID: R02081)
%         Metabolite: "NAD+" (ID: C00003)
%         Metabolite: "CoA" (ID: C00010)
%         Metabolite: "(R)-Mevalonate" (ID: C00418)
%     Match: "acyl-CoA:1-acyl-sn-glycerol-3-phosphate 2-O-acyltransferase" (ID: R02241)
%         Metabolite: "CoA" (ID: C00010)
%         Metabolite: "Phosphatidate" (ID: C00416)
%     Match: "Acetyl-CoA:L-2,3,4,5-tetrahydrodipicolinate N2-acetyltransferase" (ID: R04364)
%         Metabolite: "H2O" (ID: C00001)
%         Metabolite: "Acetyl-CoA" (ID: C00024)
%         Metabolite: "2,3,4,5-Tetrahydrodipicolinate" (ID: C03972)
%     Match: "Acetyl-CoA:D-glucosamine-1-phosphate N-acetyltransferase" (ID: R05332)
%         Metabolite: "Acetyl-CoA" (ID: C00024)
%         Metabolite: "alpha-D-Glucosamine 1-phosphate" (ID: C06156)
%     Match: "ATP:3'-dephospho-CoA 5-triphospho-alpha-D-ribosyltransferase" (ID: R09675)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "Dephospho-CoA" (ID: C00882)
%     Match: "2'-(5-triphosphoribosyl)-3'-dephospho-CoA:apo-malonate-decarboxylase 2'-(5-phosphoribosyl)-3'-dephospho-CoA-transferase" (ID: R10706)
%         Metabolite: "Apo-[acyl-carrier-protein]" (ID: C03688)
%         Metabolite: "2'-(5-Triphosphoribosyl)-3'-dephospho-CoA" (ID: C19771)
%     Match: "pyruvate:NAD+ 2-oxidoreductase (CoA-acetylating);" (ID: R00209)
%         Metabolite: "NAD+" (ID: C00003)
%         Metabolite: "CoA" (ID: C00010)
%         Metabolite: "Pyruvate" (ID: C00022)
%     Match: "succinyl-CoA:acetyl-CoA C-acyltransferase;" (ID: R00829)
%         Metabolite: "Acetyl-CoA" (ID: C00024)
%         Metabolite: "Succinyl-CoA" (ID: C00091)
%     Match: "acetyl-CoA:propanoyl-CoA 2-C-acetyltransferase;" (ID: R00927)
%         Metabolite: "Acetyl-CoA" (ID: C00024)
%         Metabolite: "Propanoyl-CoA" (ID: C00100)
%     Match: "Octanoyl-CoA:acetyl-CoA C-acyltransferase" (ID: R03778)
%         Metabolite: "Acetyl-CoA" (ID: C00024)
%         Metabolite: "Octanoyl-CoA" (ID: C01944)
%     Match: "Lauroyl-CoA:acetyl-CoA C-acyltransferase" (ID: R03858)
%         Metabolite: "Acetyl-CoA" (ID: C00024)
%         Metabolite: "Lauroyl-CoA" (ID: C01832)
%     Match: "myristoyl-CoA:acetylCoA C-myristoyltransferase" (ID: R03991)
%         Metabolite: "Acetyl-CoA" (ID: C00024)
%         Metabolite: "Tetradecanoyl-CoA" (ID: C02593)
%     Match: "Decanoyl-CoA:acetyl-CoA C-acyltransferase" (ID: R04742)
%         Metabolite: "Acetyl-CoA" (ID: C00024)
%         Metabolite: "Decanoyl-CoA" (ID: C05274)
%     Match: "Hexanoyl-CoA:acetyl-CoA C-acyltransferase" (ID: R04747)
%         Metabolite: "Acetyl-CoA" (ID: C00024)
%         Metabolite: "Hexanoyl-CoA" (ID: C05270)
%     Match: "7-methyl-3-oxo-6-octenoyl-CoA:acetyl-CoA C-acyltransferase" (ID: R08091)
%         Metabolite: "CoA" (ID: C00010)
%         Metabolite: "7-Methyl-3-oxo-6-octenoyl-CoA" (ID: C16466)
%     Match: "3-methylcrotonyl-CoA:acetyl-CoA C-acyltransferase" (ID: R08095)
%         Metabolite: "CoA" (ID: C00010)
%         Metabolite: "5-Methyl-3-oxo-4-hexenoyl-CoA" (ID: C16471)
%     Match: "2-oxoglutarate:NAD+ 2-oxidoreductase (CoA-succinylating);" (ID: R08549)
%         Metabolite: "NAD+" (ID: C00003)
%         Metabolite: "CoA" (ID: C00010)
%         Metabolite: "2-Oxoglutarate" (ID: C00026)
% Precursor "Heme" → no matches found
% Precursor "Peptidoglycan" → no matches found
% Precursor "Lipoteichoic acid" → no matches found
% Precursor "Phosphatidylglycerol" → 3 matches found
%     Match: "Phosphatidylglycerol:membrane-derived-oligosaccharide-D-glucose glycerophosphotransferase" (ID: R05081)
%         Metabolite: "Phosphatidylglycerol" (ID: C00344)
%         Metabolite: "Diglucosyldiacylglycerol" (ID: C06040)
%     Match: "phosphatidylglycerol:Glc-alpha1->2Glc-alpha1->3acyl2Gro glycerophosphotransferase" (ID: R10849)
%         Metabolite: "Phosphatidylglycerol" (ID: C00344)
%         Metabolite: "alpha-Kojibiosyldiacylglycerol" (ID: C06365)
%     Match: "CDP-diacylglycerol:phosphatidylglycerol 3-phosphatidyltransferase" (ID: R02030)
%         Metabolite: "CDP-diacylglycerol" (ID: C00269)
%         Metabolite: "Phosphatidylglycerol" (ID: C00344)
% Precursor "Cardiolipin" → no matches found
% Warning: Repeated mets in the formula for rxn 'BIOMASS_ps'. Combine the stoichiometry.
% test
% CSV table saved to "Lcrispatus_biomass_metabolites.csv"
% Added biomass reaction "BIOMASS_ps" with 819 metabolite entries (duplicates kept).

% %% [markdown]
% Quick cleaning to ensure RAVEN structures are correctly kept:

% %%
LcrispatusBiomassDraftModel = syncModelStruct(LcrispatusBiomassDraftModel, 'Lcrispatus_biomass_sync_log.csv');
% Out:
% syncModelStruct: Log saved to "Lcrispatus_biomass_sync_log.csv"

% %%
checkModelCoreConsistency(LcrispatusBiomassDraftModel);
% Out:
% --- BASIC DIMENSION CHECKS ---
% Reactions: 754
% Metabolites: 1010
% Genes: 691
% Empty grRules in 145 reactions

% %% [markdown]
% A few additional problems were discovered when attempting to import this version of the model with COBRApy. The following are additional sanitizations to hopefully avoid those issues:

% %%
LcrispatusBiomassDraftModel = sanitizeGEMforSBML(LcrispatusBiomassDraftModel); % Custom function to remove spaces, dashes, etc.

% Fix rxnConfidenceScores field
if ~isfield(LcrispatusBiomassDraftModel,'rxnConfidenceScores')
    % If missing, initialize as zeros
    LcrispatusBiomassDraftModel.rxnConfidenceScores = ...
        zeros(numel(LcrispatusBiomassDraftModel.rxns),1);
else
    % If it exists but is not double, reset as zeros of correct length
    if ~isnumeric(LcrispatusBiomassDraftModel.rxnConfidenceScores)
        LcrispatusBiomassDraftModel.rxnConfidenceScores = ...
            zeros(numel(LcrispatusBiomassDraftModel.rxns),1);
    elseif size(LcrispatusBiomassDraftModel.rxnConfidenceScores,1) ~= numel(LcrispatusBiomassDraftModel.rxns)
        % Resize if length mismatch
        LcrispatusBiomassDraftModel.rxnConfidenceScores = ...
            zeros(numel(LcrispatusBiomassDraftModel.rxns),1);
    end
end

% %% [markdown]
% I will now save the new model with the biomass reaction included:

% %%
exportModel(LcrispatusBiomassDraftModel, 'Lcrispatus_draftGEM_v3.xml');
% Out:
% WARNING: The following InChI strings are associated to more than one unique metabolite name:
%     1S/C10H20O7P2/c1-9(2)5-4-6-10(3)7-8-16-19(14,15)17-18(11,12)13/h5,7H,4,6,8H2,1-3H3,(H,14,15)(H2,11,12,13)/b10-7+
% Document written

% %%
exportToExcelFormat(LcrispatusBiomassDraftModel, 'Lcrispatus_draftGEM_v3.xlsx');
save('Lcrispatus_draftGEM_v3.mat', 'LcrispatusBiomassDraftModel');

% %% [markdown]
% ## Solving again
%
% Now that a biomass reaction has been added to the model,

% %%
%LcrispatusBiomassDraftModel = importModel('Lcrispatus_draftGEM_v3.xml');
sol2 = solveLP(LcrispatusBiomassDraftModel);
disp(sol2.f)
% Out:
%      0

% %% [markdown]
% Still 0, so still no growth.
%
% ## Stoichiometry & Gap\-filling
%
% If the exchanges aren't the issue, then the next thing to check is the stoichiometry of the biomass reaction, and then to attempt gap\-filling.

% %%
% taking a look at the gap situation
%gapReport(LcrispatusBiomassDraftModel);
gapReport_vSimple(LcrispatusBiomassDraftModel);
% Out:
% Dead-end metabolites: 557
%     {'C00018'}
%     {'C00040'}
%     {'C00053'}
%     {'C00071'}
%     {'C00077'}
%     {'C00088'}
%     {'C00094'}
%     {'C00104'}
%     {'C00114'}
%     {'C00132'}
%     {'C00134'}
%     {'C00137'}
%     {'C00145'}
%     {'C00149'}
%     {'C00158'}
%     {'C00170'}
%     {'C00180'}
%     {'C00189'}
%     {'C00201'}
%     {'C00224'}
%     {'C00233'}
%     {'C00237'}
%     {'C00242'}
%     {'C00243'}
%     {'C00249'}
%     {'C00253'}
%     {'C00262'}
%     {'C00283'}
%     {'C00327'}
%     {'C00350'}
%     {'C00353'}
%     {'C00363'}
%     {'C00369'}
%     {'C00383'}
%     {'C00385'}
%     {'C00392'}
%     {'C00395'}
%     {'C00402'}
%     {'C00447'}
%     {'C00450'}
%     {'C00454'}
%     {'C00458'}
%     {'C00459'}
%     {'C00489'}
%     {'C00491'}
%     {'C00530'}
%     {'C00577'}
%     {'C00620'}
%     {'C00627'}
%     {'C00647'}
%     {'C00653'}
%     {'C00670'}
%     {'C00691'}
%     {'C00721'}
%     {'C00785'}
%     {'C00819'}
%     {'C00846'}
%     {'C00876'}
%     {'C00881'}
%     {'C00886'}
%     {'C00935'}
%     {'C00957'}
%     {'C00962'}
%     {'C00973'}
%     {'C01019'}
%     {'C01024'}
%     {'C01041'}
%     {'C01083'}
%     {'C01096'}
%     {'C01113'}
%     {'C01127'}
%     {'C01133'}
%     {'C01190'}
%     {'C01217'}
%     {'C01228'}
%     {'C01233'}
%     {'C01235'}
%     {'C01252'}
%     {'C01260'}
%     {'C01261'}
%     {'C01278'}
%     {'C01290'}
%     {'C01297'}
%     {'C01345'}
%     {'C01419'}
%     {'C01424'}
%     {'C01451'}
%     {'C01471'}
%     {'C01592'}
%     {'C01637'}
%     {'C01642'}
%     {'C01717'}
%     {'C01752'}
%     {'C01762'}
%     {'C01801'}
%     {'C01880'}
%     {'C01921'}
%     {'C01931'}
%     {'C01962'}
%     {'C01997'}
%     {'C02047'}
%     {'C02097'}
%     {'C02163'}
%     {'C02188'}
%     {'C02247'}
%     {'C02291'}
%     {'C02323'}
%     {'C02348'}
%     {'C02350'}
%     {'C02353'}
%     {'C02354'}
%     {'C02355'}
%     {'C02380'}
%     {'C02412'}
%     {'C02415'}
%     {'C02470'}
%     {'C02501'}
%     {'C02528'}
%     {'C02553'}
%     {'C02554'}
%     {'C02686'}
%     {'C02702'}
%     {'C02780'}
%     {'C02839'}
%     {'C02952'}
%     {'C02953'}
%     {'C02984'}
%     {'C02987'}
%     {'C02988'}
%     {'C02989'}
%     {'C02992'}
%     {'C02999'}
%     {'C03028'}
%     {'C03089'}
%     {'C03125'}
%     {'C03127'}
%     {'C03150'}
%     {'C03160'}
%     {'C03161'}
%     {'C03219'}
%     {'C03241'}
%     {'C03289'}
%     {'C03294'}
%     {'C03309'}
%     {'C03453'}
%     {'C03458'}
%     {'C03479'}
%     {'C03511'}
%     {'C03512'}
%     {'C03657'}
%     {'C03658'}
%     {'C03671'}
%     {'C03692'}
%     {'C03733'}
%     {'C03758'}
%     {'C03771'}
%     {'C03892'}
%     {'C03912'}
%     {'C03939'}
%     {'C04051'}
%     {'C04076'}
%     {'C04157'}
%     {'C04236'}
%     {'C04242'}
%     {'C04260'}
%     {'C04298'}
%     {'C04334'}
%     {'C04377'}
%     {'C04392'}
%     {'C04421'}
%     {'C04431'}
%     {'C04432'}
%     {'C04442'}
%     {'C04494'}
%     {'C04522'}
%     {'C04625'}
%     {'C04672'}
%     {'C04706'}
%     {'C04718'}
%     {'C04823'}
%     {'C04877'}
%     {'C04881'}
%     {'C05122'}
%     {'C05190'}
%     {'C05191'}
%     {'C05198'}
%     {'C05199'}
%     {'C05223'}
%     {'C05269'}
%     {'C05312'}
%     {'C05322'}
%     {'C05336'}
%     {'C05394'}
%     {'C05399'}
%     {'C05400'}
%     {'C05401'}
%     {'C05403'}
%     {'C05463'}
%     {'C05464'}
%     {'C05465'}
%     {'C05466'}
%     {'C05570'}
%     {'C05577'}
%     {'C05578'}
%     {'C05587'}
%     {'C05623'}
%     {'C05625'}
%     {'C05645'}
%     {'C05691'}
%     {'C05699'}
%     {'C05703'}
%     {'C05726'}
%     {'C05729'}
%     {'C05744'}
%     {'C05746'}
%     {'C05750'}
%     {'C05753'}
%     {'C05756'}
%     {'C05759'}
%     {'C05762'}
%     {'C05766'}
%     {'C05819'}
%     {'C05840'}
%     {'C05841'}
%     {'C05847'}
%     {'C05894'}
%     {'C05898'}
%     {'C05914'}
%     {'C05916'}
%     {'C06037'}
%     {'C06041'}
%     {'C06056'}
%     {'C06066'}
%     {'C06102'}
%     {'C06103'}
%     {'C06113'}
%     {'C06126'}
%     {'C06173'}
%     {'C06186'}
%     {'C06194'}
%     {'C06198'}
%     {'C06206'}
%     {'C06481'}
%     {'C06555'}
%     {'C06567'}
%     {'C06594'}
%     {'C06597'}
%     {'C06598'}
%     {'C06602'}
%     {'C06613'}
%     {'C06620'}
%     {'C06717'}
%     {'C06735'}
%     {'C06986'}
%     {'C07304'}
%     {'C07307'}
%     {'C07335'}
%     {'C07478'}
%     {'C07479'}
%     {'C07490'}
%     {'C07541'}
%     {'C07645'}
%     {'C07647'}
%     {'C07648'}
%     {'C08537'}
%     {'C08540'}
%     {'C08543'}
%     {'C08557'}
%     {'C08565'}
%     {'C09099'}
%     {'C09315'}
%     {'C09332'}
%     {'C09382'}
%     {'C09440'}
%     {'C09789'}
%     {'C11149'}
%     {'C11402'}
%     {'C11403'}
%     {'C11404'}
%     {'C11405'}
%     {'C11406'}
%     {'C11414'}
%     {'C11417'}
%     {'C11418'}
%     {'C11419'}
%     {'C11420'}
%     {'C11437'}
%     {'C11633'}
%     {'C11634'}
%     {'C11638'}
%     {'C11680'}
%     {'C11713'}
%     {'C11714'}
%     {'C11813'}
%     {'C11814'}
%     {'C11822'}
%     {'C11838'}
%     {'C11887'}
%     {'C11930'}
%     {'C12119'}
%     {'C12396'}
%     {'C12397'}
%     {'C14090'}
%     {'C14099'}
%     {'C14180'}
%     {'C14786'}
%     {'C14787'}
%     {'C14866'}
%     {'C14909'}
%     {'C15670'}
%     {'C15809'}
%     {'C15814'}
%     {'C15986'}
%     {'C16075'}
%     {'C16138'}
%     {'C16151'}
%     {'C16152'}
%     {'C16219'}
%     {'C16220'}
%     {'C16348'}
%     {'C16392'}
%     {'C16413'}
%     {'C16556'}
%     {'C16559'}
%     {'C16614'}
%     {'C16615'}
%     {'C16617'}
%     {'C16619'}
%     {'C16634'}
%     {'C16663'}
%     {'C16664'}
%     {'C17204'}
%     {'C17349'}
%     {'C17751'}
%     {'C17752'}
%     {'C17753'}
%     {'C17754'}
%     {'C17755'}
%     {'C17757'}
%     {'C17758'}
%     {'C18022'}
%     {'C18063'}
%     {'C18064'}
%     {'C18094'}
%     {'C18235'}
%     {'C18345'}
%     {'C18871'}
%     {'C19079'}
%     {'C19084'}
%     {'C19491'}
%     {'C19563'}
%     {'C19564'}
%     {'C19566'}
%     {'C19567'}
%     {'C19568'}
%     {'C19577'}
%     {'C19578'}
%     {'C19580'}
%     {'C19581'}
%     {'C19714'}
%     {'C19723'}
%     {'C19944'}
%     {'C20231'}
%     {'C20254'}
%     {'C20271'}
%     {'C20279'}
%     {'C20297'}
%     {'C20299'}
%     {'C20312'}
%     {'C20315'}
%     {'C20329'}
%     {'C20330'}
%     {'C20361'}
%     {'C20373'}
%     {'C20377'}
%     {'C20379'}
%     {'C20390'}
%     {'C20409'}
%     {'C20449'}
%     {'C20451'}
%     {'C20457'}
%     {'C20522'}
%     {'C20565'}
%     {'C20650'}
%     {'C20729'}
%     {'C20743'}
%     {'C20836'}
%     {'C20852'}
%     {'C20853'}
%     {'C20858'}
%     {'C20897'}
%     {'C20899'}
%     {'C20900'}
%     {'C20901'}
%     {'C20906'}
%     {'C20937'}
%     {'C21026'}
%     {'C21075'}
%     {'C21140'}
%     {'C21142'}
%     {'C21152'}
%     {'C21154'}
%     {'C21192'}
%     {'C21214'}
%     {'C21408'}
%     {'C21410'}
%     {'C21412'}
%     {'C21437'}
%     {'C21442'}
%     {'C21459'}
%     {'C21476'}
%     {'C21582'}
%     {'C21589'}
%     {'C21590'}
%     {'C21599'}
%     {'C21600'}
%     {'C21620'}
%     {'C21622'}
%     {'C21623'}
%     {'C21731'}
%     {'C21751'}
%     {'C21787'}
%     {'C21873'}
%     {'C21897'}
%     {'C21922'}
%     {'C21923'}
%     {'C21930'}
%     {'C22050'}
%     {'C22051'}
%     {'C22054'}
%     {'C22070'}
%     {'C22084'}
%     {'C22092'}
%     {'C22131'}
%     {'C22148'}
%     {'C22149'}
%     {'C22238'}
%     {'C22329'}
%     {'C22331'}
%     {'C22332'}
%     {'C22333'}
%     {'C22334'}
%     {'C22395'}
%     {'C22432'}
%     {'C22438'}
%     {'C22442'}
%     {'C22488'}
%     {'C22624'}
%     {'C22647'}
%     {'C22648'}
%     {'G00092'}
%     {'G00093'}
%     {'G00177'}
%     {'G00711'}
%     {'G01275'}
%     {'G09795'}
%     {'G10008'}
%     {'G10504'}
%     {'G10552'}
%     {'G10553'}
%     {'G10555'}
%     {'G10556'}
%     {'G10608'}
%     {'G10609'}
%     {'G11112'}
%     {'G13118'}
%     {'G13167'}
%     {'G13170'}
%     {'G13171'}
%     {'G13174'}
%     {'G13175'}
%     {'G13176'}
%     {'G13177'}
%     {'G13178'}
%     {'G13179'}
%     {'G13180'}
%     {'G13182'}
%     {'G13183'}
%     {'G13185'}
%     {'G13186'}
%     {'G13188'}
%     {'G13192'}
%     {'G13193'}
%     {'C00099'}
%     {'C00164'}
%     {'C00179'}
%     {'C00184'}
%     {'C00222'}
%     {'C00248'}
%     {'C00252'}
%     {'C00280'}
%     {'C00322'}
%     {'C00338'}
%     {'C00380'}
%     {'C00435'}
%     {'C00511'}
%     {'C00512'}
%     {'C00522'}
%     {'C00546'}
%     {'C02051'}
%     {'C02232'}
%     {'C03069'}
%     {'C03198'}
%     {'C03232'}
%     {'C03344'}
%     {'C03590'}
%     {'C03859'}
%     {'C04046'}
%     {'C04115'}
%     {'C04146'}
%     {'C04216'}
%     {'C04327'}
%     {'C05259'}
%     {'C05261'}
%     {'C05263'}
%     {'C05265'}
%     {'C05267'}
%     {'C06033'}
%     {'C06231'}
%     {'C06376'}
%     {'C06377'}
%     {'C06473'}
%     {'C06715'}
%     {'C07118'}
%     {'C09812'}
%     {'C09813'}
%     {'C11588'}
%     {'C12622'}
%     {'C13508'}
%     {'C15972'}
%     {'C16330'}
%     {'C16331'}
%     {'C16334'}
%     {'C16335'}
%     {'C16338'}
%     {'C16339'}
%     {'C16470'}
%     {'C19772'}
%     {'C19929'}
%     {'C20144'}
%     {'C20247'}
%     {'C20357'}
%     {'C20420'}
%     {'C20421'}
%     {'C20422'}
%     {'C20751'}
%     {'C21084'}
%     {'C21464'}
%     {'C21502'}
%     {'C22077'}
%     {'G10611'}
%     {'G13163'}
%     {'G13165'}
%     {'G13172'}
%     {'G13191'}
%     {'G13197'}
%     {'G13198'}
% Blocked reactions: 567
%     {'R00022'      }
%     {'R00066'      }
%     {'R00104'      }
%     {'R00130'      }
%     {'R00137'      }
%     {'R00158'      }
%     {'R00161'      }
%     {'R00174'      }
%     {'R00177'      }
%     {'R00184'      }
%     {'R00188'      }
%     {'R00189'      }
%     {'R00190'      }
%     {'R00194'      }
%     {'R00220_EXP_1'}
%     {'R00228'      }
%     {'R00238'      }
%     {'R00260'      }
%     {'R00289'      }
%     {'R00291'      }
%     {'R00332_EXP_1'}
%     {'R00336'      }
%     {'R00362'      }
%     {'R00401'      }
%     {'R00416'      }
%     {'R00420'      }
%     {'R00425'      }
%     {'R00429'      }
%     {'R00451'      }
%     {'R00470'      }
%     {'R00480'      }
%     {'R00491'      }
%     {'R00505'      }
%     {'R00508'      }
%     {'R00512'      }
%     {'R00552'      }
%     {'R00597'      }
%     {'R00650'      }
%     {'R00660'      }
%     {'R00670'      }
%     {'R00720_EXP_1'}
%     {'R00754'      }
%     {'R00761'      }
%     {'R00782_EXP_1'}
%     {'R00837'      }
%     {'R00839'      }
%     {'R00856'      }
%     {'R00899'      }
%     {'R00921'      }
%     {'R00942'      }
%     {'R00943'      }
%     {'R00945'      }
%     {'R00955'      }
%     {'R00965'      }
%     {'R00969'      }
%     {'R01000'      }
%     {'R01030'      }
%     {'R01054'      }
%     {'R01056_EXP_1'}
%     {'R01057'      }
%     {'R01082'      }
%     {'R01092'      }
%     {'R01104_EXP_1'}
%     {'R01121'      }
%     {'R01122'      }
%     {'R01123'      }
%     {'R01132'      }
%     {'R01150'      }
%     {'R01172'      }
%     {'R01177'      }
%     {'R01194_EXP_1'}
%     {'R01220'      }
%     {'R01227'      }
%     {'R01229'      }
%     {'R01232'      }
%     {'R01274'      }
%     {'R01286_EXP_1'}
%     {'R01291'      }
%     {'R01329_EXP_1'}
%     {'R01353'      }
%     {'R01397'      }
%     {'R01401'      }
%     {'R01421'      }
%     {'R01466'      }
%     {'R01470'      }
%     {'R01547'      }
%     {'R01562'      }
%     {'R01579'      }
%     {'R01625'      }
%     {'R01626'      }
%     {'R01655'      }
%     {'R01658'      }
%     {'R01664'      }
%     {'R01678_EXP_1'}
%     {'R01724'      }
%     {'R01737'      }
%     {'R01771'      }
%     {'R01799'      }
%     {'R01801'      }
%     {'R01819'      }
%     {'R01829'      }
%     {'R01867'      }
%     {'R01870'      }
%     {'R01877'      }
%     {'R01909'      }
%     {'R01961'      }
%     {'R01978'      }
%     {'R01993'      }
%     {'R02003'      }
%     {'R02016'      }
%     {'R02025'      }
%     {'R02055'      }
%     {'R02059'      }
%     {'R02060'      }
%     {'R02061'      }
%     {'R02081'      }
%     {'R02090_EXP_1'}
%     {'R02094'      }
%     {'R02101'      }
%     {'R02112'      }
%     {'R02142'      }
%     {'R02148'      }
%     {'R02237'      }
%     {'R02240'      }
%     {'R02241'      }
%     {'R02245'      }
%     {'R02291'      }
%     {'R02301'      }
%     {'R02320'      }
%     {'R02323'      }
%     {'R02328'      }
%     {'R02370'      }
%     {'R02401'      }
%     {'R02408_EXP_1'}
%     {'R02493'      }
%     {'R02556'      }
%     {'R02568'      }
%     {'R02630'      }
%     {'R02703'      }
%     {'R02704'      }
%     {'R02718_EXP_1'}
%     {'R02719'      }
%     {'R02720_EXP_1'}
%     {'R02733'      }
%     {'R02734'      }
%     {'R02735'      }
%     {'R02750'      }
%     {'R02777'      }
%     {'R02780'      }
%     {'R02783'      }
%     {'R02797'      }
%     {'R02805'      }
%     {'R02918'      }
%     {'R02926_EXP_1'}
%     {'R02971'      }
%     {'R02984'      }
%     {'R02991'      }
%     {'R03005'      }
%     {'R03018'      }
%     {'R03035'      }
%     {'R03038'      }
%     {'R03104'      }
%     {'R03122'      }
%     {'R03193'      }
%     {'R03239'      }
%     {'R03245'      }
%     {'R03269'      }
%     {'R03346'      }
%     {'R03355_EXP_1'}
%     {'R03458'      }
%     {'R03459'      }
%     {'R03470'      }
%     {'R03471'      }
%     {'R03531_EXP_1'}
%     {'R03537'      }
%     {'R03538'      }
%     {'R03596'      }
%     {'R03646'      }
%     {'R03648'      }
%     {'R03650'      }
%     {'R03651'      }
%     {'R03654'      }
%     {'R03655'      }
%     {'R03656'      }
%     {'R03657'      }
%     {'R03658'      }
%     {'R03659'      }
%     {'R03660'      }
%     {'R03661'      }
%     {'R03662'      }
%     {'R03663'      }
%     {'R03664'      }
%     {'R03665'      }
%     {'R03751'      }
%     {'R03905'      }
%     {'R03929'      }
%     {'R03940'      }
%     {'R03966'      }
%     {'R03975'      }
%     {'R03977'      }
%     {'R04019_EXP_1'}
%     {'R04112'      }
%     {'R04212'      }
%     {'R04231'      }
%     {'R04364'      }
%     {'R04378'      }
%     {'R04391'      }
%     {'R04394'      }
%     {'R04405'      }
%     {'R04449'      }
%     {'R04457'      }
%     {'R04467'      }
%     {'R04470_EXP_1'}
%     {'R04486'      }
%     {'R04487'      }
%     {'R04509'      }
%     {'R04533'      }
%     {'R04534'      }
%     {'R04536'      }
%     {'R04543'      }
%     {'R04559'      }
%     {'R04566'      }
%     {'R04573'      }
%     {'R04617'      }
%     {'R04710'      }
%     {'R04771'      }
%     {'R04773'      }
%     {'R04783_EXP_1'}
%     {'R04880'      }
%     {'R04941_EXP_1'}
%     {'R04951'      }
%     {'R04953'      }
%     {'R04964'      }
%     {'R05030'      }
%     {'R05032'      }
%     {'R05081'      }
%     {'R05086'      }
%     {'R05132'      }
%     {'R05133'      }
%     {'R05134'      }
%     {'R05135'      }
%     {'R05199'      }
%     {'R05233'      }
%     {'R05234'      }
%     {'R05332'      }
%     {'R05389'      }
%     {'R05566'      }
%     {'R05577'      }
%     {'R05578'      }
%     {'R05605'      }
%     {'R05627'      }
%     {'R05629'      }
%     {'R05630'      }
%     {'R05636'      }
%     {'R05662'      }
%     {'R05820'      }
%     {'R05835'      }
%     {'R05961_EXP_1'}
%     {'R06091_EXP_1'}
%     {'R06113'      }
%     {'R06114_EXP_1'}
%     {'R06129'      }
%     {'R06173'      }
%     {'R06174'      }
%     {'R06363'      }
%     {'R06390'      }
%     {'R06391'      }
%     {'R06392'      }
%     {'R06393'      }
%     {'R06447'      }
%     {'R06513'      }
%     {'R06514'      }
%     {'R06917'      }
%     {'R06927'      }
%     {'R07281'      }
%     {'R07390'      }
%     {'R07461'      }
%     {'R07763'      }
%     {'R08218'      }
%     {'R08232'      }
%     {'R08233'      }
%     {'R08237'      }
%     {'R08238'      }
%     {'R08240'      }
%     {'R08243_EXP_1'}
%     {'R08244'      }
%     {'R08245'      }
%     {'R08555'      }
%     {'R08559'      }
%     {'R08572'      }
%     {'R08856'      }
%     {'R08878'      }
%     {'R08944'      }
%     {'R09009'      }
%     {'R09099'      }
%     {'R09365'      }
%     {'R09372'      }
%     {'R09381'      }
%     {'R09399'      }
%     {'R09400'      }
%     {'R09597'      }
%     {'R09675'      }
%     {'R09736'      }
%     {'R09748'      }
%     {'R09750'      }
%     {'R09954'      }
%     {'R10116'      }
%     {'R10120'      }
%     {'R10137'      }
%     {'R10147'      }
%     {'R10223'      }
%     {'R10330'      }
%     {'R10463'      }
%     {'R10619'      }
%     {'R10633'      }
%     {'R10634'      }
%     {'R10706'      }
%     {'R10757'      }
%     {'R10806'      }
%     {'R10831'      }
%     {'R10849'      }
%     {'R10850'      }
%     {'R10865'      }
%     {'R11170'      }
%     {'R11171'      }
%     {'R11172'      }
%     {'R11262'      }
%     {'R11319'      }
%     {'R11636'      }
%     {'R11671'      }
%     {'R11765'      }
%     {'R11896'      }
%     {'R12049'      }
%     {'R12075'      }
%     {'R12188_EXP_1'}
%     {'R12240'      }
%     {'R12241_EXP_1'}
%     {'R12345'      }
%     {'R12390'      }
%     {'R12391'      }
%     {'R12812'      }
%     {'R12851'      }
%     {'R12852_EXP_1'}
%     {'R12859'      }
%     {'R12863'      }
%     {'R12867'      }
%     {'R12871'      }
%     {'R12873'      }
%     {'R12875'      }
%     {'R12896'      }
%     {'R12900'      }
%     {'R12902'      }
%     {'R12903'      }
%     {'R12904'      }
%     {'R12958'      }
%     {'R13063'      }
%     {'R13064'      }
%     {'R00647'      }
%     {'R01652'      }
%     {'R02317'      }
%     {'R02962'      }
%     {'R03166'      }
%     {'R03186'      }
%     {'R03445'      }
%     {'R03672'      }
%     {'R03674'      }
%     {'R03954'      }
%     {'R04500'      }
%     {'R04578'      }
%     {'R04701'      }
%     {'R04769'      }
%     {'R05041'      }
%     {'R05098'      }
%     {'R05455'      }
%     {'R05483'      }
%     {'R05484'      }
%     {'R05824'      }
%     {'R05826'      }
%     {'R05844'      }
%     {'R05845'      }
%     {'R05846'      }
%     {'R05887'      }
%     {'R05889'      }
%     {'R06063'      }
%     {'R06064'      }
%     {'R06194'      }
%     {'R06650'      }
%     {'R06830'      }
%     {'R06982'      }
%     {'R07009'      }
%     {'R07010'      }
%     {'R07011'      }
%     {'R07012'      }
%     {'R07198'      }
%     {'R07316'      }
%     {'R07406'      }
%     {'R07679'      }
%     {'R07947'      }
%     {'R07948'      }
%     {'R08020'      }
%     {'R08279'      }
%     {'R08289'      }
%     {'R08358'      }
%     {'R08361'      }
%     {'R08372'      }
%     {'R08818'      }
%     {'R08820'      }
%     {'R08821'      }
%     {'R08825'      }
%     {'R08827'      }
%     {'R08829'      }
%     {'R08831'      }
%     {'R08833'      }
%     {'R08834'      }
%     {'R08835'      }
%     {'R08837'      }
%     {'R08976'      }
%     {'R09142'      }
%     {'R09143'      }
%     {'R09144'      }
%     {'R09145'      }
%     {'R09149'      }
%     {'R09274'      }
%     {'R09367'      }
%     {'R09368'      }
%     {'R09391'      }
%     {'R09392'      }
%     {'R09431'      }
%     {'R09432'      }
%     {'R09433'      }
%     {'R09434'      }
%     {'R09885'      }
%     {'R09981'      }
%     {'R10013'      }
%     {'R10018'      }
%     {'R10022'      }
%     {'R10030'      }
%     {'R10034'      }
%     {'R10041'      }
%     {'R10078'      }
%     {'R10082'      }
%     {'R10097'      }
%     {'R10245'      }
%     {'R10302'      }
%     {'R10792'      }
%     {'R10854'      }
%     {'R10856'      }
%     {'R10914'      }
%     {'R11017'      }
%     {'R11034'      }
%     {'R11049'      }
%     {'R11148'      }
%     {'R11176'      }
%     {'R11228'      }
%     {'R11523'      }
%     {'R11550'      }
%     {'R11570'      }
%     {'R11571'      }
%     {'R11572'      }
%     {'R11573'      }
%     {'R11574'      }
%     {'R11575'      }
%     {'R11576'      }
%     {'R11577'      }
%     {'R11691'      }
%     {'R11695'      }
%     {'R11709'      }
%     {'R11736'      }
%     {'R11739'      }
%     {'R11865'      }
%     {'R11947'      }
%     {'R12091'      }
%     {'R12094'      }
%     {'R12132'      }
%     {'R12140'      }
%     {'R12268'      }
%     {'R12274'      }
%     {'R12310'      }
%     {'R12335'      }
%     {'R12421'      }
%     {'R12539'      }
%     {'R12683'      }
%     {'R12686'      }
%     {'R12829'      }
%     {'R12886'      }
%     {'R12910'      }
%     {'R12974'      }
%     {'R13023'      }
%     {'R13091'      }
%     {'R13113'      }
%     {'R13114'      }
%     {'R13140'      }
%     {'R13144'      }
%     {'R00008'      }
%     {'R00196'      }
%     {'R00319'      }
%     {'R00350'      }
%     {'R00476'      }
%     {'R00566'      }
%     {'R00582'      }
%     {'R00829'      }
%     {'R00927'      }
%     {'R01012'      }
%     {'R01221'      }
%     {'R01361'      }
%     {'R01513'      }
%     {'R01698'      }
%     {'R01708'      }
%     {'R01718'      }
%     {'R01739'      }
%     {'R01869'      }
%     {'R01933'      }
%     {'R01994'      }
%     {'R02000'      }
%     {'R02030'      }
%     {'R02137'      }
%     {'R02260'      }
%     {'R02473'      }
%     {'R02689'      }
%     {'R02786'      }
%     {'R02855'      }
%     {'R02946'      }
%     {'R03223'      }
%     {'R03707'      }
%     {'R03778'      }
%     {'R03815'      }
%     {'R03858'      }
%     {'R03991'      }
%     {'R04742'      }
%     {'R04747'      }
%     {'R05168'      }
%     {'R05506'      }
%     {'R05582'      }
%     {'R05586'      }
%     {'R06633'      }
%     {'R06782'      }
%     {'R06783'      }
%     {'R07280'      }
%     {'R07618'      }
%     {'R07891'      }
%     {'R07895'      }
%     {'R07899'      }
%     {'R08091'      }
%     {'R08095'      }
%     {'R08549'      }
%     {'R09078'      }
%     {'R09247'      }
%     {'R09248'      }
%     {'R09289'      }
%     {'R09641'      }
%     {'R09800'      }
%     {'R09884'      }
%     {'R10184'      }
%     {'R10185'      }
%     {'R10505'      }
%     {'R10648'      }
%     {'R10712'      }
%     {'R11061'      }
%     {'R11543'      }
%     {'R11612'      }
%     {'R12808'      }
%     {'R12814'      }
%     {'R12819'      }
%     {'R12868'      }
%     {'R13136'      }
%     {'R13137'      }
%     {'BIOMASS_ps'  }

% %% [markdown]
% The built\-in `gapReport()` program in the RAVEN Toolbox doesn't work for my model, so I've modified `gapReport()`, `checkProduction()` and `haveFlux()` as suggested by ChatGPT, to avoid the issue and still get some results.

% %%
% This version produces a more complex result like RAVEN
% But it takes a VERY long time to run, so is commented out here
%gapReport_nosimplify(LcrispatusBiomassDraftModel);

% %% [markdown]
% It is clear that there are quite a lot of gaps and problems with this draft model.
%
% ## Sorting out exchange reactions
%
% In order for this to be a functional GEM, exchange reactions need to be added.

% %%
% Setting up the draft GEM base
%LcrispatusBiomassDraftModel = importModel('Lcrispatus_draftGEM_v3.xml');
% create a copy to avoid overwriting
LcrispatusExchangeModel = LcrispatusBiomassDraftModel;
LcrispatusExchangeModel.id = 'LcrispatusDraft';

% %% [markdown]
% Perform some cleaning:

% %%
% dealing with grRules
LcrispatusExchangeModel = ensureGrRules(LcrispatusExchangeModel);
modelKEGGgr = ensureGrRules(modelKEGG);
% Out:
% Patched grRules to match 11588 rxns

% %%
% further sanitization
modelKEGGgr = padMissingFields(modelKEGGgr, LcrispatusExchangeModel);
% Out:
% Added geneMiriams to KEGG
% Added rxnFrom to KEGG
% Added metFrom to KEGG
% Added geneFrom to KEGG
% Added rules to KEGG
% Added equations to KEGG
% Added rxnReferences to KEGG
% Added rxnConfidenceScores to KEGG
% Added metCharges to KEGG
% Added geneNames to KEGG
% Added geneShortNames to KEGG

% %% [markdown]
% Dealing with exchange reactions:

% %%
% getting a cell array of metabolites to create exchange reactions for
biomassMets = getBiomassMets(LcrispatusExchangeModel, 'BIOMASS_ps'); % get metabolites involved in the biomass reaction
% Out:
% Biomass reaction: BIOMASS_ps
% Number of metabolites in biomass reaction: 263
%     {'C00001'}
%     {'C00002'}
%     {'C00003'}
%     {'C00004'}
%     {'C00005'}
%     {'C00006'}
%     {'C00007'}
%     {'C00008'}
%     {'C00009'}
%     {'C00010'}
%     {'C00013'}
%     {'C00014'}
%     {'C00019'}
%     {'C00020'}
%     {'C00022'}
%     {'C00024'}
%     {'C00025'}
%     {'C00026'}
%     {'C00030'}
%     {'C00031'}
%     {'C00033'}
%     {'C00036'}
%     {'C00037'}
%     {'C00041'}
%     {'C00044'}
%     {'C00047'}
%     {'C00049'}
%     {'C00051'}
%     {'C00055'}
%     {'C00058'}
%     {'C00061'}
%     {'C00062'}
%     {'C00063'}
%     {'C00064'}
%     {'C00065'}
%     {'C00073'}
%     {'C00075'}
%     {'C00078'}
%     {'C00079'}
%     {'C00080'}
%     {'C00082'}
%     {'C00083'}
%     {'C00084'}
%     {'C00085'}
%     {'C00089'}
%     {'C00092'}
%     {'C00093'}
%     {'C00095'}
%     {'C00097'}
%     {'C00100'}
%     {'C00101'}
%     {'C00103'}
%     {'C00105'}
%     {'C00116'}
%     {'C00117'}
%     {'C00118'}
%     {'C00121'}
%     {'C00123'}
%     {'C00124'}
%     {'C00130'}
%     {'C00131'}
%     {'C00135'}
%     {'C00136'}
%     {'C00143'}
%     {'C00144'}
%     {'C00148'}
%     {'C00154'}
%     {'C00155'}
%     {'C00163'}
%     {'C00169'}
%     {'C00183'}
%     {'C00185'}
%     {'C00186'}
%     {'C00188'}
%     {'C00197'}
%     {'C00214'}
%     {'C00217'}
%     {'C00221'}
%     {'C00229'}
%     {'C00232'}
%     {'C00239'}
%     {'C00250'}
%     {'C00255'}
%     {'C00256'}
%     {'C00257'}
%     {'C00258'}
%     {'C00263'}
%     {'C00267'}
%     {'C00269'}
%     {'C00272'}
%     {'C00286'}
%     {'C00288'}
%     {'C00299'}
%     {'C00314'}
%     {'C00329'}
%     {'C00330'}
%     {'C00337'}
%     {'C00342'}
%     {'C00343'}
%     {'C00344'}
%     {'C00345'}
%     {'C00356'}
%     {'C00360'}
%     {'C00362'}
%     {'C00364'}
%     {'C00365'}
%     {'C00378'}
%     {'C00407'}
%     {'C00415'}
%     {'C00416'}
%     {'C00418'}
%     {'C00441'}
%     {'C00455'}
%     {'C00460'}
%     {'C00469'}
%     {'C00475'}
%     {'C00526'}
%     {'C00534'}
%     {'C00559'}
%     {'C00641'}
%     {'C00644'}
%     {'C00655'}
%     {'C00673'}
%     {'C00680'}
%     {'C00692'}
%     {'C00787'}
%     {'C00831'}
%     {'C00857'}
%     {'C00864'}
%     {'C00882'}
%     {'C00921'}
%     {'C00984'}
%     {'C00993'}
%     {'C01007'}
%     {'C01050'}
%     {'C01094'}
%     {'C01097'}
%     {'C01102'}
%     {'C01107'}
%     {'C01134'}
%     {'C01143'}
%     {'C01172'}
%     {'C01185'}
%     {'C01212'}
%     {'C01279'}
%     {'C01352'}
%     {'C01412'}
%     {'C01528'}
%     {'C01563'}
%     {'C01635'}
%     {'C01636'}
%     {'C01638'}
%     {'C01639'}
%     {'C01640'}
%     {'C01641'}
%     {'C01643'}
%     {'C01644'}
%     {'C01645'}
%     {'C01646'}
%     {'C01647'}
%     {'C01648'}
%     {'C01649'}
%     {'C01650'}
%     {'C01651'}
%     {'C01652'}
%     {'C01653'}
%     {'C01674'}
%     {'C01847'}
%     {'C01977'}
%     {'C02211'}
%     {'C02282'}
%     {'C02336'}
%     {'C02583'}
%     {'C02737'}
%     {'C02743'}
%     {'C02882'}
%     {'C02909'}
%     {'C03024'}
%     {'C03273'}
%     {'C03319'}
%     {'C03402'}
%     {'C03492'}
%     {'C03688'}
%     {'C03972'}
%     {'C04079'}
%     {'C04261'}
%     {'C04352'}
%     {'C04454'}
%     {'C04489'}
%     {'C04501'}
%     {'C04556'}
%     {'C04618'}
%     {'C04619'}
%     {'C04620'}
%     {'C04633'}
%     {'C04646'}
%     {'C04688'}
%     {'C05196'}
%     {'C05197'}
%     {'C05335'}
%     {'C05345'}
%     {'C05576'}
%     {'C05698'}
%     {'C05747'}
%     {'C05757'}
%     {'C05823'}
%     {'C05892'}
%     {'C05893'}
%     {'C05984'}
%     {'C06040'}
%     {'C06055'}
%     {'C06153'}
%     {'C06156'}
%     {'C06365'}
%     {'C06611'}
%     {'C06612'}
%     {'C09762'}
%     {'C11736'}
%     {'C14089'}
%     {'C15673'}
%     {'C15811'}
%     {'C15812'}
%     {'C15813'}
%     {'C16618'}
%     {'C16633'}
%     {'C16636'}
%     {'C18902'}
%     {'C19078'}
%     {'C19080'}
%     {'C19152'}
%     {'C19153'}
%     {'C19722'}
%     {'C19771'}
%     {'C20372'}
%     {'C20376'}
%     {'C00091'}
%     {'C00138'}
%     {'C00160'}
%     {'C00181'}
%     {'C00340'}
%     {'C00423'}
%     {'C00424'}
%     {'C00579'}
%     {'C00741'}
%     {'C01005'}
%     {'C01013'}
%     {'C01089'}
%     {'C01832'}
%     {'C01944'}
%     {'C02593'}
%     {'C02972'}
%     {'C03044'}
%     {'C03046'}
%     {'C05270'}
%     {'C05274'}
%     {'C05519'}
%     {'C05629'}
%     {'C13309'}
%     {'C15973'}
%     {'C16466'}
%     {'C16471'}
%     {'C20396'}
%     {'C20657'}

% %%
wasteMets = getCommonWasteMets(LcrispatusExchangeModel); % get list (cell array) of common waste metabolites
essentialMets = {'C00031','C00014','C00007','C00009','C00036'}; % glucose, ammonium, oxygen, phosphate, sulfate
communityMets = getCommunityExchangeMets(); % metabolites that are likely to be needed in MCMM community exchanges
allExMets = unique([biomassMets(:); wasteMets(:); essentialMets(:); communityMets(:)], 'stable'); % concatenate while avoiding potential duplicates

% add the exchange reactions to the model
LcrispatusExchangeModel = addExchangeRxnsForModel(LcrispatusExchangeModel, allExMets);
% Out:
% Warning: Metabolite C00086 not found in model, skipping.
% Warning: Metabolite C00282 not found in model, skipping.
% Warning: Metabolite C00246 not found in model, skipping.

% %%
%ensure reversibility in the model
LcrispatusExchangeModel = ensureRevField(LcrispatusExchangeModel);
% Out:
% Model already has rev field

% %%
sol3 = solveLP(LcrispatusExchangeModel);
disp(sol3.f);
% Out:
%   33.707865168539328

% %% [markdown]
% I have biomass production!!!!
%
%
% So THIS was the problem! Without exchange reactions, the model wasn't able to function properly!

% %%
% pre-export cleaning
LcrispatusExchangeModel = fixSubsystemsField(LcrispatusExchangeModel);
LcrispatusExchangeModel = sanitizeRxnMiriams(LcrispatusExchangeModel);
% Out:
% Sanitized rxnMiriams for 1019 reactions

% %% [markdown]
% Now the model is ready for export:

% %%
% export the current model version
exportModel(LcrispatusExchangeModel, 'Lcrispatus_draftGEM_v4.xml');
% Out:
% WARNING: The following InChI strings are associated to more than one unique metabolite name:
%     1S/C10H20O7P2/c1-9(2)5-4-6-10(3)7-8-16-19(14,15)17-18(11,12)13/h5,7H,4,6,8H2,1-3H3,(H,14,15)(H2,11,12,13)/b10-7+
% Document written

% %%
exportToExcelFormat(LcrispatusExchangeModel, 'Lcrispatus_draftGEM_v4.xlsx');
save('Lcrispatus_draftGEM_v4.mat', 'LcrispatusExchangeModel');

% %% [markdown]
% This will be the version used for the MCMM.
%
% ## Additional tests
%
% A few more sanity checks and tests prior to moving on to gap\-filling.

% %%
% Setting up the draft GEM base
%LcrispatusBiomassDraftModel = importModel('Lcrispatus_draftGEM_v4.xml');
% create a copy to avoid overwriting
LcrispatusBiomassObjDraftModel = LcrispatusExchangeModel;
LcrispatusBiomassObjDraftModel.id = 'LcrispatusDraft';

% %% [markdown]
% First, checking for dead\-end metabolites:

% %%
deadMets = quickDeadEnds(LcrispatusBiomassObjDraftModel);
fprintf('Dead-end metabolites: %d\n', numel(deadMets));
% Out:
% Dead-end metabolites: 0

% %% [markdown]
% Double\-check that the biomass metabolites are indeed present in the model:

% %%
biomassMets = getBiomassMets(LcrispatusBiomassObjDraftModel, 'BIOMASS_ps');
% Out:
% Biomass reaction: BIOMASS_ps
% Number of metabolites in biomass reaction: 263
%     {'C00001'}
%     {'C00002'}
%     {'C00003'}
%     {'C00004'}
%     {'C00005'}
%     {'C00006'}
%     {'C00007'}
%     {'C00008'}
%     {'C00009'}
%     {'C00010'}
%     {'C00013'}
%     {'C00014'}
%     {'C00019'}
%     {'C00020'}
%     {'C00022'}
%     {'C00024'}
%     {'C00025'}
%     {'C00026'}
%     {'C00030'}
%     {'C00031'}
%     {'C00033'}
%     {'C00036'}
%     {'C00037'}
%     {'C00041'}
%     {'C00044'}
%     {'C00047'}
%     {'C00049'}
%     {'C00051'}
%     {'C00055'}
%     {'C00058'}
%     {'C00061'}
%     {'C00062'}
%     {'C00063'}
%     {'C00064'}
%     {'C00065'}
%     {'C00073'}
%     {'C00075'}
%     {'C00078'}
%     {'C00079'}
%     {'C00080'}
%     {'C00082'}
%     {'C00083'}
%     {'C00084'}
%     {'C00085'}
%     {'C00089'}
%     {'C00092'}
%     {'C00093'}
%     {'C00095'}
%     {'C00097'}
%     {'C00100'}
%     {'C00101'}
%     {'C00103'}
%     {'C00105'}
%     {'C00116'}
%     {'C00117'}
%     {'C00118'}
%     {'C00121'}
%     {'C00123'}
%     {'C00124'}
%     {'C00130'}
%     {'C00131'}
%     {'C00135'}
%     {'C00136'}
%     {'C00143'}
%     {'C00144'}
%     {'C00148'}
%     {'C00154'}
%     {'C00155'}
%     {'C00163'}
%     {'C00169'}
%     {'C00183'}
%     {'C00185'}
%     {'C00186'}
%     {'C00188'}
%     {'C00197'}
%     {'C00214'}
%     {'C00217'}
%     {'C00221'}
%     {'C00229'}
%     {'C00232'}
%     {'C00239'}
%     {'C00250'}
%     {'C00255'}
%     {'C00256'}
%     {'C00257'}
%     {'C00258'}
%     {'C00263'}
%     {'C00267'}
%     {'C00269'}
%     {'C00272'}
%     {'C00286'}
%     {'C00288'}
%     {'C00299'}
%     {'C00314'}
%     {'C00329'}
%     {'C00330'}
%     {'C00337'}
%     {'C00342'}
%     {'C00343'}
%     {'C00344'}
%     {'C00345'}
%     {'C00356'}
%     {'C00360'}
%     {'C00362'}
%     {'C00364'}
%     {'C00365'}
%     {'C00378'}
%     {'C00407'}
%     {'C00415'}
%     {'C00416'}
%     {'C00418'}
%     {'C00441'}
%     {'C00455'}
%     {'C00460'}
%     {'C00469'}
%     {'C00475'}
%     {'C00526'}
%     {'C00534'}
%     {'C00559'}
%     {'C00641'}
%     {'C00644'}
%     {'C00655'}
%     {'C00673'}
%     {'C00680'}
%     {'C00692'}
%     {'C00787'}
%     {'C00831'}
%     {'C00857'}
%     {'C00864'}
%     {'C00882'}
%     {'C00921'}
%     {'C00984'}
%     {'C00993'}
%     {'C01007'}
%     {'C01050'}
%     {'C01094'}
%     {'C01097'}
%     {'C01102'}
%     {'C01107'}
%     {'C01134'}
%     {'C01143'}
%     {'C01172'}
%     {'C01185'}
%     {'C01212'}
%     {'C01279'}
%     {'C01352'}
%     {'C01412'}
%     {'C01528'}
%     {'C01563'}
%     {'C01635'}
%     {'C01636'}
%     {'C01638'}
%     {'C01639'}
%     {'C01640'}
%     {'C01641'}
%     {'C01643'}
%     {'C01644'}
%     {'C01645'}
%     {'C01646'}
%     {'C01647'}
%     {'C01648'}
%     {'C01649'}
%     {'C01650'}
%     {'C01651'}
%     {'C01652'}
%     {'C01653'}
%     {'C01674'}
%     {'C01847'}
%     {'C01977'}
%     {'C02211'}
%     {'C02282'}
%     {'C02336'}
%     {'C02583'}
%     {'C02737'}
%     {'C02743'}
%     {'C02882'}
%     {'C02909'}
%     {'C03024'}
%     {'C03273'}
%     {'C03319'}
%     {'C03402'}
%     {'C03492'}
%     {'C03688'}
%     {'C03972'}
%     {'C04079'}
%     {'C04261'}
%     {'C04352'}
%     {'C04454'}
%     {'C04489'}
%     {'C04501'}
%     {'C04556'}
%     {'C04618'}
%     {'C04619'}
%     {'C04620'}
%     {'C04633'}
%     {'C04646'}
%     {'C04688'}
%     {'C05196'}
%     {'C05197'}
%     {'C05335'}
%     {'C05345'}
%     {'C05576'}
%     {'C05698'}
%     {'C05747'}
%     {'C05757'}
%     {'C05823'}
%     {'C05892'}
%     {'C05893'}
%     {'C05984'}
%     {'C06040'}
%     {'C06055'}
%     {'C06153'}
%     {'C06156'}
%     {'C06365'}
%     {'C06611'}
%     {'C06612'}
%     {'C09762'}
%     {'C11736'}
%     {'C14089'}
%     {'C15673'}
%     {'C15811'}
%     {'C15812'}
%     {'C15813'}
%     {'C16618'}
%     {'C16633'}
%     {'C16636'}
%     {'C18902'}
%     {'C19078'}
%     {'C19080'}
%     {'C19152'}
%     {'C19153'}
%     {'C19722'}
%     {'C19771'}
%     {'C20372'}
%     {'C20376'}
%     {'C00091'}
%     {'C00138'}
%     {'C00160'}
%     {'C00181'}
%     {'C00340'}
%     {'C00423'}
%     {'C00424'}
%     {'C00579'}
%     {'C00741'}
%     {'C01005'}
%     {'C01013'}
%     {'C01089'}
%     {'C01832'}
%     {'C01944'}
%     {'C02593'}
%     {'C02972'}
%     {'C03044'}
%     {'C03046'}
%     {'C05270'}
%     {'C05274'}
%     {'C05519'}
%     {'C05629'}
%     {'C13309'}
%     {'C15973'}
%     {'C16466'}
%     {'C16471'}
%     {'C20396'}
%     {'C20657'}

% %%
missing = setdiff(biomassMets, LcrispatusBiomassObjDraftModel.mets);
disp(missing);

% %% [markdown]
% Perform a preliminary test for whether gap\-filling is necessary:

% %%
% block all exchange
LcrispatusBiomassObjDraftModel.lb(findExcRxns(LcrispatusBiomassObjDraftModel)) = 0;

% reopen minimal medium
allowMets = {'C00031','C00014','C00007','C00009','C00036'}; % glucose, ammonium, oxygen, phosphate, sulfate
for i = 1:numel(allowMets)
    exIdx = find(strcmp(LcrispatusBiomassObjDraftModel.mets, allowMets{i}));
    if ~isempty(exIdx)
        rxnIdx = find(LcrispatusBiomassObjDraftModel.S(exIdx,:));
        LcrispatusBiomassObjDraftModel.lb(rxnIdx) = -1000; % uptake allowed
    end
end

sol4 = solveLP(LcrispatusBiomassObjDraftModel);
disp(sol4.f);
% Out:
%   33.707865168539229

% %% [markdown]
% The solution here is the same as before, so this looks good to go.
%
%
% On Ed's recommendation, I will force the biomass flux to be positive:

% %%
% force the biomass flux to be positive
% Set lower and upper bounds of the biomass reaction
rxnID = 'BIOMASS_ps';
biomassIndex = find(ismember(LcrispatusBiomassObjDraftModel.rxns, rxnID));

LcrispatusBiomassObjDraftModel.lb(biomassIndex) = 0.1;  % minimum growth rate
LcrispatusBiomassObjDraftModel.ub(biomassIndex) = 1000; % allow up to 1000

% %% [markdown]
% Finally, run FBA on the new model:

% %%
sol3 = solveLP(LcrispatusBiomassObjDraftModel);
disp(sol3.f)
% Out:
%   33.707865168539328

% %% [markdown]
% Export the model:

% %%
exportModel(LcrispatusBiomassObjDraftModel, 'Lcrispatus_draftGEM_v5.xml');
% Out:
% WARNING: The following reactions have lower and upper bounds that indicate reversibility, but are indicated as irreversible in model.rev:
%     R00765
%     R00839
%     R02738
%     R04212
%     R05086
%     R05627
%     R12896
%     R12958
%     R08020
% WARNING: The following InChI strings are associated to more than one unique metabolite name:
%     1S/C10H20O7P2/c1-9(2)5-4-6-10(3)7-8-16-19(14,15)17-18(11,12)13/h5,7H,4,6,8H2,1-3H3,(H,14,15)(H2,11,12,13)/b10-7+
% Document written

% %%
exportToExcelFormat(LcrispatusBiomassObjDraftModel, 'Lcrispatus_draftGEM_v5.xlsx');
save('Lcrispatus_draftGEM_v5.mat', 'LcrispatusBiomassObjDraftModel');

% %% [markdown]
% ## Gap\-filling attempt
%
% On the advice of Ed, I will be doing gap\-filling from the whole of the KEGG database. While the model does technically produce biomass and so therefore is viable, it is better to add more exchanges to ensure as high\-quality of an MCMM as possible.

% %%
% trying gap filling
[Lcrispatus_filledModel, addedRxns] = fillGaps( ...
    LcrispatusBiomassObjDraftModel, ...
    modelKEGGgr, ...
    false, true, true);

% Check the output of fillGaps
if isempty(Lcrispatus_filledModel)
    disp('fillGaps returned an empty model. Check your input models and required fields.');
elseif iscell(Lcrispatus_filledModel)
    disp(['fillGaps returned a cell array of size: ', mat2str(size(Lcrispatus_filledModel))]);
else
    disp('fillGaps returned a valid model struct.');
end
% Out:
% fillGaps returned an empty model. Check your input models and required fields.

% %% [markdown]
% Check the results:

% %%
% Did fillGaps return something valid?
class(Lcrispatus_filledModel)
% Out:
% ans = 'cell'

% %%
whos Lcrispatus_filledModel
% Out:
%   Name                        Size            Bytes  Class    Attributes
%   Lcrispatus_filledModel      0x0                 0  cell

% %% [markdown]
% The fact that the filled model is empty implies that fillGaps() didn't find any gaps to fill \- the model should be good as it is.
%
% ## Draft *Lactobacillus iners* GEM
%
% Initial GEM creation:

% %%
%clear
%clc

% draft with KEGG
%The organisms with KEGG annotation and their associated ids
%(e.g. 'lid' for Lactobacillus iners) can be found from here:
%https://www.kegg.jp/kegg/catalog/org_list.html.
LinersKEGGAnnotation=getKEGGModelForOrganism('lid','','','',1,0,0);
% Out:
% *** The model reconstruction from KEGG based on the annotation available for KEGG Species lid ***
% Importing the global KEGG model from C:/Users/viragv/AppData/Roaming/MathWorks/MATLAB Add-Ons/Collections/RAVEN Toolbox/external/kegg/keggModel.mat... COMPLETE
% Importing the KEGG phylogenetic distance matrix from C:/Users/viragv/AppData/Roaming/MathWorks/MATLAB Add-Ons/Collections/RAVEN Toolbox/external/kegg/keggPhylDist.mat... COMPLETE
% Pruning the model from non-lid genes... COMPLETE
% Removing non-spontaneous reactions without GPR rules... COMPLETE
% Fixing gene names in the model... COMPLETE
% Constructing GPR associations and annotations for the model... COMPLETE
% *** Model reconstruction complete ***

% %%
LinersKEGGHomology=getKEGGModelForOrganism('LinersKEGGHMMs','lactobacillus_iners_GCF_011058775-1_prots_edit.fasta','prok90_kegg105','',1,0,0);
% Out:
% *** The model reconstruction from KEGG based on the protein homology search against KEGG Orthology specific HMMs ***
% NOTE: Found prok90_kegg105 directory with pre-trained HMMs, it will therefore be used during reconstruction
% Importing the global KEGG model from C:/Users/viragv/AppData/Roaming/MathWorks/MATLAB Add-Ons/Collections/RAVEN Toolbox/external/kegg/keggModel.mat... COMPLETE
% Removing non-spontaneous reactions without GPR rules... COMPLETE
% Fixing gene names in the model... COMPLETE
% Importing the KEGG phylogenetic distance matrix from C:/Users/viragv/AppData/Roaming/MathWorks/MATLAB Add-Ons/Collections/RAVEN Toolbox/external/kegg/keggPhylDist.mat... COMPLETE
% Generating the KEGG Orthology specific multi-FASTA files... COMPLETE
% Performing clustering and multiple alignment for KEGG Orthology specific protein sets... COMPLETE
% Training the KEGG Orthology specific HMMs... COMPLETE
% Querying the user-specified FASTA file against the KEGG Orthology specific HMMs... COMPLETE
% Parsing the HMM search results... COMPLETE
% Removing gene, KEGG Orthology associations below minScoreRatioKO, minScoreRatioG... COMPLETE
% Adding gene annotations to the model... COMPLETE
% Removing non-spontaneous reactions which after HMM search no longer have GPR rules... COMPLETE
% Constructing GPR rules and finalizing the model... COMPLETE
% *** Model reconstruction complete ***

% %%
% merge models
LinersKEGGDraftModel=mergeModels({LinersKEGGAnnotation LinersKEGGHomology});

% check reaction numbers
disp(numel(LinersKEGGHomology.rxns)+numel(LinersKEGGAnnotation.rxns));
% Out:
%         1008

% %%
disp(numel(LinersKEGGDraftModel.rxns));
% Out:
%         1008

% %%
% further model cleaning
LinersKEGGDraftModel=expandModel(LinersKEGGDraftModel);
LinersKEGGDraftModel=contractModel(LinersKEGGDraftModel);

% %% [markdown]
% At this point, a draft GEM has been created for *L. iners*, merging the information from MetaCyc and KEGG. While it needs to be improved, I'll save it for now in Excel format to avoid having to recreate it each time.

% %%
exportToExcelFormat(LinersKEGGDraftModel, 'Liners_draftGEM_v1.xlsx');
save('Liners_draftGEM_v1.mat', 'LinersKEGGDraftModel');

% %% [markdown]
% ## Cleaning *L. iners* draft GEM

% %%
%LinersCombinedDraftModel = load('Liners_draftGEM_v1.mat');
LinersCleanDraftModel = cleanGrRulesGenes(LinersKEGGDraftModel);
LinersCleanDraftModel = mergeDuplicateMetNames(LinersCleanDraftModel);
LinersCleanDraftModel = fixSubsystemsField(LinersCleanDraftModel);

% %% [markdown]
% The preliminary model should now be ready for export.

% %%
exportModel(LinersCleanDraftModel, 'Liners_draftGEM_v2.xml');
% Out:
% WARNING: No objective function found. This might be intended, but results in FBCv2 non-compliant SBML file when exported
% WARNING: The composition for the following metabolites could not be parsed:
%     C00856
%     C01977
%     C02967
%     C04157
%     C04432
%     C17324
%     C19722
%     C19723
%     C20451
%     ...and 3 more
% Document written

% %%
exportToExcelFormat(LinersCleanDraftModel, 'Liners_draftGEM_v2.xlsx');
save('Liners_draftGEM_v2.mat', 'LinersCleanDraftModel');

% %% [markdown]
% Saved in SBML standard GEM format.

% %%
% Load the model from SBML (.xml)
%LinersCleanDraftModel = importModel('Liners_draftGEM_v2.xml');

% %% [markdown]
% Now start quality checks:

% %%
%Check out if the newly generated LinersCombinedDraftModel could grow
sol=solveLP(LinersCleanDraftModel);
disp(sol.f);
% Out:
%      0

% %%
%The results indicate that this new model is non-functional
% ie., biomass = 0, which means there is no growth

% %%
% Look for reactions that produce a "biomass" metabolite
bioMets = find(contains(lower(LinersCleanDraftModel.metNames), 'biomass'));

if isempty(bioMets)
    warning('No metabolites with "biomass" in the name were found.');
else
    % Find reactions involving these metabolites
    [rxnIdx, ~] = find(LinersCleanDraftModel.S(bioMets,:) ~= 0);
    rxnIdx = unique(rxnIdx);
    disp('Potential biomass reactions:');
    disp([rxnIdx, LinersCleanDraftModel.rxns(rxnIdx)', LinersCleanDraftModel.rxnNames(rxnIdx)']);
end
% Out:
% Warning: No metabolites with "biomass" in the name were found.

% %% [markdown]
% ## Adding a biomass reaction
%
% Initial explorations showed that the current preliminary GEM draft doesn't have a biomass reaction. Hence, biomass will always be 0 until this is added. The following code was generated by ChatGPT; it seeds a biomass reaction from common building blocks like amino acids and nucleotides.

% %%
[LinersBiomassDraftModel, biomassRxnID] = addPseudoBiomass_debug_all( ...
    LinersCleanDraftModel, ...
    'BIOMASS_ps', ...
    [], ...
    true, ...
    'Liners_biomass_debug.txt', ...
    'Liners_biomass_metabolites.csv' ...
);
% Out:
% Precursor "L-alanine" → 4 matches found
%     Match: "UDP-N-acetylmuramate:L-alanine ligase (ADP-forming)" (ID: R03193)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "L-Alanine" (ID: C00041)
%         Metabolite: "UDP-N-acetylmuramate" (ID: C01050)
%     Match: "UDP-N-acetylmuramoyl-L-alanine:D-glutamate ligase(ADP-forming)" (ID: R02783)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "D-Glutamate" (ID: C00217)
%         Metabolite: "UDP-N-acetylmuramoyl-L-alanine" (ID: C01212)
%     Match: "L-Alanine:tRNA(Ala) ligase (AMP-forming)" (ID: R03038)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "L-Alanine" (ID: C00041)
%         Metabolite: "tRNA(Ala)" (ID: C01635)
%     Match: "L-selenocysteine selenide-lyase (L-alanine-forming)" (ID: R03599)
%         Metabolite: "Reduced acceptor" (ID: C00030)
%         Metabolite: "L-Selenocysteine" (ID: C05688)
% Precursor "L-arginine" → 1 matches found
%     Match: "L-Arginine:tRNA(Arg) ligase (AMP-forming)" (ID: R03646)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "L-Arginine" (ID: C00062)
%         Metabolite: "tRNA(Arg)" (ID: C01636)
% Precursor "L-aspartate" → 5 matches found
%     Match: "L-aspartate:ammonia ligase (AMP-forming)" (ID: R00483)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "Ammonia" (ID: C00014)
%         Metabolite: "L-Aspartate" (ID: C00049)
%     Match: "L-aspartate:L-glutamine amido-ligase (AMP-forming)" (ID: R00578)
%         Metabolite: "H2O" (ID: C00001)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "L-Aspartate" (ID: C00049)
%         Metabolite: "L-Glutamine" (ID: C00064)
%     Match: "IMP:L-aspartate ligase (GDP-forming)" (ID: R01135)
%         Metabolite: "GTP" (ID: C00044)
%         Metabolite: "L-Aspartate" (ID: C00049)
%         Metabolite: "IMP" (ID: C00130)
%     Match: "L-Aspartate:tRNA(Asp) ligase (AMP-forming)" (ID: R05577)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "L-Aspartate" (ID: C00049)
%         Metabolite: "tRNA(Asp)" (ID: C01638)
%     Match: "carbamoyl-phosphate:L-aspartate carbamoyltransferase" (ID: R01397)
%         Metabolite: "L-Aspartate" (ID: C00049)
%         Metabolite: "Carbamoyl phosphate" (ID: C00169)
% Precursor "L-cysteine" → 6 matches found
%     Match: "N-[(R)-4'-Phosphopantothenoyl]-L-cysteine carboxy-lyase" (ID: R03269)
%         Metabolite: "(R)-4'-Phosphopantothenoyl-L-cysteine" (ID: C04352)
%     Match: "L-Cysteine:tRNA(Cys) ligase (AMP-forming)" (ID: R03650)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "L-Cysteine" (ID: C00097)
%         Metabolite: "tRNA(Cys)" (ID: C01639)
%     Match: "(R)-4'-phosphopantothenate:L-cysteine ligase" (ID: R04231)
%         Metabolite: "CTP" (ID: C00063)
%         Metabolite: "L-Cysteine" (ID: C00097)
%         Metabolite: "D-4'-Phosphopantothenate" (ID: C03492)
%     Match: "L-cysteine:[enzyme]-cysteine sulfurtransferase" (ID: R07460)
%         Metabolite: "L-Cysteine" (ID: C00097)
%         Metabolite: "[Enzyme]-cysteine" (ID: C15811)
%     Match: "[enzyme]-S-sulfanyl-L-cysteine:adenylyl-[sulfur-carrier protein] sulfurtransferase" (ID: R07461)
%         Metabolite: "Reduced acceptor" (ID: C00030)
%         Metabolite: "[Enzyme]-S-sulfanylcysteine" (ID: C15812)
%         Metabolite: "Adenylyl-[sulfur-carrier protein]" (ID: C15813)
%     Match: "L-cysteine:sulfur-acceptor sulfurtransferase" (ID: R11528)
%         Metabolite: "L-Cysteine" (ID: C00097)
%         Metabolite: "[Protein]-L-cysteine" (ID: C02743)
% Precursor "L-glutamate" → 5 matches found
%     Match: "L-Glutamate:ammonia ligase (ADP-forming)" (ID: R00253)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "Ammonia" (ID: C00014)
%         Metabolite: "L-Glutamate" (ID: C00025)
%     Match: "Tetrahydrofolate:L-glutamate gamma-ligase (ADP-forming)" (ID: R00942)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "L-Glutamate" (ID: C00025)
%         Metabolite: "Tetrahydrofolate" (ID: C00101)
%     Match: "7,8-dihydropteroate:L-glutamate ligase (ADP-forming)" (ID: R02237)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "L-Glutamate" (ID: C00025)
%         Metabolite: "Dihydropteroate" (ID: C00921)
%     Match: "L-Glutamate:tRNA(Gln) ligase (AMP-forming)" (ID: R03651)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "L-Glutamate" (ID: C00025)
%         Metabolite: "tRNA(Gln)" (ID: C01640)
%     Match: "L-glutamate:tRNA(Glu) ligase (AMP-forming)" (ID: R05578)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "L-Glutamate" (ID: C00025)
%         Metabolite: "tRNA(Glu)" (ID: C01641)
% Precursor "L-glutamine" → 11 matches found
%     Match: "L-glutamine amidohydrolase" (ID: R00256)
%         Metabolite: "H2O" (ID: C00001)
%         Metabolite: "L-Glutamine" (ID: C00064)
%     Match: "UTP:L-glutamine amido-ligase (ADP-forming)" (ID: R00573)
%         Metabolite: "H2O" (ID: C00001)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "L-Glutamine" (ID: C00064)
%         Metabolite: "UTP" (ID: C00075)
%     Match: "HCO3-:L-glutamine amido-ligase (ADP-forming, carbamate-phosphorylating)" (ID: R00575)
%         Metabolite: "H2O" (ID: C00001)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "L-Glutamine" (ID: C00064)
%         Metabolite: "HCO3-" (ID: C00288)
%     Match: "L-aspartate:L-glutamine amido-ligase (AMP-forming)" (ID: R00578)
%         Metabolite: "H2O" (ID: C00001)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "L-Aspartate" (ID: C00049)
%         Metabolite: "L-Glutamine" (ID: C00064)
%     Match: "Xanthosine-5'-phosphate:L-glutamine amido-ligase (AMP-forming)" (ID: R01231)
%         Metabolite: "H2O" (ID: C00001)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "L-Glutamine" (ID: C00064)
%         Metabolite: "Xanthosine 5'-phosphate" (ID: C00655)
%     Match: "Glu-tRNA(Gln):L-glutamine amido-ligase(ADP-forming)" (ID: R03905)
%         Metabolite: "ADP" (ID: C00008)
%         Metabolite: "Orthophosphate" (ID: C00009)
%         Metabolite: "L-Glutamate" (ID: C00025)
%         Metabolite: "Glutaminyl-tRNA" (ID: C02282)
%     Match: "Asp-tRNA(Asn):L-glutamine amido-ligase (ADP-forming)" (ID: R04212)
%         Metabolite: "ADP" (ID: C00008)
%         Metabolite: "Orthophosphate" (ID: C00009)
%         Metabolite: "L-Glutamate" (ID: C00025)
%         Metabolite: "L-Asparaginyl-tRNA(Asn)" (ID: C03402)
%     Match: "beta-D-GlcNAc-(1->4)-Mur2Ac(oyl-L-Ala-gamma-D-Glu-L-Lys-D-Ala-D-Ala)-diphospho-ditrans,octacis-undecaprenol:L-glutamine amidoligase (ADP-forming)" (ID: R05030)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "Ammonia" (ID: C00014)
%         Metabolite: "Undecaprenyl-diphospho-N-acetylmuramoyl-(N-acetylglucosamine)-L-alanyl-gamma-D-glutamyl-L-lysyl-D-alanyl-D-alanine" (ID: C05893)
%     Match: "6-thioxanthine 5'-monophosphate:L-glutamine amido-ligase (AMP-forming)" (ID: R08244)
%         Metabolite: "H2O" (ID: C00001)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "L-Glutamine" (ID: C00064)
%         Metabolite: "6-Thioxanthine 5'-monophosphate" (ID: C16618)
%     Match: "S-adenosyl-L-methionine:[protein]-L-glutamine (N5-glutamine)-methyltransferase" (ID: R10806)
%         Metabolite: "S-Adenosyl-L-methionine" (ID: C00019)
%         Metabolite: "Protein glutamine" (ID: C02583)
%     Match: "L-glutamine:D-fructose-6-phosphate isomerase (deaminating);" (ID: R00768)
%         Metabolite: "L-Glutamine" (ID: C00064)
%         Metabolite: "D-Fructose 6-phosphate" (ID: C00085)
% Precursor "L-glycine" → no matches found
% Precursor "L-histidine" → 3 matches found
%     Match: "protein-Npi-phospho-L-histidine:N,N'-diacetylchitobiose 6'-O-phosphotransferase" (ID: R11170)
%         Metabolite: "Chitobiose" (ID: C01674)
%         Metabolite: "Protein N(pi)-phospho-L-histidine" (ID: C04261)
%     Match: "protein-Npi-phospho-L-histidine:cellobiose 6'-O-phosphotransferase" (ID: R11172)
%         Metabolite: "Cellobiose" (ID: C00185)
%         Metabolite: "Protein N(pi)-phospho-L-histidine" (ID: C04261)
%     Match: "L-Histidine:tRNA(His) ligase (AMP-forming)" (ID: R03655)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "L-Histidine" (ID: C00135)
%         Metabolite: "tRNA(His)" (ID: C01643)
% Precursor "L-isoleucine" → 1 matches found
%     Match: "L-Isoleucine:tRNA(Ile) ligase (AMP-forming)" (ID: R03656)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "L-Isoleucine" (ID: C00407)
%         Metabolite: "tRNA(Ile)" (ID: C01644)
% Precursor "L-leucine" → 1 matches found
%     Match: "L-Leucine:tRNA(Leu) ligase (AMP-forming)" (ID: R03657)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "L-Leucine" (ID: C00123)
%         Metabolite: "tRNA(Leu)" (ID: C01645)
% Precursor "L-lysine" → 4 matches found
%     Match: "L-lysine:tRNALys ligase (AMP-forming)" (ID: R03658)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "L-Lysine" (ID: C00047)
%         Metabolite: "tRNA(Lys)" (ID: C01646)
%     Match: "UDP-N-acetylmuramoyl-L-alanyl-D-glutamyl-L-lysine:alanyl-D-alanine ligase (ADP-forming)" (ID: R04573)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "D-Alanyl-D-alanine" (ID: C00993)
%         Metabolite: "UDP-N-acetylmuramoyl-L-alanyl-gamma-D-glutamyl-L-lysine" (ID: C05892)
%     Match: "L-lysine:[tRNA(Ile2)]-cytidine34 ligase (AMP-forming)" (ID: R09597)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "L-Lysine" (ID: C00047)
%         Metabolite: "[tRNA(Ile2)]-cytidine34" (ID: C19722)
%     Match: "UDP-N-acetylmuramoyl-L-alanyl-D-glutamate:L-lysine gamma-ligase (ADP-forming);" (ID: R02786)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "L-Lysine" (ID: C00047)
%         Metabolite: "UDP-N-acetylmuramoyl-L-alanyl-D-glutamate" (ID: C00692)
% Precursor "L-methionine" → 6 matches found
%     Match: "ATP:L-methionine S-adenosyltransferase" (ID: R00177)
%         Metabolite: "Orthophosphate" (ID: C00009)
%         Metabolite: "Diphosphate" (ID: C00013)
%         Metabolite: "S-Adenosyl-L-methionine" (ID: C00019)
%     Match: "S-adenosyl-L-methionine:tRNA guanine N1-methyltransferase;" (ID: R00597)
%         Metabolite: "S-Adenosyl-L-methionine" (ID: C00019)
%         Metabolite: "tRNA guanine" (ID: C01977)
%     Match: "L-Methionine:tRNAMet ligase (AMP-forming)" (ID: R03659)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "L-Methionine" (ID: C00073)
%         Metabolite: "tRNA(Met)" (ID: C01647)
%     Match: "Protein-glycine,dihydroflavodoxin:S-adenosyl-L-methionine oxidoreductase (S-adenosyl-L-methionine cleaving)" (ID: R04710)
%         Metabolite: "S-Adenosyl-L-methionine" (ID: C00019)
%         Metabolite: "Dihydroflavodoxin" (ID: C05196)
%         Metabolite: "Protein glycine" (ID: C05197)
%     Match: "S-adenosyl-L-methionine:DNA (cytosine-5-)-methyltransferase" (ID: R04858)
%         Metabolite: "S-Adenosyl-L-methionine" (ID: C00019)
%         Metabolite: "DNA cytosine" (ID: C00856)
%     Match: "S-adenosyl-L-methionine:[protein]-L-glutamine (N5-glutamine)-methyltransferase" (ID: R10806)
%         Metabolite: "S-Adenosyl-L-methionine" (ID: C00019)
%         Metabolite: "Protein glutamine" (ID: C02583)
% Precursor "L-phenylalanine" → 1 matches found
%     Match: "L-Phenylalanine:tRNA(Ala) ligase (AMP-forming)" (ID: R03660)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "L-Phenylalanine" (ID: C00079)
%         Metabolite: "tRNA(Phe)" (ID: C01648)
% Precursor "L-proline" → 1 matches found
%     Match: "L-proline:tRNA(Pro) ligase (AMP-forming)" (ID: R03661)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "L-Proline" (ID: C00148)
%         Metabolite: "tRNA(Pro)" (ID: C01649)
% Precursor "L-serine" → 3 matches found
%     Match: "L-serine ammonia-lyase" (ID: R00220_EXP_1)
%         Metabolite: "L-Serine" (ID: C00065)
%     Match: "L-Serine:tRNA(Ser) ligase (AMP-forming)" (ID: R03662)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "L-Serine" (ID: C00065)
%         Metabolite: "tRNA(Ser)" (ID: C01650)
%     Match: "L-serine:tRNASec ligase (AMP-forming)" (ID: R08218)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "L-Serine" (ID: C00065)
%         Metabolite: "tRNA(Sec)" (ID: C16636)
% Precursor "L-threonine" → 1 matches found
%     Match: "L-Threonine:tRNA(Thr) ligase (AMP-forming)" (ID: R03663)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "L-Threonine" (ID: C00188)
%         Metabolite: "tRNA(Thr)" (ID: C01651)
% Precursor "L-tryptophan" → 1 matches found
%     Match: "L-Tryptophan -tRNA(Trp) ligase (AMP-forming)" (ID: R03664)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "L-Tryptophan" (ID: C00078)
%         Metabolite: "tRNA(Trp)" (ID: C01652)
% Precursor "L-tyrosine" → 1 matches found
%     Match: "L-Tyrosine:tRNA(Tyr) ligase (AMP-forming)" (ID: R02918)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "L-Tyrosine" (ID: C00082)
%         Metabolite: "tRNA(Tyr)" (ID: C00787)
% Precursor "L-valine" → 1 matches found
%     Match: "L-Valine:tRNAVal ligase (AMP-forming)" (ID: R03665)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "L-Valine" (ID: C00183)
%         Metabolite: "tRNA(Val)" (ID: C01653)
% Precursor "ATP" → 60 matches found
%     Match: "ATP:NAD+ 2'-phosphotransferase" (ID: R00104)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "NAD+" (ID: C00003)
%     Match: "ATP:AMP phosphotransferase" (ID: R00127)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "AMP" (ID: C00020)
%     Match: "ATP:dephospho-CoA 3'-phosphotransferase" (ID: R00130)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "Dephospho-CoA" (ID: C00882)
%     Match: "ATP:nicotinamide-nucleotide adenylyltransferase" (ID: R00137)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "Nicotinamide D-ribonucleotide" (ID: C00455)
%     Match: "ATP:UMP phosphotransferase" (ID: R00158)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "UMP" (ID: C00105)
%     Match: "ATP:FMN adenylyltransferase" (ID: R00161)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "FMN" (ID: C00061)
%     Match: "ATP:pyridoxal 5'-phosphotransferase" (ID: R00174)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "Pyridoxal" (ID: C00250)
%     Match: "ATP:L-methionine S-adenosyltransferase" (ID: R00177)
%         Metabolite: "Orthophosphate" (ID: C00009)
%         Metabolite: "Diphosphate" (ID: C00013)
%         Metabolite: "S-Adenosyl-L-methionine" (ID: C00019)
%     Match: "ATP:pyruvate 2-O-phosphotransferase" (ID: R00200)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "Pyruvate" (ID: C00022)
%     Match: "ATP:acetate phosphotransferase" (ID: R00315)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "Acetate" (ID: C00033)
%     Match: "ATP:GTP 3'-diphosphotransferase" (ID: R00429)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "GTP" (ID: C00044)
%     Match: "ATP:CMP phosphotransferase" (ID: R00512)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "CMP" (ID: C00055)
%     Match: "ATP:cytidine 5'-phosphotransferase" (ID: R00513)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "Cytidine" (ID: C00475)
%     Match: "ATP:riboflavin 5'-phosphotransferase" (ID: R00549)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "Riboflavin" (ID: C00255)
%     Match: "ATP:D-fructose-6-phosphate 1-phosphotransferase" (ID: R00756)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "D-Fructose 6-phosphate" (ID: C00085)
%     Match: "ATP:uridine 5'-phosphotransferase" (ID: R00964)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "Uridine" (ID: C00299)
%     Match: "ATP:D-ribose-5-phosphate diphosphotransferase" (ID: R01049)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "D-Ribose 5-phosphate" (ID: C00117)
%     Match: "ATP:(R)-5-diphosphomevalonate carboxy-lyase (adding ATP; isopentenyl-diphosphate-forming);" (ID: R01121)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "(R)-5-Diphosphomevalonate" (ID: C01143)
%     Match: "dATP:pyruvate 2-O-phosphotransferase" (ID: R01138)
%         Metabolite: "Pyruvate" (ID: C00022)
%         Metabolite: "dATP" (ID: C00131)
%     Match: "ATP:propanoate phosphotransferase" (ID: R01353)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "Propanoate" (ID: C00163)
%     Match: "ATP:carbamate phosphotransferase" (ID: R01395)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "Carbamate" (ID: C01563)
%     Match: "ATP:3-phospho-D-glycerate 1-phosphotransferase" (ID: R01512)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "3-Phospho-D-glycerate" (ID: C00197)
%     Match: "ATP:dAMP phosphotransferase" (ID: R01547)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "dAMP" (ID: C00360)
%     Match: "ATP:thymidine 5'-phosphotransferase" (ID: R01567)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "Thymidine" (ID: C00214)
%     Match: "ATP:dCMP phosphotransferase" (ID: R01665)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "dCMP" (ID: C00239)
%     Match: "ATP:pyridoxine 5'-phosphotransferase" (ID: R01909)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "Pyridoxine" (ID: C00314)
%     Match: "ATP:deoxyguanosine 5'-phosphotransferase" (ID: R01967)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "Deoxyguanosine" (ID: C00330)
%     Match: "ATP:D-fructose-1-phosphate 6-phosphotransferase" (ID: R02071_EXP_1)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "D-Fructose 1-phosphate" (ID: C01094)
%     Match: "ATP:deoxyadenosine 5'-phosphotransferase" (ID: R02089)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "Deoxyadenosine" (ID: C00559)
%     Match: "ATP:dTMP phosphotransferase" (ID: R02094)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "dTMP" (ID: C00364)
%     Match: "ATP:dUMP phosphotransferase" (ID: R02098)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "dUMP" (ID: C00365)
%     Match: "ATP:deoxyuridine 5'-phosphotransferase" (ID: R02099)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "Deoxyuridine" (ID: C00526)
%     Match: "ATP:1,2-diacylglycerol 3-phosphotransferase" (ID: R02240)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "1,2-Diacyl-sn-glycerol" (ID: C00641)
%     Match: "ATP:pyridoxal 5'-phosphotransferase" (ID: R02493)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "Pyridoxamine" (ID: C00534)
%     Match: "ATP:pantothenate 4'-phosphotransferase" (ID: R02971)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "Pantetheine" (ID: C00831)
%     Match: "ATP:nicotinamide-nucleotide adenylyltransferase" (ID: R03005)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "Nicotinate D-ribonucleotide" (ID: C01185)
%     Match: "ATP:pantothenate 4'-phosphotransferase" (ID: R03018)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "Pantothenate" (ID: C00864)
%     Match: "ATP:pantetheine-4'-phosphate adenylyltransferase" (ID: R03035)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "Pantetheine 4'-phosphate" (ID: C01134)
%     Match: "ATP:D-tagatose-6-phosphate 1-phosphotransferase" (ID: R03236)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "D-Tagatose 6-phosphate" (ID: C01097)
%     Match: "ATP:(R)-5-phosphomevalonate phosphotransferase" (ID: R03245)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "(R)-5-Phosphomevalonate" (ID: C01107)
%     Match: "ATP:6-hydroxymethyl-7,8-dihydropterin 6'-diphosphotransferase" (ID: R03503)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "6-(Hydroxymethyl)-7,8-dihydropterin" (ID: C01300)
%     Match: "ATP:pantothenate 4'-phosphotransferase" (ID: R04391)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "N-((R)-Pantothenoyl)-L-cysteine" (ID: C04079)
%     Match: "ATP:L-selenomethione S-adenosyltransferase" (ID: R04771)
%         Metabolite: "H2O" (ID: C00001)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "L-Selenomethionine" (ID: C05335)
%     Match: "ATP:D-fructose-6-phosphate 1-phosphotransferase" (ID: R04779)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "beta-D-Fructose 6-phosphate" (ID: C05345)
%     Match: "ATP:5-fluorouridine 5'-phosphotransferase" (ID: R08232)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "5-Fluorouridine" (ID: C16633)
%     Match: "ATP:5-fluorodeoxyuridine 5'-phosphotransferase" (ID: R08233)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "5-Fluorodeoxyuridine" (ID: C11736)
%     Match: "CTP,CTP,ATP:tRNA cytidylyl,cytidylyl,adenylyltransferase" (ID: R09382)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "CTP" (ID: C00063)
%         Metabolite: "tRNA precursor" (ID: C02211)
%     Match: "ATP:tRNA adenylyltransferase" (ID: R09386)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "tRNA with a 3' CC end" (ID: C19080)
%     Match: "ATP:L-threonyl,bicarbonate adenylyltransferase" (ID: R10463)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "H+" (ID: C00080)
%         Metabolite: "L-Threonine" (ID: C00188)
%         Metabolite: "HCO3-" (ID: C00288)
%     Match: "ATP:HCO3- phosphotransferase" (ID: R10948)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "HCO3-" (ID: C00288)
%     Match: "ATP:formate 2'-oxidoreductase" (ID: R11634)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "Formate" (ID: C00058)
%     Match: "ATP:pyruvate,water phosphotransferase" (ID: R00199)
%         Metabolite: "H2O" (ID: C00001)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "Pyruvate" (ID: C00022)
%     Match: "ATP:pyruvate,phosphate phosphotransferase" (ID: R00206)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "Orthophosphate" (ID: C00009)
%         Metabolite: "Pyruvate" (ID: C00022)
%     Match: "ATP:GMP phosphotransferase" (ID: R00332)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "GMP" (ID: C00144)
%     Match: "ATP:D-ribose 5-phosphotransferase" (ID: R01051)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "D-Ribose" (ID: C00121)
%     Match: "ATP:D-glucosamine 6-phosphotransferase" (ID: R01961)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "D-Glucosamine" (ID: C00329)
%     Match: "ATP:dGMP phosphotransferase" (ID: R02090)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "dGMP" (ID: C00362)
%     Match: "ATP:(R)-mevalonate 5-phosphotransferase" (ID: R02245)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "(R)-Mevalonate" (ID: C00418)
%     Match: "ATP:2-deoxy-D-ribose 5-phosphotransferase" (ID: R02750)
%         Metabolite: "ADP" (ID: C00008)
%         Metabolite: "2-Deoxy-D-ribose 5-phosphate" (ID: C00673)
%     Match: "ATP:methylphosphonate 5-triphosphoribosyltransferase" (ID: R10185)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "Methylphosphonate" (ID: C20396)
% Precursor "GTP" → 8 matches found
%     Match: "ATP:GTP 3'-diphosphotransferase" (ID: R00429)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "GTP" (ID: C00044)
%     Match: "GTP:pyruvate 2-O-phosphotransferase" (ID: R00430)
%         Metabolite: "Pyruvate" (ID: C00022)
%         Metabolite: "GTP" (ID: C00044)
%     Match: "GTP:cytidine 5'-phosphotransferase" (ID: R00517)
%         Metabolite: "GTP" (ID: C00044)
%         Metabolite: "Cytidine" (ID: C00475)
%     Match: "GTP:uridine 5'-phosphotransferase" (ID: R00968)
%         Metabolite: "GTP" (ID: C00044)
%         Metabolite: "Uridine" (ID: C00299)
%     Match: "dGTP:pyruvate 2-O-phosphotransferase" (ID: R01858)
%         Metabolite: "Pyruvate" (ID: C00022)
%         Metabolite: "dGTP" (ID: C00286)
%     Match: "GTP:formate 2'-oxidoreductase" (ID: R11633)
%         Metabolite: "GTP" (ID: C00044)
%         Metabolite: "Formate" (ID: C00058)
%     Match: "GTP 7,8-8,9-dihydrolase" (ID: R00424)
%         Metabolite: "H2O" (ID: C00001)
%         Metabolite: "GTP" (ID: C00044)
%     Match: "GTP 8,9-hydrolase" (ID: R00428)
%         Metabolite: "H2O" (ID: C00001)
%         Metabolite: "GTP" (ID: C00044)
% Precursor "CTP" → 7 matches found
%     Match: "CTP:sn-glycerol-3-phosphate cytidylyltransferase" (ID: R00856)
%         Metabolite: "CTP" (ID: C00063)
%         Metabolite: "sn-Glycerol 3-phosphate" (ID: C00093)
%     Match: "CTP:phosphatidate cytidyltransferase" (ID: R01799)
%         Metabolite: "CTP" (ID: C00063)
%         Metabolite: "Phosphatidate" (ID: C00416)
%     Match: "CTP:D-tagatose 6-phosphate 1-phosphotransferase" (ID: R03237)
%         Metabolite: "CTP" (ID: C00063)
%         Metabolite: "D-Tagatose 6-phosphate" (ID: C01097)
%     Match: "CTP,CTP,ATP:tRNA cytidylyl,cytidylyl,adenylyltransferase" (ID: R09382)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "CTP" (ID: C00063)
%         Metabolite: "tRNA precursor" (ID: C02211)
%     Match: "CTP:tRNA cytidylyltransferase" (ID: R09383)
%         Metabolite: "CTP" (ID: C00063)
%         Metabolite: "tRNA precursor" (ID: C02211)
%     Match: "CTP:tRNA cytidylyltransferase" (ID: R09384)
%         Metabolite: "CTP" (ID: C00063)
%         Metabolite: "tRNA with a 3' cytidine" (ID: C19078)
%     Match: "CTP:formate 2'-oxidoreductase" (ID: R11636)
%         Metabolite: "Formate" (ID: C00058)
%         Metabolite: "CTP" (ID: C00063)
% Precursor "UTP" → 7 matches found
%     Match: "UTP:alpha-D-glucose-1-phosphate uridylyltransferase" (ID: R00289)
%         Metabolite: "UTP" (ID: C00075)
%         Metabolite: "D-Glucose 1-phosphate" (ID: C00103)
%     Match: "UTP:N-acetyl-alpha-D-glucosamine-1-phosphate uridylyltransferase" (ID: R00416)
%         Metabolite: "UTP" (ID: C00075)
%         Metabolite: "N-Acetyl-alpha-D-glucosamine 1-phosphate" (ID: C04501)
%     Match: "UTP:ammonia ligase (ADP-forming)" (ID: R00571)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "Ammonia" (ID: C00014)
%         Metabolite: "UTP" (ID: C00075)
%     Match: "UTP:L-glutamine amido-ligase (ADP-forming)" (ID: R00573)
%         Metabolite: "H2O" (ID: C00001)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "L-Glutamine" (ID: C00064)
%         Metabolite: "UTP" (ID: C00075)
%     Match: "dUTP nucleotidohydrolase" (ID: R02100)
%         Metabolite: "H2O" (ID: C00001)
%         Metabolite: "dUTP" (ID: C00460)
%     Match: "UTP:D-tagatose 6-phosphate 1-phosphotransferase" (ID: R03238)
%         Metabolite: "UTP" (ID: C00075)
%         Metabolite: "D-Tagatose 6-phosphate" (ID: C01097)
%     Match: "UTP:formate 2'-oxidoreductase" (ID: R11635)
%         Metabolite: "Formate" (ID: C00058)
%         Metabolite: "UTP" (ID: C00075)
% Precursor "NAD" → 51 matches found
%     Match: "ATP:NAD+ 2'-phosphotransferase" (ID: R00104)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "NAD+" (ID: C00003)
%     Match: "deamido-NAD+:ammonia ligase (AMP-forming)" (ID: R00189)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "Ammonia" (ID: C00014)
%         Metabolite: "Deamino-NAD+" (ID: C00857)
%     Match: "acetaldehyde:NAD+ oxidoreductase (CoA-acetylating)" (ID: R00228)
%         Metabolite: "NAD+" (ID: C00003)
%         Metabolite: "CoA" (ID: C00010)
%         Metabolite: "Acetaldehyde" (ID: C00084)
%     Match: "(S)-Lactate:NAD+ oxidoreductase" (ID: R00703)
%         Metabolite: "NAD+" (ID: C00003)
%         Metabolite: "(S)-Lactate" (ID: C00186)
%     Match: "ethanol:NAD+ oxidoreductase" (ID: R00754)
%         Metabolite: "NAD+" (ID: C00003)
%         Metabolite: "Ethanol" (ID: C00469)
%     Match: "D-glucose-6-phosphate:NADP+ 1-oxidoreductase" (ID: R00835)
%         Metabolite: "NADP+" (ID: C00006)
%         Metabolite: "D-Glucose 6-phosphate" (ID: C00092)
%     Match: "sn-Glycerol-3-phosphate:NAD+ 2-oxidoreductase" (ID: R00842)
%         Metabolite: "NAD+" (ID: C00003)
%         Metabolite: "sn-Glycerol 3-phosphate" (ID: C00093)
%     Match: "sn-Glycerol-3-phosphate:NADP+ 2-oxidoreductase" (ID: R00844)
%         Metabolite: "NADP+" (ID: C00006)
%         Metabolite: "sn-Glycerol 3-phosphate" (ID: C00093)
%     Match: "D-Glucitol:NAD+ 2-oxidoreductase" (ID: R00875)
%         Metabolite: "NAD+" (ID: C00003)
%         Metabolite: "D-Sorbitol" (ID: C00794)
%     Match: "5,6,7,8-tetrahydrofolate:NAD+ oxidoreductase" (ID: R00936)
%         Metabolite: "NAD+" (ID: C00003)
%         Metabolite: "Tetrahydrofolate" (ID: C00101)
%     Match: "5,6,7,8-tetrahydrofolate:NAD+ oxidoreductase" (ID: R00937)
%         Metabolite: "NAD+" (ID: C00003)
%         Metabolite: "Tetrahydrofolate" (ID: C00101)
%     Match: "5,6,7,8-tetrahydrofolate:NADP+ oxidoreductase" (ID: R00939)
%         Metabolite: "NADP+" (ID: C00006)
%         Metabolite: "Tetrahydrofolate" (ID: C00101)
%     Match: "5,6,7,8-tetrahydrofolate:NADP+ oxidoreductase" (ID: R00940)
%         Metabolite: "NADP+" (ID: C00006)
%         Metabolite: "Tetrahydrofolate" (ID: C00101)
%     Match: "2-hydroxybutyrate:NAD+ oxidoreductase" (ID: R01000)
%         Metabolite: "NAD+" (ID: C00003)
%         Metabolite: "2-Hydroxybutanoic acid" (ID: C05984)
%     Match: "D-glyceraldehyde-3-phosphate:NAD+ oxidoreductase (phosphorylating)" (ID: R01061)
%         Metabolite: "NAD+" (ID: C00003)
%         Metabolite: "Orthophosphate" (ID: C00009)
%         Metabolite: "D-Glyceraldehyde 3-phosphate" (ID: C00118)
%     Match: "IMP:NAD+ oxidoreductase" (ID: R01130)
%         Metabolite: "H2O" (ID: C00001)
%         Metabolite: "NAD+" (ID: C00003)
%         Metabolite: "IMP" (ID: C00130)
%     Match: "inosine-5'-phosphate:NADP+ oxidoreductase (aminating);" (ID: R01134)
%         Metabolite: "NADP+" (ID: C00006)
%         Metabolite: "Ammonia" (ID: C00014)
%         Metabolite: "IMP" (ID: C00130)
%     Match: "butanal:NAD+ oxidoreductase (CoA-acylating)" (ID: R01172)
%         Metabolite: "NAD+" (ID: C00003)
%         Metabolite: "CoA" (ID: C00010)
%         Metabolite: "Butanal" (ID: C01412)
%     Match: "5,10-methylenetetrahydrofolate:NADP+ oxidoreductase" (ID: R01220)
%         Metabolite: "NADP+" (ID: C00006)
%         Metabolite: "5,10-Methylenetetrahydrofolate" (ID: C00143)
%     Match: "6-phospho-D-gluconate:NADP+ 2-oxidoreductase (decarboxylating)" (ID: R01528)
%         Metabolite: "NADP+" (ID: C00006)
%         Metabolite: "6-Phospho-D-gluconate" (ID: C00345)
%     Match: "xylitol:NAD+ 2-oxidoreductase (D-xylulose-forming)" (ID: R01896)
%         Metabolite: "NAD+" (ID: C00003)
%         Metabolite: "Xylitol" (ID: C00379)
%     Match: "NADPH:oxidized-thioredoxin oxidoreductase" (ID: R02016)
%         Metabolite: "NADP+" (ID: C00006)
%         Metabolite: "Thioredoxin" (ID: C00342)
%     Match: "(R)-Mevalonate:NAD+ oxidoreductase (CoA-acetylating)" (ID: R02081)
%         Metabolite: "NAD+" (ID: C00003)
%         Metabolite: "CoA" (ID: C00010)
%         Metabolite: "(R)-Mevalonate" (ID: C00418)
%     Match: "dihydrofolate:NAD+ oxidoreductase" (ID: R02235)
%         Metabolite: "NAD+" (ID: C00003)
%         Metabolite: "Dihydrofolate" (ID: C00415)
%     Match: "dihydrofolate:NADP+ oxidoreductase" (ID: R02236)
%         Metabolite: "NADP+" (ID: C00006)
%         Metabolite: "Dihydrofolate" (ID: C00415)
%     Match: "beta-D-glucose-6-phosphate:NADP+ 1-oxoreductase" (ID: R02736)
%         Metabolite: "NADP+" (ID: C00006)
%         Metabolite: "beta-D-Glucose 6-phosphate" (ID: C01172)
%     Match: "3-Mercaptolactate:NAD+ oxidoreductase" (ID: R03104)
%         Metabolite: "NAD+" (ID: C00003)
%         Metabolite: "3-Mercaptolactate" (ID: C05823)
%     Match: "UDP-N-acetylmuramate:NADP+ oxidoreductase" (ID: R03191)
%         Metabolite: "NAD+" (ID: C00003)
%         Metabolite: "UDP-N-acetylmuramate" (ID: C01050)
%     Match: "UDP-N-acetylmuramate:NADP+ oxidoreductase" (ID: R03192)
%         Metabolite: "NADP+" (ID: C00006)
%         Metabolite: "UDP-N-acetylmuramate" (ID: C01050)
%     Match: "hydrogen selenide:NADP+ oxidoreductase" (ID: R03596)
%         Metabolite: "H2O" (ID: C00001)
%         Metabolite: "NADP+" (ID: C00006)
%         Metabolite: "Hydrogen selenide" (ID: C01528)
%     Match: "3,4-dihydroxyphenylethyleneglycol:NAD+ oxidoreductase" (ID: R04880)
%         Metabolite: "NAD+" (ID: C00003)
%         Metabolite: "3,4-Dihydroxyphenylethyleneglycol" (ID: C05576)
%     Match: "trans-3-Chloro-2-propene-1-ol:NAD+ oxidoreductase" (ID: R05233)
%         Metabolite: "NAD+" (ID: C00003)
%         Metabolite: "trans-3-Chloro-2-propene-1-ol" (ID: C06611)
%     Match: "cis-3-chloro-2-propene-1-ol:NAD+ oxidoreductase" (ID: R05234)
%         Metabolite: "NAD+" (ID: C00003)
%         Metabolite: "cis-3-Chloro-2-propene-1-ol" (ID: C06612)
%     Match: "FMNH2:NAD+ oxidoreductase" (ID: R05705)
%         Metabolite: "NAD+" (ID: C00003)
%         Metabolite: "Reduced FMN" (ID: C01847)
%     Match: "1-hydroxymethylnaphthalene:NAD+ oxidoreductase" (ID: R06917)
%         Metabolite: "NAD+" (ID: C00003)
%         Metabolite: "1-Hydroxymethylnaphthalene" (ID: C14089)
%     Match: "(2-naphthyl)methanol:NAD+ oxidoreductase" (ID: R06927)
%         Metabolite: "NAD+" (ID: C00003)
%         Metabolite: "(2-Naphthyl)methanol" (ID: C02909)
%     Match: "6-thioinosine 5'-monophosphate:NAD+ oxidoreductase" (ID: R08240)
%         Metabolite: "H2O" (ID: C00001)
%         Metabolite: "NAD+" (ID: C00003)
%         Metabolite: "6-Thioinosine-5'-monophosphate" (ID: C04646)
%     Match: "methaneselenol:NADP+ oxidoreductase" (ID: R09372)
%         Metabolite: "NADPH" (ID: C00005)
%         Metabolite: "H+" (ID: C00080)
%         Metabolite: "Methylselenic acid" (ID: C18902)
%     Match: "FADH2:NAD+ oxidoreductase" (ID: R09748)
%         Metabolite: "NAD+" (ID: C00003)
%         Metabolite: "FADH2" (ID: C01352)
%     Match: "reduced-riboflavin:NAD+ oxidoreductase" (ID: R09750)
%         Metabolite: "NAD+" (ID: C00003)
%         Metabolite: "Reduced riboflavin" (ID: C01007)
%     Match: "6-phospho-D-gluconate:NAD+ 2-oxidoreductase (decarboxylating)" (ID: R10221)
%         Metabolite: "NAD+" (ID: C00003)
%         Metabolite: "6-Phospho-D-gluconate" (ID: C00345)
%     Match: "beta-D-glucose-6-phosphate:NAD+ 1-oxidoreductase" (ID: R10907)
%         Metabolite: "NAD+" (ID: C00003)
%         Metabolite: "beta-D-Glucose 6-phosphate" (ID: C01172)
%     Match: "tetrahydrobiopterin:NADP+ oxidoreductase (7,8-dihydrobiopterin-forming)" (ID: R11765)
%         Metabolite: "NADP+" (ID: C00006)
%         Metabolite: "Tetrahydrobiopterin" (ID: C00272)
%     Match: "liquiritigenin,[reduced NADPH---hemoprotein reductase]:oxygen oxidoreductase (licodione-forming)" (ID: R07198)
%         Metabolite: "Oxygen" (ID: C00007)
%         Metabolite: "[Reduced NADPH---hemoprotein reductase]" (ID: C03024)
%         Metabolite: "Liquiritigenin" (ID: C09762)
%     Match: "(S)-dihydroorotate:NAD+ oxidoreductase" (ID: R01869)
%         Metabolite: "NAD+" (ID: C00003)
%         Metabolite: "(S)-Dihydroorotate" (ID: C00337)
%     Match: "rubredoxin:NAD+ oxidoreductase" (ID: R02000)
%         Metabolite: "NAD+" (ID: C00003)
%         Metabolite: "H+" (ID: C00080)
%         Metabolite: "Reduced rubredoxin" (ID: C00340)
%     Match: "3-phenylpropanoate,NADH:oxygen oxidoreductase (2,3-hydroxylating)" (ID: R06782)
%         Metabolite: "NADH" (ID: C00004)
%         Metabolite: "Oxygen" (ID: C00007)
%         Metabolite: "H+" (ID: C00080)
%         Metabolite: "Phenylpropanoate" (ID: C05629)
%     Match: "trans-cinnamate,NADH:oxygen oxidoreductase (2,3-hydroxylating)" (ID: R06783)
%         Metabolite: "NADH" (ID: C00004)
%         Metabolite: "Oxygen" (ID: C00007)
%         Metabolite: "H+" (ID: C00080)
%         Metabolite: "trans-Cinnamate" (ID: C00423)
%     Match: "3-hydroxypropionate:NADP+ oxidoreductase" (ID: R09289)
%         Metabolite: "NADP+" (ID: C00006)
%         Metabolite: "3-Hydroxypropanoate" (ID: C01013)
%     Match: "L-allo-threonine:NADP+ 3-oxidoreductase" (ID: R10851)
%         Metabolite: "NADP+" (ID: C00006)
%         Metabolite: "L-Allothreonine" (ID: C05519)
%     Match: "L-allo-threonine:NADP+ 3-oxidoreductase (decarboxylating)" (ID: R10852)
%         Metabolite: "NADP+" (ID: C00006)
%         Metabolite: "L-Allothreonine" (ID: C05519)
% Precursor "NADP" → 19 matches found
%     Match: "D-glucose-6-phosphate:NADP+ 1-oxidoreductase" (ID: R00835)
%         Metabolite: "NADP+" (ID: C00006)
%         Metabolite: "D-Glucose 6-phosphate" (ID: C00092)
%     Match: "sn-Glycerol-3-phosphate:NADP+ 2-oxidoreductase" (ID: R00844)
%         Metabolite: "NADP+" (ID: C00006)
%         Metabolite: "sn-Glycerol 3-phosphate" (ID: C00093)
%     Match: "5,6,7,8-tetrahydrofolate:NADP+ oxidoreductase" (ID: R00939)
%         Metabolite: "NADP+" (ID: C00006)
%         Metabolite: "Tetrahydrofolate" (ID: C00101)
%     Match: "5,6,7,8-tetrahydrofolate:NADP+ oxidoreductase" (ID: R00940)
%         Metabolite: "NADP+" (ID: C00006)
%         Metabolite: "Tetrahydrofolate" (ID: C00101)
%     Match: "inosine-5'-phosphate:NADP+ oxidoreductase (aminating);" (ID: R01134)
%         Metabolite: "NADP+" (ID: C00006)
%         Metabolite: "Ammonia" (ID: C00014)
%         Metabolite: "IMP" (ID: C00130)
%     Match: "5,10-methylenetetrahydrofolate:NADP+ oxidoreductase" (ID: R01220)
%         Metabolite: "NADP+" (ID: C00006)
%         Metabolite: "5,10-Methylenetetrahydrofolate" (ID: C00143)
%     Match: "6-phospho-D-gluconate:NADP+ 2-oxidoreductase (decarboxylating)" (ID: R01528)
%         Metabolite: "NADP+" (ID: C00006)
%         Metabolite: "6-Phospho-D-gluconate" (ID: C00345)
%     Match: "NADPH:oxidized-thioredoxin oxidoreductase" (ID: R02016)
%         Metabolite: "NADP+" (ID: C00006)
%         Metabolite: "Thioredoxin" (ID: C00342)
%     Match: "dihydrofolate:NADP+ oxidoreductase" (ID: R02236)
%         Metabolite: "NADP+" (ID: C00006)
%         Metabolite: "Dihydrofolate" (ID: C00415)
%     Match: "beta-D-glucose-6-phosphate:NADP+ 1-oxoreductase" (ID: R02736)
%         Metabolite: "NADP+" (ID: C00006)
%         Metabolite: "beta-D-Glucose 6-phosphate" (ID: C01172)
%     Match: "UDP-N-acetylmuramate:NADP+ oxidoreductase" (ID: R03191)
%         Metabolite: "NAD+" (ID: C00003)
%         Metabolite: "UDP-N-acetylmuramate" (ID: C01050)
%     Match: "UDP-N-acetylmuramate:NADP+ oxidoreductase" (ID: R03192)
%         Metabolite: "NADP+" (ID: C00006)
%         Metabolite: "UDP-N-acetylmuramate" (ID: C01050)
%     Match: "hydrogen selenide:NADP+ oxidoreductase" (ID: R03596)
%         Metabolite: "H2O" (ID: C00001)
%         Metabolite: "NADP+" (ID: C00006)
%         Metabolite: "Hydrogen selenide" (ID: C01528)
%     Match: "methaneselenol:NADP+ oxidoreductase" (ID: R09372)
%         Metabolite: "NADPH" (ID: C00005)
%         Metabolite: "H+" (ID: C00080)
%         Metabolite: "Methylselenic acid" (ID: C18902)
%     Match: "tetrahydrobiopterin:NADP+ oxidoreductase (7,8-dihydrobiopterin-forming)" (ID: R11765)
%         Metabolite: "NADP+" (ID: C00006)
%         Metabolite: "Tetrahydrobiopterin" (ID: C00272)
%     Match: "liquiritigenin,[reduced NADPH---hemoprotein reductase]:oxygen oxidoreductase (licodione-forming)" (ID: R07198)
%         Metabolite: "Oxygen" (ID: C00007)
%         Metabolite: "[Reduced NADPH---hemoprotein reductase]" (ID: C03024)
%         Metabolite: "Liquiritigenin" (ID: C09762)
%     Match: "3-hydroxypropionate:NADP+ oxidoreductase" (ID: R09289)
%         Metabolite: "NADP+" (ID: C00006)
%         Metabolite: "3-Hydroxypropanoate" (ID: C01013)
%     Match: "L-allo-threonine:NADP+ 3-oxidoreductase" (ID: R10851)
%         Metabolite: "NADP+" (ID: C00006)
%         Metabolite: "L-Allothreonine" (ID: C05519)
%     Match: "L-allo-threonine:NADP+ 3-oxidoreductase (decarboxylating)" (ID: R10852)
%         Metabolite: "NADP+" (ID: C00006)
%         Metabolite: "L-Allothreonine" (ID: C05519)
% Precursor "FAD" → 1 matches found
%     Match: "FADH2:NAD+ oxidoreductase" (ID: R09748)
%         Metabolite: "NAD+" (ID: C00003)
%         Metabolite: "FADH2" (ID: C01352)
% Precursor "CoA" → 21 matches found
%     Match: "ATP:dephospho-CoA 3'-phosphotransferase" (ID: R00130)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "Dephospho-CoA" (ID: C00882)
%     Match: "acetaldehyde:NAD+ oxidoreductase (CoA-acetylating)" (ID: R00228)
%         Metabolite: "NAD+" (ID: C00003)
%         Metabolite: "CoA" (ID: C00010)
%         Metabolite: "Acetaldehyde" (ID: C00084)
%     Match: "acetyl-CoA:phosphate acetyltransferase" (ID: R00230)
%         Metabolite: "Orthophosphate" (ID: C00009)
%         Metabolite: "Acetyl-CoA" (ID: C00024)
%     Match: "acetyl-CoA:acetyl-CoA C-acetyltransferase" (ID: R00238)
%         Metabolite: "Acetyl-CoA" (ID: C00024)
%     Match: "propanoyl-CoA:phosphate propanoyltransferase" (ID: R00921)
%         Metabolite: "Orthophosphate" (ID: C00009)
%         Metabolite: "Propanoyl-CoA" (ID: C00100)
%     Match: "butanal:NAD+ oxidoreductase (CoA-acylating)" (ID: R01172)
%         Metabolite: "NAD+" (ID: C00003)
%         Metabolite: "CoA" (ID: C00010)
%         Metabolite: "Butanal" (ID: C01412)
%     Match: "butanoyl-CoA:acetyl-CoA C-butanoyltransferase" (ID: R01177)
%         Metabolite: "Acetyl-CoA" (ID: C00024)
%         Metabolite: "Butanoyl-CoA" (ID: C00136)
%     Match: "CoA:apo-[acyl-carrier-protein] pantetheinephosphotransferase" (ID: R01625)
%         Metabolite: "CoA" (ID: C00010)
%         Metabolite: "Apo-[acyl-carrier-protein]" (ID: C03688)
%     Match: "acetyl-CoA:acetoacetyl-CoA C-acetyltransferase (thioester-hydrolysing, carboxymethyl-forming)" (ID: R01978)
%         Metabolite: "CoA" (ID: C00010)
%         Metabolite: "(S)-3-Hydroxy-3-methylglutaryl-CoA" (ID: C00356)
%     Match: "(R)-Mevalonate:NAD+ oxidoreductase (CoA-acetylating)" (ID: R02081)
%         Metabolite: "NAD+" (ID: C00003)
%         Metabolite: "CoA" (ID: C00010)
%         Metabolite: "(R)-Mevalonate" (ID: C00418)
%     Match: "acyl-CoA:1-acyl-sn-glycerol-3-phosphate 2-O-acyltransferase" (ID: R02241)
%         Metabolite: "CoA" (ID: C00010)
%         Metabolite: "Phosphatidate" (ID: C00416)
%     Match: "Acetyl-CoA:D-glucosamine-1-phosphate N-acetyltransferase" (ID: R05332)
%         Metabolite: "Acetyl-CoA" (ID: C00024)
%         Metabolite: "alpha-D-Glucosamine 1-phosphate" (ID: C06156)
%     Match: "succinyl-CoA:acetyl-CoA C-acyltransferase;" (ID: R00829)
%         Metabolite: "Acetyl-CoA" (ID: C00024)
%         Metabolite: "Succinyl-CoA" (ID: C00091)
%     Match: "acetyl-CoA:propanoyl-CoA 2-C-acetyltransferase;" (ID: R00927)
%         Metabolite: "Acetyl-CoA" (ID: C00024)
%         Metabolite: "Propanoyl-CoA" (ID: C00100)
%     Match: "Octanoyl-CoA:acetyl-CoA C-acyltransferase" (ID: R03778)
%         Metabolite: "Acetyl-CoA" (ID: C00024)
%         Metabolite: "Octanoyl-CoA" (ID: C01944)
%     Match: "Lauroyl-CoA:acetyl-CoA C-acyltransferase" (ID: R03858)
%         Metabolite: "Acetyl-CoA" (ID: C00024)
%         Metabolite: "Lauroyl-CoA" (ID: C01832)
%     Match: "myristoyl-CoA:acetylCoA C-myristoyltransferase" (ID: R03991)
%         Metabolite: "Acetyl-CoA" (ID: C00024)
%         Metabolite: "Tetradecanoyl-CoA" (ID: C02593)
%     Match: "Decanoyl-CoA:acetyl-CoA C-acyltransferase" (ID: R04742)
%         Metabolite: "Acetyl-CoA" (ID: C00024)
%         Metabolite: "Decanoyl-CoA" (ID: C05274)
%     Match: "Hexanoyl-CoA:acetyl-CoA C-acyltransferase" (ID: R04747)
%         Metabolite: "Acetyl-CoA" (ID: C00024)
%         Metabolite: "Hexanoyl-CoA" (ID: C05270)
%     Match: "7-methyl-3-oxo-6-octenoyl-CoA:acetyl-CoA C-acyltransferase" (ID: R08091)
%         Metabolite: "CoA" (ID: C00010)
%         Metabolite: "7-Methyl-3-oxo-6-octenoyl-CoA" (ID: C16466)
%     Match: "3-methylcrotonyl-CoA:acetyl-CoA C-acyltransferase" (ID: R08095)
%         Metabolite: "CoA" (ID: C00010)
%         Metabolite: "5-Methyl-3-oxo-4-hexenoyl-CoA" (ID: C16471)
% Precursor "Heme" → 1 matches found
%     Match: "protoheme ferro-lyase (protoporphyrin-forming)" (ID: R00310)
%         Metabolite: "Protoporphyrin" (ID: C02191)
%         Metabolite: "Fe2+" (ID: C14818)
% Precursor "Peptidoglycan" → no matches found
% Precursor "Lipoteichoic acid" → no matches found
% Precursor "Phosphatidylglycerol" → 2 matches found
%     Match: "Phosphatidylglycerol:membrane-derived-oligosaccharide-D-glucose glycerophosphotransferase" (ID: R05081)
%         Metabolite: "Phosphatidylglycerol" (ID: C00344)
%         Metabolite: "Diglucosyldiacylglycerol" (ID: C06040)
%     Match: "phosphatidylglycerol:Glc-alpha1->2Glc-alpha1->3acyl2Gro glycerophosphotransferase" (ID: R10849)
%         Metabolite: "Phosphatidylglycerol" (ID: C00344)
%         Metabolite: "alpha-Kojibiosyldiacylglycerol" (ID: C06365)
% Precursor "Cardiolipin" → no matches found
% Warning: Repeated mets in the formula for rxn 'BIOMASS_ps'. Combine the stoichiometry.
% test
% CSV table saved to "Liners_biomass_metabolites.csv"
% Added biomass reaction "BIOMASS_ps" with 547 metabolite entries (duplicates kept).

% %% [markdown]
% Quick cleaning to ensure RAVEN structures are correctly kept:

% %%
LinersBiomassDraftModel = syncModelStruct(LinersBiomassDraftModel, 'Liners_biomass_sync_log.csv');
% Out:
% syncModelStruct: Log saved to "Liners_biomass_sync_log.csv"

% %%
checkModelCoreConsistency(LinersBiomassDraftModel);
% Out:
% --- BASIC DIMENSION CHECKS ---
% Reactions: 574
% Metabolites: 825
% Genes: 437
% Empty grRules in 145 reactions

% %%
LinersBiomassDraftModel = sanitizeGEMforSBML(LinersBiomassDraftModel);
LinersBiomassDraftModel = fixRxnConfidenceScores(LinersBiomassDraftModel);

% %% [markdown]
% I will now save the new model with the biomass reaction included:

% %%
exportModel(LinersBiomassDraftModel, 'Liners_draftGEM_v3.xml');
% Out:
% Document written

% %%
exportToExcelFormat(LinersBiomassDraftModel, 'Liners_draftGEM_v3.xlsx');
save('Liners_draftGEM_v3.mat', 'LinersBiomassDraftModel');

% %% [markdown]
% Now that a biomass reaction has been added to the model, I will try to solve again:

% %%
%LinersBiomassDraftModel = importModel('Liners_draftGEM_v3.xml');
sol2 = solveLP(LinersBiomassDraftModel);
disp(sol2.f)
% Out:
%      0

% %% [markdown]
% Still 0, so still no growth.
%
% ## Addition of exchange reactions
%
% The simplified gap report:

% %%
% taking a look at the gap situation
%gapReport(LinersBiomassDraftModel);
gapReport_vSimple(LinersBiomassDraftModel);
% Out:
% Dead-end metabolites: 461
%     {'C00018'}
%     {'C00026'}
%     {'C00032'}
%     {'C00036'}
%     {'C00040'}
%     {'C00053'}
%     {'C00071'}
%     {'C00083'}
%     {'C00088'}
%     {'C00094'}
%     {'C00104'}
%     {'C00127'}
%     {'C00132'}
%     {'C00140'}
%     {'C00155'}
%     {'C00159'}
%     {'C00170'}
%     {'C00184'}
%     {'C00201'}
%     {'C00224'}
%     {'C00233'}
%     {'C00237'}
%     {'C00253'}
%     {'C00262'}
%     {'C00263'}
%     {'C00310'}
%     {'C00353'}
%     {'C00363'}
%     {'C00378'}
%     {'C00395'}
%     {'C00402'}
%     {'C00447'}
%     {'C00450'}
%     {'C00454'}
%     {'C00458'}
%     {'C00577'}
%     {'C00620'}
%     {'C00627'}
%     {'C00647'}
%     {'C00653'}
%     {'C00680'}
%     {'C00700'}
%     {'C00718'}
%     {'C00721'}
%     {'C00842'}
%     {'C00957'}
%     {'C00973'}
%     {'C01019'}
%     {'C01024'}
%     {'C01041'}
%     {'C01096'}
%     {'C01133'}
%     {'C01252'}
%     {'C01297'}
%     {'C01345'}
%     {'C01419'}
%     {'C01424'}
%     {'C01451'}
%     {'C01471'}
%     {'C01592'}
%     {'C01637'}
%     {'C01642'}
%     {'C01717'}
%     {'C01752'}
%     {'C01931'}
%     {'C02047'}
%     {'C02097'}
%     {'C02247'}
%     {'C02348'}
%     {'C02350'}
%     {'C02380'}
%     {'C02412'}
%     {'C02470'}
%     {'C02553'}
%     {'C02554'}
%     {'C02702'}
%     {'C02713'}
%     {'C02952'}
%     {'C02953'}
%     {'C02967'}
%     {'C02984'}
%     {'C02987'}
%     {'C02992'}
%     {'C03028'}
%     {'C03089'}
%     {'C03125'}
%     {'C03127'}
%     {'C03160'}
%     {'C03161'}
%     {'C03219'}
%     {'C03241'}
%     {'C03289'}
%     {'C03294'}
%     {'C03309'}
%     {'C03458'}
%     {'C03479'}
%     {'C03511'}
%     {'C03512'}
%     {'C03539'}
%     {'C03658'}
%     {'C03671'}
%     {'C03758'}
%     {'C03771'}
%     {'C03892'}
%     {'C03912'}
%     {'C04051'}
%     {'C04076'}
%     {'C04157'}
%     {'C04236'}
%     {'C04242'}
%     {'C04260'}
%     {'C04431'}
%     {'C04432'}
%     {'C04494'}
%     {'C04522'}
%     {'C04534'}
%     {'C04625'}
%     {'C04672'}
%     {'C04706'}
%     {'C04718'}
%     {'C04823'}
%     {'C04881'}
%     {'C05190'}
%     {'C05191'}
%     {'C05198'}
%     {'C05199'}
%     {'C05269'}
%     {'C05312'}
%     {'C05322'}
%     {'C05336'}
%     {'C05539'}
%     {'C05570'}
%     {'C05577'}
%     {'C05578'}
%     {'C05587'}
%     {'C05645'}
%     {'C05691'}
%     {'C05703'}
%     {'C05726'}
%     {'C05729'}
%     {'C05766'}
%     {'C05770'}
%     {'C05840'}
%     {'C05894'}
%     {'C05898'}
%     {'C05914'}
%     {'C05916'}
%     {'C05980'}
%     {'C06041'}
%     {'C06066'}
%     {'C06102'}
%     {'C06113'}
%     {'C06173'}
%     {'C06186'}
%     {'C06187'}
%     {'C06188'}
%     {'C06481'}
%     {'C06555'}
%     {'C06567'}
%     {'C06594'}
%     {'C06597'}
%     {'C06598'}
%     {'C06602'}
%     {'C06613'}
%     {'C06620'}
%     {'C06717'}
%     {'C06735'}
%     {'C06986'}
%     {'C07304'}
%     {'C07307'}
%     {'C07335'}
%     {'C07490'}
%     {'C07541'}
%     {'C07645'}
%     {'C07647'}
%     {'C07648'}
%     {'C08537'}
%     {'C08540'}
%     {'C08543'}
%     {'C08557'}
%     {'C08565'}
%     {'C09315'}
%     {'C09332'}
%     {'C09382'}
%     {'C09440'}
%     {'C11149'}
%     {'C11405'}
%     {'C11419'}
%     {'C11633'}
%     {'C11634'}
%     {'C11638'}
%     {'C11680'}
%     {'C11713'}
%     {'C11714'}
%     {'C11813'}
%     {'C11814'}
%     {'C11822'}
%     {'C11887'}
%     {'C11930'}
%     {'C12119'}
%     {'C12396'}
%     {'C12397'}
%     {'C14090'}
%     {'C14099'}
%     {'C14180'}
%     {'C14786'}
%     {'C14787'}
%     {'C14866'}
%     {'C14909'}
%     {'C15670'}
%     {'C15809'}
%     {'C15814'}
%     {'C15986'}
%     {'C16075'}
%     {'C16138'}
%     {'C16151'}
%     {'C16152'}
%     {'C16348'}
%     {'C16392'}
%     {'C16413'}
%     {'C16556'}
%     {'C16559'}
%     {'C16614'}
%     {'C16615'}
%     {'C16617'}
%     {'C16619'}
%     {'C16634'}
%     {'C16663'}
%     {'C16664'}
%     {'C16698'}
%     {'C17204'}
%     {'C17349'}
%     {'C17751'}
%     {'C17752'}
%     {'C17753'}
%     {'C17754'}
%     {'C17755'}
%     {'C17757'}
%     {'C17758'}
%     {'C18022'}
%     {'C18063'}
%     {'C18064'}
%     {'C18235'}
%     {'C18345'}
%     {'C18871'}
%     {'C19079'}
%     {'C19084'}
%     {'C19491'}
%     {'C19563'}
%     {'C19564'}
%     {'C19566'}
%     {'C19567'}
%     {'C19568'}
%     {'C19577'}
%     {'C19578'}
%     {'C19580'}
%     {'C19581'}
%     {'C19714'}
%     {'C19723'}
%     {'C19944'}
%     {'C20231'}
%     {'C20254'}
%     {'C20271'}
%     {'C20279'}
%     {'C20297'}
%     {'C20299'}
%     {'C20312'}
%     {'C20315'}
%     {'C20329'}
%     {'C20330'}
%     {'C20361'}
%     {'C20379'}
%     {'C20390'}
%     {'C20409'}
%     {'C20449'}
%     {'C20451'}
%     {'C20457'}
%     {'C20565'}
%     {'C20650'}
%     {'C20658'}
%     {'C20729'}
%     {'C20836'}
%     {'C20852'}
%     {'C20853'}
%     {'C20858'}
%     {'C20897'}
%     {'C20899'}
%     {'C20900'}
%     {'C20901'}
%     {'C20906'}
%     {'C20937'}
%     {'C21008'}
%     {'C21026'}
%     {'C21065'}
%     {'C21075'}
%     {'C21140'}
%     {'C21142'}
%     {'C21152'}
%     {'C21154'}
%     {'C21192'}
%     {'C21214'}
%     {'C21284'}
%     {'C21408'}
%     {'C21410'}
%     {'C21412'}
%     {'C21437'}
%     {'C21442'}
%     {'C21459'}
%     {'C21476'}
%     {'C21582'}
%     {'C21589'}
%     {'C21590'}
%     {'C21599'}
%     {'C21600'}
%     {'C21620'}
%     {'C21622'}
%     {'C21623'}
%     {'C21731'}
%     {'C21751'}
%     {'C21787'}
%     {'C21873'}
%     {'C21897'}
%     {'C21922'}
%     {'C21923'}
%     {'C21930'}
%     {'C22050'}
%     {'C22051'}
%     {'C22054'}
%     {'C22070'}
%     {'C22084'}
%     {'C22092'}
%     {'C22131'}
%     {'C22148'}
%     {'C22149'}
%     {'C22238'}
%     {'C22329'}
%     {'C22331'}
%     {'C22332'}
%     {'C22333'}
%     {'C22334'}
%     {'C22395'}
%     {'C22432'}
%     {'C22438'}
%     {'C22488'}
%     {'C22624'}
%     {'C22647'}
%     {'C22648'}
%     {'G00177'}
%     {'G09795'}
%     {'G10552'}
%     {'G10553'}
%     {'G10555'}
%     {'G10556'}
%     {'G10608'}
%     {'G10609'}
%     {'G11112'}
%     {'G13118'}
%     {'G13167'}
%     {'G13170'}
%     {'G13171'}
%     {'G13174'}
%     {'G13175'}
%     {'G13176'}
%     {'G13177'}
%     {'G13178'}
%     {'G13179'}
%     {'G13180'}
%     {'G13182'}
%     {'G13183'}
%     {'G13185'}
%     {'G13186'}
%     {'G13188'}
%     {'G13192'}
%     {'G13193'}
%     {'C00060'}
%     {'C00077'}
%     {'C00099'}
%     {'C00114'}
%     {'C00178'}
%     {'C00189'}
%     {'C00221'}
%     {'C00243'}
%     {'C00247'}
%     {'C00252'}
%     {'C00294'}
%     {'C00327'}
%     {'C00387'}
%     {'C00435'}
%     {'C00437'}
%     {'C00511'}
%     {'C00512'}
%     {'C00522'}
%     {'C00527'}
%     {'C00670'}
%     {'C00785'}
%     {'C00791'}
%     {'C00881'}
%     {'C00886'}
%     {'C00954'}
%     {'C01035'}
%     {'C01132'}
%     {'C01228'}
%     {'C01233'}
%     {'C01586'}
%     {'C01659'}
%     {'C01697'}
%     {'C01762'}
%     {'C01801'}
%     {'C02163'}
%     {'C02232'}
%     {'C02376'}
%     {'C02505'}
%     {'C02565'}
%     {'C02693'}
%     {'C02839'}
%     {'C02888'}
%     {'C02988'}
%     {'C03069'}
%     {'C03078'}
%     {'C03150'}
%     {'C03344'}
%     {'C03620'}
%     {'C04421'}
%     {'C04454'}
%     {'C04732'}
%     {'C05259'}
%     {'C05261'}
%     {'C05263'}
%     {'C05265'}
%     {'C05267'}
%     {'C05512'}
%     {'C05841'}
%     {'C06231'}
%     {'C06311'}
%     {'C06377'}
%     {'C06715'}
%     {'C06893'}
%     {'C07086'}
%     {'C07118'}
%     {'C09815'}
%     {'C11588'}
%     {'C12622'}
%     {'C13508'}
%     {'C15532'}
%     {'C16330'}
%     {'C16331'}
%     {'C16334'}
%     {'C16335'}
%     {'C16338'}
%     {'C16339'}
%     {'C16470'}
%     {'C19929'}
%     {'C20422'}
%     {'C20522'}
%     {'C20751'}
%     {'C21464'}
%     {'C21502'}
%     {'C22077'}
%     {'C22442'}
%     {'G13165'}
%     {'G13172'}
% Blocked reactions: 452
%     {'R00028'      }
%     {'R00104'      }
%     {'R00130'      }
%     {'R00137'      }
%     {'R00161'      }
%     {'R00174'      }
%     {'R00177'      }
%     {'R00188'      }
%     {'R00189'      }
%     {'R00190'      }
%     {'R00192'      }
%     {'R00194'      }
%     {'R00220_EXP_1'}
%     {'R00228'      }
%     {'R00230'      }
%     {'R00238'      }
%     {'R00260'      }
%     {'R00289'      }
%     {'R00291'      }
%     {'R00310'      }
%     {'R00315'      }
%     {'R00416'      }
%     {'R00420'      }
%     {'R00429'      }
%     {'R00491'      }
%     {'R00508'      }
%     {'R00597'      }
%     {'R00615'      }
%     {'R00658'      }
%     {'R00660'      }
%     {'R00703'      }
%     {'R00720_EXP_1'}
%     {'R00754'      }
%     {'R00837'      }
%     {'R00838'      }
%     {'R00856'      }
%     {'R00875'      }
%     {'R00899'      }
%     {'R00921'      }
%     {'R00942'      }
%     {'R00943'      }
%     {'R00965'      }
%     {'R01000'      }
%     {'R01012'      }
%     {'R01015'      }
%     {'R01054'      }
%     {'R01056'      }
%     {'R01057'      }
%     {'R01061'      }
%     {'R01083'      }
%     {'R01121'      }
%     {'R01122'      }
%     {'R01123'      }
%     {'R01132'      }
%     {'R01135'      }
%     {'R01150'      }
%     {'R01172'      }
%     {'R01177'      }
%     {'R01220'      }
%     {'R01353'      }
%     {'R01401'      }
%     {'R01512'      }
%     {'R01518'      }
%     {'R01529'      }
%     {'R01547'      }
%     {'R01555'      }
%     {'R01625'      }
%     {'R01655'      }
%     {'R01658'      }
%     {'R01724'      }
%     {'R01799'      }
%     {'R01801'      }
%     {'R01819'      }
%     {'R01829'      }
%     {'R01867'      }
%     {'R01870'      }
%     {'R01896'      }
%     {'R01909'      }
%     {'R01978'      }
%     {'R02003'      }
%     {'R02016'      }
%     {'R02035'      }
%     {'R02059'      }
%     {'R02060'      }
%     {'R02061'      }
%     {'R02071_EXP_1'}
%     {'R02081'      }
%     {'R02094'      }
%     {'R02101'      }
%     {'R02111'      }
%     {'R02112'      }
%     {'R02135'      }
%     {'R02237'      }
%     {'R02240'      }
%     {'R02241'      }
%     {'R02301'      }
%     {'R02320'      }
%     {'R02493'      }
%     {'R02568'      }
%     {'R02630'      }
%     {'R02718_EXP_1'}
%     {'R02720_EXP_1'}
%     {'R02738'      }
%     {'R02780'      }
%     {'R02788'      }
%     {'R02971'      }
%     {'R02984'      }
%     {'R03005'      }
%     {'R03018'      }
%     {'R03035'      }
%     {'R03104'      }
%     {'R03122'      }
%     {'R03193'      }
%     {'R03239'      }
%     {'R03245'      }
%     {'R03269'      }
%     {'R03504'      }
%     {'R03531_EXP_1'}
%     {'R03596'      }
%     {'R03648'      }
%     {'R03650'      }
%     {'R03651'      }
%     {'R03654'      }
%     {'R03656'      }
%     {'R03657'      }
%     {'R03658'      }
%     {'R03659'      }
%     {'R03660'      }
%     {'R03661'      }
%     {'R03662'      }
%     {'R03663'      }
%     {'R03664'      }
%     {'R03665'      }
%     {'R03905'      }
%     {'R03940'      }
%     {'R04111'      }
%     {'R04212'      }
%     {'R04231'      }
%     {'R04378'      }
%     {'R04391'      }
%     {'R04394'      }
%     {'R04467'      }
%     {'R04559'      }
%     {'R04573'      }
%     {'R04617'      }
%     {'R04710'      }
%     {'R04771'      }
%     {'R04773'      }
%     {'R04858'      }
%     {'R04880'      }
%     {'R04951'      }
%     {'R05030'      }
%     {'R05032'      }
%     {'R05081'      }
%     {'R05132'      }
%     {'R05199'      }
%     {'R05233'      }
%     {'R05234'      }
%     {'R05332'      }
%     {'R05566'      }
%     {'R05577'      }
%     {'R05578'      }
%     {'R05627'      }
%     {'R05629'      }
%     {'R05630'      }
%     {'R05662'      }
%     {'R05705'      }
%     {'R05820'      }
%     {'R06113'      }
%     {'R06129'      }
%     {'R06173'      }
%     {'R06174'      }
%     {'R06363'      }
%     {'R06447'      }
%     {'R06917'      }
%     {'R06927'      }
%     {'R07390'      }
%     {'R07461'      }
%     {'R08218'      }
%     {'R08232'      }
%     {'R08233'      }
%     {'R08237'      }
%     {'R08238'      }
%     {'R08240'      }
%     {'R08243_EXP_1'}
%     {'R08244'      }
%     {'R08245'      }
%     {'R08559'      }
%     {'R08856'      }
%     {'R09372'      }
%     {'R09381'      }
%     {'R09597'      }
%     {'R09748'      }
%     {'R09750'      }
%     {'R10137'      }
%     {'R10223'      }
%     {'R10463'      }
%     {'R10806'      }
%     {'R10849'      }
%     {'R10850'      }
%     {'R10865'      }
%     {'R11037'      }
%     {'R11073'      }
%     {'R11170'      }
%     {'R11172'      }
%     {'R11262'      }
%     {'R11319'      }
%     {'R11329'      }
%     {'R11636'      }
%     {'R11765'      }
%     {'R11896'      }
%     {'R12049'      }
%     {'R12075'      }
%     {'R12240'      }
%     {'R12241_EXP_1'}
%     {'R12345'      }
%     {'R12390'      }
%     {'R12391'      }
%     {'R12812'      }
%     {'R12851'      }
%     {'R12859'      }
%     {'R12863'      }
%     {'R12867'      }
%     {'R12871'      }
%     {'R12873'      }
%     {'R12875'      }
%     {'R12896'      }
%     {'R12900'      }
%     {'R12902'      }
%     {'R12903'      }
%     {'R12904'      }
%     {'R00647'      }
%     {'R01652'      }
%     {'R02317'      }
%     {'R02962'      }
%     {'R03166'      }
%     {'R03186'      }
%     {'R03445'      }
%     {'R03672'      }
%     {'R03674'      }
%     {'R03954'      }
%     {'R04500'      }
%     {'R04578'      }
%     {'R04701'      }
%     {'R04769'      }
%     {'R05041'      }
%     {'R05098'      }
%     {'R05455'      }
%     {'R05483'      }
%     {'R05484'      }
%     {'R05824'      }
%     {'R05826'      }
%     {'R05844'      }
%     {'R05845'      }
%     {'R05846'      }
%     {'R05887'      }
%     {'R05889'      }
%     {'R06063'      }
%     {'R06064'      }
%     {'R06194'      }
%     {'R06650'      }
%     {'R06830'      }
%     {'R06982'      }
%     {'R07009'      }
%     {'R07010'      }
%     {'R07011'      }
%     {'R07012'      }
%     {'R07198'      }
%     {'R07316'      }
%     {'R07406'      }
%     {'R07679'      }
%     {'R07947'      }
%     {'R07948'      }
%     {'R08020'      }
%     {'R08279'      }
%     {'R08289'      }
%     {'R08358'      }
%     {'R08361'      }
%     {'R08372'      }
%     {'R08818'      }
%     {'R08820'      }
%     {'R08821'      }
%     {'R08825'      }
%     {'R08827'      }
%     {'R08829'      }
%     {'R08831'      }
%     {'R08833'      }
%     {'R08834'      }
%     {'R08835'      }
%     {'R08837'      }
%     {'R08976'      }
%     {'R09142'      }
%     {'R09143'      }
%     {'R09144'      }
%     {'R09145'      }
%     {'R09149'      }
%     {'R09274'      }
%     {'R09367'      }
%     {'R09368'      }
%     {'R09391'      }
%     {'R09392'      }
%     {'R09431'      }
%     {'R09432'      }
%     {'R09433'      }
%     {'R09434'      }
%     {'R09885'      }
%     {'R09981'      }
%     {'R10013'      }
%     {'R10018'      }
%     {'R10022'      }
%     {'R10030'      }
%     {'R10034'      }
%     {'R10041'      }
%     {'R10078'      }
%     {'R10082'      }
%     {'R10097'      }
%     {'R10245'      }
%     {'R10302'      }
%     {'R10792'      }
%     {'R10854'      }
%     {'R10856'      }
%     {'R10914'      }
%     {'R11017'      }
%     {'R11034'      }
%     {'R11049'      }
%     {'R11148'      }
%     {'R11176'      }
%     {'R11228'      }
%     {'R11523'      }
%     {'R11550'      }
%     {'R11570'      }
%     {'R11571'      }
%     {'R11572'      }
%     {'R11573'      }
%     {'R11574'      }
%     {'R11575'      }
%     {'R11576'      }
%     {'R11577'      }
%     {'R11691'      }
%     {'R11695'      }
%     {'R11709'      }
%     {'R11736'      }
%     {'R11739'      }
%     {'R11865'      }
%     {'R11947'      }
%     {'R12091'      }
%     {'R12094'      }
%     {'R12132'      }
%     {'R12140'      }
%     {'R12268'      }
%     {'R12274'      }
%     {'R12310'      }
%     {'R12335'      }
%     {'R12421'      }
%     {'R12539'      }
%     {'R12683'      }
%     {'R12686'      }
%     {'R12829'      }
%     {'R12886'      }
%     {'R12910'      }
%     {'R12974'      }
%     {'R13023'      }
%     {'R13091'      }
%     {'R13113'      }
%     {'R13114'      }
%     {'R13140'      }
%     {'R13144'      }
%     {'R00183'      }
%     {'R00332'      }
%     {'R00336'      }
%     {'R00401'      }
%     {'R00669'      }
%     {'R00761'      }
%     {'R00829'      }
%     {'R00841'      }
%     {'R00927'      }
%     {'R01030'      }
%     {'R01069'      }
%     {'R01126'      }
%     {'R01227'      }
%     {'R01397'      }
%     {'R01411'      }
%     {'R01424'      }
%     {'R01470'      }
%     {'R01621'      }
%     {'R01664'      }
%     {'R01718'      }
%     {'R01869'      }
%     {'R01961'      }
%     {'R01993'      }
%     {'R02000'      }
%     {'R02090'      }
%     {'R02245'      }
%     {'R02323'      }
%     {'R02473'      }
%     {'R02540'      }
%     {'R02719'      }
%     {'R02727'      }
%     {'R02733'      }
%     {'R02734'      }
%     {'R02750'      }
%     {'R02783'      }
%     {'R02786'      }
%     {'R02918'      }
%     {'R02922'      }
%     {'R03038'      }
%     {'R03096'      }
%     {'R03180'      }
%     {'R03232'      }
%     {'R03240'      }
%     {'R03256'      }
%     {'R03346'      }
%     {'R03599'      }
%     {'R03646'      }
%     {'R03655'      }
%     {'R03778'      }
%     {'R03858'      }
%     {'R03909'      }
%     {'R03991'      }
%     {'R04076'      }
%     {'R04393'      }
%     {'R04742'      }
%     {'R04747'      }
%     {'R05168'      }
%     {'R05378'      }
%     {'R05506'      }
%     {'R05551'      }
%     {'R05570'      }
%     {'R05586'      }
%     {'R05590'      }
%     {'R06782'      }
%     {'R06783'      }
%     {'R07280'      }
%     {'R07891'      }
%     {'R07895'      }
%     {'R07899'      }
%     {'R08091'      }
%     {'R08095'      }
%     {'R08366'      }
%     {'R09107'      }
%     {'R09289'      }
%     {'R09800'      }
%     {'R10185'      }
%     {'R10330'      }
%     {'R10648'      }
%     {'R11543'      }
%     {'R11612'      }
%     {'R12852'      }
%     {'R12868'      }
%     {'R12958'      }
%     {'R13137'      }
%     {'BIOMASS_ps'  }

% %% [markdown]
% In order for this to be a functional GEM, exchange reactions need to be added.

% %%
% Setting up the draft GEM base
%LinersBiomassDraftModel = importModel('Liners_draftGEM_v3.xml');
% create a copy to avoid overwriting
LinersExchangeModel = LinersBiomassDraftModel;
LinersExchangeModel.id = 'LinersDraft';

% %% [markdown]
% Perform some cleaning:

% %%
% deal with grRules issues
LinersExchangeModel = ensureGrRules(LinersExchangeModel);
modelKEGGgr = ensureGrRules(modelKEGG);
% Out:
% Patched grRules to match 11588 rxns

% %%
% further sanitization
modelKEGGgr = padMissingFields(modelKEGGgr, LinersExchangeModel);
% Out:
% Added geneMiriams to KEGG
% Added rxnFrom to KEGG
% Added metFrom to KEGG
% Added geneFrom to KEGG
% Added rules to KEGG
% Added equations to KEGG
% Added rxnReferences to KEGG
% Added rxnConfidenceScores to KEGG
% Added metCharges to KEGG
% Added geneNames to KEGG
% Added geneShortNames to KEGG

% %% [markdown]
% Dealing with exchange reactions:

% %%
% getting a cell array of metabolites to create exchange reactions for
biomassMets = getBiomassMets(LinersExchangeModel, 'BIOMASS_ps'); % get metabolites involved in the biomass reaction
% Out:
% Biomass reaction: BIOMASS_ps
% Number of metabolites in biomass reaction: 202
%     {'C00001'}
%     {'C00002'}
%     {'C00003'}
%     {'C00004'}
%     {'C00005'}
%     {'C00006'}
%     {'C00007'}
%     {'C00008'}
%     {'C00009'}
%     {'C00010'}
%     {'C00013'}
%     {'C00014'}
%     {'C00019'}
%     {'C00020'}
%     {'C00022'}
%     {'C00024'}
%     {'C00025'}
%     {'C00030'}
%     {'C00033'}
%     {'C00041'}
%     {'C00044'}
%     {'C00047'}
%     {'C00049'}
%     {'C00055'}
%     {'C00058'}
%     {'C00061'}
%     {'C00063'}
%     {'C00064'}
%     {'C00065'}
%     {'C00073'}
%     {'C00075'}
%     {'C00078'}
%     {'C00079'}
%     {'C00080'}
%     {'C00082'}
%     {'C00084'}
%     {'C00085'}
%     {'C00092'}
%     {'C00093'}
%     {'C00097'}
%     {'C00100'}
%     {'C00101'}
%     {'C00103'}
%     {'C00105'}
%     {'C00117'}
%     {'C00118'}
%     {'C00123'}
%     {'C00130'}
%     {'C00131'}
%     {'C00136'}
%     {'C00143'}
%     {'C00144'}
%     {'C00148'}
%     {'C00163'}
%     {'C00169'}
%     {'C00183'}
%     {'C00185'}
%     {'C00186'}
%     {'C00188'}
%     {'C00197'}
%     {'C00214'}
%     {'C00217'}
%     {'C00239'}
%     {'C00250'}
%     {'C00255'}
%     {'C00272'}
%     {'C00286'}
%     {'C00288'}
%     {'C00299'}
%     {'C00314'}
%     {'C00330'}
%     {'C00337'}
%     {'C00342'}
%     {'C00344'}
%     {'C00345'}
%     {'C00356'}
%     {'C00360'}
%     {'C00362'}
%     {'C00364'}
%     {'C00365'}
%     {'C00379'}
%     {'C00407'}
%     {'C00415'}
%     {'C00416'}
%     {'C00418'}
%     {'C00455'}
%     {'C00460'}
%     {'C00469'}
%     {'C00475'}
%     {'C00526'}
%     {'C00534'}
%     {'C00559'}
%     {'C00641'}
%     {'C00655'}
%     {'C00692'}
%     {'C00794'}
%     {'C00831'}
%     {'C00856'}
%     {'C00857'}
%     {'C00864'}
%     {'C00882'}
%     {'C00921'}
%     {'C00993'}
%     {'C01007'}
%     {'C01050'}
%     {'C01094'}
%     {'C01097'}
%     {'C01107'}
%     {'C01134'}
%     {'C01143'}
%     {'C01172'}
%     {'C01185'}
%     {'C01212'}
%     {'C01300'}
%     {'C01352'}
%     {'C01412'}
%     {'C01528'}
%     {'C01563'}
%     {'C01638'}
%     {'C01639'}
%     {'C01640'}
%     {'C01641'}
%     {'C01644'}
%     {'C01645'}
%     {'C01646'}
%     {'C01647'}
%     {'C01648'}
%     {'C01649'}
%     {'C01650'}
%     {'C01651'}
%     {'C01652'}
%     {'C01653'}
%     {'C01674'}
%     {'C01847'}
%     {'C01977'}
%     {'C02191'}
%     {'C02211'}
%     {'C02282'}
%     {'C02583'}
%     {'C02743'}
%     {'C02909'}
%     {'C03024'}
%     {'C03402'}
%     {'C03492'}
%     {'C03688'}
%     {'C04079'}
%     {'C04261'}
%     {'C04352'}
%     {'C04501'}
%     {'C04646'}
%     {'C05196'}
%     {'C05197'}
%     {'C05335'}
%     {'C05345'}
%     {'C05576'}
%     {'C05823'}
%     {'C05892'}
%     {'C05893'}
%     {'C05984'}
%     {'C06040'}
%     {'C06156'}
%     {'C06365'}
%     {'C06611'}
%     {'C06612'}
%     {'C09762'}
%     {'C11736'}
%     {'C14089'}
%     {'C14818'}
%     {'C15811'}
%     {'C15812'}
%     {'C15813'}
%     {'C16618'}
%     {'C16633'}
%     {'C16636'}
%     {'C18902'}
%     {'C19078'}
%     {'C19080'}
%     {'C19722'}
%     {'C00062'}
%     {'C00091'}
%     {'C00121'}
%     {'C00135'}
%     {'C00329'}
%     {'C00340'}
%     {'C00423'}
%     {'C00673'}
%     {'C00787'}
%     {'C01013'}
%     {'C01635'}
%     {'C01636'}
%     {'C01643'}
%     {'C01832'}
%     {'C01944'}
%     {'C02593'}
%     {'C05270'}
%     {'C05274'}
%     {'C05519'}
%     {'C05629'}
%     {'C05688'}
%     {'C16466'}
%     {'C16471'}
%     {'C20396'}

% %%
wasteMets = getCommonWasteMets(LinersExchangeModel); % get list (cell array) of common waste metabolites
essentialMets = {'C00031','C00014','C00007','C00009','C00036'}; % glucose, ammonium, oxygen, phosphate, sulfate
communityMets = getCommunityExchangeMets(); % metabolites that are likely to be needed in MCMM community exchanges
allExMets = unique([biomassMets(:); wasteMets(:); essentialMets(:); communityMets(:)], 'stable'); % concatenate while avoiding potential duplicates

% add the exchange reactions to the model
LinersExchangeModel = addExchangeRxnsForModel(LinersExchangeModel, allExMets);
% Out:
% Warning: Metabolite C00086 not found in model, skipping.
% Warning: Metabolite C00282 not found in model, skipping.
% Warning: Metabolite C00246 not found in model, skipping.

% %%
% ensure reversibility of reactions
LinersExchangeModel = ensureRevField(LinersExchangeModel);
% Out:
% Model already has rev field

% %%
sol3 = solveLP(LinersExchangeModel);
disp(sol3.f);
% Out:
%   66.666666666666671

% %% [markdown]
% There is now biomass production!

% %%
% pre-export cleaning
LinersExchangeModel = fixSubsystemsField(LinersExchangeModel);
LinersExchangeModel = sanitizeRxnMiriams(LinersExchangeModel);
% Out:
% Sanitized rxnMiriams for 781 reactions

% %% [markdown]
% Now the model is ready for export:

% %%
% export the current model version
exportModel(LinersExchangeModel, 'Liners_draftGEM_v4.xml');
% Out:
% Document written

% %%
exportToExcelFormat(LinersExchangeModel, 'Liners_draftGEM_v4.xlsx');
save('Liners_draftGEM_v4.mat', 'LinersExchangeModel');

% %% [markdown]
% This will be the version used for the MCMM.
%
% ## Additional tests
%
% A few more sanity checks and tests prior to moving on to gap\-filling.

% %%
% Setting up the draft GEM base
%LinersBiomassDraftModel = importModel('Liners_draftGEM_v4.xml');
% create a copy to avoid overwriting
LinersBiomassObjDraftModel = LinersExchangeModel;
LinersBiomassObjDraftModel.id = 'LinersDraft';

% %% [markdown]
% First, checking for dead\-end metabolites:

% %%
deadMets = quickDeadEnds(LinersBiomassObjDraftModel);
fprintf('Dead-end metabolites: %d\n', numel(deadMets));
% Out:
% Dead-end metabolites: 0

% %% [markdown]
% Double\-check that the biomass metabolites are indeed present in the model:

% %%
biomassMets = getBiomassMets(LinersBiomassObjDraftModel, 'BIOMASS_ps');
% Out:
% Biomass reaction: BIOMASS_ps
% Number of metabolites in biomass reaction: 202
%     {'C00001'}
%     {'C00002'}
%     {'C00003'}
%     {'C00004'}
%     {'C00005'}
%     {'C00006'}
%     {'C00007'}
%     {'C00008'}
%     {'C00009'}
%     {'C00010'}
%     {'C00013'}
%     {'C00014'}
%     {'C00019'}
%     {'C00020'}
%     {'C00022'}
%     {'C00024'}
%     {'C00025'}
%     {'C00030'}
%     {'C00033'}
%     {'C00041'}
%     {'C00044'}
%     {'C00047'}
%     {'C00049'}
%     {'C00055'}
%     {'C00058'}
%     {'C00061'}
%     {'C00063'}
%     {'C00064'}
%     {'C00065'}
%     {'C00073'}
%     {'C00075'}
%     {'C00078'}
%     {'C00079'}
%     {'C00080'}
%     {'C00082'}
%     {'C00084'}
%     {'C00085'}
%     {'C00092'}
%     {'C00093'}
%     {'C00097'}
%     {'C00100'}
%     {'C00101'}
%     {'C00103'}
%     {'C00105'}
%     {'C00117'}
%     {'C00118'}
%     {'C00123'}
%     {'C00130'}
%     {'C00131'}
%     {'C00136'}
%     {'C00143'}
%     {'C00144'}
%     {'C00148'}
%     {'C00163'}
%     {'C00169'}
%     {'C00183'}
%     {'C00185'}
%     {'C00186'}
%     {'C00188'}
%     {'C00197'}
%     {'C00214'}
%     {'C00217'}
%     {'C00239'}
%     {'C00250'}
%     {'C00255'}
%     {'C00272'}
%     {'C00286'}
%     {'C00288'}
%     {'C00299'}
%     {'C00314'}
%     {'C00330'}
%     {'C00337'}
%     {'C00342'}
%     {'C00344'}
%     {'C00345'}
%     {'C00356'}
%     {'C00360'}
%     {'C00362'}
%     {'C00364'}
%     {'C00365'}
%     {'C00379'}
%     {'C00407'}
%     {'C00415'}
%     {'C00416'}
%     {'C00418'}
%     {'C00455'}
%     {'C00460'}
%     {'C00469'}
%     {'C00475'}
%     {'C00526'}
%     {'C00534'}
%     {'C00559'}
%     {'C00641'}
%     {'C00655'}
%     {'C00692'}
%     {'C00794'}
%     {'C00831'}
%     {'C00856'}
%     {'C00857'}
%     {'C00864'}
%     {'C00882'}
%     {'C00921'}
%     {'C00993'}
%     {'C01007'}
%     {'C01050'}
%     {'C01094'}
%     {'C01097'}
%     {'C01107'}
%     {'C01134'}
%     {'C01143'}
%     {'C01172'}
%     {'C01185'}
%     {'C01212'}
%     {'C01300'}
%     {'C01352'}
%     {'C01412'}
%     {'C01528'}
%     {'C01563'}
%     {'C01638'}
%     {'C01639'}
%     {'C01640'}
%     {'C01641'}
%     {'C01644'}
%     {'C01645'}
%     {'C01646'}
%     {'C01647'}
%     {'C01648'}
%     {'C01649'}
%     {'C01650'}
%     {'C01651'}
%     {'C01652'}
%     {'C01653'}
%     {'C01674'}
%     {'C01847'}
%     {'C01977'}
%     {'C02191'}
%     {'C02211'}
%     {'C02282'}
%     {'C02583'}
%     {'C02743'}
%     {'C02909'}
%     {'C03024'}
%     {'C03402'}
%     {'C03492'}
%     {'C03688'}
%     {'C04079'}
%     {'C04261'}
%     {'C04352'}
%     {'C04501'}
%     {'C04646'}
%     {'C05196'}
%     {'C05197'}
%     {'C05335'}
%     {'C05345'}
%     {'C05576'}
%     {'C05823'}
%     {'C05892'}
%     {'C05893'}
%     {'C05984'}
%     {'C06040'}
%     {'C06156'}
%     {'C06365'}
%     {'C06611'}
%     {'C06612'}
%     {'C09762'}
%     {'C11736'}
%     {'C14089'}
%     {'C14818'}
%     {'C15811'}
%     {'C15812'}
%     {'C15813'}
%     {'C16618'}
%     {'C16633'}
%     {'C16636'}
%     {'C18902'}
%     {'C19078'}
%     {'C19080'}
%     {'C19722'}
%     {'C00062'}
%     {'C00091'}
%     {'C00121'}
%     {'C00135'}
%     {'C00329'}
%     {'C00340'}
%     {'C00423'}
%     {'C00673'}
%     {'C00787'}
%     {'C01013'}
%     {'C01635'}
%     {'C01636'}
%     {'C01643'}
%     {'C01832'}
%     {'C01944'}
%     {'C02593'}
%     {'C05270'}
%     {'C05274'}
%     {'C05519'}
%     {'C05629'}
%     {'C05688'}
%     {'C16466'}
%     {'C16471'}
%     {'C20396'}

% %%
missing = setdiff(biomassMets, LinersBiomassObjDraftModel.mets);
disp(missing);

% %% [markdown]
% Perform a preliminary test for whether gap\-filling is necessary:

% %%
% block all exchange
LinersBiomassObjDraftModel.lb(findExcRxns(LinersBiomassObjDraftModel)) = 0;

% reopen minimal medium
allowMets = {'C00031','C00014','C00007','C00009','C00036'}; % glucose, ammonium, oxygen, phosphate, sulfate
for i = 1:numel(allowMets)
    exIdx = find(strcmp(LinersBiomassObjDraftModel.mets, allowMets{i}));
    if ~isempty(exIdx)
        rxnIdx = find(LinersBiomassObjDraftModel.S(exIdx,:));
        LinersBiomassObjDraftModel.lb(rxnIdx) = -1000; % uptake allowed
    end
end

sol4 = solveLP(LinersBiomassObjDraftModel);
disp(sol4.f);
% Out:
%   53.333333333333258

% %% [markdown]
% The solution here is the same as before, so this looks good to go.
%
%
% On Ed's recommendation, I will force the biomass flux to be positive:

% %%
% force the biomass flux to be positive
% Set lower and upper bounds of the biomass reaction
rxnID = 'BIOMASS_ps';
biomassIndex = find(ismember(LinersBiomassObjDraftModel.rxns, rxnID));

LinersBiomassObjDraftModel.lb(biomassIndex) = 0.1;  % minimum growth rate
LinersBiomassObjDraftModel.ub(biomassIndex) = 1000; % allow up to 1000

% %% [markdown]
% Finally, run FBA on the new model:

% %%
sol3 = solveLP(LinersBiomassObjDraftModel);
disp(sol3.f)
% Out:
%   53.333333333333357

% %% [markdown]
% Export the model:

% %%
exportModel(LinersBiomassObjDraftModel, 'Liners_draftGEM_v5.xml');
% Out:
% WARNING: The following reactions have lower and upper bounds that indicate reversibility, but are indicated as irreversible in model.rev:
%     R00765
%     R02738
%     R04212
%     R05627
%     R11037
%     R12896
%     R08020
%     R12958
% Document written

% %%
exportToExcelFormat(LinersBiomassObjDraftModel, 'Liners_draftGEM_v5.xlsx');
save('Liners_draftGEM_v5.mat', 'LinersBiomassObjDraftModel');

% %% [markdown]
% ## Gap\-filling attempt
%
% On the advice of Ed, I will be doing gap\-filling from the whole of the KEGG database. While the model does technically produce biomass and so therefore is viable, it is better to add more exchanges to ensure as high\-quality of an MCMM as possible.

% %%
% trying gap filling
[Liners_filledModel, addedRxns] = fillGaps( ...
    LinersBiomassObjDraftModel, ...
    modelKEGGgr, ...
    false, true, true);

% Check the output of fillGaps
if isempty(Liners_filledModel)
    disp('fillGaps returned an empty model. Check your input models and required fields.');
elseif iscell(Liners_filledModel)
    disp(['fillGaps returned a cell array of size: ', mat2str(size(Liners_filledModel))]);
else
    disp('fillGaps returned a valid model struct.');
end
% Out:
% fillGaps returned an empty model. Check your input models and required fields.

% %% [markdown]
% Check the results:

% %%
% Did fillGaps return something valid?
class(Liners_filledModel)
% Out:
% ans = 'cell'

% %%
whos Liners_filledModel
% Out:
%   Name                    Size            Bytes  Class    Attributes
%   Liners_filledModel      0x0                 0  cell

% %% [markdown]
% As before, it appears that gap\-filling is unnecessary in this case.
%
% ## Draft *Gardnerella vaginalis* GEM
%
% Initial GEM creation:

% %%
%clear
%clc

% draft with KEGG
%The organisms with KEGG annotation and their associated ids
%(e.g. 'gvh' for Gardnerella vaginalis HMP9231) can be found from here:
%https://www.kegg.jp/kegg/catalog/org_list.html.
GvaginalisKEGGAnnotation=getKEGGModelForOrganism('gvh','','','',1,0,0);
% Out:
% *** The model reconstruction from KEGG based on the annotation available for KEGG Species gvh ***
% Importing the global KEGG model from C:/Users/viragv/AppData/Roaming/MathWorks/MATLAB Add-Ons/Collections/RAVEN Toolbox/external/kegg/keggModel.mat... COMPLETE
% Importing the KEGG phylogenetic distance matrix from C:/Users/viragv/AppData/Roaming/MathWorks/MATLAB Add-Ons/Collections/RAVEN Toolbox/external/kegg/keggPhylDist.mat... COMPLETE
% Pruning the model from non-gvh genes... COMPLETE
% Removing non-spontaneous reactions without GPR rules... COMPLETE
% Fixing gene names in the model... COMPLETE
% Constructing GPR associations and annotations for the model... COMPLETE
% *** Model reconstruction complete ***

% %%
GvaginalisKEGGHomology=getKEGGModelForOrganism('GvaginalisKEGGHMMs','gardnerella_vaginalis_GCF_001042655-1_prots_edit.fasta','prok90_kegg105','',1,0,0);
% Out:
% *** The model reconstruction from KEGG based on the protein homology search against KEGG Orthology specific HMMs ***
% NOTE: Found prok90_kegg105 directory with pre-trained HMMs, it will therefore be used during reconstruction
% Importing the global KEGG model from C:/Users/viragv/AppData/Roaming/MathWorks/MATLAB Add-Ons/Collections/RAVEN Toolbox/external/kegg/keggModel.mat... COMPLETE
% Removing non-spontaneous reactions without GPR rules... COMPLETE
% Fixing gene names in the model... COMPLETE
% Importing the KEGG phylogenetic distance matrix from C:/Users/viragv/AppData/Roaming/MathWorks/MATLAB Add-Ons/Collections/RAVEN Toolbox/external/kegg/keggPhylDist.mat... COMPLETE
% Generating the KEGG Orthology specific multi-FASTA files... COMPLETE
% Performing clustering and multiple alignment for KEGG Orthology specific protein sets... COMPLETE
% Training the KEGG Orthology specific HMMs... COMPLETE
% Querying the user-specified FASTA file against the KEGG Orthology specific HMMs... COMPLETE
% Parsing the HMM search results... COMPLETE
% Removing gene, KEGG Orthology associations below minScoreRatioKO, minScoreRatioG... COMPLETE
% Adding gene annotations to the model... COMPLETE
% Removing non-spontaneous reactions which after HMM search no longer have GPR rules... COMPLETE
% Constructing GPR rules and finalizing the model... COMPLETE
% *** Model reconstruction complete ***

% %%
% merge models
GvaginalisKEGGDraftModel=mergeModels({GvaginalisKEGGAnnotation GvaginalisKEGGHomology});

% check reaction numbers
disp(numel(GvaginalisKEGGHomology.rxns)+numel(GvaginalisKEGGAnnotation.rxns));
% Out:
%         1283

% %%
disp(numel(GvaginalisKEGGDraftModel.rxns));
% Out:
%         1283

% %%
% further model cleaning
GvaginalisKEGGDraftModel=expandModel(GvaginalisKEGGDraftModel);
GvaginalisKEGGDraftModel=contractModel(GvaginalisKEGGDraftModel);

% %% [markdown]
% At this point, a draft GEM has been created for *G. vaginalis*, merging the information from MetaCyc and KEGG. While it needs to be improved, I'll save it for now in Excel format to avoid having to recreate it each time.

% %%
exportToExcelFormat(GvaginalisKEGGDraftModel, 'Gvaginalis_draftGEM_v1.xlsx');
save('Gvaginalis_draftGEM_v1.mat', 'GvaginalisKEGGDraftModel');

% %% [markdown]
% ## Cleaning *G. vaginalis* draft GEM

% %%
%GvaginalisCombinedDraftModel = load('Gvaginalis_draftGEM_v1.mat');
GvaginalisCleanDraftModel = cleanGrRulesGenes(GvaginalisKEGGDraftModel);
GvaginalisCleanDraftModel = mergeDuplicateMetNames(GvaginalisCleanDraftModel);
GvaginalisCleanDraftModel = fixSubsystemsField(GvaginalisCleanDraftModel);

% %% [markdown]
% The preliminary model should now be ready for export.

% %%
exportModel(GvaginalisCleanDraftModel, 'Gvaginalis_draftGEM_v2.xml');
% Out:
% WARNING: No objective function found. This might be intended, but results in FBCv2 non-compliant SBML file when exported
% WARNING: The composition for the following metabolites could not be parsed:
%     C00856
%     C01977
%     C02967
%     C04157
%     C04432
%     C17324
%     C19722
%     C19723
%     C20446
%     ...and 4 more
% WARNING: The following InChI strings are associated to more than one unique metabolite name:
%     1S/C10H20O7P2/c1-9(2)5-4-6-10(3)7-8-16-19(14,15)17-18(11,12)13/h5,7H,4,6,8H2,1-3H3,(H,14,15)(H2,11,12,13)/b10-7+
% Document written

% %%
exportToExcelFormat(GvaginalisCleanDraftModel, 'Gvaginalis_draftGEM_v2.xlsx');
save('Gvaginalis_draftGEM_v2.mat', 'GvaginalisCleanDraftModel');

% %% [markdown]
% Saved in SBML standard GEM format.

% %%
% Load the model from SBML (.xml)
%GvaginalisCleanDraftModel = importModel('Gvaginalis_draftGEM_v2.xml');

% %% [markdown]
% Now start quality checks:

% %%
%Check out if the newly generated GvaginalisCombinedDraftModel could grow
sol=solveLP(GvaginalisCleanDraftModel);
disp(sol.f);
% Out:
%      0

% %%
%The results indicate that this new model is non-functional
% ie., biomass = 0, which means there is no growth

% %%
% Look for reactions that produce a "biomass" metabolite
bioMets = find(contains(lower(GvaginalisCleanDraftModel.metNames), 'biomass'));

if isempty(bioMets)
    warning('No metabolites with "biomass" in the name were found.');
else
    % Find reactions involving these metabolites
    [rxnIdx, ~] = find(GvaginalisCleanDraftModel.S(bioMets,:) ~= 0);
    rxnIdx = unique(rxnIdx);
    disp('Potential biomass reactions:');
    disp([rxnIdx, GvaginalisCleanDraftModel.rxns(rxnIdx)', GvaginalisCleanDraftModel.rxnNames(rxnIdx)']);
end
% Out:
% Warning: No metabolites with "biomass" in the name were found.

% %% [markdown]
% ## Adding a biomass reaction
%
% Initial explorations showed that the current preliminary GEM draft doesn't have a biomass reaction. Hence, biomass will always be 0 until this is added. The following code was generated by ChatGPT; it seeds a biomass reaction from common building blocks like amino acids and nucleotides.

% %%
[GvaginalisBiomassDraftModel, biomassRxnID] = addPseudoBiomass_debug_all( ...
    GvaginalisCleanDraftModel, ...
    'BIOMASS_ps', ...
    [], ...
    true, ...
    'Gvaginalis_biomass_debug.txt', ...
    'Gvaginalis_biomass_metabolites.csv' ...
);
% Out:
% Precursor "L-alanine" → 6 matches found
%     Match: "L-Alanine:2-oxoglutarate aminotransferase" (ID: R00258)
%         Metabolite: "2-Oxoglutarate" (ID: C00026)
%         Metabolite: "L-Alanine" (ID: C00041)
%     Match: "3-sulfino-L-alanine:2-oxoglutarate aminotransferase" (ID: R02619)
%         Metabolite: "2-Oxoglutarate" (ID: C00026)
%         Metabolite: "3-Sulfino-L-alanine" (ID: C00606)
%     Match: "UDP-N-acetylmuramoyl-L-alanine:D-glutamate ligase(ADP-forming)" (ID: R02783)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "D-Glutamate" (ID: C00217)
%         Metabolite: "UDP-N-acetylmuramoyl-L-alanine" (ID: C01212)
%     Match: "L-Alanine:tRNA(Ala) ligase (AMP-forming)" (ID: R03038)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "L-Alanine" (ID: C00041)
%         Metabolite: "tRNA(Ala)" (ID: C01635)
%     Match: "UDP-N-acetylmuramate:L-alanine ligase (ADP-forming)" (ID: R03193)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "L-Alanine" (ID: C00041)
%         Metabolite: "UDP-N-acetylmuramate" (ID: C01050)
%     Match: "L-selenocysteine selenide-lyase (L-alanine-forming)" (ID: R03599)
%         Metabolite: "Reduced acceptor" (ID: C00030)
%         Metabolite: "L-Selenocysteine" (ID: C05688)
% Precursor "L-arginine" → 1 matches found
%     Match: "L-Arginine:tRNA(Arg) ligase (AMP-forming)" (ID: R03646)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "L-Arginine" (ID: C00062)
%         Metabolite: "tRNA(Arg)" (ID: C01636)
% Precursor "L-aspartate" → 9 matches found
%     Match: "L-Aspartate:2-oxoglutarate aminotransferase" (ID: R00355)
%         Metabolite: "2-Oxoglutarate" (ID: C00026)
%         Metabolite: "L-Aspartate" (ID: C00049)
%     Match: "IMP:L-aspartate ligase (GDP-forming)" (ID: R01135)
%         Metabolite: "GTP" (ID: C00044)
%         Metabolite: "L-Aspartate" (ID: C00049)
%         Metabolite: "IMP" (ID: C00130)
%     Match: "carbamoyl-phosphate:L-aspartate carbamoyltransferase" (ID: R01397)
%         Metabolite: "L-Aspartate" (ID: C00049)
%         Metabolite: "Carbamoyl phosphate" (ID: C00169)
%     Match: "L-Citrulline:L-aspartate ligase (AMP-forming)" (ID: R01954)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "L-Aspartate" (ID: C00049)
%         Metabolite: "L-Citrulline" (ID: C00327)
%     Match: "L-Aspartate-4-semialdehyde:NADP+ oxidoreductase (phosphorylating)" (ID: R02291)
%         Metabolite: "NADP+" (ID: C00006)
%         Metabolite: "Orthophosphate" (ID: C00009)
%         Metabolite: "L-Aspartate 4-semialdehyde" (ID: C00441)
%     Match: "1-(5-Phosphoribosyl)-5-amino-4-carboxyimidazole:L-aspartate ligase (ADP-forming)" (ID: R04591)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "L-Aspartate" (ID: C00049)
%         Metabolite: "1-(5-Phospho-D-ribosyl)-5-amino-4-imidazolecarboxylate" (ID: C04751)
%     Match: "L-Aspartate:tRNA(Asp) ligase (AMP-forming)" (ID: R05577)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "L-Aspartate" (ID: C00049)
%         Metabolite: "tRNA(Asp)" (ID: C01638)
%     Match: "L-aspartate-4-semialdehyde hydro-lyase [adding pyruvate and cyclizing; (2S,4S)-4-hydroxy-2,3,4,5-tetrahydrodipicolinate-forming]" (ID: R10147)
%         Metabolite: "Pyruvate" (ID: C00022)
%         Metabolite: "L-Aspartate 4-semialdehyde" (ID: C00441)
%     Match: "ATP:L-aspartate 4-phosphotransferase" (ID: R00480)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "L-Aspartate" (ID: C00049)
% Precursor "L-cysteine" → 6 matches found
%     Match: "L-cysteine:2-oxoglutarate aminotransferase" (ID: R00896)
%         Metabolite: "2-Oxoglutarate" (ID: C00026)
%         Metabolite: "L-Cysteine" (ID: C00097)
%     Match: "L-Cysteine:tRNA(Cys) ligase (AMP-forming)" (ID: R03650)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "L-Cysteine" (ID: C00097)
%         Metabolite: "tRNA(Cys)" (ID: C01639)
%     Match: "O3-acetyl-L-serine:thiosulfate 2-amino-2-carboxyethyltransferase (reducing, L-cysteine-forming);" (ID: R04859)
%         Metabolite: "H+" (ID: C00080)
%         Metabolite: "Thiosulfate" (ID: C00320)
%         Metabolite: "Thioredoxin" (ID: C00342)
%         Metabolite: "O-Acetyl-L-serine" (ID: C00979)
%     Match: "L-cysteine:sulfur-acceptor sulfurtransferase" (ID: R11528)
%         Metabolite: "L-Cysteine" (ID: C00097)
%         Metabolite: "[Protein]-L-cysteine" (ID: C02743)
%     Match: "L-serine hydro-lyase (adding hydrogen sulfide, L-cysteine-forming)" (ID: R00891)
%         Metabolite: "L-Serine" (ID: C00065)
%         Metabolite: "Hydrogen sulfide" (ID: C00283)
%     Match: "[enzyme]-S-sulfanyl-L-cysteine:adenylyl-[sulfur-carrier protein] sulfurtransferase" (ID: R07461)
%         Metabolite: "Reduced acceptor" (ID: C00030)
%         Metabolite: "Adenylyl-[sulfur-carrier protein]" (ID: C15813)
%         Metabolite: "[Enzyme]-S-sulfanylcysteine" (ID: C15812)
% Precursor "L-glutamate" → 9 matches found
%     Match: "ATP:L-glutamate 5-phosphotransferase" (ID: R00239)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "L-Glutamate" (ID: C00025)
%     Match: "L-Glutamate:ammonia ligase (ADP-forming)" (ID: R00253)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "Ammonia" (ID: C00014)
%         Metabolite: "L-Glutamate" (ID: C00025)
%     Match: "Tetrahydrofolate:L-glutamate gamma-ligase (ADP-forming)" (ID: R00942)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "L-Glutamate" (ID: C00025)
%         Metabolite: "Tetrahydrofolate" (ID: C00101)
%     Match: "7,8-dihydropteroate:L-glutamate ligase (ADP-forming)" (ID: R02237)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "L-Glutamate" (ID: C00025)
%         Metabolite: "Dihydropteroate" (ID: C00921)
%     Match: "L-glutamate-5-semialdehyde:NADP+ 5-oxidoreductase (phosphorylating)" (ID: R03313)
%         Metabolite: "NADP+" (ID: C00006)
%         Metabolite: "Orthophosphate" (ID: C00009)
%         Metabolite: "L-Glutamate 5-semialdehyde" (ID: C01165)
%     Match: "5-Methyltetrahydropteroyltri-L-glutamate:L-homocysteine S-methyltransferase" (ID: R04405)
%         Metabolite: "L-Homocysteine" (ID: C00155)
%         Metabolite: "5-Methyltetrahydropteroyltri-L-glutamate" (ID: C04489)
%     Match: "L-glutamate:tRNA(Glu) ligase (AMP-forming)" (ID: R05578)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "L-Glutamate" (ID: C00025)
%         Metabolite: "tRNA(Glu)" (ID: C01641)
%     Match: "5-methyltetrahydropteroyltri-L-glutamate:L-selenohomocysteine Se-methyltransferase" (ID: R09365)
%         Metabolite: "5-Methyltetrahydropteroyltri-L-glutamate" (ID: C04489)
%         Metabolite: "Selenohomocysteine" (ID: C05698)
%     Match: "L-Glutamate:tRNA(Gln) ligase (AMP-forming)" (ID: R03651)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "L-Glutamate" (ID: C00025)
%         Metabolite: "tRNA(Gln)" (ID: C01640)
% Precursor "L-glutamine" → 12 matches found
%     Match: "L-glutamine amidohydrolase" (ID: R00256)
%         Metabolite: "H2O" (ID: C00001)
%         Metabolite: "L-Glutamine" (ID: C00064)
%     Match: "Deamido-NAD+:L-glutamine amido-ligase (AMP-forming)" (ID: R00257)
%         Metabolite: "H2O" (ID: C00001)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "L-Glutamine" (ID: C00064)
%         Metabolite: "Deamino-NAD+" (ID: C00857)
%     Match: "UTP:L-glutamine amido-ligase (ADP-forming)" (ID: R00573)
%         Metabolite: "H2O" (ID: C00001)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "L-Glutamine" (ID: C00064)
%         Metabolite: "UTP" (ID: C00075)
%     Match: "HCO3-:L-glutamine amido-ligase (ADP-forming, carbamate-phosphorylating)" (ID: R00575)
%         Metabolite: "H2O" (ID: C00001)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "L-Glutamine" (ID: C00064)
%         Metabolite: "HCO3-" (ID: C00288)
%     Match: "L-glutamine:D-fructose-6-phosphate isomerase (deaminating);" (ID: R00768)
%         Metabolite: "L-Glutamine" (ID: C00064)
%         Metabolite: "D-Fructose 6-phosphate" (ID: C00085)
%     Match: "Xanthosine-5'-phosphate:L-glutamine amido-ligase (AMP-forming)" (ID: R01231)
%         Metabolite: "H2O" (ID: C00001)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "L-Glutamine" (ID: C00064)
%         Metabolite: "Xanthosine 5'-phosphate" (ID: C00655)
%     Match: "Glu-tRNA(Gln):L-glutamine amido-ligase(ADP-forming)" (ID: R03905)
%         Metabolite: "ADP" (ID: C00008)
%         Metabolite: "Orthophosphate" (ID: C00009)
%         Metabolite: "L-Glutamate" (ID: C00025)
%         Metabolite: "Glutaminyl-tRNA" (ID: C02282)
%     Match: "Asp-tRNA(Asn):L-glutamine amido-ligase (ADP-forming)" (ID: R04212)
%         Metabolite: "ADP" (ID: C00008)
%         Metabolite: "Orthophosphate" (ID: C00009)
%         Metabolite: "L-Glutamate" (ID: C00025)
%         Metabolite: "L-Asparaginyl-tRNA(Asn)" (ID: C03402)
%     Match: "5'-Phosphoribosylformylglycinamide:L-glutamine amido-ligase (ADP-forming)" (ID: R04463)
%         Metabolite: "H2O" (ID: C00001)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "L-Glutamine" (ID: C00064)
%         Metabolite: "5'-Phosphoribosyl-N-formylglycinamide" (ID: C04376)
%     Match: "beta-D-GlcNAc-(1->4)-Mur2Ac(oyl-L-Ala-gamma-D-Glu-L-Lys-D-Ala-D-Ala)-diphospho-ditrans,octacis-undecaprenol:L-glutamine amidoligase (ADP-forming)" (ID: R05030)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "Ammonia" (ID: C00014)
%         Metabolite: "Undecaprenyl-diphospho-N-acetylmuramoyl-(N-acetylglucosamine)-L-alanyl-gamma-D-glutamyl-L-lysyl-D-alanyl-D-alanine" (ID: C05893)
%     Match: "6-thioxanthine 5'-monophosphate:L-glutamine amido-ligase (AMP-forming)" (ID: R08244)
%         Metabolite: "H2O" (ID: C00001)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "L-Glutamine" (ID: C00064)
%         Metabolite: "6-Thioxanthine 5'-monophosphate" (ID: C16618)
%     Match: "S-adenosyl-L-methionine:[protein]-L-glutamine (N5-glutamine)-methyltransferase" (ID: R10806)
%         Metabolite: "S-Adenosyl-L-methionine" (ID: C00019)
%         Metabolite: "Protein glutamine" (ID: C02583)
% Precursor "L-glycine" → no matches found
% Precursor "L-histidine" → 3 matches found
%     Match: "L-Histidine:tRNA(His) ligase (AMP-forming)" (ID: R03655)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "L-Histidine" (ID: C00135)
%         Metabolite: "tRNA(His)" (ID: C01643)
%     Match: "protein-Npi-phospho-L-histidine:N,N'-diacetylchitobiose 6'-O-phosphotransferase" (ID: R11170)
%         Metabolite: "Chitobiose" (ID: C01674)
%         Metabolite: "Protein N(pi)-phospho-L-histidine" (ID: C04261)
%     Match: "protein-Npi-phospho-L-histidine:cellobiose 6'-O-phosphotransferase" (ID: R11172)
%         Metabolite: "Cellobiose" (ID: C00185)
%         Metabolite: "Protein N(pi)-phospho-L-histidine" (ID: C04261)
% Precursor "L-isoleucine" → 2 matches found
%     Match: "L-Isoleucine:2-oxoglutarate aminotransferase" (ID: R02199)
%         Metabolite: "2-Oxoglutarate" (ID: C00026)
%         Metabolite: "L-Isoleucine" (ID: C00407)
%     Match: "L-Isoleucine:tRNA(Ile) ligase (AMP-forming)" (ID: R03656)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "L-Isoleucine" (ID: C00407)
%         Metabolite: "tRNA(Ile)" (ID: C01644)
% Precursor "L-leucine" → 2 matches found
%     Match: "L-Leucine:2-oxoglutarate aminotransferase" (ID: R01090)
%         Metabolite: "2-Oxoglutarate" (ID: C00026)
%         Metabolite: "L-Leucine" (ID: C00123)
%     Match: "L-Leucine:tRNA(Leu) ligase (AMP-forming)" (ID: R03657)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "L-Leucine" (ID: C00123)
%         Metabolite: "tRNA(Leu)" (ID: C01645)
% Precursor "L-lysine" → 4 matches found
%     Match: "L-lysine:tRNALys ligase (AMP-forming)" (ID: R03658)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "L-Lysine" (ID: C00047)
%         Metabolite: "tRNA(Lys)" (ID: C01646)
%     Match: "UDP-N-acetylmuramoyl-L-alanyl-D-glutamyl-L-lysine:alanyl-D-alanine ligase (ADP-forming)" (ID: R04573)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "D-Alanyl-D-alanine" (ID: C00993)
%         Metabolite: "UDP-N-acetylmuramoyl-L-alanyl-gamma-D-glutamyl-L-lysine" (ID: C05892)
%     Match: "L-lysine:[tRNA(Ile2)]-cytidine34 ligase (AMP-forming)" (ID: R09597)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "L-Lysine" (ID: C00047)
%         Metabolite: "[tRNA(Ile2)]-cytidine34" (ID: C19722)
%     Match: "UDP-N-acetylmuramoyl-L-alanyl-D-glutamate:L-lysine gamma-ligase (ADP-forming);" (ID: R02786)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "L-Lysine" (ID: C00047)
%         Metabolite: "UDP-N-acetylmuramoyl-L-alanyl-D-glutamate" (ID: C00692)
% Precursor "L-methionine" → 7 matches found
%     Match: "ATP:L-methionine S-adenosyltransferase" (ID: R00177)
%         Metabolite: "Orthophosphate" (ID: C00009)
%         Metabolite: "Diphosphate" (ID: C00013)
%         Metabolite: "S-Adenosyl-L-methionine" (ID: C00019)
%     Match: "S-adenosyl-L-methionine:tRNA guanine N1-methyltransferase;" (ID: R00597)
%         Metabolite: "S-Adenosyl-L-methionine" (ID: C00019)
%         Metabolite: "tRNA guanine" (ID: C01977)
%     Match: "L-Methionine:tRNAMet ligase (AMP-forming)" (ID: R03659)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "L-Methionine" (ID: C00073)
%         Metabolite: "tRNA(Met)" (ID: C01647)
%     Match: "Protein-glycine,dihydroflavodoxin:S-adenosyl-L-methionine oxidoreductase (S-adenosyl-L-methionine cleaving)" (ID: R04710)
%         Metabolite: "S-Adenosyl-L-methionine" (ID: C00019)
%         Metabolite: "Dihydroflavodoxin" (ID: C05196)
%         Metabolite: "Protein glycine" (ID: C05197)
%     Match: "S-adenosyl-L-methionine:DNA (cytosine-5-)-methyltransferase" (ID: R04858)
%         Metabolite: "S-Adenosyl-L-methionine" (ID: C00019)
%         Metabolite: "DNA cytosine" (ID: C00856)
%     Match: "S-adenosyl-L-methionine:[protein]-L-glutamine (N5-glutamine)-methyltransferase" (ID: R10806)
%         Metabolite: "S-Adenosyl-L-methionine" (ID: C00019)
%         Metabolite: "Protein glutamine" (ID: C02583)
%     Match: "coproporphyrinogen-III:S-adenosyl-L-methionine oxidoreductase(decarboxylating)" (ID: R06895)
%         Metabolite: "S-Adenosyl-L-methionine" (ID: C00019)
%         Metabolite: "Coproporphyrinogen III" (ID: C03263)
% Precursor "L-phenylalanine" → 3 matches found
%     Match: "L-arogenate hydro-lyase (decarboxylating; L-phenylalanine-forming)" (ID: R00691)
%         Metabolite: "L-Arogenate" (ID: C00826)
%     Match: "L-Phenylalanine:2-oxoglutarate aminotransferase" (ID: R00694)
%         Metabolite: "2-Oxoglutarate" (ID: C00026)
%         Metabolite: "L-Phenylalanine" (ID: C00079)
%     Match: "L-Phenylalanine:tRNA(Ala) ligase (AMP-forming)" (ID: R03660)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "L-Phenylalanine" (ID: C00079)
%         Metabolite: "tRNA(Phe)" (ID: C01648)
% Precursor "L-proline" → 5 matches found
%     Match: "L-Proline:NAD+ 5-oxidoreductase" (ID: R01248)
%         Metabolite: "NAD+" (ID: C00003)
%         Metabolite: "L-Proline" (ID: C00148)
%     Match: "L-Proline:NADP+ 5-oxidoreductase" (ID: R01251)
%         Metabolite: "NADP+" (ID: C00006)
%         Metabolite: "L-Proline" (ID: C00148)
%     Match: "trans-4-Hydroxy-L-proline:NAD+ 5-oxidoreductase" (ID: R03291)
%         Metabolite: "NAD+" (ID: C00003)
%         Metabolite: "Hydroxyproline" (ID: C01157)
%     Match: "trans-4-Hydroxy-L-proline:NADP+ 5-oxidoreductase" (ID: R03293)
%         Metabolite: "NADP+" (ID: C00006)
%         Metabolite: "Hydroxyproline" (ID: C01157)
%     Match: "L-proline:tRNA(Pro) ligase (AMP-forming)" (ID: R03661)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "L-Proline" (ID: C00148)
%         Metabolite: "tRNA(Pro)" (ID: C01649)
% Precursor "L-serine" → 12 matches found
%     Match: "L-serine ammonia-lyase" (ID: R00220)
%         Metabolite: "L-Serine" (ID: C00065)
%     Match: "O-phospho-L-serine phosphohydrolase" (ID: R00582)
%         Metabolite: "H2O" (ID: C00001)
%         Metabolite: "O-Phospho-L-serine" (ID: C01005)
%     Match: "acetyl-CoA:L-serine O-acetyltransferase" (ID: R00586)
%         Metabolite: "Acetyl-CoA" (ID: C00024)
%         Metabolite: "L-Serine" (ID: C00065)
%     Match: "O3-acetyl-L-serine:hydrogen-sulfide 2-amino-2-carboxyethyltransferase;" (ID: R00897)
%         Metabolite: "Hydrogen sulfide" (ID: C00283)
%         Metabolite: "O-Acetyl-L-serine" (ID: C00979)
%     Match: "O3-Acetyl-L-serine acetate-lyase (adding hydrogen sulfide)" (ID: R03601)
%         Metabolite: "O-Acetyl-L-serine" (ID: C00979)
%         Metabolite: "Hydrogen selenide" (ID: C01528)
%     Match: "L-Serine:tRNA(Ser) ligase (AMP-forming)" (ID: R03662)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "L-Serine" (ID: C00065)
%         Metabolite: "tRNA(Ser)" (ID: C01650)
%     Match: "O3-acetyl-L-serine:thiosulfate 2-amino-2-carboxyethyltransferase (reducing, L-cysteine-forming);" (ID: R04859)
%         Metabolite: "H+" (ID: C00080)
%         Metabolite: "Thiosulfate" (ID: C00320)
%         Metabolite: "Thioredoxin" (ID: C00342)
%         Metabolite: "O-Acetyl-L-serine" (ID: C00979)
%     Match: "O-phospho-L-serine:hydrogen-sulfide 2-amino-2-carboxyethyltransferase" (ID: R07274)
%         Metabolite: "Hydrogen sulfide" (ID: C00283)
%         Metabolite: "O-Phospho-L-serine" (ID: C01005)
%     Match: "L-serine:tRNASec ligase (AMP-forming)" (ID: R08218)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "L-Serine" (ID: C00065)
%         Metabolite: "tRNA(Sec)" (ID: C16636)
%     Match: "L-serine hydro-lyase (adding hydrogen sulfide, L-cysteine-forming)" (ID: R00891)
%         Metabolite: "L-Serine" (ID: C00065)
%         Metabolite: "Hydrogen sulfide" (ID: C00283)
%     Match: "L-serine hydro-lyase (adding homocysteine; L-cystathionine-forming)" (ID: R01290)
%         Metabolite: "L-Serine" (ID: C00065)
%         Metabolite: "L-Homocysteine" (ID: C00155)
%     Match: "L-Serine hydro-lyase (adding homocysteine)" (ID: R04942)
%         Metabolite: "L-Serine" (ID: C00065)
%         Metabolite: "Selenohomocysteine" (ID: C05698)
% Precursor "L-threonine" → 3 matches found
%     Match: "O-phospho-L-homoserine phosphate-lyase (adding water;L-threonine-forming)" (ID: R01466)
%         Metabolite: "H2O" (ID: C00001)
%         Metabolite: "O-Phospho-L-homoserine" (ID: C01102)
%     Match: "L-Threonine:tRNA(Thr) ligase (AMP-forming)" (ID: R03663)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "L-Threonine" (ID: C00188)
%         Metabolite: "tRNA(Thr)" (ID: C01651)
%     Match: "O-Phospho-4-hydroxy-L-threonine phospho-lyase (adding water)" (ID: R05086)
%         Metabolite: "H2O" (ID: C00001)
%         Metabolite: "O-Phospho-4-hydroxy-L-threonine" (ID: C06055)
% Precursor "L-tryptophan" → 1 matches found
%     Match: "L-Tryptophan -tRNA(Trp) ligase (AMP-forming)" (ID: R03664)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "L-Tryptophan" (ID: C00078)
%         Metabolite: "tRNA(Trp)" (ID: C01652)
% Precursor "L-tyrosine" → 2 matches found
%     Match: "L-tyrosine:2-oxoglutarate aminotransferase" (ID: R00734)
%         Metabolite: "2-Oxoglutarate" (ID: C00026)
%         Metabolite: "L-Tyrosine" (ID: C00082)
%     Match: "L-Tyrosine:tRNA(Tyr) ligase (AMP-forming)" (ID: R02918)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "L-Tyrosine" (ID: C00082)
%         Metabolite: "tRNA(Tyr)" (ID: C00787)
% Precursor "L-valine" → 3 matches found
%     Match: "L-Valine:2-oxoglutarate aminotransferase" (ID: R01214)
%         Metabolite: "2-Oxoglutarate" (ID: C00026)
%         Metabolite: "L-Valine" (ID: C00183)
%     Match: "L-Valine:pyruvate aminotransferase" (ID: R01215)
%         Metabolite: "Pyruvate" (ID: C00022)
%         Metabolite: "L-Valine" (ID: C00183)
%     Match: "L-Valine:tRNAVal ligase (AMP-forming)" (ID: R03665)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "L-Valine" (ID: C00183)
%         Metabolite: "tRNA(Val)" (ID: C01653)
% Precursor "ATP" → 65 matches found
%     Match: "ATP:NAD+ 2'-phosphotransferase" (ID: R00104)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "NAD+" (ID: C00003)
%     Match: "ATP:AMP phosphotransferase" (ID: R00127)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "AMP" (ID: C00020)
%     Match: "ATP:dephospho-CoA 3'-phosphotransferase" (ID: R00130)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "Dephospho-CoA" (ID: C00882)
%     Match: "ATP:nicotinamide-nucleotide adenylyltransferase" (ID: R00137)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "Nicotinamide D-ribonucleotide" (ID: C00455)
%     Match: "ATP:UMP phosphotransferase" (ID: R00158)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "UMP" (ID: C00105)
%     Match: "ATP:FMN adenylyltransferase" (ID: R00161)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "FMN" (ID: C00061)
%     Match: "ATP:L-methionine S-adenosyltransferase" (ID: R00177)
%         Metabolite: "Orthophosphate" (ID: C00009)
%         Metabolite: "Diphosphate" (ID: C00013)
%         Metabolite: "S-Adenosyl-L-methionine" (ID: C00019)
%     Match: "ATP:pyruvate 2-O-phosphotransferase" (ID: R00200)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "Pyruvate" (ID: C00022)
%     Match: "ATP:L-glutamate 5-phosphotransferase" (ID: R00239)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "L-Glutamate" (ID: C00025)
%     Match: "ATP:D-glucose 6-phosphotransferase" (ID: R00299)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "D-Glucose" (ID: C00031)
%     Match: "ATP:acetate phosphotransferase" (ID: R00315)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "Acetate" (ID: C00033)
%     Match: "ATP:GMP phosphotransferase" (ID: R00332)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "GMP" (ID: C00144)
%     Match: "ATP:GTP 3'-diphosphotransferase" (ID: R00429)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "GTP" (ID: C00044)
%     Match: "ATP:riboflavin 5'-phosphotransferase" (ID: R00549)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "Riboflavin" (ID: C00255)
%     Match: "ATP:thiamine diphosphotransferase" (ID: R00619)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "Thiamine" (ID: C00378)
%     Match: "ATP:D-fructose 6-phosphotransferase" (ID: R00760)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "D-Fructose" (ID: C00095)
%     Match: "ATP:D-fructose 6-phosphotransferase" (ID: R00867)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "D-Fructose" (ID: C00095)
%     Match: "ATP:D-ribose-5-phosphate diphosphotransferase" (ID: R01049)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "D-Ribose 5-phosphate" (ID: C00117)
%     Match: "ATP:D-ribose 5-phosphotransferase" (ID: R01051)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "D-Ribose" (ID: C00121)
%     Match: "ATP:alpha-D-galactose 1-phosphotransferase" (ID: R01092)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "alpha-D-Galactose" (ID: C00984)
%     Match: "ATP:(R)-5-diphosphomevalonate carboxy-lyase (adding ATP; isopentenyl-diphosphate-forming);" (ID: R01121)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "(R)-5-Diphosphomevalonate" (ID: C01143)
%     Match: "dATP:pyruvate 2-O-phosphotransferase" (ID: R01138)
%         Metabolite: "Pyruvate" (ID: C00022)
%         Metabolite: "dATP" (ID: C00131)
%     Match: "ATP:propanoate phosphotransferase" (ID: R01353)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "Propanoate" (ID: C00163)
%     Match: "ATP:carbamate phosphotransferase" (ID: R01395)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "Carbamate" (ID: C01563)
%     Match: "ATP:3-phospho-D-glycerate 1-phosphotransferase" (ID: R01512)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "3-Phospho-D-glycerate" (ID: C00197)
%     Match: "ATP:dAMP phosphotransferase" (ID: R01547)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "dAMP" (ID: C00360)
%     Match: "ATP:beta-D-glucose 6-phosphotransferase" (ID: R01600)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "beta-D-Glucose" (ID: C00221)
%     Match: "ATP:D-xylulose 5-phosphotransferase" (ID: R01639)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "D-Xylulose" (ID: C00310)
%     Match: "ATP:D-gluconate 6-phosphotransferase" (ID: R01737)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "D-Gluconic acid" (ID: C00257)
%     Match: "ATP:L-homoserine O-phosphotransferase" (ID: R01771_EXP_1)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "L-Homoserine" (ID: C00263)
%     Match: "ATP:alpha-D-glucose 6-phosphotransferase" (ID: R01786)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "alpha-D-Glucose" (ID: C00267)
%     Match: "ATP:dGMP phosphotransferase" (ID: R02090)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "dGMP" (ID: C00362)
%     Match: "ATP:dTMP phosphotransferase" (ID: R02094)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "dTMP" (ID: C00364)
%     Match: "ATP:dUMP phosphotransferase" (ID: R02098)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "dUMP" (ID: C00365)
%     Match: "ATP:(R)-mevalonate 5-phosphotransferase" (ID: R02245)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "(R)-Mevalonate" (ID: C00418)
%     Match: "ATP:shikimate 3-phosphotransferase" (ID: R02412)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "Shikimate" (ID: C00493)
%     Match: "ATP:2-deoxy-D-ribose 5-phosphotransferase" (ID: R02750)
%         Metabolite: "ADP" (ID: C00008)
%         Metabolite: "2-Deoxy-D-ribose 5-phosphate" (ID: C00673)
%     Match: "ATP:pantothenate 4'-phosphotransferase" (ID: R02971)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "Pantetheine" (ID: C00831)
%     Match: "ATP:nicotinamide-nucleotide adenylyltransferase" (ID: R03005)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "Nicotinate D-ribonucleotide" (ID: C01185)
%     Match: "ATP:pantothenate 4'-phosphotransferase" (ID: R03018)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "Pantothenate" (ID: C00864)
%     Match: "ATP:pantetheine-4'-phosphate adenylyltransferase" (ID: R03035)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "Pantetheine 4'-phosphate" (ID: C01134)
%     Match: "ATP:6-hydroxymethyl-7,8-dihydropterin 6'-diphosphotransferase" (ID: R03503)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "6-(Hydroxymethyl)-7,8-dihydropterin" (ID: C01300)
%     Match: "ATP:D-fructose 6-phosphotransferase" (ID: R03920)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "beta-D-Fructose" (ID: C02336)
%     Match: "ATP:pantothenate 4'-phosphotransferase" (ID: R04391)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "N-((R)-Pantothenoyl)-L-cysteine" (ID: C04079)
%     Match: "ATP:4-methyl-5-(2-hydroxyethyl)thiazole 2-phosphotransferase" (ID: R04448)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "5-(2-Hydroxyethyl)-4-methylthiazole" (ID: C04294)
%     Match: "ATP:L-selenomethione S-adenosyltransferase" (ID: R04771)
%         Metabolite: "H2O" (ID: C00001)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "L-Selenomethionine" (ID: C05335)
%     Match: "ATP:[sulfur-carrier protein] adenylyltransferase" (ID: R07459)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "Sulfur-carrier protein" (ID: C15810)
%     Match: "ATP:L-threonyl,bicarbonate adenylyltransferase" (ID: R10463)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "H+" (ID: C00080)
%         Metabolite: "L-Threonine" (ID: C00188)
%         Metabolite: "HCO3-" (ID: C00288)
%     Match: "ATP:HCO3- phosphotransferase" (ID: R10948)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "HCO3-" (ID: C00288)
%     Match: "ATP:formate 2'-oxidoreductase" (ID: R11634)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "Formate" (ID: C00058)
%     Match: "ATP:L-aspartate 4-phosphotransferase" (ID: R00480)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "L-Aspartate" (ID: C00049)
%     Match: "ATP:adenylylsulfate 3'-phosphotransferase" (ID: R00509)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "Adenylyl sulfate" (ID: C00224)
%     Match: "ATP:CMP phosphotransferase" (ID: R00512)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "CMP" (ID: C00055)
%     Match: "ATP:sulfate adenylyltransferase" (ID: R00529)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "Sulfate" (ID: C00059)
%     Match: "ATP:dCMP phosphotransferase" (ID: R01665)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "dCMP" (ID: C00239)
%     Match: "ATP:1,2-diacylglycerol 3-phosphotransferase" (ID: R02240)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "1,2-Diacyl-sn-glycerol" (ID: C00641)
%     Match: "ATP:(R)-5-phosphomevalonate phosphotransferase" (ID: R03245)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "(R)-5-Phosphomevalonate" (ID: C01107)
%     Match: "ATP:pseudouridine 5'-phosphotransferase" (ID: R03315)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "Pseudouridine" (ID: C02067)
%     Match: "ATP:4-amino-5-hydroxymethyl-2-methylpyrimidine 5-phosphotransferase" (ID: R03471)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "4-Amino-5-hydroxymethyl-2-methylpyrimidine" (ID: C01279)
%     Match: "ATP:4-amino-2-methyl-5-phosphomethylpyrimidine phosphotransferase" (ID: R04509)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "4-Amino-2-methyl-5-(phosphooxymethyl)pyrimidine" (ID: C04556)
%     Match: "ATP:adenylylsulfate 3'-phosphotransferase" (ID: R04928)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "Adenylylselenate" (ID: C05686)
%     Match: "ATP:selenate adenylyltransferase" (ID: R04929)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "Selenate" (ID: C05697)
%     Match: "CTP,CTP,ATP:tRNA cytidylyl,cytidylyl,adenylyltransferase" (ID: R09382)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "CTP" (ID: C00063)
%         Metabolite: "tRNA precursor" (ID: C02211)
%     Match: "ATP:tRNA adenylyltransferase" (ID: R09386)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "tRNA with a 3' CC end" (ID: C19080)
%     Match: "ATP:methylphosphonate 5-triphosphoribosyltransferase" (ID: R10185)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "Methylphosphonate" (ID: C20396)
% Precursor "GTP" → 5 matches found
%     Match: "ATP:GTP 3'-diphosphotransferase" (ID: R00429)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "GTP" (ID: C00044)
%     Match: "GTP:pyruvate 2-O-phosphotransferase" (ID: R00430)
%         Metabolite: "Pyruvate" (ID: C00022)
%         Metabolite: "GTP" (ID: C00044)
%     Match: "dGTP triphosphohydrolase" (ID: R01856)
%         Metabolite: "H2O" (ID: C00001)
%         Metabolite: "dGTP" (ID: C00286)
%     Match: "dGTP:pyruvate 2-O-phosphotransferase" (ID: R01858)
%         Metabolite: "Pyruvate" (ID: C00022)
%         Metabolite: "dGTP" (ID: C00286)
%     Match: "GTP:formate 2'-oxidoreductase" (ID: R11633)
%         Metabolite: "GTP" (ID: C00044)
%         Metabolite: "Formate" (ID: C00058)
% Precursor "CTP" → 7 matches found
%     Match: "CTP diphosphohydrolase (diphosphate-forming);" (ID: R00515)
%         Metabolite: "H2O" (ID: C00001)
%         Metabolite: "CTP" (ID: C00063)
%     Match: "CTP:phosphatidate cytidyltransferase" (ID: R01799)
%         Metabolite: "CTP" (ID: C00063)
%         Metabolite: "Phosphatidate" (ID: C00416)
%     Match: "dCTP aminohydrolase" (ID: R02325)
%         Metabolite: "H2O" (ID: C00001)
%         Metabolite: "dCTP" (ID: C00458)
%     Match: "CTP:formate 2'-oxidoreductase" (ID: R11636)
%         Metabolite: "Formate" (ID: C00058)
%         Metabolite: "CTP" (ID: C00063)
%     Match: "CTP,CTP,ATP:tRNA cytidylyl,cytidylyl,adenylyltransferase" (ID: R09382)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "CTP" (ID: C00063)
%         Metabolite: "tRNA precursor" (ID: C02211)
%     Match: "CTP:tRNA cytidylyltransferase" (ID: R09383)
%         Metabolite: "CTP" (ID: C00063)
%         Metabolite: "tRNA precursor" (ID: C02211)
%     Match: "CTP:tRNA cytidylyltransferase" (ID: R09384)
%         Metabolite: "CTP" (ID: C00063)
%         Metabolite: "tRNA with a 3' cytidine" (ID: C19078)
% Precursor "UTP" → 6 matches found
%     Match: "UTP:alpha-D-glucose-1-phosphate uridylyltransferase" (ID: R00289)
%         Metabolite: "UTP" (ID: C00075)
%         Metabolite: "D-Glucose 1-phosphate" (ID: C00103)
%     Match: "UTP:N-acetyl-alpha-D-glucosamine-1-phosphate uridylyltransferase" (ID: R00416)
%         Metabolite: "UTP" (ID: C00075)
%         Metabolite: "N-Acetyl-alpha-D-glucosamine 1-phosphate" (ID: C04501)
%     Match: "UTP:ammonia ligase (ADP-forming)" (ID: R00571)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "Ammonia" (ID: C00014)
%         Metabolite: "UTP" (ID: C00075)
%     Match: "UTP:L-glutamine amido-ligase (ADP-forming)" (ID: R00573)
%         Metabolite: "H2O" (ID: C00001)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "L-Glutamine" (ID: C00064)
%         Metabolite: "UTP" (ID: C00075)
%     Match: "dUTP nucleotidohydrolase" (ID: R02100)
%         Metabolite: "H2O" (ID: C00001)
%         Metabolite: "dUTP" (ID: C00460)
%     Match: "UTP:formate 2'-oxidoreductase" (ID: R11635)
%         Metabolite: "Formate" (ID: C00058)
%         Metabolite: "UTP" (ID: C00075)
% Precursor "NAD" → 109 matches found
%     Match: "ATP:NAD+ 2'-phosphotransferase" (ID: R00104)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "NAD+" (ID: C00003)
%     Match: "acetaldehyde:NAD+ oxidoreductase (CoA-acetylating)" (ID: R00228)
%         Metabolite: "NAD+" (ID: C00003)
%         Metabolite: "CoA" (ID: C00010)
%         Metabolite: "Acetaldehyde" (ID: C00084)
%     Match: "Deamido-NAD+:L-glutamine amido-ligase (AMP-forming)" (ID: R00257)
%         Metabolite: "H2O" (ID: C00001)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "L-Glutamine" (ID: C00064)
%         Metabolite: "Deamino-NAD+" (ID: C00857)
%     Match: "(S)-Lactate:NAD+ oxidoreductase" (ID: R00703)
%         Metabolite: "NAD+" (ID: C00003)
%         Metabolite: "(S)-Lactate" (ID: C00186)
%     Match: "ethanol:NAD+ oxidoreductase" (ID: R00754)
%         Metabolite: "NAD+" (ID: C00003)
%         Metabolite: "Ethanol" (ID: C00469)
%     Match: "D-glucose-6-phosphate:NADP+ 1-oxidoreductase" (ID: R00835)
%         Metabolite: "NADP+" (ID: C00006)
%         Metabolite: "D-Glucose 6-phosphate" (ID: C00092)
%     Match: "sn-Glycerol-3-phosphate:NAD+ 2-oxidoreductase" (ID: R00842)
%         Metabolite: "NAD+" (ID: C00003)
%         Metabolite: "sn-Glycerol 3-phosphate" (ID: C00093)
%     Match: "sn-Glycerol-3-phosphate:NADP+ 2-oxidoreductase" (ID: R00844)
%         Metabolite: "NADP+" (ID: C00006)
%         Metabolite: "sn-Glycerol 3-phosphate" (ID: C00093)
%     Match: "5,6,7,8-tetrahydrofolate:NAD+ oxidoreductase" (ID: R00936)
%         Metabolite: "NAD+" (ID: C00003)
%         Metabolite: "Tetrahydrofolate" (ID: C00101)
%     Match: "5,6,7,8-tetrahydrofolate:NAD+ oxidoreductase" (ID: R00937)
%         Metabolite: "NAD+" (ID: C00003)
%         Metabolite: "Tetrahydrofolate" (ID: C00101)
%     Match: "5,6,7,8-tetrahydrofolate:NADP+ oxidoreductase" (ID: R00939)
%         Metabolite: "NADP+" (ID: C00006)
%         Metabolite: "Tetrahydrofolate" (ID: C00101)
%     Match: "5,6,7,8-tetrahydrofolate:NADP+ oxidoreductase" (ID: R00940)
%         Metabolite: "NADP+" (ID: C00006)
%         Metabolite: "Tetrahydrofolate" (ID: C00101)
%     Match: "2-hydroxybutyrate:NAD+ oxidoreductase" (ID: R01000)
%         Metabolite: "NAD+" (ID: C00003)
%         Metabolite: "2-Hydroxybutanoic acid" (ID: C05984)
%     Match: "D-glyceraldehyde-3-phosphate:NAD+ oxidoreductase (phosphorylating)" (ID: R01061)
%         Metabolite: "NAD+" (ID: C00003)
%         Metabolite: "Orthophosphate" (ID: C00009)
%         Metabolite: "D-Glyceraldehyde 3-phosphate" (ID: C00118)
%     Match: "IMP:NAD+ oxidoreductase" (ID: R01130)
%         Metabolite: "H2O" (ID: C00001)
%         Metabolite: "NAD+" (ID: C00003)
%         Metabolite: "IMP" (ID: C00130)
%     Match: "butanal:NAD+ oxidoreductase (CoA-acylating)" (ID: R01172)
%         Metabolite: "NAD+" (ID: C00003)
%         Metabolite: "CoA" (ID: C00010)
%         Metabolite: "Butanal" (ID: C01412)
%     Match: "5,10-methylenetetrahydrofolate:NADP+ oxidoreductase" (ID: R01220)
%         Metabolite: "NADP+" (ID: C00006)
%         Metabolite: "5,10-Methylenetetrahydrofolate" (ID: C00143)
%     Match: "L-Proline:NAD+ 5-oxidoreductase" (ID: R01248)
%         Metabolite: "NAD+" (ID: C00003)
%         Metabolite: "L-Proline" (ID: C00148)
%     Match: "L-Proline:NADP+ 5-oxidoreductase" (ID: R01251)
%         Metabolite: "NADP+" (ID: C00006)
%         Metabolite: "L-Proline" (ID: C00148)
%     Match: "6-phospho-D-gluconate:NADP+ 2-oxidoreductase (decarboxylating)" (ID: R01528)
%         Metabolite: "NADP+" (ID: C00006)
%         Metabolite: "6-Phospho-D-gluconate" (ID: C00345)
%     Match: "4-hydroxybutanoate:NAD+ oxidoreductase" (ID: R01644)
%         Metabolite: "NAD+" (ID: C00003)
%         Metabolite: "4-Hydroxybutanoic acid" (ID: C00989)
%     Match: "Pyridoxine:NADP+ 4-oxidoreductase" (ID: R01708)
%         Metabolite: "NADP+" (ID: C00006)
%         Metabolite: "Pyridoxine" (ID: C00314)
%     Match: "prephenate:NAD+ oxidoreductase(decarboxylating)" (ID: R01728)
%         Metabolite: "NAD+" (ID: C00003)
%         Metabolite: "Prephenate" (ID: C00254)
%     Match: "L-Homoserine:NAD+ oxidoreductase" (ID: R01773)
%         Metabolite: "NAD+" (ID: C00003)
%         Metabolite: "L-Homoserine" (ID: C00263)
%     Match: "L-homoserine:NADP+ oxidoreductase" (ID: R01775)
%         Metabolite: "NADP+" (ID: C00006)
%         Metabolite: "L-Homoserine" (ID: C00263)
%     Match: "1,2-Ethanediol:NAD+ oxidoreductase" (ID: R01781)
%         Metabolite: "NAD+" (ID: C00003)
%         Metabolite: "Ethylene glycol" (ID: C01380)
%     Match: "(S)-dihydroorotate:NAD+ oxidoreductase" (ID: R01869)
%         Metabolite: "NAD+" (ID: C00003)
%         Metabolite: "(S)-Dihydroorotate" (ID: C00337)
%     Match: "NADPH:oxidized-thioredoxin oxidoreductase" (ID: R02016)
%         Metabolite: "NADP+" (ID: C00006)
%         Metabolite: "Thioredoxin" (ID: C00342)
%     Match: "(R)-Mevalonate:NAD+ oxidoreductase (CoA-acetylating)" (ID: R02081)
%         Metabolite: "NAD+" (ID: C00003)
%         Metabolite: "CoA" (ID: C00010)
%         Metabolite: "(R)-Mevalonate" (ID: C00418)
%     Match: "retinol:NAD+ oxidoreductase" (ID: R02124)
%         Metabolite: "NAD+" (ID: C00003)
%         Metabolite: "Retinol" (ID: C00473)
%     Match: "dihydrofolate:NAD+ oxidoreductase" (ID: R02235)
%         Metabolite: "NAD+" (ID: C00003)
%         Metabolite: "Dihydrofolate" (ID: C00415)
%     Match: "dihydrofolate:NADP+ oxidoreductase" (ID: R02236)
%         Metabolite: "NADP+" (ID: C00006)
%         Metabolite: "Dihydrofolate" (ID: C00415)
%     Match: "Propane-1,2-diol:NAD+ oxidoreductase" (ID: R02257)
%         Metabolite: "NAD+" (ID: C00003)
%         Metabolite: "Propane-1,2-diol" (ID: C00583)
%     Match: "L-Aspartate-4-semialdehyde:NADP+ oxidoreductase (phosphorylating)" (ID: R02291)
%         Metabolite: "NADP+" (ID: C00006)
%         Metabolite: "Orthophosphate" (ID: C00009)
%         Metabolite: "L-Aspartate 4-semialdehyde" (ID: C00441)
%     Match: "(R)-pantoate:NADP+ 2-oxidoreductase" (ID: R02472)
%         Metabolite: "NADP+" (ID: C00006)
%         Metabolite: "(R)-Pantoate" (ID: C00522)
%     Match: "beta-D-glucose-6-phosphate:NADP+ 1-oxoreductase" (ID: R02736)
%         Metabolite: "NADP+" (ID: C00006)
%         Metabolite: "beta-D-Glucose 6-phosphate" (ID: C01172)
%     Match: "dTDP-beta-L-rhamnose:NADP+ 4-oxidoreductase;" (ID: R02777)
%         Metabolite: "NADP+" (ID: C00006)
%         Metabolite: "dTDP-L-rhamnose" (ID: C03319)
%     Match: "3-Mercaptolactate:NAD+ oxidoreductase" (ID: R03104)
%         Metabolite: "NAD+" (ID: C00003)
%         Metabolite: "3-Mercaptolactate" (ID: C05823)
%     Match: "UDP-N-acetylmuramate:NADP+ oxidoreductase" (ID: R03191)
%         Metabolite: "NAD+" (ID: C00003)
%         Metabolite: "UDP-N-acetylmuramate" (ID: C01050)
%     Match: "UDP-N-acetylmuramate:NADP+ oxidoreductase" (ID: R03192)
%         Metabolite: "NADP+" (ID: C00006)
%         Metabolite: "UDP-N-acetylmuramate" (ID: C01050)
%     Match: "trans-4-Hydroxy-L-proline:NAD+ 5-oxidoreductase" (ID: R03291)
%         Metabolite: "NAD+" (ID: C00003)
%         Metabolite: "Hydroxyproline" (ID: C01157)
%     Match: "trans-4-Hydroxy-L-proline:NADP+ 5-oxidoreductase" (ID: R03293)
%         Metabolite: "NADP+" (ID: C00006)
%         Metabolite: "Hydroxyproline" (ID: C01157)
%     Match: "L-glutamate-5-semialdehyde:NADP+ 5-oxidoreductase (phosphorylating)" (ID: R03313)
%         Metabolite: "NADP+" (ID: C00006)
%         Metabolite: "Orthophosphate" (ID: C00009)
%         Metabolite: "L-Glutamate 5-semialdehyde" (ID: C01165)
%     Match: "hydrogen selenide:NADP+ oxidoreductase" (ID: R03596)
%         Metabolite: "H2O" (ID: C00001)
%         Metabolite: "NADP+" (ID: C00006)
%         Metabolite: "Hydrogen selenide" (ID: C01528)
%     Match: "butyryl-[acp]:NAD+ trans-2-oxidoreductase" (ID: R04429)
%         Metabolite: "NAD+" (ID: C00003)
%         Metabolite: "Butyryl-[acp]" (ID: C05745)
%     Match: "(3R)-3-hydroxybutanoyl-[acyl-carrier protein]:NADP+ oxidoreductase" (ID: R04533)
%         Metabolite: "NADP+" (ID: C00006)
%         Metabolite: "(3R)-3-Hydroxybutanoyl-[acyl-carrier protein]" (ID: C04618)
%     Match: "(3R)-3-hydroxydecanoyl-[acyl-carrier-protein]:NADP+ oxidoreductase" (ID: R04534)
%         Metabolite: "NADP+" (ID: C00006)
%         Metabolite: "(3R)-3-Hydroxydecanoyl-[acyl-carrier protein]" (ID: C04619)
%     Match: "(3R)-3-hydroxyoctanoyl-[acyl-carrier-protein]:NADP+ oxidoreductase" (ID: R04536)
%         Metabolite: "NADP+" (ID: C00006)
%         Metabolite: "(3R)-3-Hydroxyoctanoyl-[acyl-carrier protein]" (ID: C04620)
%     Match: "(3R)-3-hydroxypalmitoyl-[acyl-carrier-protein]:NADP+ oxidoreductase" (ID: R04543)
%         Metabolite: "NADP+" (ID: C00006)
%         Metabolite: "(3R)-3-Hydroxypalmitoyl-[acyl-carrier protein]" (ID: C04633)
%     Match: "(3R)-3-hydroxytetradecanoyl-[acyl-carrier-protein]:NADP+ oxidoreductase" (ID: R04566)
%         Metabolite: "NADP+" (ID: C00006)
%         Metabolite: "(3R)-3-Hydroxytetradecanoyl-[acyl-carrier protein]" (ID: C04688)
%     Match: "dodecanoyl-[acp]:NAD+ trans-2-oxidoreductase" (ID: R04724)
%         Metabolite: "NAD+" (ID: C00003)
%         Metabolite: "Dodecanoyl-[acyl-carrier protein]" (ID: C05223)
%     Match: "3,4-dihydroxyphenylethyleneglycol:NAD+ oxidoreductase" (ID: R04880)
%         Metabolite: "NAD+" (ID: C00003)
%         Metabolite: "3,4-Dihydroxyphenylethyleneglycol" (ID: C05576)
%     Match: "(3R)-3-hydroxyhexanoyl-[acyl-carrier-protein]:NADP+ oxidoreductase" (ID: R04953)
%         Metabolite: "NADP+" (ID: C00006)
%         Metabolite: "(3R)-3-Hydroxyhexanoyl-[acyl-carrier protein]" (ID: C05747)
%     Match: "hexanoyl-[acp]:NAD+ trans-2-oxidoreductase" (ID: R04955)
%         Metabolite: "NAD+" (ID: C00003)
%         Metabolite: "Hexanoyl-[acp]" (ID: C05749)
%     Match: "octanoyl-[acp]:NAD+ trans-2-oxidoreductase" (ID: R04958)
%         Metabolite: "NAD+" (ID: C00003)
%         Metabolite: "Octanoyl-[acp]" (ID: C05752)
%     Match: "decanoyl-[acp]:NAD+ trans-2-oxidoreductase" (ID: R04961)
%         Metabolite: "NAD+" (ID: C00003)
%         Metabolite: "Decanoyl-[acp]" (ID: C05755)
%     Match: "(3R)-3-hydroxydodecanoyl-[acyl-carrier-protein]:NADP+ oxidoreductase" (ID: R04964)
%         Metabolite: "NADP+" (ID: C00006)
%         Metabolite: "(3R)-3-Hydroxydodecanoyl-[acyl-carrier protein]" (ID: C05757)
%     Match: "tetradecanoyl-[acp]:NAD+ trans-2-oxidoreductase" (ID: R04966)
%         Metabolite: "NAD+" (ID: C00003)
%         Metabolite: "Tetradecanoyl-[acp]" (ID: C05761)
%     Match: "hexadecanoyl-[acp]:NAD+ trans-2-oxidoreductase" (ID: R04969)
%         Metabolite: "NAD+" (ID: C00003)
%         Metabolite: "Hexadecanoyl-[acp]" (ID: C05764)
%     Match: "trans-3-Chloro-2-propene-1-ol:NAD+ oxidoreductase" (ID: R05233)
%         Metabolite: "NAD+" (ID: C00003)
%         Metabolite: "trans-3-Chloro-2-propene-1-ol" (ID: C06611)
%     Match: "cis-3-chloro-2-propene-1-ol:NAD+ oxidoreductase" (ID: R05234)
%         Metabolite: "NAD+" (ID: C00003)
%         Metabolite: "cis-3-Chloro-2-propene-1-ol" (ID: C06612)
%     Match: "FMNH2:NADP+ oxidoreductase" (ID: R05706)
%         Metabolite: "NADP+" (ID: C00006)
%         Metabolite: "Reduced FMN" (ID: C01847)
%     Match: "1-hydroxymethylnaphthalene:NAD+ oxidoreductase" (ID: R06917)
%         Metabolite: "NAD+" (ID: C00003)
%         Metabolite: "1-Hydroxymethylnaphthalene" (ID: C14089)
%     Match: "(2-naphthyl)methanol:NAD+ oxidoreductase" (ID: R06927)
%         Metabolite: "NAD+" (ID: C00003)
%         Metabolite: "(2-Naphthyl)methanol" (ID: C02909)
%     Match: "trichloroethanol:NAD+ oxidoreductase" (ID: R07105)
%         Metabolite: "NADH" (ID: C00004)
%         Metabolite: "H+" (ID: C00080)
%         Metabolite: "Chloral hydrate" (ID: C06899)
%     Match: "5-methyltetrahydrofolate:NAD+ oxidoreductase" (ID: R07168)
%         Metabolite: "NAD+" (ID: C00003)
%         Metabolite: "5-Methyltetrahydrofolate" (ID: C00440)
%     Match: "octadecanoyl-[acp]:NAD+ trans-2-oxidoreductase" (ID: R07765)
%         Metabolite: "NADH" (ID: C00004)
%         Metabolite: "H+" (ID: C00080)
%         Metabolite: "(2E)-Octadecenoyl-[acp]" (ID: C16221)
%     Match: "6-thioinosine 5'-monophosphate:NAD+ oxidoreductase" (ID: R08240)
%         Metabolite: "H2O" (ID: C00001)
%         Metabolite: "NAD+" (ID: C00003)
%         Metabolite: "6-Thioinosine-5'-monophosphate" (ID: C04646)
%     Match: "alcophosphamide:NAD+ oxidoreductase" (ID: R08281)
%         Metabolite: "NADH" (ID: C00004)
%         Metabolite: "H+" (ID: C00080)
%         Metabolite: "Aldophosphamide" (ID: C07645)
%     Match: "2-phenyl-1,3-propanediol monocarbamate:NAD+ oxidoreductase" (ID: R08306)
%         Metabolite: "NAD+" (ID: C00003)
%         Metabolite: "2-Phenyl-1,3-propanediol monocarbamate" (ID: C16586)
%     Match: "4-hydroxy-5-phenyltetrahydro-1,3-oxazin-2-one:NAD+ oxidoreductase" (ID: R08310)
%         Metabolite: "NAD+" (ID: C00003)
%         Metabolite: "4-Hydroxy-5-phenyltetrahydro-1,3-oxazin-2-one" (ID: C16595)
%     Match: "2-dehydro-L-idonate:NADP+ 5-oxidoreductase" (ID: R08878)
%         Metabolite: "NADP+" (ID: C00006)
%         Metabolite: "2-Dehydro-L-idonate" (ID: C15673)
%     Match: "methaneselenol:NADP+ oxidoreductase" (ID: R09372)
%         Metabolite: "NADPH" (ID: C00005)
%         Metabolite: "H+" (ID: C00080)
%         Metabolite: "Methylselenic acid" (ID: C18902)
%     Match: "adrenodoxin:NADP+ oxidoreductase" (ID: R10159)
%         Metabolite: "NADP+" (ID: C00006)
%         Metabolite: "H+" (ID: C00080)
%         Metabolite: "Reduced adrenal ferredoxin" (ID: C00662)
%     Match: "6-phospho-D-gluconate:NAD+ 2-oxidoreductase (decarboxylating)" (ID: R10221)
%         Metabolite: "NAD+" (ID: C00003)
%         Metabolite: "6-Phospho-D-gluconate" (ID: C00345)
%     Match: "beta-D-glucose-6-phosphate:NAD+ 1-oxidoreductase" (ID: R10907)
%         Metabolite: "NAD+" (ID: C00003)
%         Metabolite: "beta-D-Glucose 6-phosphate" (ID: C01172)
%     Match: "tetrahydrobiopterin:NADP+ oxidoreductase (7,8-dihydrobiopterin-forming)" (ID: R11765)
%         Metabolite: "NADP+" (ID: C00006)
%         Metabolite: "Tetrahydrobiopterin" (ID: C00272)
%     Match: "beta-L-fucopyranose:NADP+ 1-oxidoreductase" (ID: R13105)
%         Metabolite: "NADP+" (ID: C00006)
%         Metabolite: "beta-L-Fucopyranose" (ID: C20836)
%     Match: "liquiritigenin,[reduced NADPH---hemoprotein reductase]:oxygen oxidoreductase (licodione-forming)" (ID: R07198)
%         Metabolite: "Oxygen" (ID: C00007)
%         Metabolite: "[Reduced NADPH---hemoprotein reductase]" (ID: C03024)
%         Metabolite: "Liquiritigenin" (ID: C09762)
%     Match: "pyruvate:NAD+ 2-oxidoreductase (CoA-acetylating);" (ID: R00209)
%         Metabolite: "NAD+" (ID: C00003)
%         Metabolite: "CoA" (ID: C00010)
%         Metabolite: "Pyruvate" (ID: C00022)
%     Match: "glycine:NAD+ 2-oxidoreductase (tetrahydrofolate-methylene-adding);" (ID: R01221)
%         Metabolite: "NAD+" (ID: C00003)
%         Metabolite: "Glycine" (ID: C00037)
%         Metabolite: "Tetrahydrofolate" (ID: C00101)
%     Match: "beta-D-Glucose:NAD+ 1-oxoreductase" (ID: R01520)
%         Metabolite: "NAD+" (ID: C00003)
%         Metabolite: "beta-D-Glucose" (ID: C00221)
%     Match: "beta-D-Glucose:NADP+ 1-oxoreductase" (ID: R01521)
%         Metabolite: "NADP+" (ID: C00006)
%         Metabolite: "beta-D-Glucose" (ID: C00221)
%     Match: "2-Dehydro-3-deoxy-D-gluconate:NAD+ 5-oxidoreductase" (ID: R01542)
%         Metabolite: "NAD+" (ID: C00003)
%         Metabolite: "2-Dehydro-3-deoxy-D-gluconate" (ID: C00204)
%     Match: "Dihydrolipoamide:NAD+ oxidoreductase" (ID: R01698)
%         Metabolite: "NAD+" (ID: C00003)
% ...
%     Match: "2-oxoglutarate:NAD+ 2-oxidoreductase (CoA-succinylating);" (ID: R08549)
%         Metabolite: "NAD+" (ID: C00003)
%         Metabolite: "CoA" (ID: C00010)
%         Metabolite: "2-Oxoglutarate" (ID: C00026)
%     Match: "(S)-acetoin:NAD+ oxidoreductase" (ID: R09078)
%         Metabolite: "NADH" (ID: C00004)
%         Metabolite: "H+" (ID: C00080)
%         Metabolite: "Diacetyl" (ID: C00741)
%     Match: "3-hydroxyglutaryl-[acp]-methyl-ester:NADP+ oxidoreductase" (ID: R10116)
%         Metabolite: "NADPH" (ID: C00005)
%         Metabolite: "H+" (ID: C00080)
%         Metabolite: "3-Ketoglutaryl-[acp] methyl ester" (ID: C20372)
%     Match: "3-hydroxypimeloyl-[acp]-methyl-ester:NADP+ oxidoreductase" (ID: R10120)
%         Metabolite: "NADPH" (ID: C00005)
%         Metabolite: "H+" (ID: C00080)
%         Metabolite: "3-Ketopimeloyl-[acp] methyl ester" (ID: C20376)
%     Match: "dTDP-6-deoxy-beta-L-talose:NAD+ 4-oxidoreductase" (ID: R10190)
%         Metabolite: "NAD+" (ID: C00003)
%         Metabolite: "dTDP-6-deoxy-beta-L-talose" (ID: C03187)
%     Match: "meso-2,3-butanediol:NAD+ oxidoreductase [(R)-acetoin forming]" (ID: R10505)
%         Metabolite: "NAD+" (ID: C00003)
%         Metabolite: "meso-2,3-Butanediol" (ID: C20657)
%     Match: "L-dihydroanticapsin:NAD+ oxidoreductase" (ID: R10917)
%         Metabolite: "NAD+" (ID: C00003)
%         Metabolite: "L-Dihydroanticapsin" (ID: C20940)
%     Match: "2-dehydro-3-deoxy-L-rhamnonate:NAD+ 4-oxidoreductase" (ID: R11339)
%         Metabolite: "NAD+" (ID: C00003)
%         Metabolite: "2-Dehydro-3-deoxy-L-rhamnonate" (ID: C03979)
% Precursor "NADP" → 40 matches found
%     Match: "D-glucose-6-phosphate:NADP+ 1-oxidoreductase" (ID: R00835)
%         Metabolite: "NADP+" (ID: C00006)
%         Metabolite: "D-Glucose 6-phosphate" (ID: C00092)
%     Match: "sn-Glycerol-3-phosphate:NADP+ 2-oxidoreductase" (ID: R00844)
%         Metabolite: "NADP+" (ID: C00006)
%         Metabolite: "sn-Glycerol 3-phosphate" (ID: C00093)
%     Match: "5,6,7,8-tetrahydrofolate:NADP+ oxidoreductase" (ID: R00939)
%         Metabolite: "NADP+" (ID: C00006)
%         Metabolite: "Tetrahydrofolate" (ID: C00101)
%     Match: "5,6,7,8-tetrahydrofolate:NADP+ oxidoreductase" (ID: R00940)
%         Metabolite: "NADP+" (ID: C00006)
%         Metabolite: "Tetrahydrofolate" (ID: C00101)
%     Match: "5,10-methylenetetrahydrofolate:NADP+ oxidoreductase" (ID: R01220)
%         Metabolite: "NADP+" (ID: C00006)
%         Metabolite: "5,10-Methylenetetrahydrofolate" (ID: C00143)
%     Match: "L-Proline:NADP+ 5-oxidoreductase" (ID: R01251)
%         Metabolite: "NADP+" (ID: C00006)
%         Metabolite: "L-Proline" (ID: C00148)
%     Match: "6-phospho-D-gluconate:NADP+ 2-oxidoreductase (decarboxylating)" (ID: R01528)
%         Metabolite: "NADP+" (ID: C00006)
%         Metabolite: "6-Phospho-D-gluconate" (ID: C00345)
%     Match: "Pyridoxine:NADP+ 4-oxidoreductase" (ID: R01708)
%         Metabolite: "NADP+" (ID: C00006)
%         Metabolite: "Pyridoxine" (ID: C00314)
%     Match: "L-homoserine:NADP+ oxidoreductase" (ID: R01775)
%         Metabolite: "NADP+" (ID: C00006)
%         Metabolite: "L-Homoserine" (ID: C00263)
%     Match: "NADPH:oxidized-thioredoxin oxidoreductase" (ID: R02016)
%         Metabolite: "NADP+" (ID: C00006)
%         Metabolite: "Thioredoxin" (ID: C00342)
%     Match: "dihydrofolate:NADP+ oxidoreductase" (ID: R02236)
%         Metabolite: "NADP+" (ID: C00006)
%         Metabolite: "Dihydrofolate" (ID: C00415)
%     Match: "L-Aspartate-4-semialdehyde:NADP+ oxidoreductase (phosphorylating)" (ID: R02291)
%         Metabolite: "NADP+" (ID: C00006)
%         Metabolite: "Orthophosphate" (ID: C00009)
%         Metabolite: "L-Aspartate 4-semialdehyde" (ID: C00441)
%     Match: "(R)-pantoate:NADP+ 2-oxidoreductase" (ID: R02472)
%         Metabolite: "NADP+" (ID: C00006)
%         Metabolite: "(R)-Pantoate" (ID: C00522)
%     Match: "beta-D-glucose-6-phosphate:NADP+ 1-oxoreductase" (ID: R02736)
%         Metabolite: "NADP+" (ID: C00006)
%         Metabolite: "beta-D-Glucose 6-phosphate" (ID: C01172)
%     Match: "dTDP-beta-L-rhamnose:NADP+ 4-oxidoreductase;" (ID: R02777)
%         Metabolite: "NADP+" (ID: C00006)
%         Metabolite: "dTDP-L-rhamnose" (ID: C03319)
%     Match: "UDP-N-acetylmuramate:NADP+ oxidoreductase" (ID: R03191)
%         Metabolite: "NAD+" (ID: C00003)
%         Metabolite: "UDP-N-acetylmuramate" (ID: C01050)
%     Match: "UDP-N-acetylmuramate:NADP+ oxidoreductase" (ID: R03192)
%         Metabolite: "NADP+" (ID: C00006)
%         Metabolite: "UDP-N-acetylmuramate" (ID: C01050)
%     Match: "trans-4-Hydroxy-L-proline:NADP+ 5-oxidoreductase" (ID: R03293)
%         Metabolite: "NADP+" (ID: C00006)
%         Metabolite: "Hydroxyproline" (ID: C01157)
%     Match: "L-glutamate-5-semialdehyde:NADP+ 5-oxidoreductase (phosphorylating)" (ID: R03313)
%         Metabolite: "NADP+" (ID: C00006)
%         Metabolite: "Orthophosphate" (ID: C00009)
%         Metabolite: "L-Glutamate 5-semialdehyde" (ID: C01165)
%     Match: "hydrogen selenide:NADP+ oxidoreductase" (ID: R03596)
%         Metabolite: "H2O" (ID: C00001)
%         Metabolite: "NADP+" (ID: C00006)
%         Metabolite: "Hydrogen selenide" (ID: C01528)
%     Match: "(3R)-3-hydroxybutanoyl-[acyl-carrier protein]:NADP+ oxidoreductase" (ID: R04533)
%         Metabolite: "NADP+" (ID: C00006)
%         Metabolite: "(3R)-3-Hydroxybutanoyl-[acyl-carrier protein]" (ID: C04618)
%     Match: "(3R)-3-hydroxydecanoyl-[acyl-carrier-protein]:NADP+ oxidoreductase" (ID: R04534)
%         Metabolite: "NADP+" (ID: C00006)
%         Metabolite: "(3R)-3-Hydroxydecanoyl-[acyl-carrier protein]" (ID: C04619)
%     Match: "(3R)-3-hydroxyoctanoyl-[acyl-carrier-protein]:NADP+ oxidoreductase" (ID: R04536)
%         Metabolite: "NADP+" (ID: C00006)
%         Metabolite: "(3R)-3-Hydroxyoctanoyl-[acyl-carrier protein]" (ID: C04620)
%     Match: "(3R)-3-hydroxypalmitoyl-[acyl-carrier-protein]:NADP+ oxidoreductase" (ID: R04543)
%         Metabolite: "NADP+" (ID: C00006)
%         Metabolite: "(3R)-3-Hydroxypalmitoyl-[acyl-carrier protein]" (ID: C04633)
%     Match: "(3R)-3-hydroxytetradecanoyl-[acyl-carrier-protein]:NADP+ oxidoreductase" (ID: R04566)
%         Metabolite: "NADP+" (ID: C00006)
%         Metabolite: "(3R)-3-Hydroxytetradecanoyl-[acyl-carrier protein]" (ID: C04688)
%     Match: "(3R)-3-hydroxyhexanoyl-[acyl-carrier-protein]:NADP+ oxidoreductase" (ID: R04953)
%         Metabolite: "NADP+" (ID: C00006)
%         Metabolite: "(3R)-3-Hydroxyhexanoyl-[acyl-carrier protein]" (ID: C05747)
%     Match: "(3R)-3-hydroxydodecanoyl-[acyl-carrier-protein]:NADP+ oxidoreductase" (ID: R04964)
%         Metabolite: "NADP+" (ID: C00006)
%         Metabolite: "(3R)-3-Hydroxydodecanoyl-[acyl-carrier protein]" (ID: C05757)
%     Match: "FMNH2:NADP+ oxidoreductase" (ID: R05706)
%         Metabolite: "NADP+" (ID: C00006)
%         Metabolite: "Reduced FMN" (ID: C01847)
%     Match: "2-dehydro-L-idonate:NADP+ 5-oxidoreductase" (ID: R08878)
%         Metabolite: "NADP+" (ID: C00006)
%         Metabolite: "2-Dehydro-L-idonate" (ID: C15673)
%     Match: "methaneselenol:NADP+ oxidoreductase" (ID: R09372)
%         Metabolite: "NADPH" (ID: C00005)
%         Metabolite: "H+" (ID: C00080)
%         Metabolite: "Methylselenic acid" (ID: C18902)
%     Match: "adrenodoxin:NADP+ oxidoreductase" (ID: R10159)
%         Metabolite: "NADP+" (ID: C00006)
%         Metabolite: "H+" (ID: C00080)
%         Metabolite: "Reduced adrenal ferredoxin" (ID: C00662)
%     Match: "tetrahydrobiopterin:NADP+ oxidoreductase (7,8-dihydrobiopterin-forming)" (ID: R11765)
%         Metabolite: "NADP+" (ID: C00006)
%         Metabolite: "Tetrahydrobiopterin" (ID: C00272)
%     Match: "beta-L-fucopyranose:NADP+ 1-oxidoreductase" (ID: R13105)
%         Metabolite: "NADP+" (ID: C00006)
%         Metabolite: "beta-L-Fucopyranose" (ID: C20836)
%     Match: "liquiritigenin,[reduced NADPH---hemoprotein reductase]:oxygen oxidoreductase (licodione-forming)" (ID: R07198)
%         Metabolite: "Oxygen" (ID: C00007)
%         Metabolite: "[Reduced NADPH---hemoprotein reductase]" (ID: C03024)
%         Metabolite: "Liquiritigenin" (ID: C09762)
%     Match: "beta-D-Glucose:NADP+ 1-oxoreductase" (ID: R01521)
%         Metabolite: "NADP+" (ID: C00006)
%         Metabolite: "beta-D-Glucose" (ID: C00221)
%     Match: "(3R)-3-hydroxyacyl-CoA:NADP+ oxidoreductase" (ID: R01779)
%         Metabolite: "NADP+" (ID: C00006)
%         Metabolite: "(3R)-3-Hydroxyacyl-CoA" (ID: C01086)
%     Match: "(R)-3-Hydroxybutanoyl-CoA:NADP+ oxidoreductase" (ID: R01977)
%         Metabolite: "NADP+" (ID: C00006)
%         Metabolite: "(R)-3-Hydroxybutanoyl-CoA" (ID: C03561)
%     Match: "(S)-lactaldehyde:NADP+ oxidoreductase" (ID: R02260)
%         Metabolite: "NADP+" (ID: C00006)
%         Metabolite: "(S)-Lactaldehyde" (ID: C00424)
%     Match: "3-hydroxyglutaryl-[acp]-methyl-ester:NADP+ oxidoreductase" (ID: R10116)
%         Metabolite: "NADPH" (ID: C00005)
%         Metabolite: "H+" (ID: C00080)
%         Metabolite: "3-Ketoglutaryl-[acp] methyl ester" (ID: C20372)
%     Match: "3-hydroxypimeloyl-[acp]-methyl-ester:NADP+ oxidoreductase" (ID: R10120)
%         Metabolite: "NADPH" (ID: C00005)
%         Metabolite: "H+" (ID: C00080)
%         Metabolite: "3-Ketopimeloyl-[acp] methyl ester" (ID: C20376)
% Precursor "FAD" → no matches found
% Precursor "CoA" → 35 matches found
%     Match: "ATP:dephospho-CoA 3'-phosphotransferase" (ID: R00130)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "Dephospho-CoA" (ID: C00882)
%     Match: "Acetyl-CoA:formate C-acetyltransferase" (ID: R00212)
%         Metabolite: "Acetyl-CoA" (ID: C00024)
%         Metabolite: "Formate" (ID: C00058)
%     Match: "acetaldehyde:NAD+ oxidoreductase (CoA-acetylating)" (ID: R00228)
%         Metabolite: "NAD+" (ID: C00003)
%         Metabolite: "CoA" (ID: C00010)
%         Metabolite: "Acetaldehyde" (ID: C00084)
%     Match: "acetyl-CoA:phosphate acetyltransferase" (ID: R00230)
%         Metabolite: "Orthophosphate" (ID: C00009)
%         Metabolite: "Acetyl-CoA" (ID: C00024)
%     Match: "acetyl-CoA:acetyl-CoA C-acetyltransferase" (ID: R00238)
%         Metabolite: "Acetyl-CoA" (ID: C00024)
%     Match: "acetyl-CoA:L-serine O-acetyltransferase" (ID: R00586)
%         Metabolite: "Acetyl-CoA" (ID: C00024)
%         Metabolite: "L-Serine" (ID: C00065)
%     Match: "acetyl-CoA:carbon-dioxide ligase (ADP-forming)" (ID: R00742)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "Acetyl-CoA" (ID: C00024)
%         Metabolite: "HCO3-" (ID: C00288)
%     Match: "propanoyl-CoA:phosphate propanoyltransferase" (ID: R00921)
%         Metabolite: "Orthophosphate" (ID: C00009)
%         Metabolite: "Propanoyl-CoA" (ID: C00100)
%     Match: "biotin:CoA ligase (AMP-forming);" (ID: R01074)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "Biotin" (ID: C00120)
%     Match: "butanal:NAD+ oxidoreductase (CoA-acylating)" (ID: R01172)
%         Metabolite: "NAD+" (ID: C00003)
%         Metabolite: "CoA" (ID: C00010)
%         Metabolite: "Butanal" (ID: C01412)
%     Match: "butanoyl-CoA:acetyl-CoA C-butanoyltransferase" (ID: R01177)
%         Metabolite: "Acetyl-CoA" (ID: C00024)
%         Metabolite: "Butanoyl-CoA" (ID: C00136)
%     Match: "Palmitate:CoA ligase (AMP-forming)" (ID: R01280)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "CoA" (ID: C00010)
%         Metabolite: "Hexadecanoic acid" (ID: C00249)
%     Match: "acetyl-CoA:[acyl-carrier-protein] S-acetyltransferase" (ID: R01624)
%         Metabolite: "Acetyl-CoA" (ID: C00024)
%         Metabolite: "Acyl-carrier protein" (ID: C00229)
%     Match: "CoA:apo-[acyl-carrier-protein] pantetheinephosphotransferase" (ID: R01625)
%         Metabolite: "CoA" (ID: C00010)
%         Metabolite: "Apo-[acyl-carrier-protein]" (ID: C03688)
%     Match: "Malonyl-CoA:[acyl-carrier-protein] S-malonyltransferase" (ID: R01626)
%         Metabolite: "Malonyl-CoA" (ID: C00083)
%         Metabolite: "Acyl-carrier protein" (ID: C00229)
%     Match: "propanoyl-CoA:carbon-dioxide ligase (ADP-forming)" (ID: R01859)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "Propanoyl-CoA" (ID: C00100)
%         Metabolite: "HCO3-" (ID: C00288)
%     Match: "acetyl-CoA:acetoacetyl-CoA C-acetyltransferase (thioester-hydrolysing, carboxymethyl-forming)" (ID: R01978)
%         Metabolite: "CoA" (ID: C00010)
%         Metabolite: "(S)-3-Hydroxy-3-methylglutaryl-CoA" (ID: C00356)
%     Match: "(R)-Mevalonate:NAD+ oxidoreductase (CoA-acetylating)" (ID: R02081)
%         Metabolite: "NAD+" (ID: C00003)
%         Metabolite: "CoA" (ID: C00010)
%         Metabolite: "(R)-Mevalonate" (ID: C00418)
%     Match: "acyl-CoA:1-acyl-sn-glycerol-3-phosphate 2-O-acyltransferase" (ID: R02241)
%         Metabolite: "CoA" (ID: C00010)
%         Metabolite: "Phosphatidate" (ID: C00416)
%     Match: "Acetyl-CoA:D-glucosamine-1-phosphate N-acetyltransferase" (ID: R05332)
%         Metabolite: "Acetyl-CoA" (ID: C00024)
%         Metabolite: "alpha-D-Glucosamine 1-phosphate" (ID: C06156)
%     Match: "propanoyl-CoA:formate C-propanoyltransferase" (ID: R06987)
%         Metabolite: "CoA" (ID: C00010)
%         Metabolite: "2-Oxobutanoate" (ID: C00109)
%     Match: "palmitoyl-[acp]:CoA S-palmitoyltransferase" (ID: R10700)
%         Metabolite: "CoA" (ID: C00010)
%         Metabolite: "Hexadecanoyl-[acp]" (ID: C05764)
%     Match: "pyruvate:NAD+ 2-oxidoreductase (CoA-acetylating);" (ID: R00209)
%         Metabolite: "NAD+" (ID: C00003)
%         Metabolite: "CoA" (ID: C00010)
%         Metabolite: "Pyruvate" (ID: C00022)
%     Match: "succinyl-CoA:acetyl-CoA C-acyltransferase;" (ID: R00829)
%         Metabolite: "Acetyl-CoA" (ID: C00024)
%         Metabolite: "Succinyl-CoA" (ID: C00091)
%     Match: "acetyl-CoA:propanoyl-CoA 2-C-acetyltransferase;" (ID: R00927)
%         Metabolite: "Acetyl-CoA" (ID: C00024)
%         Metabolite: "Propanoyl-CoA" (ID: C00100)
%     Match: "(3R)-3-hydroxyacyl-CoA:NADP+ oxidoreductase" (ID: R01779)
%         Metabolite: "NADP+" (ID: C00006)
%         Metabolite: "(3R)-3-Hydroxyacyl-CoA" (ID: C01086)
%     Match: "(R)-3-Hydroxybutanoyl-CoA:NADP+ oxidoreductase" (ID: R01977)
%         Metabolite: "NADP+" (ID: C00006)
%         Metabolite: "(R)-3-Hydroxybutanoyl-CoA" (ID: C03561)
%     Match: "Octanoyl-CoA:acetyl-CoA C-acyltransferase" (ID: R03778)
%         Metabolite: "Acetyl-CoA" (ID: C00024)
%         Metabolite: "Octanoyl-CoA" (ID: C01944)
%     Match: "Lauroyl-CoA:acetyl-CoA C-acyltransferase" (ID: R03858)
%         Metabolite: "Acetyl-CoA" (ID: C00024)
%         Metabolite: "Lauroyl-CoA" (ID: C01832)
%     Match: "myristoyl-CoA:acetylCoA C-myristoyltransferase" (ID: R03991)
%         Metabolite: "Acetyl-CoA" (ID: C00024)
%         Metabolite: "Tetradecanoyl-CoA" (ID: C02593)
%     Match: "Decanoyl-CoA:acetyl-CoA C-acyltransferase" (ID: R04742)
%         Metabolite: "Acetyl-CoA" (ID: C00024)
%         Metabolite: "Decanoyl-CoA" (ID: C05274)
%     Match: "Hexanoyl-CoA:acetyl-CoA C-acyltransferase" (ID: R04747)
%         Metabolite: "Acetyl-CoA" (ID: C00024)
%         Metabolite: "Hexanoyl-CoA" (ID: C05270)
%     Match: "7-methyl-3-oxo-6-octenoyl-CoA:acetyl-CoA C-acyltransferase" (ID: R08091)
%         Metabolite: "CoA" (ID: C00010)
%         Metabolite: "7-Methyl-3-oxo-6-octenoyl-CoA" (ID: C16466)
%     Match: "3-methylcrotonyl-CoA:acetyl-CoA C-acyltransferase" (ID: R08095)
%         Metabolite: "CoA" (ID: C00010)
%         Metabolite: "5-Methyl-3-oxo-4-hexenoyl-CoA" (ID: C16471)
%     Match: "2-oxoglutarate:NAD+ 2-oxidoreductase (CoA-succinylating);" (ID: R08549)
%         Metabolite: "NAD+" (ID: C00003)
%         Metabolite: "CoA" (ID: C00010)
%         Metabolite: "2-Oxoglutarate" (ID: C00026)
% Precursor "Heme" → no matches found
% Precursor "Peptidoglycan" → no matches found
% Precursor "Lipoteichoic acid" → no matches found
% Precursor "Phosphatidylglycerol" → 1 matches found
%     Match: "CDP-diacylglycerol:phosphatidylglycerol 3-phosphatidyltransferase" (ID: R02030)
%         Metabolite: "CDP-diacylglycerol" (ID: C00269)
%         Metabolite: "Phosphatidylglycerol" (ID: C00344)
% Precursor "Cardiolipin" → no matches found
% Warning: Repeated mets in the formula for rxn 'BIOMASS_ps'. Combine the stoichiometry.
% test
% CSV table saved to "Gvaginalis_biomass_metabolites.csv"
% Added biomass reaction "BIOMASS_ps" with 827 metabolite entries (duplicates kept).

% %% [markdown]
% Quick cleaning to ensure RAVEN structures are correctly kept:

% %%
GvaginalisBiomassDraftModel = syncModelStruct(GvaginalisBiomassDraftModel, 'Gvaginalis_biomass_sync_log.csv');
% Out:
% syncModelStruct: Log saved to "Gvaginalis_biomass_sync_log.csv"

% %%
checkModelCoreConsistency(GvaginalisBiomassDraftModel);
% Out:
% --- BASIC DIMENSION CHECKS ---
% Reactions: 706
% Metabolites: 979
% Genes: 583
% Empty grRules in 147 reactions

% %%
GvaginalisBiomassDraftModel = sanitizeGEMforSBML(GvaginalisBiomassDraftModel);
GvaginalisBiomassDraftModel = fixRxnConfidenceScores(GvaginalisBiomassDraftModel);

% %% [markdown]
% I will now save the new model with the biomass reaction included:

% %%
exportModel(GvaginalisBiomassDraftModel, 'Gvaginalis_draftGEM_v3.xml');
% Out:
% WARNING: The following InChI strings are associated to more than one unique metabolite name:
%     1S/C10H20O7P2/c1-9(2)5-4-6-10(3)7-8-16-19(14,15)17-18(11,12)13/h5,7H,4,6,8H2,1-3H3,(H,14,15)(H2,11,12,13)/b10-7+
% Document written

% %%
exportToExcelFormat(GvaginalisBiomassDraftModel, 'Gvaginalis_draftGEM_v3.xlsx');
save('Gvaginalis_draftGEM_v3.mat', 'GvaginalisBiomassDraftModel');

% %% [markdown]
% Now that a biomass reaction has been added to the model, I will try to solve again:

% %%
%GvaginalisBiomassDraftModel = importModel('Gvaginalis_draftGEM_v3.xml');
sol2 = solveLP(GvaginalisBiomassDraftModel);
disp(sol2.f)
% Out:
%      0

% %% [markdown]
% Still 0, so still no growth.
%
% ## Addition of exchange reactions
%
% The simplified gap report:

% %%
% taking a look at the gap situation
%gapReport(GvaginalisBiomassDraftModel);
gapReport_vSimple(GvaginalisBiomassDraftModel);
% Out:
% Dead-end metabolites: 494
%     {'C00016'}
%     {'C00040'}
%     {'C00042'}
%     {'C00071'}
%     {'C00081'}
%     {'C00088'}
%     {'C00089'}
%     {'C00127'}
%     {'C00132'}
%     {'C00173'}
%     {'C00201'}
%     {'C00232'}
%     {'C00243'}
%     {'C00250'}
%     {'C00252'}
%     {'C00253'}
%     {'C00259'}
%     {'C00299'}
%     {'C00302'}
%     {'C00330'}
%     {'C00353'}
%     {'C00354'}
%     {'C00363'}
%     {'C00376'}
%     {'C00447'}
%     {'C00450'}
%     {'C00454'}
%     {'C00506'}
%     {'C00536'}
%     {'C00577'}
%     {'C00667'}
%     {'C00671'}
%     {'C00683'}
%     {'C00700'}
%     {'C00721'}
%     {'C00935'}
%     {'C00962'}
%     {'C00966'}
%     {'C00973'}
%     {'C00988'}
%     {'C01019'}
%     {'C01024'}
%     {'C01041'}
%     {'C01094'}
%     {'C01100'}
%     {'C01101'}
%     {'C01117'}
%     {'C01133'}
%     {'C01177'}
%     {'C01190'}
%     {'C01252'}
%     {'C01267'}
%     {'C01289'}
%     {'C01290'}
%     {'C01297'}
%     {'C01345'}
%     {'C01353'}
%     {'C01390'}
%     {'C01419'}
%     {'C01424'}
%     {'C01471'}
%     {'C01592'}
%     {'C01642'}
%     {'C01717'}
%     {'C01720'}
%     {'C01752'}
%     {'C01801'}
%     {'C01888'}
%     {'C01931'}
%     {'C01997'}
%     {'C02047'}
%     {'C02097'}
%     {'C02163'}
%     {'C02188'}
%     {'C02348'}
%     {'C02350'}
%     {'C02356'}
%     {'C02380'}
%     {'C02412'}
%     {'C02415'}
%     {'C02470'}
%     {'C02479'}
%     {'C02553'}
%     {'C02554'}
%     {'C02637'}
%     {'C02686'}
%     {'C02702'}
%     {'C02780'}
%     {'C02839'}
%     {'C02952'}
%     {'C02953'}
%     {'C02967'}
%     {'C02984'}
%     {'C02987'}
%     {'C02988'}
%     {'C02992'}
%     {'C03028'}
%     {'C03089'}
%     {'C03125'}
%     {'C03127'}
%     {'C03160'}
%     {'C03161'}
%     {'C03219'}
%     {'C03241'}
%     {'C03289'}
%     {'C03294'}
%     {'C03309'}
%     {'C03458'}
%     {'C03492'}
%     {'C03508'}
%     {'C03511'}
%     {'C03512'}
%     {'C03546'}
%     {'C03657'}
%     {'C03658'}
%     {'C03671'}
%     {'C03733'}
%     {'C03758'}
%     {'C03771'}
%     {'C03826'}
%     {'C03827'}
%     {'C03892'}
%     {'C04046'}
%     {'C04051'}
%     {'C04076'}
%     {'C04088'}
%     {'C04157'}
%     {'C04188'}
%     {'C04236'}
%     {'C04242'}
%     {'C04257'}
%     {'C04327'}
%     {'C04352'}
%     {'C04419'}
%     {'C04431'}
%     {'C04432'}
%     {'C04522'}
%     {'C04534'}
%     {'C04574'}
%     {'C04625'}
%     {'C04672'}
%     {'C04706'}
%     {'C04718'}
%     {'C04807'}
%     {'C04874'}
%     {'C04877'}
%     {'C04895'}
%     {'C05190'}
%     {'C05191'}
%     {'C05199'}
%     {'C05269'}
%     {'C05312'}
%     {'C05322'}
%     {'C05336'}
%     {'C05378'}
%     {'C05394'}
%     {'C05403'}
%     {'C05527'}
%     {'C05528'}
%     {'C05570'}
%     {'C05577'}
%     {'C05578'}
%     {'C05587'}
%     {'C05645'}
%     {'C05691'}
%     {'C05703'}
%     {'C05726'}
%     {'C05729'}
%     {'C05766'}
%     {'C05840'}
%     {'C05847'}
%     {'C05894'}
%     {'C05898'}
%     {'C05914'}
%     {'C05916'}
%     {'C05921'}
%     {'C05923'}
%     {'C05946'}
%     {'C05947'}
%     {'C05980'}
%     {'C06056'}
%     {'C06066'}
%     {'C06102'}
%     {'C06113'}
%     {'C06128'}
%     {'C06173'}
%     {'C06196'}
%     {'C06250'}
%     {'C06364'}
%     {'C06481'}
%     {'C06555'}
%     {'C06594'}
%     {'C06597'}
%     {'C06598'}
%     {'C06602'}
%     {'C06613'}
%     {'C06620'}
%     {'C06717'}
%     {'C06735'}
%     {'C06755'}
%     {'C06986'}
%     {'C07304'}
%     {'C07307'}
%     {'C07335'}
%     {'C07541'}
%     {'C07647'}
%     {'C07648'}
%     {'C08353'}
%     {'C08537'}
%     {'C08540'}
%     {'C08543'}
%     {'C08557'}
%     {'C08565'}
%     {'C09315'}
%     {'C09332'}
%     {'C09382'}
%     {'C09440'}
%     {'C11149'}
%     {'C11405'}
%     {'C11419'}
%     {'C11437'}
%     {'C11633'}
%     {'C11634'}
%     {'C11638'}
%     {'C11680'}
%     {'C11713'}
%     {'C11714'}
%     {'C11813'}
%     {'C11814'}
%     {'C11822'}
%     {'C11838'}
%     {'C11887'}
%     {'C11930'}
%     {'C12119'}
%     {'C12214'}
%     {'C12215'}
%     {'C12396'}
%     {'C12397'}
%     {'C14090'}
%     {'C14099'}
%     {'C14180'}
%     {'C14786'}
%     {'C14787'}
%     {'C14866'}
%     {'C14909'}
%     {'C15670'}
%     {'C15986'}
%     {'C16075'}
%     {'C16138'}
%     {'C16151'}
%     {'C16152'}
%     {'C16186'}
%     {'C16348'}
%     {'C16392'}
%     {'C16413'}
%     {'C16551'}
%     {'C16556'}
%     {'C16559'}
%     {'C16587'}
%     {'C16596'}
%     {'C16614'}
%     {'C16615'}
%     {'C16617'}
%     {'C16619'}
%     {'C16639'}
%     {'C16663'}
%     {'C16664'}
%     {'C16675'}
%     {'C16999'}
%     {'C17204'}
%     {'C17211'}
%     {'C17213'}
%     {'C17216'}
%     {'C17217'}
%     {'C17349'}
%     {'C17550'}
%     {'C17751'}
%     {'C17752'}
%     {'C17753'}
%     {'C17754'}
%     {'C17755'}
%     {'C17757'}
%     {'C17758'}
%     {'C18022'}
%     {'C18028'}
%     {'C18063'}
%     {'C18064'}
%     {'C18094'}
%     {'C18235'}
%     {'C18345'}
%     {'C18871'}
%     {'C19079'}
%     {'C19084'}
%     {'C19491'}
%     {'C19563'}
%     {'C19564'}
%     {'C19566'}
%     {'C19567'}
%     {'C19568'}
%     {'C19577'}
%     {'C19578'}
%     {'C19580'}
%     {'C19581'}
%     {'C19714'}
%     {'C19723'}
%     {'C19847'}
%     {'C19944'}
%     {'C20231'}
%     {'C20246'}
%     {'C20254'}
%     {'C20258'}
%     {'C20267'}
%     {'C20271'}
%     {'C20279'}
%     {'C20297'}
%     {'C20299'}
%     {'C20312'}
%     {'C20315'}
%     {'C20329'}
%     {'C20330'}
%     {'C20361'}
%     {'C20379'}
%     {'C20390'}
%     {'C20409'}
%     {'C20446'}
%     {'C20449'}
%     {'C20451'}
%     {'C20457'}
%     {'C20650'}
%     {'C20729'}
%     {'C20743'}
%     {'C20773'}
%     {'C20835'}
%     {'C20852'}
%     {'C20853'}
%     {'C20858'}
%     {'C20899'}
%     {'C20900'}
%     {'C20901'}
%     {'C20937'}
%     {'C21026'}
%     {'C21075'}
%     {'C21140'}
%     {'C21142'}
%     {'C21152'}
%     {'C21154'}
%     {'C21158'}
%     {'C21192'}
%     {'C21214'}
%     {'C21408'}
%     {'C21410'}
%     {'C21412'}
%     {'C21437'}
%     {'C21440'}
%     {'C21442'}
%     {'C21459'}
%     {'C21476'}
%     {'C21582'}
%     {'C21589'}
%     {'C21590'}
%     {'C21599'}
%     {'C21600'}
%     {'C21620'}
%     {'C21622'}
%     {'C21623'}
%     {'C21731'}
%     {'C21751'}
%     {'C21787'}
%     {'C21897'}
%     {'C21922'}
%     {'C21923'}
%     {'C21930'}
%     {'C22050'}
%     {'C22051'}
%     {'C22054'}
%     {'C22070'}
%     {'C22084'}
%     {'C22148'}
%     {'C22149'}
%     {'C22238'}
%     {'C22329'}
%     {'C22331'}
%     {'C22332'}
%     {'C22333'}
%     {'C22334'}
%     {'C22395'}
%     {'C22432'}
%     {'C22438'}
%     {'C22442'}
%     {'C22488'}
%     {'C22624'}
%     {'C22647'}
%     {'C22648'}
%     {'G00317'}
%     {'G10504'}
%     {'G10552'}
%     {'G10553'}
%     {'G10555'}
%     {'G10556'}
%     {'G10608'}
%     {'G10609'}
%     {'G11121'}
%     {'G13118'}
%     {'G13119'}
%     {'G13121'}
%     {'G13163'}
%     {'G13164'}
%     {'G13187'}
%     {'G13191'}
%     {'C00053'}
%     {'C00180'}
%     {'C00248'}
%     {'C00264'}
%     {'C00322'}
%     {'C00380'}
%     {'C00435'}
%     {'C00475'}
%     {'C00512'}
%     {'C00546'}
%     {'C00689'}
%     {'C00854'}
%     {'C01079'}
%     {'C01168'}
%     {'C01586'}
%     {'C01762'}
%     {'C01921'}
%     {'C02051'}
%     {'C02232'}
%     {'C02291'}
%     {'C02528'}
%     {'C03063'}
%     {'C03069'}
%     {'C03344'}
%     {'C03405'}
%     {'C03752'}
%     {'C04052'}
%     {'C04132'}
%     {'C04349'}
%     {'C04752'}
%     {'C05122'}
%     {'C05259'}
%     {'C05261'}
%     {'C05263'}
%     {'C05265'}
%     {'C05267'}
%     {'C05463'}
%     {'C05464'}
%     {'C05465'}
%     {'C05466'}
%     {'C05480'}
%     {'C05481'}
%     {'C05482'}
%     {'C05483'}
%     {'C05696'}
%     {'C05699'}
%     {'C06715'}
%     {'C07118'}
%     {'C09812'}
%     {'C09813'}
%     {'C11588'}
%     {'C12622'}
%     {'C14604'}
%     {'C15811'}
%     {'C15972'}
%     {'C16330'}
%     {'C16331'}
%     {'C16334'}
%     {'C16335'}
%     {'C16338'}
%     {'C16339'}
%     {'C16470'}
%     {'C16826'}
%     {'C18321'}
%     {'C18351'}
%     {'C20373'}
%     {'C20377'}
%     {'C20422'}
%     {'C20751'}
%     {'C20830'}
%     {'C20941'}
%     {'C22467'}
%     {'C22507'}
%     {'G00093'}
%     {'G00094'}
%     {'G00108'}
%     {'G00109'}
%     {'G09795'}
%     {'G10611'}
%     {'G10665'}
%     {'G13056'}
%     {'G13073'}
%     {'G13074'}
%     {'G13197'}
%     {'G13198'}
% Blocked reactions: 583
%     {'R00104'      }
%     {'R00127'      }
%     {'R00130'      }
%     {'R00132'      }
%     {'R00161'      }
%     {'R00177'      }
%     {'R00188'      }
%     {'R00190'      }
%     {'R00192'      }
%     {'R00194_EXP_1'}
%     {'R00220'      }
%     {'R00228'      }
%     {'R00238'      }
%     {'R00239'      }
%     {'R00260'      }
%     {'R00289'      }
%     {'R00291'      }
%     {'R00299'      }
%     {'R00332'      }
%     {'R00345'      }
%     {'R00355'      }
%     {'R00401'      }
%     {'R00416'      }
%     {'R00505'      }
%     {'R00515'      }
%     {'R00549'      }
%     {'R00597'      }
%     {'R00619'      }
%     {'R00658'      }
%     {'R00660'      }
%     {'R00691'      }
%     {'R00694'      }
%     {'R00703'      }
%     {'R00720'      }
%     {'R00734'      }
%     {'R00742'      }
%     {'R00754'      }
%     {'R00801'      }
%     {'R00841'      }
%     {'R00896'      }
%     {'R00899'      }
%     {'R00921'      }
%     {'R00942'      }
%     {'R00943'      }
%     {'R00955'      }
%     {'R00965_EXP_1'}
%     {'R00966'      }
%     {'R01000'      }
%     {'R01015'      }
%     {'R01049'      }
%     {'R01061'      }
%     {'R01066'      }
%     {'R01068'      }
%     {'R01070'      }
%     {'R01072'      }
%     {'R01074'      }
%     {'R01080'      }
%     {'R01083'      }
%     {'R01086'      }
%     {'R01090'      }
%     {'R01092'      }
%     {'R01121'      }
%     {'R01122'      }
%     {'R01123'      }
%     {'R01127'      }
%     {'R01130'      }
%     {'R01132'      }
%     {'R01135'      }
%     {'R01150'      }
%     {'R01172'      }
%     {'R01177'      }
%     {'R01185'      }
%     {'R01186'      }
%     {'R01187'      }
%     {'R01220'      }
%     {'R01229'      }
%     {'R01280'      }
%     {'R01291'      }
%     {'R01334'      }
%     {'R01353'      }
%     {'R01373'      }
%     {'R01397'      }
%     {'R01401_EXP_1'}
%     {'R01402'      }
%     {'R01466'      }
%     {'R01512'      }
%     {'R01518'      }
%     {'R01529'      }
%     {'R01547'      }
%     {'R01560'      }
%     {'R01624'      }
%     {'R01625'      }
%     {'R01626'      }
%     {'R01639'      }
%     {'R01641'      }
%     {'R01644'      }
%     {'R01655'      }
%     {'R01658'      }
%     {'R01678'      }
%     {'R01708'      }
%     {'R01714'      }
%     {'R01715_EXP_1'}
%     {'R01718'      }
%     {'R01724'      }
%     {'R01728'      }
%     {'R01737'      }
%     {'R01761'      }
%     {'R01771_EXP_1'}
%     {'R01781'      }
%     {'R01782'      }
%     {'R01799'      }
%     {'R01801'      }
%     {'R01826'      }
%     {'R01827'      }
%     {'R01829'      }
%     {'R01856'      }
%     {'R01859'      }
%     {'R01868'      }
%     {'R01869'      }
%     {'R01870'      }
%     {'R01954'      }
%     {'R01978'      }
%     {'R01993'      }
%     {'R02003'      }
%     {'R02024'      }
%     {'R02030'      }
%     {'R02035'      }
%     {'R02059'      }
%     {'R02060'      }
%     {'R02061'      }
%     {'R02081'      }
%     {'R02087'      }
%     {'R02090'      }
%     {'R02094'      }
%     {'R02101'      }
%     {'R02110'      }
%     {'R02111'      }
%     {'R02112'      }
%     {'R02124'      }
%     {'R02133'      }
%     {'R02142'      }
%     {'R02164'      }
%     {'R02199'      }
%     {'R02237'      }
%     {'R02241'      }
%     {'R02245'      }
%     {'R02257'      }
%     {'R02291'      }
%     {'R02320'      }
%     {'R02328'      }
%     {'R02412'      }
%     {'R02433'      }
%     {'R02472'      }
%     {'R02568'      }
%     {'R02619'      }
%     {'R02689'      }
%     {'R02720'      }
%     {'R02750'      }
%     {'R02777'      }
%     {'R02783'      }
%     {'R02918'      }
%     {'R02971'      }
%     {'R02984'      }
%     {'R03018'      }
%     {'R03035'      }
%     {'R03038'      }
%     {'R03083'      }
%     {'R03084'      }
%     {'R03104'      }
%     {'R03122'      }
%     {'R03193'      }
%     {'R03243'      }
%     {'R03313'      }
%     {'R03355'      }
%     {'R03460'      }
%     {'R03472'      }
%     {'R03503'      }
%     {'R03504'      }
%     {'R03531'      }
%     {'R03596'      }
%     {'R03599'      }
%     {'R03601'      }
%     {'R03646'      }
%     {'R03650'      }
%     {'R03654'      }
%     {'R03655'      }
%     {'R03656'      }
%     {'R03657'      }
%     {'R03658'      }
%     {'R03659'      }
%     {'R03660'      }
%     {'R03661'      }
%     {'R03662'      }
%     {'R03663'      }
%     {'R03664'      }
%     {'R03665'      }
%     {'R03688'      }
%     {'R03905'      }
%     {'R03920'      }
%     {'R03940'      }
%     {'R04018'      }
%     {'R04144'      }
%     {'R04208'      }
%     {'R04212'      }
%     {'R04355'      }
%     {'R04378'      }
%     {'R04385'      }
%     {'R04391'      }
%     {'R04405'      }
%     {'R04428'      }
%     {'R04429'      }
%     {'R04448'      }
%     {'R04463'      }
%     {'R04533'      }
%     {'R04534'      }
%     {'R04535'      }
%     {'R04536'      }
%     {'R04537'      }
%     {'R04543'      }
%     {'R04544'      }
%     {'R04559'      }
%     {'R04560'      }
%     {'R04566'      }
%     {'R04568'      }
%     {'R04573'      }
%     {'R04591'      }
%     {'R04617'      }
%     {'R04710'      }
%     {'R04724'      }
%     {'R04726'      }
%     {'R04771'      }
%     {'R04773'      }
%     {'R04783'      }
%     {'R04858'      }
%     {'R04859'      }
%     {'R04880'      }
%     {'R04951'      }
%     {'R04952'      }
%     {'R04953'      }
%     {'R04954'      }
%     {'R04955'      }
%     {'R04957'      }
%     {'R04958'      }
%     {'R04960'      }
%     {'R04961'      }
%     {'R04963'      }
%     {'R04964'      }
%     {'R04965'      }
%     {'R04966'      }
%     {'R04968'      }
%     {'R04969'      }
%     {'R05030'      }
%     {'R05032'      }
%     {'R05052'      }
%     {'R05086'      }
%     {'R05233'      }
%     {'R05234'      }
%     {'R05287'      }
%     {'R05332'      }
%     {'R05577'      }
%     {'R05578'      }
%     {'R05629'      }
%     {'R05630'      }
%     {'R05662'      }
%     {'R05706'      }
%     {'R05850'      }
%     {'R06114'      }
%     {'R06147'      }
%     {'R06173'      }
%     {'R06174'      }
%     {'R06447'      }
%     {'R06513'      }
%     {'R06514'      }
%     {'R06590'      }
%     {'R06917'      }
%     {'R06927'      }
%     {'R06974'      }
%     {'R06987'      }
%     {'R07105'      }
%     {'R07168'      }
%     {'R07324'      }
%     {'R07404'      }
%     {'R07405'      }
%     {'R07459'      }
%     {'R07463'      }
%     {'R07671'      }
%     {'R07762'      }
%     {'R07763'      }
%     {'R07764'      }
%     {'R07765'      }
%     {'R08218'      }
%     {'R08237'      }
%     {'R08238'      }
%     {'R08240'      }
%     {'R08243'      }
%     {'R08244'      }
%     {'R08245'      }
%     {'R08247'      }
%     {'R08281'      }
%     {'R08306'      }
%     {'R08310'      }
%     {'R08622'      }
%     {'R08626'      }
%     {'R08779'      }
%     {'R08856'      }
%     {'R08878'      }
%     {'R09009'      }
%     {'R09365'      }
%     {'R09372'      }
%     {'R09381'      }
%     {'R09597'      }
%     {'R09993'      }
%     {'R10092'      }
%     {'R10137'      }
%     {'R10147'      }
%     {'R10159'      }
%     {'R10209'      }
%     {'R10223'      }
%     {'R10247'      }
%     {'R10463'      }
%     {'R10619'      }
%     {'R10633'      }
%     {'R10634'      }
%     {'R10695'      }
%     {'R10700'      }
%     {'R10757'      }
%     {'R10764'      }
%     {'R10806'      }
%     {'R10850'      }
%     {'R10991'      }
%     {'R11170'      }
%     {'R11172'      }
%     {'R11188'      }
%     {'R11262'      }
%     {'R11319'      }
%     {'R11323'      }
%     {'R11528'      }
%     {'R11765'      }
%     {'R11896'      }
%     {'R12075'      }
%     {'R12078'      }
%     {'R12079'      }
%     {'R12808'      }
%     {'R12814'      }
%     {'R12851'      }
%     {'R12852'      }
%     {'R12859'      }
%     {'R12897'      }
%     {'R12902'      }
%     {'R12991'      }
%     {'R13105'      }
%     {'R00647'      }
%     {'R01652'      }
%     {'R02317'      }
%     {'R02962'      }
%     {'R03166'      }
%     {'R03186'      }
%     {'R03445'      }
%     {'R03672'      }
%     {'R03674'      }
%     {'R03758'      }
%     {'R03954'      }
%     {'R04500'      }
%     {'R04578'      }
%     {'R04639'      }
%     {'R04701'      }
%     {'R04769'      }
%     {'R05041'      }
%     {'R05048'      }
%     {'R05098'      }
%     {'R05455'      }
%     {'R05483'      }
%     {'R05484'      }
%     {'R05824'      }
%     {'R05826'      }
%     {'R05844'      }
%     {'R05845'      }
%     {'R05846'      }
%     {'R05887'      }
%     {'R05889'      }
%     {'R06063'      }
%     {'R06064'      }
%     {'R06194'      }
%     {'R06650'      }
%     {'R06830'      }
%     {'R06982'      }
%     {'R07009'      }
%     {'R07010'      }
%     {'R07011'      }
%     {'R07012'      }
%     {'R07198'      }
%     {'R07316'      }
%     {'R07406'      }
%     {'R07679'      }
%     {'R07947'      }
%     {'R07948'      }
%     {'R08020'      }
%     {'R08279'      }
%     {'R08289'      }
%     {'R08358'      }
%     {'R08361'      }
%     {'R08372'      }
%     {'R08818'      }
%     {'R08820'      }
%     {'R08821'      }
%     {'R08825'      }
%     {'R08827'      }
%     {'R08829'      }
%     {'R08831'      }
%     {'R08833'      }
%     {'R08834'      }
%     {'R08835'      }
%     {'R08837'      }
%     {'R08976'      }
%     {'R09142'      }
%     {'R09143'      }
%     {'R09144'      }
%     {'R09145'      }
%     {'R09149'      }
%     {'R09274'      }
%     {'R09367'      }
%     {'R09368'      }
%     {'R09391'      }
%     {'R09392'      }
%     {'R09431'      }
%     {'R09432'      }
%     {'R09433'      }
%     {'R09434'      }
%     {'R09885'      }
%     {'R09981'      }
%     {'R10013'      }
%     {'R10018'      }
%     {'R10022'      }
%     {'R10030'      }
%     {'R10034'      }
%     {'R10041'      }
%     {'R10078'      }
%     {'R10082'      }
%     {'R10097'      }
%     {'R10245'      }
%     {'R10302'      }
%     {'R10792'      }
%     {'R10854'      }
%     {'R10856'      }
%     {'R10914'      }
%     {'R11017'      }
%     {'R11034'      }
%     {'R11049'      }
%     {'R11148'      }
%     {'R11176'      }
%     {'R11228'      }
%     {'R11523'      }
%     {'R11550'      }
%     {'R11570'      }
%     {'R11571'      }
%     {'R11572'      }
%     {'R11573'      }
%     {'R11574'      }
%     {'R11575'      }
%     {'R11576'      }
%     {'R11577'      }
%     {'R11691'      }
%     {'R11695'      }
%     {'R11709'      }
%     {'R11736'      }
%     {'R11739'      }
%     {'R11865'      }
%     {'R11947'      }
%     {'R12091'      }
%     {'R12094'      }
%     {'R12132'      }
%     {'R12140'      }
%     {'R12268'      }
%     {'R12274'      }
%     {'R12310'      }
%     {'R12335'      }
%     {'R12421'      }
%     {'R12539'      }
%     {'R12683'      }
%     {'R12686'      }
%     {'R12829'      }
%     {'R12886'      }
%     {'R12910'      }
%     {'R12974'      }
%     {'R13023'      }
%     {'R13091'      }
%     {'R13113'      }
%     {'R13114'      }
%     {'R13140'      }
%     {'R13144'      }
%     {'R00022'      }
%     {'R00480'      }
%     {'R00509'      }
%     {'R00512'      }
%     {'R00529'      }
%     {'R00829'      }
%     {'R00837'      }
%     {'R00927'      }
%     {'R01221'      }
%     {'R01290'      }
%     {'R01424'      }
%     {'R01542'      }
%     {'R01544'      }
%     {'R01665'      }
%     {'R01698'      }
%     {'R01779'      }
%     {'R01933'      }
%     {'R01977'      }
%     {'R02000'      }
%     {'R02137'      }
%     {'R02143'      }
%     {'R02229'      }
%     {'R02240'      }
%     {'R02260'      }
%     {'R02786'      }
%     {'R02797'      }
%     {'R02855'      }
%     {'R02946'      }
%     {'R03245'      }
%     {'R03315'      }
%     {'R03471'      }
%     {'R03651'      }
%     {'R03707'      }
%     {'R03778'      }
%     {'R03815'      }
%     {'R03858'      }
%     {'R03975'      }
%     {'R03977'      }
%     {'R03991'      }
%     {'R04134'      }
%     {'R04380'      }
%     {'R04486'      }
%     {'R04487'      }
%     {'R04509'      }
%     {'R04742'      }
%     {'R04747'      }
%     {'R04831'      }
%     {'R04834'      }
%     {'R04844'      }
%     {'R04847'      }
%     {'R04928'      }
%     {'R04929'      }
%     {'R04942'      }
%     {'R05506'      }
%     {'R05582'      }
%     {'R05586'      }
%     {'R05835'      }
%     {'R05963'      }
%     {'R06004'      }
%     {'R06113'      }
%     {'R06782'      }
%     {'R06783'      }
%     {'R06895'      }
%     {'R06988'      }
%     {'R07461'      }
%     {'R07618'      }
%     {'R07809'      }
%     {'R07810'      }
%     {'R07891'      }
%     {'R07895'      }
%     {'R07899'      }
%     {'R08091'      }
%     {'R08095'      }
%     {'R08549'      }
%     {'R09078'      }
%     {'R09244'      }
%     {'R09284'      }
%     {'R10116'      }
%     {'R10120'      }
%     {'R10185'      }
%     {'R10190'      }
%     {'R10505'      }
%     {'R10648'      }
%     {'R10691'      }
%     {'R10765'      }
%     {'R10917'      }
%     {'R11316'      }
%     {'R11339'      }
%     {'R11671'      }
%     {'R12819'      }
%     {'R12963'      }
%     {'R12996'      }
%     {'BIOMASS_ps'  }

% %% [markdown]
% In order for this to be a functional GEM, exchange reactions need to be added.

% %%
% Setting up the draft GEM base
%GvaginalisBiomassDraftModel = importModel('Gvaginalis_draftGEM_v3.xml');
% create a copy to avoid overwriting
GvaginalisExchangeModel = GvaginalisBiomassDraftModel;
GvaginalisExchangeModel.id = 'GvaginalisDraft';

% %% [markdown]
% Perform some cleaning:

% %%
% deal with grRules issues
GvaginalisExchangeModel = ensureGrRules(GvaginalisExchangeModel);
modelKEGGgr = ensureGrRules(modelKEGG);
% Out:
% Patched grRules to match 11588 rxns

% %%
% further sanitization
modelKEGGgr = padMissingFields(modelKEGGgr, GvaginalisExchangeModel);
% Out:
% Added geneMiriams to KEGG
% Added rxnFrom to KEGG
% Added metFrom to KEGG
% Added geneFrom to KEGG
% Added rules to KEGG
% Added equations to KEGG
% Added rxnReferences to KEGG
% Added rxnConfidenceScores to KEGG
% Added metCharges to KEGG
% Added geneNames to KEGG
% Added geneShortNames to KEGG

% %% [markdown]
% Dealing with exchange reactions:

% %%
% getting a cell array of metabolites to create exchange reactions for
biomassMets = getBiomassMets(GvaginalisExchangeModel, 'BIOMASS_ps'); % get metabolites involved in the biomass reaction
% Out:
% Biomass reaction: BIOMASS_ps
% Number of metabolites in biomass reaction: 273
%     {'C00001'}
%     {'C00002'}
%     {'C00003'}
%     {'C00004'}
%     {'C00005'}
%     {'C00006'}
%     {'C00007'}
%     {'C00008'}
%     {'C00009'}
%     {'C00010'}
%     {'C00013'}
%     {'C00014'}
%     {'C00019'}
%     {'C00020'}
%     {'C00022'}
%     {'C00024'}
%     {'C00025'}
%     {'C00026'}
%     {'C00030'}
%     {'C00031'}
%     {'C00033'}
%     {'C00037'}
%     {'C00041'}
%     {'C00044'}
%     {'C00047'}
%     {'C00049'}
%     {'C00055'}
%     {'C00058'}
%     {'C00061'}
%     {'C00062'}
%     {'C00063'}
%     {'C00064'}
%     {'C00065'}
%     {'C00073'}
%     {'C00075'}
%     {'C00078'}
%     {'C00079'}
%     {'C00080'}
%     {'C00082'}
%     {'C00083'}
%     {'C00084'}
%     {'C00085'}
%     {'C00092'}
%     {'C00093'}
%     {'C00095'}
%     {'C00097'}
%     {'C00100'}
%     {'C00101'}
%     {'C00103'}
%     {'C00105'}
%     {'C00109'}
%     {'C00117'}
%     {'C00118'}
%     {'C00120'}
%     {'C00121'}
%     {'C00123'}
%     {'C00130'}
%     {'C00131'}
%     {'C00135'}
%     {'C00136'}
%     {'C00143'}
%     {'C00144'}
%     {'C00148'}
%     {'C00155'}
%     {'C00163'}
%     {'C00169'}
%     {'C00183'}
%     {'C00185'}
%     {'C00186'}
%     {'C00188'}
%     {'C00197'}
%     {'C00217'}
%     {'C00221'}
%     {'C00229'}
%     {'C00249'}
%     {'C00254'}
%     {'C00255'}
%     {'C00257'}
%     {'C00263'}
%     {'C00267'}
%     {'C00269'}
%     {'C00272'}
%     {'C00283'}
%     {'C00286'}
%     {'C00288'}
%     {'C00310'}
%     {'C00314'}
%     {'C00320'}
%     {'C00327'}
%     {'C00337'}
%     {'C00342'}
%     {'C00344'}
%     {'C00345'}
%     {'C00356'}
%     {'C00360'}
%     {'C00362'}
%     {'C00364'}
%     {'C00365'}
%     {'C00378'}
%     {'C00407'}
%     {'C00415'}
%     {'C00416'}
%     {'C00418'}
%     {'C00424'}
%     {'C00440'}
%     {'C00441'}
%     {'C00455'}
%     {'C00458'}
%     {'C00460'}
%     {'C00469'}
%     {'C00473'}
%     {'C00493'}
%     {'C00522'}
%     {'C00583'}
%     {'C00606'}
%     {'C00641'}
%     {'C00655'}
%     {'C00662'}
%     {'C00673'}
%     {'C00692'}
%     {'C00787'}
%     {'C00826'}
%     {'C00831'}
%     {'C00856'}
%     {'C00857'}
%     {'C00864'}
%     {'C00882'}
%     {'C00921'}
%     {'C00979'}
%     {'C00984'}
%     {'C00989'}
%     {'C00993'}
%     {'C01005'}
%     {'C01050'}
%     {'C01102'}
%     {'C01107'}
%     {'C01134'}
%     {'C01143'}
%     {'C01157'}
%     {'C01165'}
%     {'C01172'}
%     {'C01185'}
%     {'C01212'}
%     {'C01279'}
%     {'C01300'}
%     {'C01380'}
%     {'C01412'}
%     {'C01528'}
%     {'C01563'}
%     {'C01635'}
%     {'C01636'}
%     {'C01638'}
%     {'C01639'}
%     {'C01641'}
%     {'C01643'}
%     {'C01644'}
%     {'C01645'}
%     {'C01646'}
%     {'C01647'}
%     {'C01648'}
%     {'C01649'}
%     {'C01650'}
%     {'C01651'}
%     {'C01652'}
%     {'C01653'}
%     {'C01674'}
%     {'C01847'}
%     {'C01977'}
%     {'C02282'}
%     {'C02336'}
%     {'C02583'}
%     {'C02743'}
%     {'C02909'}
%     {'C03024'}
%     {'C03319'}
%     {'C03402'}
%     {'C03688'}
%     {'C04079'}
%     {'C04261'}
%     {'C04294'}
%     {'C04376'}
%     {'C04489'}
%     {'C04501'}
%     {'C04556'}
%     {'C04618'}
%     {'C04619'}
%     {'C04620'}
%     {'C04633'}
%     {'C04646'}
%     {'C04688'}
%     {'C04751'}
%     {'C05196'}
%     {'C05197'}
%     {'C05223'}
%     {'C05335'}
%     {'C05576'}
%     {'C05688'}
%     {'C05698'}
%     {'C05745'}
%     {'C05747'}
%     {'C05749'}
%     {'C05752'}
%     {'C05755'}
%     {'C05757'}
%     {'C05761'}
%     {'C05764'}
%     {'C05823'}
%     {'C05892'}
%     {'C05893'}
%     {'C05984'}
%     {'C06055'}
%     {'C06156'}
%     {'C06611'}
%     {'C06612'}
%     {'C06899'}
%     {'C07645'}
%     {'C09762'}
%     {'C14089'}
%     {'C15673'}
%     {'C15810'}
%     {'C15813'}
%     {'C16221'}
%     {'C16586'}
%     {'C16595'}
%     {'C16618'}
%     {'C16636'}
%     {'C18902'}
%     {'C19722'}
%     {'C20836'}
%     {'C00059'}
%     {'C00091'}
%     {'C00204'}
%     {'C00224'}
%     {'C00239'}
%     {'C00340'}
%     {'C00414'}
%     {'C00423'}
%     {'C00579'}
%     {'C00741'}
%     {'C01086'}
%     {'C01640'}
%     {'C01832'}
%     {'C01944'}
%     {'C02067'}
%     {'C02211'}
%     {'C02593'}
%     {'C02972'}
%     {'C03044'}
%     {'C03046'}
%     {'C03187'}
%     {'C03263'}
%     {'C03561'}
%     {'C03979'}
%     {'C05270'}
%     {'C05274'}
%     {'C05470'}
%     {'C05472'}
%     {'C05478'}
%     {'C05484'}
%     {'C05629'}
%     {'C05686'}
%     {'C05697'}
%     {'C15812'}
%     {'C15973'}
%     {'C16466'}
%     {'C16471'}
%     {'C19078'}
%     {'C19080'}
%     {'C20372'}
%     {'C20376'}
%     {'C20396'}
%     {'C20657'}
%     {'C20940'}

% %%
wasteMets = getCommonWasteMets(GvaginalisExchangeModel); % get list (cell array) of common waste metabolites
essentialMets = {'C00031','C00014','C00007','C00009','C00036'}; % glucose, ammonium, oxygen, phosphate, sulfate
communityMets = getCommunityExchangeMets(); % metabolites that are likely to be needed in MCMM community exchanges
allExMets = unique([biomassMets(:); wasteMets(:); essentialMets(:); communityMets(:)], 'stable'); % concatenate while avoiding potential duplicates

% add the exchange reactions to the model
GvaginalisExchangeModel = addExchangeRxnsForModel(GvaginalisExchangeModel, allExMets);
% Out:
% Warning: Metabolite C00086 not found in model, skipping.
% Warning: Metabolite C00282 not found in model, skipping.
% Warning: Metabolite C00246 not found in model, skipping.

% %%
% ensure reversibility of reactions
GvaginalisExchangeModel = ensureRevField(GvaginalisExchangeModel);
% Out:
% Model already has rev field

% %%
sol3 = solveLP(GvaginalisExchangeModel);
disp(sol3.f);
% Out:
%   36.585365853658530

% %% [markdown]
% There is now biomass production!

% %%
% pre-export cleaning
GvaginalisExchangeModel = fixSubsystemsField(GvaginalisExchangeModel);
GvaginalisExchangeModel = sanitizeRxnMiriams(GvaginalisExchangeModel);
% Out:
% Sanitized rxnMiriams for 984 reactions

% %% [markdown]
% Now the model is ready for export:

% %%
% export the current model version
exportModel(GvaginalisExchangeModel, 'Gvaginalis_draftGEM_v4.xml');
% Out:
% WARNING: The following InChI strings are associated to more than one unique metabolite name:
%     1S/C10H20O7P2/c1-9(2)5-4-6-10(3)7-8-16-19(14,15)17-18(11,12)13/h5,7H,4,6,8H2,1-3H3,(H,14,15)(H2,11,12,13)/b10-7+
% Document written

% %%
exportToExcelFormat(GvaginalisExchangeModel, 'Gvaginalis_draftGEM_v4.xlsx');
save('Gvaginalis_draftGEM_v4.mat', 'GvaginalisExchangeModel');

% %% [markdown]
% This will be the version used for the MCMM.
%
% ## Additional tests
%
% A few more sanity checks and tests prior to moving on to gap\-filling.

% %%
% Setting up the draft GEM base
%GvaginalisBiomassDraftModel = importModel('Gvaginalis_draftGEM_v4.xml');
% create a copy to avoid overwriting
GvaginalisBiomassObjDraftModel = GvaginalisExchangeModel;
GvaginalisBiomassObjDraftModel.id = 'GvaginalisDraft';

% %% [markdown]
% First, checking for dead\-end metabolites:

% %%
deadMets = quickDeadEnds(GvaginalisBiomassObjDraftModel);
fprintf('Dead-end metabolites: %d\n', numel(deadMets));
% Out:
% Dead-end metabolites: 0

% %% [markdown]
% Double\-check that the biomass metabolites are indeed present in the model:

% %%
biomassMets = getBiomassMets(GvaginalisBiomassObjDraftModel, 'BIOMASS_ps');
% Out:
% Biomass reaction: BIOMASS_ps
% Number of metabolites in biomass reaction: 273
%     {'C00001'}
%     {'C00002'}
%     {'C00003'}
%     {'C00004'}
%     {'C00005'}
%     {'C00006'}
%     {'C00007'}
%     {'C00008'}
%     {'C00009'}
%     {'C00010'}
%     {'C00013'}
%     {'C00014'}
%     {'C00019'}
%     {'C00020'}
%     {'C00022'}
%     {'C00024'}
%     {'C00025'}
%     {'C00026'}
%     {'C00030'}
%     {'C00031'}
%     {'C00033'}
%     {'C00037'}
%     {'C00041'}
%     {'C00044'}
%     {'C00047'}
%     {'C00049'}
%     {'C00055'}
%     {'C00058'}
%     {'C00061'}
%     {'C00062'}
%     {'C00063'}
%     {'C00064'}
%     {'C00065'}
%     {'C00073'}
%     {'C00075'}
%     {'C00078'}
%     {'C00079'}
%     {'C00080'}
%     {'C00082'}
%     {'C00083'}
%     {'C00084'}
%     {'C00085'}
%     {'C00092'}
%     {'C00093'}
%     {'C00095'}
%     {'C00097'}
%     {'C00100'}
%     {'C00101'}
%     {'C00103'}
%     {'C00105'}
%     {'C00109'}
%     {'C00117'}
%     {'C00118'}
%     {'C00120'}
%     {'C00121'}
%     {'C00123'}
%     {'C00130'}
%     {'C00131'}
%     {'C00135'}
%     {'C00136'}
%     {'C00143'}
%     {'C00144'}
%     {'C00148'}
%     {'C00155'}
%     {'C00163'}
%     {'C00169'}
%     {'C00183'}
%     {'C00185'}
%     {'C00186'}
%     {'C00188'}
%     {'C00197'}
%     {'C00217'}
%     {'C00221'}
%     {'C00229'}
%     {'C00249'}
%     {'C00254'}
%     {'C00255'}
%     {'C00257'}
%     {'C00263'}
%     {'C00267'}
%     {'C00269'}
%     {'C00272'}
%     {'C00283'}
%     {'C00286'}
%     {'C00288'}
%     {'C00310'}
%     {'C00314'}
%     {'C00320'}
%     {'C00327'}
%     {'C00337'}
%     {'C00342'}
%     {'C00344'}
%     {'C00345'}
%     {'C00356'}
%     {'C00360'}
%     {'C00362'}
%     {'C00364'}
%     {'C00365'}
%     {'C00378'}
%     {'C00407'}
%     {'C00415'}
%     {'C00416'}
%     {'C00418'}
%     {'C00424'}
%     {'C00440'}
%     {'C00441'}
%     {'C00455'}
%     {'C00458'}
%     {'C00460'}
%     {'C00469'}
%     {'C00473'}
%     {'C00493'}
%     {'C00522'}
%     {'C00583'}
%     {'C00606'}
%     {'C00641'}
%     {'C00655'}
%     {'C00662'}
%     {'C00673'}
%     {'C00692'}
%     {'C00787'}
%     {'C00826'}
%     {'C00831'}
%     {'C00856'}
%     {'C00857'}
%     {'C00864'}
%     {'C00882'}
%     {'C00921'}
%     {'C00979'}
%     {'C00984'}
%     {'C00989'}
%     {'C00993'}
%     {'C01005'}
%     {'C01050'}
%     {'C01102'}
%     {'C01107'}
%     {'C01134'}
%     {'C01143'}
%     {'C01157'}
%     {'C01165'}
%     {'C01172'}
%     {'C01185'}
%     {'C01212'}
%     {'C01279'}
%     {'C01300'}
%     {'C01380'}
%     {'C01412'}
%     {'C01528'}
%     {'C01563'}
%     {'C01635'}
%     {'C01636'}
%     {'C01638'}
%     {'C01639'}
%     {'C01641'}
%     {'C01643'}
%     {'C01644'}
%     {'C01645'}
%     {'C01646'}
%     {'C01647'}
%     {'C01648'}
%     {'C01649'}
%     {'C01650'}
%     {'C01651'}
%     {'C01652'}
%     {'C01653'}
%     {'C01674'}
%     {'C01847'}
%     {'C01977'}
%     {'C02282'}
%     {'C02336'}
%     {'C02583'}
%     {'C02743'}
%     {'C02909'}
%     {'C03024'}
%     {'C03319'}
%     {'C03402'}
%     {'C03688'}
%     {'C04079'}
%     {'C04261'}
%     {'C04294'}
%     {'C04376'}
%     {'C04489'}
%     {'C04501'}
%     {'C04556'}
%     {'C04618'}
%     {'C04619'}
%     {'C04620'}
%     {'C04633'}
%     {'C04646'}
%     {'C04688'}
%     {'C04751'}
%     {'C05196'}
%     {'C05197'}
%     {'C05223'}
%     {'C05335'}
%     {'C05576'}
%     {'C05688'}
%     {'C05698'}
%     {'C05745'}
%     {'C05747'}
%     {'C05749'}
%     {'C05752'}
%     {'C05755'}
%     {'C05757'}
%     {'C05761'}
%     {'C05764'}
%     {'C05823'}
%     {'C05892'}
%     {'C05893'}
%     {'C05984'}
%     {'C06055'}
%     {'C06156'}
%     {'C06611'}
%     {'C06612'}
%     {'C06899'}
%     {'C07645'}
%     {'C09762'}
%     {'C14089'}
%     {'C15673'}
%     {'C15810'}
%     {'C15813'}
%     {'C16221'}
%     {'C16586'}
%     {'C16595'}
%     {'C16618'}
%     {'C16636'}
%     {'C18902'}
%     {'C19722'}
%     {'C20836'}
%     {'C00059'}
%     {'C00091'}
%     {'C00204'}
%     {'C00224'}
%     {'C00239'}
%     {'C00340'}
%     {'C00414'}
%     {'C00423'}
%     {'C00579'}
%     {'C00741'}
%     {'C01086'}
%     {'C01640'}
%     {'C01832'}
%     {'C01944'}
%     {'C02067'}
%     {'C02211'}
%     {'C02593'}
%     {'C02972'}
%     {'C03044'}
%     {'C03046'}
%     {'C03187'}
%     {'C03263'}
%     {'C03561'}
%     {'C03979'}
%     {'C05270'}
%     {'C05274'}
%     {'C05470'}
%     {'C05472'}
%     {'C05478'}
%     {'C05484'}
%     {'C05629'}
%     {'C05686'}
%     {'C05697'}
%     {'C15812'}
%     {'C15973'}
%     {'C16466'}
%     {'C16471'}
%     {'C19078'}
%     {'C19080'}
%     {'C20372'}
%     {'C20376'}
%     {'C20396'}
%     {'C20657'}
%     {'C20940'}

% %%
missing = setdiff(biomassMets, GvaginalisBiomassObjDraftModel.mets);
disp(missing);

% %% [markdown]
% Perform a preliminary test for whether gap\-filling is necessary:

% %%
% block all exchange
GvaginalisBiomassObjDraftModel.lb(findExcRxns(GvaginalisBiomassObjDraftModel)) = 0;

% reopen minimal medium
allowMets = {'C00031','C00014','C00007','C00009','C00036'}; % glucose, ammonium, oxygen, phosphate, sulfate
for i = 1:numel(allowMets)
    exIdx = find(strcmp(GvaginalisBiomassObjDraftModel.mets, allowMets{i}));
    if ~isempty(exIdx)
        rxnIdx = find(GvaginalisBiomassObjDraftModel.S(exIdx,:));
        GvaginalisBiomassObjDraftModel.lb(rxnIdx) = -1000; % uptake allowed
    end
end

sol4 = solveLP(GvaginalisBiomassObjDraftModel);
disp(sol4.f);
% Out:
%   36.585365853658459

% %% [markdown]
% The solution here is the same as before, so this looks good to go.
%
%
% On Ed's recommendation, I will force the biomass flux to be positive:

% %%
% force the biomass flux to be positive
% Set lower and upper bounds of the biomass reaction
rxnID = 'BIOMASS_ps';
biomassIndex = find(ismember(GvaginalisBiomassObjDraftModel.rxns, rxnID));

GvaginalisBiomassObjDraftModel.lb(biomassIndex) = 0.1;  % minimum growth rate
GvaginalisBiomassObjDraftModel.ub(biomassIndex) = 1000; % allow up to 1000

% %% [markdown]
% Finally, run FBA on the new model:

% %%
sol3 = solveLP(GvaginalisBiomassObjDraftModel);
disp(sol3.f)
% Out:
%   36.585365853658537

% %% [markdown]
% Export the model:

% %%
exportModel(GvaginalisBiomassObjDraftModel, 'Gvaginalis_draftGEM_v5.xml');
% Out:
% WARNING: The following reactions have lower and upper bounds that indicate reversibility, but are indicated as irreversible in model.rev:
%     R00765
%     R04212
%     R05086
%     R08020
% WARNING: The following InChI strings are associated to more than one unique metabolite name:
%     1S/C10H20O7P2/c1-9(2)5-4-6-10(3)7-8-16-19(14,15)17-18(11,12)13/h5,7H,4,6,8H2,1-3H3,(H,14,15)(H2,11,12,13)/b10-7+
% Document written

% %%
exportToExcelFormat(GvaginalisBiomassObjDraftModel, 'Gvaginalis_draftGEM_v5.xlsx');
save('Gvaginalis_draftGEM_v5.mat', 'GvaginalisBiomassObjDraftModel');

% %% [markdown]
% ## Gap\-filling attempt
%
% On the advice of Ed, I will be doing gap\-filling from the whole of the KEGG database. While the model does technically produce biomass and so therefore is viable, it is better to add more exchanges to ensure as high\-quality of an MCMM as possible.

% %%
% trying gap filling
[Gvaginalis_filledModel, addedRxns] = fillGaps( ...
    GvaginalisBiomassObjDraftModel, ...
    modelKEGGgr, ...
    false, true, true);

% Check the output of fillGaps
if isempty(Gvaginalis_filledModel)
    disp('fillGaps returned an empty model. Check your input models and required fields.');
elseif iscell(Gvaginalis_filledModel)
    disp(['fillGaps returned a cell array of size: ', mat2str(size(Gvaginalis_filledModel))]);
else
    disp('fillGaps returned a valid model struct.');
end
% Out:
% fillGaps returned an empty model. Check your input models and required fields.

% %% [markdown]
% Check the results:

% %%
% Did fillGaps return something valid?
class(Gvaginalis_filledModel)
% Out:
% ans = 'cell'

% %%
whos Gvaginalis_filledModel
% Out:
%   Name                        Size            Bytes  Class    Attributes
%   Gvaginalis_filledModel      0x0                 0  cell

% %% [markdown]
% As before, it appears that gap\-filling is unnecessary in this case.
%
% ## Draft *Prevotella bivia* GEM
%
% Initial GEM creation:

% %%
%clear
%clc

% draft with KEGG
%The organisms with KEGG annotation and their associated ids
%(e.g. 'pbiv' for Prevotella bivia) can be found from here:
%https://www.kegg.jp/kegg/catalog/org_list.html.
%PbiviaKEGGAnnotation=getKEGGModelForOrganism('pbiv','','','',1,0,0);
% in this case, things were more complicated
% pbiv was added to KEGG in 2023
% but appears not to be included in the version of RAVEN that is available
% in MATLAB
% so I'm using the closest relative I can find that's available
% it looks like p. denticola seems to cluster with P. bivia genomically
% ref: https://www.sciencedirect.com/science/article/pii/S2213716523001789
% (Peng et al. 2023)
% in KEGG, P. denticola is 'pdn'
PdenticolaKEGGAnnotation=getKEGGModelForOrganism('pdn','','','',1,0,0);
% Out:
% *** The model reconstruction from KEGG based on the annotation available for KEGG Species pdn ***
% Importing the global KEGG model from C:/Users/viragv/AppData/Roaming/MathWorks/MATLAB Add-Ons/Collections/RAVEN Toolbox/external/kegg/keggModel.mat... COMPLETE
% Importing the KEGG phylogenetic distance matrix from C:/Users/viragv/AppData/Roaming/MathWorks/MATLAB Add-Ons/Collections/RAVEN Toolbox/external/kegg/keggPhylDist.mat... COMPLETE
% Pruning the model from non-pdn genes... COMPLETE
% Removing non-spontaneous reactions without GPR rules... COMPLETE
% Fixing gene names in the model... COMPLETE
% Constructing GPR associations and annotations for the model... COMPLETE
% *** Model reconstruction complete ***

% %%
% local FASTA model
PbiviaKEGGHomology=getKEGGModelForOrganism('PbiviaKEGGHMMs','prevotella_bivia_GCF_000262545-1_prots_edit.fasta','prok90_kegg105','',1,0,0);
% Out:
% *** The model reconstruction from KEGG based on the protein homology search against KEGG Orthology specific HMMs ***
% NOTE: Found prok90_kegg105 directory with pre-trained HMMs, it will therefore be used during reconstruction
% Importing the global KEGG model from C:/Users/viragv/AppData/Roaming/MathWorks/MATLAB Add-Ons/Collections/RAVEN Toolbox/external/kegg/keggModel.mat... COMPLETE
% Removing non-spontaneous reactions without GPR rules... COMPLETE
% Fixing gene names in the model... COMPLETE
% Importing the KEGG phylogenetic distance matrix from C:/Users/viragv/AppData/Roaming/MathWorks/MATLAB Add-Ons/Collections/RAVEN Toolbox/external/kegg/keggPhylDist.mat... COMPLETE
% Generating the KEGG Orthology specific multi-FASTA files... COMPLETE
% Performing clustering and multiple alignment for KEGG Orthology specific protein sets... COMPLETE
% Training the KEGG Orthology specific HMMs... COMPLETE
% Querying the user-specified FASTA file against the KEGG Orthology specific HMMs... COMPLETE
% Parsing the HMM search results... COMPLETE
% Removing gene, KEGG Orthology associations below minScoreRatioKO, minScoreRatioG... COMPLETE
% Adding gene annotations to the model... COMPLETE
% Removing non-spontaneous reactions which after HMM search no longer have GPR rules... COMPLETE
% Constructing GPR rules and finalizing the model... COMPLETE
% *** Model reconstruction complete ***

% %%
% merge models
PbiviaKEGGDraftModel=mergeModels({PdenticolaKEGGAnnotation PbiviaKEGGHomology});

% check reaction numbers
disp(numel(PbiviaKEGGHomology.rxns)+numel(PdenticolaKEGGAnnotation.rxns));
% Out:
%         1623

% %%
disp(numel(PbiviaKEGGDraftModel.rxns));
% Out:
%         1623

% %%
% further model cleaning
PbiviaKEGGDraftModel=expandModel(PbiviaKEGGDraftModel);
PbiviaKEGGDraftModel=contractModel(PbiviaKEGGDraftModel);

% %% [markdown]
% At this point, a draft GEM has been created for *P. bivia*, merging the information from MetaCyc and KEGG. While it needs to be improved, I'll save it for now in Excel format to avoid having to recreate it each time.

% %%
exportToExcelFormat(PbiviaKEGGDraftModel, 'Pbivia_draftGEM_v1.xlsx');
save('Pbivia_draftGEM_v1.mat', 'PbiviaKEGGDraftModel');

% %% [markdown]
% ## Cleaning *P. bivia* draft GEM

% %%
%PbiviaCombinedDraftModel = load('Pbivia_draftGEM_v1.mat');
PbiviaCleanDraftModel = cleanGrRulesGenes(PbiviaKEGGDraftModel);
PbiviaCleanDraftModel = mergeDuplicateMetNames(PbiviaCleanDraftModel);
PbiviaCleanDraftModel = mergeDuplicateMetNames2(PbiviaCleanDraftModel);
PbiviaCleanDraftModel = fixSubsystemsField(PbiviaCleanDraftModel);

% %% [markdown]
% The preliminary model should now be ready for export.

% %%
exportModel(PbiviaCleanDraftModel, 'Pbivia_draftGEM_v2.xml');
% Out:
% WARNING: No objective function found. This might be intended, but results in FBCv2 non-compliant SBML file when exported
% WARNING: The composition for the following metabolites could not be parsed:
%     C01977
%     C01978
%     C04157
%     C04432
%     C17324
%     C19647
%     C19722
%     C19723
%     C20446
%     ...and 9 more
% WARNING: The following InChI strings are associated to more than one unique metabolite name:
%     1S/C10H20O7P2/c1-9(2)5-4-6-10(3)7-8-16-19(14,15)17-18(11,12)13/h5,7H,4,6,8H2,1-3H3,(H,14,15)(H2,11,12,13)/b10-7+
% Document written

% %%
exportToExcelFormat(PbiviaCleanDraftModel, 'Pbivia_draftGEM_v2.xlsx');
save('Pbivia_draftGEM_v2.mat', 'PbiviaCleanDraftModel');

% %% [markdown]
% Saved in SBML standard GEM format.

% %%
% Load the model from SBML (.xml)
%PbiviaCleanDraftModel = importModel('Pbivia_draftGEM_v2.xml');

% %% [markdown]
% Now start quality checks:

% %%
%Check out if the newly generated PbiviaCombinedDraftModel could grow
sol=solveLP(PbiviaCleanDraftModel);
disp(sol.f);
% Out:
%      0

% %%
%The results indicate that this new model is non-functional
% ie., biomass = 0, which means there is no growth

% %%
% Look for reactions that produce a "biomass" metabolite
bioMets = find(contains(lower(PbiviaCleanDraftModel.metNames), 'biomass'));

if isempty(bioMets)
    warning('No metabolites with "biomass" in the name were found.');
else
    % Find reactions involving these metabolites
    [rxnIdx, ~] = find(PbiviaCleanDraftModel.S(bioMets,:) ~= 0);
    rxnIdx = unique(rxnIdx);
    disp('Potential biomass reactions:');
    disp([rxnIdx, PbiviaCleanDraftModel.rxns(rxnIdx)', PbiviaCleanDraftModel.rxnNames(rxnIdx)']);
end
% Out:
% Warning: No metabolites with "biomass" in the name were found.

% %% [markdown]
% ## Adding a biomass reaction
%
% Initial explorations showed that the current preliminary GEM draft doesn't have a biomass reaction. Hence, biomass will always be 0 until this is added. The following code was generated by ChatGPT; it seeds a biomass reaction from common building blocks like amino acids and nucleotides.

% %%
[PbiviaBiomassDraftModel, biomassRxnID] = addPseudoBiomass_gramNegative( ...
    PbiviaCleanDraftModel, ...
    'BIOMASS_ps', ...
    [], ...
    true, ...
    'Pbivia_biomass_debug.txt', ...
    'Pbivia_biomass_metabolites.csv' ...
);
% Out:
% Precursor "L-alanine" → 7 matches found
%     Match: "3-sulfino-L-alanine:2-oxoglutarate aminotransferase" (ID: R02619_EXP_1)
%         Metabolite: "2-Oxoglutarate" (ID: C00026)
%         Metabolite: "3-Sulfino-L-alanine" (ID: C00606)
%     Match: "UDP-N-acetylmuramoyl-L-alanine:D-glutamate ligase(ADP-forming)" (ID: R02783)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "D-Glutamate" (ID: C00217)
%         Metabolite: "UDP-N-acetylmuramoyl-L-alanine" (ID: C01212)
%     Match: "L-Alanine:tRNA(Ala) ligase (AMP-forming)" (ID: R03038)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "L-Alanine" (ID: C00041)
%         Metabolite: "tRNA(Ala)" (ID: C01635)
%     Match: "UDP-N-acetylmuramate:L-alanine ligase (ADP-forming)" (ID: R03193)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "L-Alanine" (ID: C00041)
%         Metabolite: "UDP-N-acetylmuramate" (ID: C01050)
%     Match: "pimeloyl-CoA:L-alanine C-carboxyhexanoyltransferase (decarboxylating)" (ID: R03210)
%         Metabolite: "L-Alanine" (ID: C00041)
%         Metabolite: "Pimeloyl-CoA" (ID: C01063)
%     Match: "L-selenocysteine selenide-lyase (L-alanine-forming)" (ID: R03599)
%         Metabolite: "Reduced acceptor" (ID: C00030)
%         Metabolite: "L-Selenocysteine" (ID: C05688)
%     Match: "pimeloyl-[acyl-carrier protein]:L-alanine C-pimeloyltransferase (decarboxylating)" (ID: R10124)
%         Metabolite: "L-Alanine" (ID: C00041)
%         Metabolite: "Pimeloyl-[acyl-carrier protein]" (ID: C19845)
% Precursor "L-arginine" → 2 matches found
%     Match: "L-arginine carboxy-lyase (agmatine-forming)" (ID: R00566)
%         Metabolite: "L-Arginine" (ID: C00062)
%     Match: "L-Arginine:tRNA(Arg) ligase (AMP-forming)" (ID: R03646)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "L-Arginine" (ID: C00062)
%         Metabolite: "tRNA(Arg)" (ID: C01636)
% Precursor "L-aspartate" → 13 matches found
%     Match: "L-Aspartate:2-oxoglutarate aminotransferase" (ID: R00355_EXP_1)
%         Metabolite: "2-Oxoglutarate" (ID: C00026)
%         Metabolite: "L-Aspartate" (ID: C00049)
%     Match: "ATP:L-aspartate 4-phosphotransferase" (ID: R00480)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "L-Aspartate" (ID: C00049)
%     Match: "L-aspartate:oxygen oxidoreductase" (ID: R00481)
%         Metabolite: "Oxygen" (ID: C00007)
%         Metabolite: "L-Aspartate" (ID: C00049)
%     Match: "L-aspartate:ammonia ligase (AMP-forming)" (ID: R00483)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "Ammonia" (ID: C00014)
%         Metabolite: "L-Aspartate" (ID: C00049)
%     Match: "L-aspartate 1-carboxy-lyase (beta-alanine-forming)" (ID: R00489)
%         Metabolite: "L-Aspartate" (ID: C00049)
%     Match: "L-aspartate ammonia-lyase (fumarate-forming)" (ID: R00490)
%         Metabolite: "L-Aspartate" (ID: C00049)
%     Match: "IMP:L-aspartate ligase (GDP-forming)" (ID: R01135)
%         Metabolite: "GTP" (ID: C00044)
%         Metabolite: "L-Aspartate" (ID: C00049)
%         Metabolite: "IMP" (ID: C00130)
%     Match: "carbamoyl-phosphate:L-aspartate carbamoyltransferase" (ID: R01397)
%         Metabolite: "L-Aspartate" (ID: C00049)
%         Metabolite: "Carbamoyl phosphate" (ID: C00169)
%     Match: "L-Aspartate-4-semialdehyde:NADP+ oxidoreductase (phosphorylating)" (ID: R02291)
%         Metabolite: "NADP+" (ID: C00006)
%         Metabolite: "Orthophosphate" (ID: C00009)
%         Metabolite: "L-Aspartate 4-semialdehyde" (ID: C00441)
%     Match: "1-(5-Phosphoribosyl)-5-amino-4-carboxyimidazole:L-aspartate ligase (ADP-forming)" (ID: R04591)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "L-Aspartate" (ID: C00049)
%         Metabolite: "1-(5-Phospho-D-ribosyl)-5-amino-4-imidazolecarboxylate" (ID: C04751)
%     Match: "L-Aspartate:tRNA(Asp) ligase (AMP-forming)" (ID: R05577)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "L-Aspartate" (ID: C00049)
%         Metabolite: "tRNA(Asp)" (ID: C01638)
%     Match: "L-aspartate-4-semialdehyde hydro-lyase [adding pyruvate and cyclizing; (2S,4S)-4-hydroxy-2,3,4,5-tetrahydrodipicolinate-forming]" (ID: R10147)
%         Metabolite: "Pyruvate" (ID: C00022)
%         Metabolite: "L-Aspartate 4-semialdehyde" (ID: C00441)
%     Match: "[ribosomal protein S12]-L-aspartate:sulfur-donor,S-adenosyl-L-methionine C3-methylthiotransferase" (ID: R10652)
%         Metabolite: "S-Adenosyl-L-methionine" (ID: C00019)
%         Metabolite: "Sulfur donor" (ID: C17023)
%         Metabolite: "[Ribosomal protein S12]-L-aspartate" (ID: C20756)
% Precursor "L-cysteine" → 9 matches found
%     Match: "L-cysteine:2-oxoglutarate aminotransferase" (ID: R00896_EXP_1)
%         Metabolite: "2-Oxoglutarate" (ID: C00026)
%         Metabolite: "L-Cysteine" (ID: C00097)
%     Match: "N-[(R)-4'-Phosphopantothenoyl]-L-cysteine carboxy-lyase" (ID: R03269)
%         Metabolite: "(R)-4'-Phosphopantothenoyl-L-cysteine" (ID: C04352)
%     Match: "L-Cysteine:tRNA(Cys) ligase (AMP-forming)" (ID: R03650)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "L-Cysteine" (ID: C00097)
%         Metabolite: "tRNA(Cys)" (ID: C01639)
%     Match: "(R)-4'-phosphopantothenate:L-cysteine ligase" (ID: R04231)
%         Metabolite: "CTP" (ID: C00063)
%         Metabolite: "L-Cysteine" (ID: C00097)
%         Metabolite: "D-4'-Phosphopantothenate" (ID: C03492)
%     Match: "O3-acetyl-L-serine:thiosulfate 2-amino-2-carboxyethyltransferase (reducing, L-cysteine-forming);" (ID: R04859)
%         Metabolite: "H+" (ID: C00080)
%         Metabolite: "Thiosulfate" (ID: C00320)
%         Metabolite: "Thioredoxin" (ID: C00342)
%         Metabolite: "O-Acetyl-L-serine" (ID: C00979)
%     Match: "L-cysteine:sulfur-acceptor sulfurtransferase" (ID: R11528)
%         Metabolite: "L-Cysteine" (ID: C00097)
%         Metabolite: "[Protein]-L-cysteine" (ID: C02743)
%     Match: "L-cysteine hydrogen-sulfide-lyase (deaminating; pyruvate-forming)" (ID: R00782)
%         Metabolite: "H2O" (ID: C00001)
%         Metabolite: "L-Cysteine" (ID: C00097)
%     Match: "L-serine hydro-lyase (adding hydrogen sulfide, L-cysteine-forming)" (ID: R00891)
%         Metabolite: "L-Serine" (ID: C00065)
%         Metabolite: "Hydrogen sulfide" (ID: C00283)
%     Match: "L-cysteine-S-conjugate thiol-lyase (deaminating; 2-aminoprop-2-enoate-forming)" (ID: R12188)
%         Metabolite: "H2O" (ID: C00001)
%         Metabolite: "L-Cysteine-S-conjugate" (ID: C02882)
% Precursor "L-glutamate" → 11 matches found
%     Match: "L-glutamate:NADP+ oxidoreductase (transaminating)" (ID: R00114)
%         Metabolite: "NADP+" (ID: C00006)
%         Metabolite: "L-Glutamate" (ID: C00025)
%     Match: "L-glutamate:NADP+ oxidoreductase (deaminating)" (ID: R00248)
%         Metabolite: "H2O" (ID: C00001)
%         Metabolite: "NADP+" (ID: C00006)
%         Metabolite: "L-Glutamate" (ID: C00025)
%     Match: "L-Glutamate:ammonia ligase (ADP-forming)" (ID: R00253_EXP_1)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "Ammonia" (ID: C00014)
%         Metabolite: "L-Glutamate" (ID: C00025)
%     Match: "Tetrahydrofolate:L-glutamate gamma-ligase (ADP-forming)" (ID: R00942)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "L-Glutamate" (ID: C00025)
%         Metabolite: "Tetrahydrofolate" (ID: C00101)
%     Match: "7,8-dihydropteroate:L-glutamate ligase (ADP-forming)" (ID: R02237)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "L-Glutamate" (ID: C00025)
%         Metabolite: "Dihydropteroate" (ID: C00921)
%     Match: "5-Formiminotetrahydrofolate:L-glutamate N-formiminotransferase" (ID: R02287)
%         Metabolite: "L-Glutamate" (ID: C00025)
%         Metabolite: "5-Formiminotetrahydrofolate" (ID: C00664)
%     Match: "5-Formyltetrahydrofolate:L-glutamate N-formiminotransferase" (ID: R03189)
%         Metabolite: "L-Glutamate" (ID: C00025)
%         Metabolite: "Folinic acid" (ID: C03479)
%     Match: "5-Methyltetrahydropteroyltri-L-glutamate:L-homocysteine S-methyltransferase" (ID: R04405)
%         Metabolite: "L-Homocysteine" (ID: C00155)
%         Metabolite: "5-Methyltetrahydropteroyltri-L-glutamate" (ID: C04489)
%     Match: "L-glutamate:tRNA(Glu) ligase (AMP-forming)" (ID: R05578)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "L-Glutamate" (ID: C00025)
%         Metabolite: "tRNA(Glu)" (ID: C01641)
%     Match: "5-methyltetrahydropteroyltri-L-glutamate:L-selenohomocysteine Se-methyltransferase" (ID: R09365)
%         Metabolite: "5-Methyltetrahydropteroyltri-L-glutamate" (ID: C04489)
%         Metabolite: "Selenohomocysteine" (ID: C05698)
%     Match: "L-Glutamate:tRNA(Gln) ligase (AMP-forming)" (ID: R03651)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "L-Glutamate" (ID: C00025)
%         Metabolite: "tRNA(Gln)" (ID: C01640)
% Precursor "L-glutamine" → 11 matches found
%     Match: "L-glutamine amidohydrolase" (ID: R00256)
%         Metabolite: "H2O" (ID: C00001)
%         Metabolite: "L-Glutamine" (ID: C00064)
%     Match: "Deamido-NAD+:L-glutamine amido-ligase (AMP-forming)" (ID: R00257)
%         Metabolite: "H2O" (ID: C00001)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "L-Glutamine" (ID: C00064)
%         Metabolite: "Deamino-NAD+" (ID: C00857)
%     Match: "UTP:L-glutamine amido-ligase (ADP-forming)" (ID: R00573)
%         Metabolite: "H2O" (ID: C00001)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "L-Glutamine" (ID: C00064)
%         Metabolite: "UTP" (ID: C00075)
%     Match: "HCO3-:L-glutamine amido-ligase (ADP-forming, carbamate-phosphorylating)" (ID: R00575)
%         Metabolite: "H2O" (ID: C00001)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "L-Glutamine" (ID: C00064)
%         Metabolite: "HCO3-" (ID: C00288)
%     Match: "L-glutamine:D-fructose-6-phosphate isomerase (deaminating);" (ID: R00768)
%         Metabolite: "L-Glutamine" (ID: C00064)
%         Metabolite: "D-Fructose 6-phosphate" (ID: C00085)
%     Match: "Xanthosine-5'-phosphate:L-glutamine amido-ligase (AMP-forming)" (ID: R01231)
%         Metabolite: "H2O" (ID: C00001)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "L-Glutamine" (ID: C00064)
%         Metabolite: "Xanthosine 5'-phosphate" (ID: C00655)
%     Match: "chorismate:L-glutamine aminotransferase" (ID: R01716)
%         Metabolite: "L-Glutamine" (ID: C00064)
%         Metabolite: "Chorismate" (ID: C00251)
%     Match: "L-Glutamine:tRNA(Gln) ligase (AMP-forming)" (ID: R03652)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "L-Glutamine" (ID: C00064)
%         Metabolite: "tRNA(Gln)" (ID: C01640)
%     Match: "5'-Phosphoribosylformylglycinamide:L-glutamine amido-ligase (ADP-forming)" (ID: R04463)
%         Metabolite: "H2O" (ID: C00001)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "L-Glutamine" (ID: C00064)
%         Metabolite: "5'-Phosphoribosyl-N-formylglycinamide" (ID: C04376)
%     Match: "6-thioxanthine 5'-monophosphate:L-glutamine amido-ligase (AMP-forming)" (ID: R08244)
%         Metabolite: "H2O" (ID: C00001)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "L-Glutamine" (ID: C00064)
%         Metabolite: "6-Thioxanthine 5'-monophosphate" (ID: C16618)
%     Match: "S-adenosyl-L-methionine:[protein]-L-glutamine (N5-glutamine)-methyltransferase" (ID: R10806)
%         Metabolite: "S-Adenosyl-L-methionine" (ID: C00019)
%         Metabolite: "Protein glutamine" (ID: C02583)
% Precursor "L-glycine" → no matches found
% Precursor "L-histidine" → 2 matches found
%     Match: "L-histidine ammonia-lyase (urocanate-forming)" (ID: R01168)
%         Metabolite: "L-Histidine" (ID: C00135)
%     Match: "L-Histidine:tRNA(His) ligase (AMP-forming)" (ID: R03655)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "L-Histidine" (ID: C00135)
%         Metabolite: "tRNA(His)" (ID: C01643)
% Precursor "L-isoleucine" → 2 matches found
%     Match: "L-Isoleucine:2-oxoglutarate aminotransferase" (ID: R02199)
%         Metabolite: "2-Oxoglutarate" (ID: C00026)
%         Metabolite: "L-Isoleucine" (ID: C00407)
%     Match: "L-Isoleucine:tRNA(Ile) ligase (AMP-forming)" (ID: R03656)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "L-Isoleucine" (ID: C00407)
%         Metabolite: "tRNA(Ile)" (ID: C01644)
% Precursor "L-leucine" → 2 matches found
%     Match: "L-Leucine:2-oxoglutarate aminotransferase" (ID: R01090)
%         Metabolite: "2-Oxoglutarate" (ID: C00026)
%         Metabolite: "L-Leucine" (ID: C00123)
%     Match: "L-Leucine:tRNA(Leu) ligase (AMP-forming)" (ID: R03657)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "L-Leucine" (ID: C00123)
%         Metabolite: "tRNA(Leu)" (ID: C01645)
% Precursor "L-lysine" → 8 matches found
%     Match: "meso-2,6-diaminoheptanedioate carboxy-lyase (L-lysine-forming)" (ID: R00451)
%         Metabolite: "meso-2,6-Diaminoheptanedioate" (ID: C00680)
%     Match: "N6-(L-1,3-Dicarboxypropyl)-L-lysine:NAD+ oxidoreductase (L-lysine-forming)" (ID: R00715)
%         Metabolite: "H2O" (ID: C00001)
%         Metabolite: "NAD+" (ID: C00003)
%         Metabolite: "N6-(L-1,3-Dicarboxypropyl)-L-lysine" (ID: C00449)
%     Match: "L-lysine:tRNALys ligase (AMP-forming)" (ID: R03658)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "L-Lysine" (ID: C00047)
%         Metabolite: "tRNA(Lys)" (ID: C01646)
%     Match: "UDP-N-acetylmuramoyl-L-alanyl-D-glutamyl-L-lysine:alanyl-D-alanine ligase (ADP-forming)" (ID: R04573)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "D-Alanyl-D-alanine" (ID: C00993)
%         Metabolite: "UDP-N-acetylmuramoyl-L-alanyl-gamma-D-glutamyl-L-lysine" (ID: C05892)
%     Match: "[protein]-N6-(octanoyl)-L-lysine:an [Fe-S] cluster scaffold protein carrying a [4Fe-4S]2+ cluster sulfurtransferase" (ID: R07767)
%         Metabolite: "S-Adenosyl-L-methionine" (ID: C00019)
%         Metabolite: "H+" (ID: C00080)
%         Metabolite: "[Protein]-N6-(octanoyl)-L-lysine" (ID: C16236)
%         Metabolite: "Reduced [2Fe-2S] ferredoxin" (ID: C22150)
%         Metabolite: "[Fe-S] cluster scaffold protein carrying a [4Fe-4S]2+ cluster" (ID: C22154)
%     Match: "L-lysine:[tRNA(Ile2)]-cytidine34 ligase (AMP-forming)" (ID: R09597)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "L-Lysine" (ID: C00047)
%         Metabolite: "[tRNA(Ile2)]-cytidine34" (ID: C19722)
%     Match: "[lipoyl-carrier protein E2]-N6-(octanoyl)-L-lysine:[Fe-S] cluster scaffold protein carrying a [4Fe-4S]2+ cluster sulfurtransferase" (ID: R12423)
%         Metabolite: "S-Adenosyl-L-methionine" (ID: C00019)
%         Metabolite: "H+" (ID: C00080)
%         Metabolite: "Reduced [2Fe-2S] ferredoxin" (ID: C22150)
%         Metabolite: "[Fe-S] cluster scaffold protein carrying a [4Fe-4S]2+ cluster" (ID: C22154)
%         Metabolite: "[Lipoyl-carrier protein E2]-N6-octanoyl-L-lysine" (ID: C22160)
%     Match: "[glycine cleavage system H]-N6-octanoyl-L-lysine:[Fe-S] cluster scaffold protein carrying a [4Fe-4S]2+ cluster sulfurtransferase" (ID: R12424)
%         Metabolite: "S-Adenosyl-L-methionine" (ID: C00019)
%         Metabolite: "H+" (ID: C00080)
%         Metabolite: "Reduced [2Fe-2S] ferredoxin" (ID: C22150)
%         Metabolite: "[Fe-S] cluster scaffold protein carrying a [4Fe-4S]2+ cluster" (ID: C22154)
%         Metabolite: "[Glycine cleavage system H]-N6-octanoyl-L-lysine" (ID: C22159)
% Precursor "L-methionine" → 14 matches found
%     Match: "ATP:L-methionine S-adenosyltransferase" (ID: R00177)
%         Metabolite: "Orthophosphate" (ID: C00009)
%         Metabolite: "Diphosphate" (ID: C00013)
%         Metabolite: "S-Adenosyl-L-methionine" (ID: C00019)
%     Match: "S-adenosyl-L-methionine:tRNA guanine N1-methyltransferase;" (ID: R00597)
%         Metabolite: "S-Adenosyl-L-methionine" (ID: C00019)
%         Metabolite: "tRNA guanine" (ID: C01977)
%     Match: "S-Adenosyl-L-methionine:caffeoyl-CoA 3-O-methyltransferase" (ID: R01942)
%         Metabolite: "S-Adenosyl-L-methionine" (ID: C00019)
%         Metabolite: "Caffeoyl-CoA" (ID: C00323)
%     Match: "L-methionine:oxidized-thioredoxin S-oxidoreductase" (ID: R02025)
%         Metabolite: "H2O" (ID: C00001)
%         Metabolite: "L-Methionine" (ID: C00073)
%         Metabolite: "Thioredoxin disulfide" (ID: C00343)
%     Match: "L-Methionine:tRNAMet ligase (AMP-forming)" (ID: R03659)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "L-Methionine" (ID: C00073)
%         Metabolite: "tRNA(Met)" (ID: C01647)
%     Match: "Protein-glycine,dihydroflavodoxin:S-adenosyl-L-methionine oxidoreductase (S-adenosyl-L-methionine cleaving)" (ID: R04710)
%         Metabolite: "S-Adenosyl-L-methionine" (ID: C00019)
%         Metabolite: "Dihydroflavodoxin" (ID: C05196)
%         Metabolite: "Protein glycine" (ID: C05197)
%     Match: "S-adenosyl-L-methionine:caffeoyl-CoA 3-O-methyltransferase" (ID: R06578)
%         Metabolite: "S-Adenosyl-L-methionine" (ID: C00019)
%         Metabolite: "5-Hydroxyferuloyl-CoA" (ID: C12203)
%     Match: "S-adenosyl-L-methionine:7-aminomethyl-7-deazaguanosine ribosyltransferase (ribosyl isomerizing; L-methionine, adenine releasing)" (ID: R10220)
%         Metabolite: "S-Adenosyl-L-methionine" (ID: C00019)
%         Metabolite: "tRNA 7-aminomethyl-7-carbaguanine" (ID: C20446)
%     Match: "tRNA (N6-dimethylallyladenosine):sulfur-donor,S-adenosyl-L-methionine C2-methylthiotransferase" (ID: R10645)
%         Metabolite: "S-Adenosyl-L-methionine" (ID: C00019)
%         Metabolite: "tRNA containing 6-isopentenyladenosine" (ID: C04432)
%         Metabolite: "Sulfur donor" (ID: C17023)
%     Match: "tRNA (N6-L-threonylcarbamoyladenosine37):sulfur-donor,S-adenosyl-L-methionine C2-methylthiotransferase" (ID: R10649)
%         Metabolite: "S-Adenosyl-L-methionine" (ID: C00019)
%         Metabolite: "Sulfur donor" (ID: C17023)
%         Metabolite: "N6-L-Threonylcarbamoyladenine in tRNA" (ID: C20751)
%     Match: "[ribosomal protein S12]-L-aspartate:sulfur-donor,S-adenosyl-L-methionine C3-methylthiotransferase" (ID: R10652)
%         Metabolite: "S-Adenosyl-L-methionine" (ID: C00019)
%         Metabolite: "Sulfur donor" (ID: C17023)
%         Metabolite: "[Ribosomal protein S12]-L-aspartate" (ID: C20756)
%     Match: "S-adenosyl-L-methionine:[protein]-L-glutamine (N5-glutamine)-methyltransferase" (ID: R10806)
%         Metabolite: "S-Adenosyl-L-methionine" (ID: C00019)
%         Metabolite: "Protein glutamine" (ID: C02583)
%     Match: "S-adenosyl-L-methionine:DNA (cytosine-5-)-methyltransferase" (ID: R04858)
%         Metabolite: "S-Adenosyl-L-methionine" (ID: C00019)
%         Metabolite: "DNA cytosine" (ID: C00856)
%     Match: "coproporphyrinogen-III:S-adenosyl-L-methionine oxidoreductase(decarboxylating)" (ID: R06895)
%         Metabolite: "S-Adenosyl-L-methionine" (ID: C00019)
%         Metabolite: "Coproporphyrinogen III" (ID: C03263)
% Precursor "L-phenylalanine" → 3 matches found
%     Match: "L-arogenate hydro-lyase (decarboxylating; L-phenylalanine-forming)" (ID: R00691)
%         Metabolite: "L-Arogenate" (ID: C00826)
%     Match: "L-Phenylalanine:2-oxoglutarate aminotransferase" (ID: R00694)
%         Metabolite: "2-Oxoglutarate" (ID: C00026)
%         Metabolite: "L-Phenylalanine" (ID: C00079)
%     Match: "L-Phenylalanine:tRNA(Ala) ligase (AMP-forming)" (ID: R03660)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "L-Phenylalanine" (ID: C00079)
%         Metabolite: "tRNA(Phe)" (ID: C01648)
% Precursor "L-proline" → 1 matches found
%     Match: "L-proline:tRNA(Pro) ligase (AMP-forming)" (ID: R03661)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "L-Proline" (ID: C00148)
%         Metabolite: "tRNA(Pro)" (ID: C01649)
% Precursor "L-serine" → 15 matches found
%     Match: "L-serine ammonia-lyase" (ID: R00220)
%         Metabolite: "L-Serine" (ID: C00065)
%     Match: "acetyl-CoA:L-serine O-acetyltransferase" (ID: R00586)
%         Metabolite: "Acetyl-CoA" (ID: C00024)
%         Metabolite: "L-Serine" (ID: C00065)
%     Match: "L-serine hydro-lyase (adding indole; L-tryptophan-forming)" (ID: R00674)
%         Metabolite: "L-Serine" (ID: C00065)
%         Metabolite: "Indole" (ID: C00463)
%     Match: "O3-acetyl-L-serine:hydrogen-sulfide 2-amino-2-carboxyethyltransferase;" (ID: R00897)
%         Metabolite: "Hydrogen sulfide" (ID: C00283)
%         Metabolite: "O-Acetyl-L-serine" (ID: C00979)
%     Match: "CDP-diacylglycerol:L-serine 3-phosphatidyltransferase" (ID: R01800)
%         Metabolite: "L-Serine" (ID: C00065)
%         Metabolite: "CDP-diacylglycerol" (ID: C00269)
%     Match: "Phsophatidyl-L-serine carboxy-lyase" (ID: R02055)
%         Metabolite: "Phosphatidylserine" (ID: C02737)
%     Match: "L-serine hydro-lyase [adding 1-C-(indol-3-yl)glycerol 3-phosphate; L-tryptophan and glyceraldehyde-3-phosphate-forming]" (ID: R02722)
%         Metabolite: "L-Serine" (ID: C00065)
%         Metabolite: "Indoleglycerol phosphate" (ID: C03506)
%     Match: "O3-Acetyl-L-serine acetate-lyase (adding hydrogen sulfide)" (ID: R03601)
%         Metabolite: "O-Acetyl-L-serine" (ID: C00979)
%         Metabolite: "Hydrogen selenide" (ID: C01528)
%     Match: "L-Serine:tRNA(Ser) ligase (AMP-forming)" (ID: R03662)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "L-Serine" (ID: C00065)
%         Metabolite: "tRNA(Ser)" (ID: C01650)
%     Match: "O3-acetyl-L-serine:thiosulfate 2-amino-2-carboxyethyltransferase (reducing, L-cysteine-forming);" (ID: R04859)
%         Metabolite: "H+" (ID: C00080)
%         Metabolite: "Thiosulfate" (ID: C00320)
%         Metabolite: "Thioredoxin" (ID: C00342)
%         Metabolite: "O-Acetyl-L-serine" (ID: C00979)
%     Match: "O-phospho-L-serine:hydrogen-sulfide 2-amino-2-carboxyethyltransferase" (ID: R07274)
%         Metabolite: "Hydrogen sulfide" (ID: C00283)
%         Metabolite: "O-Phospho-L-serine" (ID: C01005)
%     Match: "L-serine:tRNASec ligase (AMP-forming)" (ID: R08218)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "L-Serine" (ID: C00065)
%         Metabolite: "tRNA(Sec)" (ID: C16636)
%     Match: "L-serine hydro-lyase (adding hydrogen sulfide, L-cysteine-forming)" (ID: R00891)
%         Metabolite: "L-Serine" (ID: C00065)
%         Metabolite: "Hydrogen sulfide" (ID: C00283)
%     Match: "L-serine hydro-lyase (adding homocysteine; L-cystathionine-forming)" (ID: R01290)
%         Metabolite: "L-Serine" (ID: C00065)
%         Metabolite: "L-Homocysteine" (ID: C00155)
%     Match: "L-Serine hydro-lyase (adding homocysteine)" (ID: R04942)
%         Metabolite: "L-Serine" (ID: C00065)
%         Metabolite: "Selenohomocysteine" (ID: C05698)
% Precursor "L-threonine" → 2 matches found
%     Match: "L-Threonine:tRNA(Thr) ligase (AMP-forming)" (ID: R03663)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "L-Threonine" (ID: C00188)
%         Metabolite: "tRNA(Thr)" (ID: C01651)
%     Match: "O-Phospho-4-hydroxy-L-threonine:2-oxoglutarate aminotransferase" (ID: R05085)
%         Metabolite: "2-Oxoglutarate" (ID: C00026)
%         Metabolite: "O-Phospho-4-hydroxy-L-threonine" (ID: C06055)
% Precursor "L-tryptophan" → 3 matches found
%     Match: "L-serine hydro-lyase (adding indole; L-tryptophan-forming)" (ID: R00674)
%         Metabolite: "L-Serine" (ID: C00065)
%         Metabolite: "Indole" (ID: C00463)
%     Match: "L-serine hydro-lyase [adding 1-C-(indol-3-yl)glycerol 3-phosphate; L-tryptophan and glyceraldehyde-3-phosphate-forming]" (ID: R02722)
%         Metabolite: "L-Serine" (ID: C00065)
%         Metabolite: "Indoleglycerol phosphate" (ID: C03506)
%     Match: "L-Tryptophan -tRNA(Trp) ligase (AMP-forming)" (ID: R03664)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "L-Tryptophan" (ID: C00078)
%         Metabolite: "tRNA(Trp)" (ID: C01652)
% Precursor "L-tyrosine" → 2 matches found
%     Match: "L-tyrosine:2-oxoglutarate aminotransferase" (ID: R00734)
%         Metabolite: "2-Oxoglutarate" (ID: C00026)
%         Metabolite: "L-Tyrosine" (ID: C00082)
%     Match: "L-Tyrosine:tRNA(Tyr) ligase (AMP-forming)" (ID: R02918)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "L-Tyrosine" (ID: C00082)
%         Metabolite: "tRNA(Tyr)" (ID: C00787)
% Precursor "L-valine" → 2 matches found
%     Match: "L-Valine:2-oxoglutarate aminotransferase" (ID: R01214)
%         Metabolite: "2-Oxoglutarate" (ID: C00026)
%         Metabolite: "L-Valine" (ID: C00183)
%     Match: "L-Valine:tRNAVal ligase (AMP-forming)" (ID: R03665)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "L-Valine" (ID: C00183)
%         Metabolite: "tRNA(Val)" (ID: C01653)
% Precursor "ATP" → 84 matches found
%     Match: "ATP diphosphate-lyase (cyclizing; 3',5'-cyclic-AMP-forming)" (ID: R00089)
%         Metabolite: "ATP" (ID: C00002)
%     Match: "ATP:NAD+ 2'-phosphotransferase" (ID: R00104)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "NAD+" (ID: C00003)
%     Match: "ATP:AMP phosphotransferase" (ID: R00127)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "AMP" (ID: C00020)
%     Match: "ATP:dephospho-CoA 3'-phosphotransferase" (ID: R00130)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "Dephospho-CoA" (ID: C00882)
%     Match: "ATP:nicotinamide-nucleotide adenylyltransferase" (ID: R00137)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "Nicotinamide D-ribonucleotide" (ID: C00455)
%     Match: "ATP:UMP phosphotransferase" (ID: R00158)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "UMP" (ID: C00105)
%     Match: "ATP:FMN adenylyltransferase" (ID: R00161)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "FMN" (ID: C00061)
%     Match: "ATP:pyridoxal 5'-phosphotransferase" (ID: R00174)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "Pyridoxal" (ID: C00250)
%     Match: "ATP:L-methionine S-adenosyltransferase" (ID: R00177)
%         Metabolite: "Orthophosphate" (ID: C00009)
%         Metabolite: "Diphosphate" (ID: C00013)
%         Metabolite: "S-Adenosyl-L-methionine" (ID: C00019)
%     Match: "ATP:pyruvate 2-O-phosphotransferase" (ID: R00200)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "Pyruvate" (ID: C00022)
%     Match: "ATP:pyruvate,phosphate phosphotransferase" (ID: R00206)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "Orthophosphate" (ID: C00009)
%         Metabolite: "Pyruvate" (ID: C00022)
%     Match: "ATP:D-glucose 6-phosphotransferase" (ID: R00299)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "D-Glucose" (ID: C00031)
%     Match: "ATP:acetate phosphotransferase" (ID: R00315)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "Acetate" (ID: C00033)
%     Match: "ATP:acetate adenylyltransferase" (ID: R00316)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "Acetate" (ID: C00033)
%     Match: "ATP:GMP phosphotransferase" (ID: R00332)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "GMP" (ID: C00144)
%     Match: "ATP:oxaloacetate carboxy-lyase (transphosphorylating;phosphoenolpyruvate-forming)" (ID: R00341)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "Oxaloacetate" (ID: C00036)
%     Match: "ATP:GTP 3'-diphosphotransferase" (ID: R00429)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "GTP" (ID: C00044)
%     Match: "ATP:L-aspartate 4-phosphotransferase" (ID: R00480)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "L-Aspartate" (ID: C00049)
%     Match: "ATP:CMP phosphotransferase" (ID: R00512)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "CMP" (ID: C00055)
%     Match: "ATP:cytidine 5'-phosphotransferase" (ID: R00513_EXP_1)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "Cytidine" (ID: C00475)
%     Match: "ATP:riboflavin 5'-phosphotransferase" (ID: R00549)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "Riboflavin" (ID: C00255)
%     Match: "ATP:thiamin-phosphate phosphotransferase" (ID: R00617)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "Thiamin monophosphate" (ID: C01081)
%     Match: "ATP:thiamine diphosphotransferase" (ID: R00619)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "Thiamine" (ID: C00378)
%     Match: "ATP:D-fructose-6-phosphate 1-phosphotransferase" (ID: R00756)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "D-Fructose 6-phosphate" (ID: C00085)
%     Match: "ATP:D-fructose 6-phosphotransferase" (ID: R00760)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "D-Fructose" (ID: C00095)
%     Match: "ATP:glycerol 3-phosphotransferase" (ID: R00847)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "Glycerol" (ID: C00116)
%     Match: "ATP:D-fructose 6-phosphotransferase" (ID: R00867)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "D-Fructose" (ID: C00095)
%     Match: "ATP:uridine 5'-phosphotransferase" (ID: R00964_EXP_1)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "Uridine" (ID: C00299)
%     Match: "ATP:D-ribose-5-phosphate diphosphotransferase" (ID: R01049)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "D-Ribose 5-phosphate" (ID: C00117)
%     Match: "ATP:alpha-D-galactose 1-phosphotransferase" (ID: R01092)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "alpha-D-Galactose" (ID: C00984)
%     Match: "dATP:pyruvate 2-O-phosphotransferase" (ID: R01138)
%         Metabolite: "Pyruvate" (ID: C00022)
%         Metabolite: "dATP" (ID: C00131)
%     Match: "ATP:propanoate phosphotransferase" (ID: R01353)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "Propanoate" (ID: C00163)
%     Match: "ATP:propanoate adenylyltransferase" (ID: R01354)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "Propanoate" (ID: C00163)
%     Match: "ATP:carbamate phosphotransferase" (ID: R01395)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "Carbamate" (ID: C01563)
%     Match: "ATP:3-phospho-D-glycerate 1-phosphotransferase" (ID: R01512)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "3-Phospho-D-glycerate" (ID: C00197)
%     Match: "ATP:dAMP phosphotransferase" (ID: R01547)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "dAMP" (ID: C00360)
%     Match: "ATP:thymidine 5'-phosphotransferase" (ID: R01567)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "Thymidine" (ID: C00214)
%     Match: "ATP:beta-D-glucose 6-phosphotransferase" (ID: R01600)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "beta-D-Glucose" (ID: C00221)
%     Match: "ATP:dCMP phosphotransferase" (ID: R01665)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "dCMP" (ID: C00239)
%     Match: "ATP:deoxycitidine 5'-phosphotransferase" (ID: R01666)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "Deoxycytidine" (ID: C00881)
%     Match: "ATP:butanoate 1-phosphotransferase" (ID: R01688)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "Butanoic acid" (ID: C00246)
%     Match: "ATP:alpha-D-glucose 6-phosphotransferase" (ID: R01786)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "alpha-D-Glucose" (ID: C00267)
%     Match: "ATP:pyridoxine 5'-phosphotransferase" (ID: R01909)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "Pyridoxine" (ID: C00314)
%     Match: "ATP:D-glucosamine 6-phosphotransferase" (ID: R01961)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "D-Glucosamine" (ID: C00329)
%     Match: "ATP:deoxyadenosine 5'-phosphotransferase" (ID: R02089)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "Deoxyadenosine" (ID: C00559)
%     Match: "ATP:dGMP phosphotransferase" (ID: R02090)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "dGMP" (ID: C00362)
%     Match: "ATP:deoxyuridine 5'-phosphotransferase" (ID: R02099)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "Deoxyuridine" (ID: C00526)
%     Match: "ATP:shikimate 3-phosphotransferase" (ID: R02412)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "Shikimate" (ID: C00493)
%     Match: "ATP:pyridoxal 5'-phosphotransferase" (ID: R02493)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "Pyridoxamine" (ID: C00534)
%     Match: "ATP:pantothenate 4'-phosphotransferase" (ID: R02971)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "Pantetheine" (ID: C00831)
%     Match: "ATP:nicotinamide-nucleotide adenylyltransferase" (ID: R03005)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "Nicotinate D-ribonucleotide" (ID: C01185)
%     Match: "ATP:pantothenate 4'-phosphotransferase" (ID: R03018)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "Pantothenate" (ID: C00864)
%     Match: "ATP:pantetheine-4'-phosphate adenylyltransferase" (ID: R03035)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "Pantetheine 4'-phosphate" (ID: C01134)
%     Match: "ATP:D-tagatose-6-phosphate 1-phosphotransferase" (ID: R03236)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "D-Tagatose 6-phosphate" (ID: C01097)
%     Match: "ATP:4-amino-5-hydroxymethyl-2-methylpyrimidine 5-phosphotransferase" (ID: R03471)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "4-Amino-5-hydroxymethyl-2-methylpyrimidine" (ID: C01279)
%     Match: "ATP:6-hydroxymethyl-7,8-dihydropterin 6'-diphosphotransferase" (ID: R03503_EXP_1)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "6-(Hydroxymethyl)-7,8-dihydropterin" (ID: C01300)
%     Match: "ATP:D-fructose 6-phosphotransferase" (ID: R03920)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "beta-D-Fructose" (ID: C02336)
%     Match: "ATP:pantothenate 4'-phosphotransferase" (ID: R04391)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "N-((R)-Pantothenoyl)-L-cysteine" (ID: C04079)
%     Match: "ATP:4-amino-2-methyl-5-phosphomethylpyrimidine phosphotransferase" (ID: R04509)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "4-Amino-2-methyl-5-(phosphooxymethyl)pyrimidine" (ID: C04556)
%     Match: "ATP:2,3,2',3'-tetrakis(3-hydroxytetradecanoyl)-D-glucosaminyl-beta-D-1,6-glucosaminyl-alpha-phosphate 4-O'-phosphotransferase" (ID: R04657)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "Lipid A disaccharide" (ID: C04932)
%     Match: "ATP:L-selenomethione S-adenosyltransferase" (ID: R04771)
%         Metabolite: "H2O" (ID: C00001)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "L-Selenomethionine" (ID: C05335)
%     Match: "ATP:D-fructose-6-phosphate 1-phosphotransferase" (ID: R04779)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "beta-D-Fructose 6-phosphate" (ID: C05345)
%     Match: "ATP:4-(Cytidine 5'-diphospho)-2-C-methyl-D-erythritol 2-phosphotransferase" (ID: R05634)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "4-(Cytidine 5'-diphospho)-2-C-methyl-D-erythritol" (ID: C11435)
%     Match: "ATP:5-fluorouridine 5'-phosphotransferase" (ID: R08232_EXP_1)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "5-Fluorouridine" (ID: C16633)
%     Match: "ATP:5-fluorodeoxyuridine 5'-phosphotransferase" (ID: R08233)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "5-Fluorodeoxyuridine" (ID: C11736)
%     Match: "ATP:(R)-glycerate 2-phosphotransferase" (ID: R08572)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "D-Glycerate" (ID: C00258)
%     Match: "ATP:L-threonyl,bicarbonate adenylyltransferase" (ID: R10463)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "H+" (ID: C00080)
%         Metabolite: "L-Threonine" (ID: C00188)
%         Metabolite: "HCO3-" (ID: C00288)
%     Match: "ATP:HCO3- phosphotransferase" (ID: R10948)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "HCO3-" (ID: C00288)
%     Match: "ATP:formate 2'-oxidoreductase" (ID: R11634)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "Formate" (ID: C00058)
%     Match: "ATP diphosphohydrolase (diphosphate-forming);" (ID: R00087)
%         Metabolite: "H2O" (ID: C00001)
%         Metabolite: "ATP" (ID: C00002)
%     Match: "ATP:adenylylsulfate 3'-phosphotransferase" (ID: R00509)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "Adenylyl sulfate" (ID: C00224)
%     Match: "ATP:sulfate adenylyltransferase" (ID: R00529)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "Sulfate" (ID: C00059)
%     Match: "ATP:cob(I)alamin Co-beta-adenosyltransferase" (ID: R01492)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "Cob(I)alamin" (ID: C00853)
%     Match: "ATP:1,2-diacylglycerol 3-phosphotransferase" (ID: R02240)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "1,2-Diacyl-sn-glycerol" (ID: C00641)
%     Match: "ATP:adenylylsulfate 3'-phosphotransferase" (ID: R04928)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "Adenylylselenate" (ID: C05686)
%     Match: "ATP:selenate adenylyltransferase" (ID: R04929)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "Selenate" (ID: C05697)
%     Match: "ATP:cob(I)yrinic acid-a,c-diamide Cobeta-adenosyltransferase" (ID: R05220)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "Cob(I)yrinate a,c diamide" (ID: C06505)
%     Match: "ATP:cobinamide Cobeta-adenosyltransferase" (ID: R07268)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "Cobinamide" (ID: C05774)
%     Match: "ATP:N-acetyl-D-hexosamine 1-phosphotransferase" (ID: R08962)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "N-Acetyl-D-hexosamine" (ID: C03136)
%     Match: "ATP:N-acetyl-D-glucosamine 1-phosphotransferase" (ID: R08968)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "N-Acetyl-D-glucosamine" (ID: C00140)
%     Match: "CTP,CTP,ATP:tRNA cytidylyl,cytidylyl,adenylyltransferase" (ID: R09382)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "CTP" (ID: C00063)
%         Metabolite: "tRNA precursor" (ID: C02211)
%     Match: "ATP:tRNA adenylyltransferase" (ID: R09386)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "tRNA with a 3' CC end" (ID: C19080)
%     Match: "ATP:N-acetyl-D-muramate 1-phosphotransferase" (ID: R11024)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "N-Acetylmuramate" (ID: C02713)
%     Match: "ATP:Cob(II)yrinate diamide Cobeta-adenosyltransferase" (ID: R12184)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "[Reduced NADPH---hemoprotein reductase]" (ID: C03024)
%         Metabolite: "Cob(II)yrinate a,c diamide" (ID: C06504)
% Precursor "GTP" → 13 matches found
%     Match: "GTP 7,8-8,9-dihydrolase" (ID: R00424)
%         Metabolite: "H2O" (ID: C00001)
%         Metabolite: "GTP" (ID: C00044)
%     Match: "GTP 7,8-8,9-dihydrolase (diphosphate-forming)" (ID: R00425)
%         Metabolite: "H2O" (ID: C00001)
%         Metabolite: "GTP" (ID: C00044)
%     Match: "GTP 8,9-hydrolase" (ID: R00428)
%         Metabolite: "H2O" (ID: C00001)
%         Metabolite: "GTP" (ID: C00044)
%     Match: "ATP:GTP 3'-diphosphotransferase" (ID: R00429)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "GTP" (ID: C00044)
%     Match: "GTP:pyruvate 2-O-phosphotransferase" (ID: R00430)
%         Metabolite: "Pyruvate" (ID: C00022)
%         Metabolite: "GTP" (ID: C00044)
%     Match: "GTP diphosphate-lyase (cyclizing; 3',5'-cyclic-GMP-forming)" (ID: R00434)
%         Metabolite: "GTP" (ID: C00044)
%     Match: "GTP:cytidine 5'-phosphotransferase" (ID: R00517_EXP_1)
%         Metabolite: "GTP" (ID: C00044)
%         Metabolite: "Cytidine" (ID: C00475)
%     Match: "GTP:alpha-D-mannose-1-phosphate guanylyltransferase" (ID: R00885)
%         Metabolite: "GTP" (ID: C00044)
%         Metabolite: "D-Mannose 1-phosphate" (ID: C00636)
%     Match: "GTP:uridine 5'-phosphotransferase" (ID: R00968_EXP_1)
%         Metabolite: "GTP" (ID: C00044)
%         Metabolite: "Uridine" (ID: C00299)
%     Match: "dGTP triphosphohydrolase" (ID: R01856)
%         Metabolite: "H2O" (ID: C00001)
%         Metabolite: "dGTP" (ID: C00286)
%     Match: "dGTP:pyruvate 2-O-phosphotransferase" (ID: R01858)
%         Metabolite: "Pyruvate" (ID: C00022)
%         Metabolite: "dGTP" (ID: C00286)
%     Match: "GTP:formate 2'-oxidoreductase" (ID: R11633)
%         Metabolite: "GTP" (ID: C00044)
%         Metabolite: "Formate" (ID: C00058)
%     Match: "GTP diphosphohydrolase (diphosphate-forming);" (ID: R00426)
%         Metabolite: "H2O" (ID: C00001)
%         Metabolite: "GTP" (ID: C00044)
% Precursor "CTP" → 11 matches found
%     Match: "CTP diphosphohydrolase (diphosphate-forming);" (ID: R00515)
%         Metabolite: "H2O" (ID: C00001)
%         Metabolite: "CTP" (ID: C00063)
%     Match: "CTP:phosphatidate cytidyltransferase" (ID: R01799)
%         Metabolite: "CTP" (ID: C00063)
%         Metabolite: "Phosphatidate" (ID: C00416)
%     Match: "CTP:D-tagatose 6-phosphate 1-phosphotransferase" (ID: R03237)
%         Metabolite: "CTP" (ID: C00063)
%         Metabolite: "D-Tagatose 6-phosphate" (ID: C01097)
%     Match: "CTP:3-deoxy-D-manno-octulosonate cytidylyltransferase" (ID: R03351)
%         Metabolite: "CTP" (ID: C00063)
%         Metabolite: "3-Deoxy-D-manno-octulosonate" (ID: C01187)
%     Match: "CTP: 2-C-Methyl-D-erythritol 4-phosphate cytidylyltransferase" (ID: R05633)
%         Metabolite: "CTP" (ID: C00063)
%         Metabolite: "2-C-Methyl-D-erythritol 4-phosphate" (ID: C11434)
%     Match: "CTP:8-amino-3,8-dideoxy-D-manno-octulosonate cytidylyltransferase" (ID: R11396)
%         Metabolite: "CTP" (ID: C00063)
%         Metabolite: "8-Amino-3,8-dideoxy-D-manno-octulosonate" (ID: C21333)
%     Match: "CTP:formate 2'-oxidoreductase" (ID: R11636)
%         Metabolite: "Formate" (ID: C00058)
%         Metabolite: "CTP" (ID: C00063)
%     Match: "CTP:D-ribitol-5-phosphate cytidylyltransferase" (ID: R02921)
%         Metabolite: "CTP" (ID: C00063)
%         Metabolite: "D-Ribitol 5-phosphate" (ID: C01068)
%     Match: "CTP,CTP,ATP:tRNA cytidylyl,cytidylyl,adenylyltransferase" (ID: R09382)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "CTP" (ID: C00063)
%         Metabolite: "tRNA precursor" (ID: C02211)
%     Match: "CTP:tRNA cytidylyltransferase" (ID: R09383)
%         Metabolite: "CTP" (ID: C00063)
%         Metabolite: "tRNA precursor" (ID: C02211)
%     Match: "CTP:tRNA cytidylyltransferase" (ID: R09384)
%         Metabolite: "CTP" (ID: C00063)
%         Metabolite: "tRNA with a 3' cytidine" (ID: C19078)
% Precursor "UTP" → 6 matches found
%     Match: "UTP:ammonia ligase (ADP-forming)" (ID: R00571)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "Ammonia" (ID: C00014)
%         Metabolite: "UTP" (ID: C00075)
%     Match: "UTP:L-glutamine amido-ligase (ADP-forming)" (ID: R00573)
%         Metabolite: "H2O" (ID: C00001)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "L-Glutamine" (ID: C00064)
%         Metabolite: "UTP" (ID: C00075)
%     Match: "dUTP nucleotidohydrolase" (ID: R02100)
%         Metabolite: "H2O" (ID: C00001)
%         Metabolite: "dUTP" (ID: C00460)
%     Match: "UTP:D-tagatose 6-phosphate 1-phosphotransferase" (ID: R03238)
%         Metabolite: "UTP" (ID: C00075)
%         Metabolite: "D-Tagatose 6-phosphate" (ID: C01097)
%     Match: "UTP:N-acetyl-alpha-D-muramate-1-phosphate uridylyltransferase" (ID: R11025)
%         Metabolite: "UTP" (ID: C00075)
%         Metabolite: "N-Acetylmuramic acid alpha-1-phosphate" (ID: C21027)
%     Match: "UTP:formate 2'-oxidoreductase" (ID: R11635)
%         Metabolite: "Formate" (ID: C00058)
%         Metabolite: "UTP" (ID: C00075)
% Precursor "NAD" → 119 matches found
%     Match: "NAD+ phosphohydrolase" (ID: R00103)
%         Metabolite: "H2O" (ID: C00001)
%         Metabolite: "NAD+" (ID: C00003)
%     Match: "ATP:NAD+ 2'-phosphotransferase" (ID: R00104)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "NAD+" (ID: C00003)
%     Match: "L-glutamate:NADP+ oxidoreductase (transaminating)" (ID: R00114)
%         Metabolite: "NADP+" (ID: C00006)
%         Metabolite: "L-Glutamate" (ID: C00025)
%     Match: "ammonia:NAD+ oxidoreductase;" (ID: R00143)
%         Metabolite: "H2O" (ID: C00001)
%         Metabolite: "NAD+" (ID: C00003)
%         Metabolite: "Ammonia" (ID: C00014)
%     Match: "pyruvate:NAD+ 2-oxidoreductase (CoA-acetylating);" (ID: R00209)
%         Metabolite: "NAD+" (ID: C00003)
%         Metabolite: "CoA" (ID: C00010)
%         Metabolite: "Pyruvate" (ID: C00022)
%     Match: "(S)-Malate:NADP+ oxidoreductase(oxaloacetate-decarboxylating)" (ID: R00216)
%         Metabolite: "NADP+" (ID: C00006)
%         Metabolite: "(S)-Malate" (ID: C00149)
%     Match: "L-glutamate:NADP+ oxidoreductase (deaminating)" (ID: R00248)
%         Metabolite: "H2O" (ID: C00001)
%         Metabolite: "NADP+" (ID: C00006)
%         Metabolite: "L-Glutamate" (ID: C00025)
%     Match: "Deamido-NAD+:L-glutamine amido-ligase (AMP-forming)" (ID: R00257)
%         Metabolite: "H2O" (ID: C00001)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "L-Glutamine" (ID: C00064)
%         Metabolite: "Deamino-NAD+" (ID: C00857)
%     Match: "UDP-glucose:NAD+ 6-oxidoreductase" (ID: R00286)
%         Metabolite: "H2O" (ID: C00001)
%         Metabolite: "NAD+" (ID: C00003)
%         Metabolite: "UDP-glucose" (ID: C00029)
%     Match: "(S)-malate:NAD+ oxidoreductase" (ID: R00342)
%         Metabolite: "NAD+" (ID: C00003)
%         Metabolite: "(S)-Malate" (ID: C00149)
%     Match: "(R)-Lactate:NAD+ oxidoreductase" (ID: R00704)
%         Metabolite: "NAD+" (ID: C00003)
%         Metabolite: "(R)-Lactate" (ID: C00256)
%     Match: "N6-(L-1,3-Dicarboxypropyl)-L-lysine:NAD+ oxidoreductase (L-lysine-forming)" (ID: R00715)
%         Metabolite: "H2O" (ID: C00001)
%         Metabolite: "NAD+" (ID: C00003)
%         Metabolite: "N6-(L-1,3-Dicarboxypropyl)-L-lysine" (ID: C00449)
%     Match: "Glycolate:NAD+ oxidoreductase" (ID: R00717)
%         Metabolite: "NAD+" (ID: C00003)
%         Metabolite: "Glycolate" (ID: C00160)
%     Match: "sn-Glycerol-3-phosphate:NAD+ 2-oxidoreductase" (ID: R00842)
%         Metabolite: "NAD+" (ID: C00003)
%         Metabolite: "sn-Glycerol 3-phosphate" (ID: C00093)
%     Match: "sn-Glycerol-3-phosphate:NADP+ 2-oxidoreductase" (ID: R00844)
%         Metabolite: "NADP+" (ID: C00006)
%         Metabolite: "sn-Glycerol 3-phosphate" (ID: C00093)
%     Match: "5,6,7,8-tetrahydrofolate:NAD+ oxidoreductase" (ID: R00936)
%         Metabolite: "NAD+" (ID: C00003)
%         Metabolite: "Tetrahydrofolate" (ID: C00101)
%     Match: "5,6,7,8-tetrahydrofolate:NAD+ oxidoreductase" (ID: R00937)
%         Metabolite: "NAD+" (ID: C00003)
%         Metabolite: "Tetrahydrofolate" (ID: C00101)
%     Match: "5,6,7,8-tetrahydrofolate:NADP+ oxidoreductase" (ID: R00939)
%         Metabolite: "NADP+" (ID: C00006)
%         Metabolite: "Tetrahydrofolate" (ID: C00101)
%     Match: "5,6,7,8-tetrahydrofolate:NADP+ oxidoreductase" (ID: R00940)
%         Metabolite: "NADP+" (ID: C00006)
%         Metabolite: "Tetrahydrofolate" (ID: C00101)
%     Match: "D-glyceraldehyde-3-phosphate:NAD+ oxidoreductase (phosphorylating)" (ID: R01061)
%         Metabolite: "NAD+" (ID: C00003)
%         Metabolite: "Orthophosphate" (ID: C00009)
%         Metabolite: "D-Glyceraldehyde 3-phosphate" (ID: C00118)
%     Match: "IMP:NAD+ oxidoreductase" (ID: R01130)
%         Metabolite: "H2O" (ID: C00001)
%         Metabolite: "NAD+" (ID: C00003)
%         Metabolite: "IMP" (ID: C00130)
%     Match: "5,10-methylenetetrahydrofolate:NADP+ oxidoreductase" (ID: R01220)
%         Metabolite: "NADP+" (ID: C00006)
%         Metabolite: "5,10-Methylenetetrahydrofolate" (ID: C00143)
%     Match: "glycine:NAD+ 2-oxidoreductase (tetrahydrofolate-methylene-adding);" (ID: R01221)
%         Metabolite: "NAD+" (ID: C00003)
%         Metabolite: "Glycine" (ID: C00037)
%         Metabolite: "Tetrahydrofolate" (ID: C00101)
%     Match: "D-Glycerate:NAD+ 2-oxidoreductase" (ID: R01388)
%         Metabolite: "NAD+" (ID: C00003)
%         Metabolite: "D-Glycerate" (ID: C00258)
%     Match: "acyl-[acyl-carrier-protein]:NAD+ oxidoreductase" (ID: R01403)
%         Metabolite: "NAD+" (ID: C00003)
%         Metabolite: "Acyl-[acyl-carrier protein]" (ID: C00173)
%     Match: "acyl-[acyl-carrier protein]:NADP+ oxidoreductase" (ID: R01404)
%         Metabolite: "NADP+" (ID: C00006)
%         Metabolite: "Acyl-[acyl-carrier protein]" (ID: C00173)
%     Match: "3-Phospho-D-glycerate:NAD+ 2-oxidoreductase" (ID: R01513)
%         Metabolite: "NAD+" (ID: C00003)
%         Metabolite: "3-Phospho-D-glycerate" (ID: C00197)
%     Match: "propan-2-ol:NADP+ oxidoreductase" (ID: R01550)
%         Metabolite: "NADPH" (ID: C00005)
%         Metabolite: "H+" (ID: C00080)
%         Metabolite: "Acetone" (ID: C00207)
%     Match: "Dihydrolipoamide:NAD+ oxidoreductase" (ID: R01698)
%         Metabolite: "NAD+" (ID: C00003)
%         Metabolite: "Dihydrolipoamide" (ID: C00579)
%     Match: "prephenate:NAD+ oxidoreductase(decarboxylating)" (ID: R01728)
%         Metabolite: "NAD+" (ID: C00003)
%         Metabolite: "Prephenate" (ID: C00254)
%     Match: "L-Homoserine:NAD+ oxidoreductase" (ID: R01773)
%         Metabolite: "NAD+" (ID: C00003)
%         Metabolite: "L-Homoserine" (ID: C00263)
%     Match: "L-homoserine:NADP+ oxidoreductase" (ID: R01775)
%         Metabolite: "NADP+" (ID: C00006)
%         Metabolite: "L-Homoserine" (ID: C00263)
% ...
%         Metabolite: "NADP+" (ID: C00006)
%         Metabolite: "(3R)-3-Hydroxydodecanoyl-[acyl-carrier protein]" (ID: C05757)
%     Match: "tetradecanoyl-[acp]:NADP+ trans-2-oxidoreductase" (ID: R04967)
%         Metabolite: "NADP+" (ID: C00006)
%         Metabolite: "Tetradecanoyl-[acp]" (ID: C05761)
%     Match: "hexadecanoyl-[acp]:NADP+ trans-2-oxidoreductase" (ID: R04970)
%         Metabolite: "NADP+" (ID: C00006)
%         Metabolite: "Hexadecanoyl-[acp]" (ID: C05764)
%     Match: "GDP-L-fucose:NADP+ 4-oxidoreductase (3,5-epimerizing)" (ID: R05692)
%         Metabolite: "NADP+" (ID: C00006)
%         Metabolite: "GDP-L-fucose" (ID: C00325)
%     Match: "FMNH2:NADP+ oxidoreductase" (ID: R05706)
%         Metabolite: "NADP+" (ID: C00006)
%         Metabolite: "Reduced FMN" (ID: C01847)
%     Match: "7-aminomethyl-7-carbaguanine:NADP+ oxidoreductase" (ID: R07605)
%         Metabolite: "NADP+" (ID: C00006)
%         Metabolite: "7-Aminomethyl-7-carbaguanine" (ID: C16675)
%     Match: "3-hydroxypropionate:NADP+ oxidoreductase" (ID: R09289)
%         Metabolite: "NADP+" (ID: C00006)
%         Metabolite: "3-Hydroxypropanoate" (ID: C01013)
%     Match: "methaneselenol:NADP+ oxidoreductase" (ID: R09372)
%         Metabolite: "NADPH" (ID: C00005)
%         Metabolite: "H+" (ID: C00080)
%         Metabolite: "Methylselenic acid" (ID: C18902)
%     Match: "scyllo-inositol:NADP+ oxidoreductase" (ID: R09954)
%         Metabolite: "NADP+" (ID: C00006)
%         Metabolite: "scyllo-Inositol" (ID: C06153)
%     Match: "3-hydroxyglutaryl-[acp]-methyl-ester:NADP+ oxidoreductase" (ID: R10116_EXP_1)
%         Metabolite: "NADPH" (ID: C00005)
%         Metabolite: "H+" (ID: C00080)
%         Metabolite: "3-Ketoglutaryl-[acp] methyl ester" (ID: C20372)
%     Match: "glutaryl-[acp]-methyl-ester:NADP+ oxidoreductase" (ID: R10118)
%         Metabolite: "NADPH" (ID: C00005)
%         Metabolite: "H+" (ID: C00080)
%         Metabolite: "Enoylglutaryl-[acp] methyl ester" (ID: C20374)
%     Match: "3-hydroxypimeloyl-[acp]-methyl-ester:NADP+ oxidoreductase" (ID: R10120_EXP_1)
%         Metabolite: "NADPH" (ID: C00005)
%         Metabolite: "H+" (ID: C00080)
%         Metabolite: "3-Ketopimeloyl-[acp] methyl ester" (ID: C20376)
%     Match: "pimelyl-[acyl-carrier protein]-methyl-ester:NADP+ oxidoreductase" (ID: R10122)
%         Metabolite: "NADPH" (ID: C00005)
%         Metabolite: "H+" (ID: C00080)
%         Metabolite: "Enoylpimeloyl-[acp] methyl ester" (ID: C20378)
%     Match: "L-allo-threonine:NADP+ 3-oxidoreductase" (ID: R10851)
%         Metabolite: "NADP+" (ID: C00006)
%         Metabolite: "L-Allothreonine" (ID: C05519)
%     Match: "L-allo-threonine:NADP+ 3-oxidoreductase (decarboxylating)" (ID: R10852)
%         Metabolite: "NADP+" (ID: C00006)
%         Metabolite: "L-Allothreonine" (ID: C05519)
%     Match: "tetrahydrobiopterin:NADP+ oxidoreductase (7,8-dihydrobiopterin-forming)" (ID: R11765)
%         Metabolite: "NADP+" (ID: C00006)
%         Metabolite: "Tetrahydrobiopterin" (ID: C00272)
%     Match: "liquiritigenin,[reduced NADPH---hemoprotein reductase]:oxygen oxidoreductase (licodione-forming)" (ID: R07198)
%         Metabolite: "Oxygen" (ID: C00007)
%         Metabolite: "[Reduced NADPH---hemoprotein reductase]" (ID: C03024)
%         Metabolite: "Liquiritigenin" (ID: C09762)
%     Match: "formate:NADP+ oxidoreductase" (ID: R00134)
%         Metabolite: "NADP+" (ID: C00006)
%         Metabolite: "Formate" (ID: C00058)
%     Match: "Isocitrate:NADP+ oxidoreductase (decarboxylating)" (ID: R00267)
%         Metabolite: "NADP+" (ID: C00006)
%         Metabolite: "Isocitrate" (ID: C00311)
%     Match: "D-xylose:NADP+ 1-oxidoreductase" (ID: R01430)
%         Metabolite: "NADP+" (ID: C00006)
%         Metabolite: "D-Xylose" (ID: C00181)
%     Match: "beta-D-Glucose:NADP+ 1-oxoreductase" (ID: R01521)
%         Metabolite: "NADP+" (ID: C00006)
%         Metabolite: "beta-D-Glucose" (ID: C00221)
%     Match: "(3R)-3-hydroxyacyl-CoA:NADP+ oxidoreductase" (ID: R01779)
%         Metabolite: "NADP+" (ID: C00006)
%         Metabolite: "(3R)-3-Hydroxyacyl-CoA" (ID: C01086)
%     Match: "Isocitrate:NADP+ oxidoreductase" (ID: R01899)
%         Metabolite: "NADP+" (ID: C00006)
%         Metabolite: "Isocitrate" (ID: C00311)
%     Match: "(R)-3-Hydroxybutanoyl-CoA:NADP+ oxidoreductase" (ID: R01977)
%         Metabolite: "NADP+" (ID: C00006)
%         Metabolite: "(R)-3-Hydroxybutanoyl-CoA" (ID: C03561)
%     Match: "Shikimate:NADP+ 3-oxidoreductase" (ID: R02413)
%         Metabolite: "NADP+" (ID: C00006)
%         Metabolite: "Shikimate" (ID: C00493)
%     Match: "CDP-4-dehydro-3,6-dideoxy-D-glucose:NADP+ 3-oxydoreductase" (ID: R03392)
%         Metabolite: "H2O" (ID: C00001)
%         Metabolite: "NADP+" (ID: C00006)
%         Metabolite: "CDP-4-dehydro-3,6-dideoxy-D-glucose" (ID: C04297)
%     Match: "Toluene,NADPH:oxogen oxidoreductase (3-hydroxylating)" (ID: R03562)
%         Metabolite: "NADPH" (ID: C00005)
%         Metabolite: "Oxygen" (ID: C00007)
%         Metabolite: "H+" (ID: C00080)
%         Metabolite: "Toluene" (ID: C01455)
%     Match: "NADPH:demethylphylloquinone oxidoreductase" (ID: R11061)
%         Metabolite: "NADPH" (ID: C00005)
%         Metabolite: "H+" (ID: C00080)
%         Metabolite: "2-Phytyl-1,4-naphthoquinone" (ID: C13309)
% Precursor "FAD" → no matches found
% Precursor "CoA" → 50 matches found
%     Match: "ATP:dephospho-CoA 3'-phosphotransferase" (ID: R00130)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "Dephospho-CoA" (ID: C00882)
%     Match: "pyruvate:NAD+ 2-oxidoreductase (CoA-acetylating);" (ID: R00209)
%         Metabolite: "NAD+" (ID: C00003)
%         Metabolite: "CoA" (ID: C00010)
%         Metabolite: "Pyruvate" (ID: C00022)
%     Match: "Acetyl-CoA:formate C-acetyltransferase" (ID: R00212)
%         Metabolite: "Acetyl-CoA" (ID: C00024)
%         Metabolite: "Formate" (ID: C00058)
%     Match: "acetyl-CoA:phosphate acetyltransferase" (ID: R00230)
%         Metabolite: "Orthophosphate" (ID: C00009)
%         Metabolite: "Acetyl-CoA" (ID: C00024)
%     Match: "Acetate:CoA ligase (AMP-forming)" (ID: R00235)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "CoA" (ID: C00010)
%         Metabolite: "Acetate" (ID: C00033)
%     Match: "acetyl adenylate:CoA acetyltransferase" (ID: R00236)
%         Metabolite: "CoA" (ID: C00010)
%         Metabolite: "Acetyl adenylate" (ID: C05993)
%     Match: "Acetyl-CoA:glycine C-acetyltransferase" (ID: R00371)
%         Metabolite: "Acetyl-CoA" (ID: C00024)
%         Metabolite: "Glycine" (ID: C00037)
%     Match: "Succinate:CoA ligase (ADP-forming)" (ID: R00405)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "CoA" (ID: C00010)
%         Metabolite: "Succinate" (ID: C00042)
%     Match: "acetyl-CoA:L-serine O-acetyltransferase" (ID: R00586)
%         Metabolite: "Acetyl-CoA" (ID: C00024)
%         Metabolite: "L-Serine" (ID: C00065)
%     Match: "propanoyl-CoA:phosphate propanoyltransferase" (ID: R00921)
%         Metabolite: "Orthophosphate" (ID: C00009)
%         Metabolite: "Propanoyl-CoA" (ID: C00100)
%     Match: "Propanoate:CoA ligase (AMP-forming)" (ID: R00925)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "CoA" (ID: C00010)
%         Metabolite: "Propanoate" (ID: C00163)
%     Match: "Propionyladenylate:CoA propionyltransferase" (ID: R00926)
%         Metabolite: "CoA" (ID: C00010)
%         Metabolite: "Propionyladenylate" (ID: C05983)
%     Match: "biotin:CoA ligase (AMP-forming);" (ID: R01074)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "Biotin" (ID: C00120)
%     Match: "acetyl-CoA:putrescine N-acetyltransferase" (ID: R01154)
%         Metabolite: "Acetyl-CoA" (ID: C00024)
%         Metabolite: "Putrescine" (ID: C00134)
%     Match: "pyruvate:ferredoxin 2-oxidoreductase (CoA-acetylating)" (ID: R01196)
%         Metabolite: "CO2" (ID: C00011)
%         Metabolite: "Acetyl-CoA" (ID: C00024)
%         Metabolite: "H+" (ID: C00080)
%         Metabolite: "Reduced ferredoxin" (ID: C00138)
%     Match: "Palmitate:CoA ligase (AMP-forming)" (ID: R01280)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "CoA" (ID: C00010)
%         Metabolite: "Hexadecanoic acid" (ID: C00249)
%     Match: "CoA:apo-[acyl-carrier-protein] pantetheinephosphotransferase" (ID: R01625)
%         Metabolite: "CoA" (ID: C00010)
%         Metabolite: "Apo-[acyl-carrier-protein]" (ID: C03688)
%     Match: "Malonyl-CoA:[acyl-carrier-protein] S-malonyltransferase" (ID: R01626)
%         Metabolite: "Malonyl-CoA" (ID: C00083)
%         Metabolite: "Acyl-carrier protein" (ID: C00229)
%     Match: "Acetyl-CoA:L-homoserine O-acetyltransferase" (ID: R01776)
%         Metabolite: "Acetyl-CoA" (ID: C00024)
%         Metabolite: "L-Homoserine" (ID: C00263)
%     Match: "Succinyl-CoA:L-homoserine O-succinyltransferase" (ID: R01777)
%         Metabolite: "Succinyl-CoA" (ID: C00091)
%         Metabolite: "L-Homoserine" (ID: C00263)
%     Match: "S-Adenosyl-L-methionine:caffeoyl-CoA 3-O-methyltransferase" (ID: R01942)
%         Metabolite: "S-Adenosyl-L-methionine" (ID: C00019)
%         Metabolite: "Caffeoyl-CoA" (ID: C00323)
%     Match: "acyl-CoA:1-acyl-sn-glycerol-3-phosphate 2-O-acyltransferase" (ID: R02241)
%         Metabolite: "CoA" (ID: C00010)
%         Metabolite: "Phosphatidate" (ID: C00416)
%     Match: "Itaconate:CoA ligase (ADP-forming)" (ID: R02404)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "CoA" (ID: C00010)
%         Metabolite: "Itaconate" (ID: C00490)
%     Match: "glutaconyl-1-CoA carboxy-lyase;" (ID: R03028)
%         Metabolite: "Glutaconyl-1-CoA" (ID: C02411)
%     Match: "pimeloyl-CoA:L-alanine C-carboxyhexanoyltransferase (decarboxylating)" (ID: R03210)
%         Metabolite: "L-Alanine" (ID: C00041)
%         Metabolite: "Pimeloyl-CoA" (ID: C01063)
%     Match: "O-Succinylbenzoate:CoA ligase (AMP-forming)" (ID: R04030)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "CoA" (ID: C00010)
%         Metabolite: "2-Succinylbenzoate" (ID: C02730)
%     Match: "S-adenosyl-L-methionine:caffeoyl-CoA 3-O-methyltransferase" (ID: R06578)
%         Metabolite: "S-Adenosyl-L-methionine" (ID: C00019)
%         Metabolite: "5-Hydroxyferuloyl-CoA" (ID: C12203)
%     Match: "propanoyl-CoA:formate C-propanoyltransferase" (ID: R06987)
%         Metabolite: "CoA" (ID: C00010)
%         Metabolite: "2-Oxobutanoate" (ID: C00109)
%     Match: "1,4-dihydroxy-2-naphthoyl-CoA hydrolase" (ID: R07262)
%         Metabolite: "H2O" (ID: C00001)
%         Metabolite: "1,4-Dihydroxy-2-naphthoyl-CoA" (ID: C15547)
%     Match: "4-(2-carboxyphenyl)-4-oxobutanoyl-CoA dehydratase (cyclizing)" (ID: R07263)
%         Metabolite: "2-Succinylbenzoyl-CoA" (ID: C03160)
%     Match: "2-oxoglutarate:NAD+ 2-oxidoreductase (CoA-succinylating);" (ID: R08549)
%         Metabolite: "NAD+" (ID: C00003)
%         Metabolite: "CoA" (ID: C00010)
%         Metabolite: "2-Oxoglutarate" (ID: C00026)
%     Match: "acetyl-CoA:malonyl-[acyl-carrier protein] C-acetyltransferase (decarboxylating)" (ID: R10707)
%         Metabolite: "Acetyl-CoA" (ID: C00024)
%         Metabolite: "Malonyl-[acyl-carrier protein]" (ID: C01209)
%     Match: "pyruvate:flavodoxin 2-oxidoreductase (CoA-acetylating)" (ID: R10866)
%         Metabolite: "CoA" (ID: C00010)
%         Metabolite: "Pyruvate" (ID: C00022)
%         Metabolite: "Oxidized flavodoxin" (ID: C02869)
%     Match: "acetyl-CoA:carbon-dioxide ligase (ADP-forming)" (ID: R00742)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "Acetyl-CoA" (ID: C00024)
%         Metabolite: "HCO3-" (ID: C00288)
%     Match: "butanoyl-CoA:phosphate butanoyltransferase" (ID: R01174)
%         Metabolite: "Orthophosphate" (ID: C00009)
%         Metabolite: "Butanoyl-CoA" (ID: C00136)
%     Match: "butanoyl-CoA:electron-transfer flavoprotein 2,3-oxidoreductase" (ID: R01175)
%         Metabolite: "FAD" (ID: C00016)
%         Metabolite: "Butanoyl-CoA" (ID: C00136)
%     Match: "(S)-malate:CoA ligase (ADP-forming)" (ID: R01256)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "CoA" (ID: C00010)
%         Metabolite: "(S)-Malate" (ID: C00149)
%     Match: "(3R)-3-hydroxyacyl-CoA:NADP+ oxidoreductase" (ID: R01779)
%         Metabolite: "NADP+" (ID: C00006)
%         Metabolite: "(3R)-3-Hydroxyacyl-CoA" (ID: C01086)
%     Match: "propanoyl-CoA:carbon-dioxide ligase (ADP-forming)" (ID: R01859)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "Propanoyl-CoA" (ID: C00100)
%         Metabolite: "HCO3-" (ID: C00288)
%     Match: "(R)-3-Hydroxybutanoyl-CoA:NADP+ oxidoreductase" (ID: R01977)
%         Metabolite: "NADP+" (ID: C00006)
%         Metabolite: "(R)-3-Hydroxybutanoyl-CoA" (ID: C03561)
%     Match: "2-methylpropanoyl-CoA:(acceptor) 2,3-oxidoreductase" (ID: R02661)
%         Metabolite: "Acceptor" (ID: C00028)
%         Metabolite: "2-Methylpropanoyl-CoA" (ID: C00630)
%     Match: "Dephospho-CoA nucleotidohydrolase" (ID: R03036)
%         Metabolite: "H2O" (ID: C00001)
%         Metabolite: "Dephospho-CoA" (ID: C00882)
%     Match: "(S)-2-methylbutanoyl-CoA:acceptor 2,3-oxidoreductase" (ID: R03172)
%         Metabolite: "Acceptor" (ID: C00028)
%         Metabolite: "(S)-2-Methylbutanoyl-CoA" (ID: C15980)
%     Match: "propanoyl-CoA:electron-transfer flavoprotein 2,3-oxidoreductase" (ID: R04432)
%         Metabolite: "Propanoyl-CoA" (ID: C00100)
%         Metabolite: "Electron-transferring flavoprotein" (ID: C04253)
%     Match: "hexanoyl-CoA:electron-transfer flavoprotein 2,3-oxidoreductase" (ID: R04751)
%         Metabolite: "FAD" (ID: C00016)
%         Metabolite: "Hexanoyl-CoA" (ID: C05270)
%     Match: "3-methyl-2-oxobutanoate:ferredoxin oxidoreductase (decarboxylating;CoA-2-methylpropanoylating)" (ID: R07160)
%         Metabolite: "CoA" (ID: C00010)
%         Metabolite: "Oxidized ferredoxin" (ID: C00139)
%         Metabolite: "3-Methyl-2-oxobutanoic acid" (ID: C00141)
%     Match: "4-methyl-2-oxopentanoate:ferredoxin oxidoreductase (decarboxylating; CoA-3-methylbutanoylating)" (ID: R08566)
%         Metabolite: "CoA" (ID: C00010)
%         Metabolite: "Oxidized ferredoxin" (ID: C00139)
%         Metabolite: "4-Methyl-2-oxopentanoate" (ID: C00233)
%     Match: "(S)-3-methyl-2-oxopentanoate:ferredoxin oxidoreductase (decarboxylating; CoA-2-methylbutanoylating)" (ID: R08567)
%         Metabolite: "CoA" (ID: C00010)
%         Metabolite: "Oxidized ferredoxin" (ID: C00139)
%         Metabolite: "(S)-3-Methyl-2-oxopentanoic acid" (ID: C00671)
%     Match: "2'-(5-triphosphoribosyl)-3'-dephospho-CoA:apo-malonate-decarboxylase 2'-(5-phosphoribosyl)-3'-dephospho-CoA-transferase" (ID: R10706)
%         Metabolite: "Apo-[acyl-carrier-protein]" (ID: C03688)
%         Metabolite: "2'-(5-Triphosphoribosyl)-3'-dephospho-CoA" (ID: C19771)
%     Match: "3-(methylsulfanyl)propanoyl-CoA:acceptor 2-oxidoreductase" (ID: R11130)
%         Metabolite: "Acceptor" (ID: C00028)
%         Metabolite: "3-(Methylthio)propanoyl-CoA" (ID: C20870)
% Precursor "Heme" → no matches found
% Precursor "Thiamine" → 1 matches found
%     Match: "ATP:thiamine diphosphotransferase" (ID: R00619)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "Thiamine" (ID: C00378)
% Precursor "Biotin" → 1 matches found
%     Match: "biotin:CoA ligase (AMP-forming);" (ID: R01074)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "Biotin" (ID: C00120)
% Precursor "Peptidoglycan" → no matches found
% Precursor "Lipid A" → no matches found
% Precursor "Lipopolysaccharide" → no matches found
% Precursor "Core oligosaccharide" → no matches found
% Precursor "Phosphatidylethanolamine" → no matches found
% Precursor "Phosphatidylglycerol" → 2 matches found
%     Match: "Phosphatidylglycerol:membrane-derived-oligosaccharide-D-glucose glycerophosphotransferase" (ID: R05081)
%         Metabolite: "Phosphatidylglycerol" (ID: C00344)
%         Metabolite: "Diglucosyldiacylglycerol" (ID: C06040)
%     Match: "phosphatidylglycerol:Glc-alpha1->2Glc-alpha1->3acyl2Gro glycerophosphotransferase" (ID: R10849)
%         Metabolite: "Phosphatidylglycerol" (ID: C00344)
%         Metabolite: "alpha-Kojibiosyldiacylglycerol" (ID: C06365)
% Precursor "Cardiolipin" → no matches found
% Warning: Repeated mets in the formula for rxn 'BIOMASS_ps'. Combine the stoichiometry.
% test
% CSV table saved to "Pbivia_biomass_metabolites.csv"
% Added biomass reaction "BIOMASS_ps" with 1054 metabolite entries (duplicates kept).

% %% [markdown]
% Quick cleaning to ensure RAVEN structures are correctly kept:

% %%
PbiviaBiomassDraftModel = syncModelStruct(PbiviaBiomassDraftModel, 'Pbivia_biomass_sync_log.csv');
% Out:
% syncModelStruct: Log saved to "Pbivia_biomass_sync_log.csv"

% %%
checkModelCoreConsistency(PbiviaBiomassDraftModel);
% Out:
% --- BASIC DIMENSION CHECKS ---
% Reactions: 938
% Metabolites: 1159
% Genes: 809
% Empty grRules in 142 reactions

% %%
PbiviaBiomassDraftModel = sanitizeGEMforSBML(PbiviaBiomassDraftModel);
PbiviaBiomassDraftModel = fixRxnConfidenceScores(PbiviaBiomassDraftModel);

% %% [markdown]
% I will now save the new model with the biomass reaction included:

% %%
exportModel(PbiviaBiomassDraftModel, 'Pbivia_draftGEM_v3.xml');
% Out:
% WARNING: The following InChI strings are associated to more than one unique metabolite name:
%     1S/C10H20O7P2/c1-9(2)5-4-6-10(3)7-8-16-19(14,15)17-18(11,12)13/h5,7H,4,6,8H2,1-3H3,(H,14,15)(H2,11,12,13)/b10-7+
% Document written

% %%
exportToExcelFormat(PbiviaBiomassDraftModel, 'Pbivia_draftGEM_v3.xlsx');
save('Pbivia_draftGEM_v3.mat', 'PbiviaBiomassDraftModel');

% %% [markdown]
% Now that a biomass reaction has been added to the model, I will try to solve again:

% %%
%PbiviaBiomassDraftModel = importModel('Pbivia_draftGEM_v3.xml');
sol2 = solveLP(PbiviaBiomassDraftModel);
disp(sol2.f)
% Out:
%      0

% %% [markdown]
% Still 0, so still no growth.
%
% ## Addition of exchange reactions
%
% The simplified gap report:

% %%
% taking a look at the gap situation
%gapReport(PbiviaBiomassDraftModel);
gapReport_vSimple(PbiviaBiomassDraftModel);
% Out:
% Dead-end metabolites: 559
%     {'C00040'}
%     {'C00052'}
%     {'C00071'}
%     {'C00084'}
%     {'C00104'}
%     {'C00110'}
%     {'C00132'}
%     {'C00154'}
%     {'C00159'}
%     {'C00168'}
%     {'C00190'}
%     {'C00192'}
%     {'C00201'}
%     {'C00222'}
%     {'C00243'}
%     {'C00248'}
%     {'C00301'}
%     {'C00302'}
%     {'C00307'}
%     {'C00315'}
%     {'C00322'}
%     {'C00345'}
%     {'C00350'}
%     {'C00353'}
%     {'C00389'}
%     {'C00406'}
%     {'C00409'}
%     {'C00411'}
%     {'C00446'}
%     {'C00447'}
%     {'C00450'}
%     {'C00454'}
%     {'C00458'}
%     {'C00473'}
%     {'C00506'}
%     {'C00509'}
%     {'C00522'}
%     {'C00527'}
%     {'C00531'}
%     {'C00546'}
%     {'C00561'}
%     {'C00575'}
%     {'C00577'}
%     {'C00627'}
%     {'C00647'}
%     {'C00666'}
%     {'C00673'}
%     {'C00697'}
%     {'C00700'}
%     {'C00721'}
%     {'C00794'}
%     {'C00886'}
%     {'C00887'}
%     {'C00942'}
%     {'C00957'}
%     {'C00962'}
%     {'C00963'}
%     {'C00966'}
%     {'C00988'}
%     {'C01019'}
%     {'C01041'}
%     {'C01045'}
%     {'C01051'}
%     {'C01074'}
%     {'C01094'}
%     {'C01100'}
%     {'C01118'}
%     {'C01133'}
%     {'C01151'}
%     {'C01170'}
%     {'C01190'}
%     {'C01217'}
%     {'C01228'}
%     {'C01235'}
%     {'C01236'}
%     {'C01252'}
%     {'C01267'}
%     {'C01289'}
%     {'C01290'}
%     {'C01297'}
%     {'C01302'}
%     {'C01335'}
%     {'C01345'}
%     {'C01346'}
%     {'C01419'}
%     {'C01424'}
%     {'C01471'}
%     {'C01592'}
%     {'C01594'}
%     {'C01637'}
%     {'C01642'}
%     {'C01674'}
%     {'C01717'}
%     {'C01752'}
%     {'C01898'}
%     {'C01931'}
%     {'C01978'}
%     {'C01997'}
%     {'C02047'}
%     {'C02097'}
%     {'C02163'}
%     {'C02188'}
%     {'C02247'}
%     {'C02282'}
%     {'C02348'}
%     {'C02353'}
%     {'C02354'}
%     {'C02355'}
%     {'C02356'}
%     {'C02380'}
%     {'C02412'}
%     {'C02415'}
%     {'C02470'}
%     {'C02553'}
%     {'C02554'}
%     {'C02659'}
%     {'C02702'}
%     {'C02714'}
%     {'C02839'}
%     {'C02952'}
%     {'C02953'}
%     {'C02962'}
%     {'C02964'}
%     {'C02984'}
%     {'C02987'}
%     {'C02988'}
%     {'C02989'}
%     {'C02992'}
%     {'C02999'}
%     {'C03028'}
%     {'C03089'}
%     {'C03125'}
%     {'C03127'}
%     {'C03219'}
%     {'C03241'}
%     {'C03289'}
%     {'C03294'}
%     {'C03309'}
%     {'C03375'}
%     {'C03402'}
%     {'C03405'}
%     {'C03458'}
%     {'C03511'}
%     {'C03512'}
%     {'C03658'}
%     {'C03671'}
%     {'C03692'}
%     {'C03742'}
%     {'C03758'}
%     {'C03771'}
%     {'C03862'}
%     {'C03871'}
%     {'C03912'}
%     {'C03939'}
%     {'C04006'}
%     {'C04051'}
%     {'C04076'}
%     {'C04132'}
%     {'C04146'}
%     {'C04157'}
%     {'C04188'}
%     {'C04236'}
%     {'C04242'}
%     {'C04327'}
%     {'C04377'}
%     {'C04431'}
%     {'C04494'}
%     {'C04522'}
%     {'C04625'}
%     {'C04672'}
%     {'C04691'}
%     {'C04706'}
%     {'C04718'}
%     {'C05143'}
%     {'C05190'}
%     {'C05191'}
%     {'C05199'}
%     {'C05312'}
%     {'C05322'}
%     {'C05336'}
%     {'C05394'}
%     {'C05399'}
%     {'C05400'}
%     {'C05401'}
%     {'C05403'}
%     {'C05527'}
%     {'C05570'}
%     {'C05578'}
%     {'C05587'}
%     {'C05623'}
%     {'C05645'}
%     {'C05691'}
%     {'C05703'}
%     {'C05712'}
%     {'C05713'}
%     {'C05726'}
%     {'C05729'}
%     {'C05766'}
%     {'C05819'}
%     {'C05838'}
%     {'C05839'}
%     {'C05847'}
%     {'C05893'}
%     {'C05898'}
%     {'C05914'}
%     {'C05916'}
%     {'C05921'}
%     {'C05946'}
%     {'C05947'}
%     {'C05980'}
%     {'C06037'}
%     {'C06054'}
%     {'C06066'}
%     {'C06102'}
%     {'C06126'}
%     {'C06128'}
%     {'C06173'}
%     {'C06194'}
%     {'C06251'}
%     {'C06481'}
%     {'C06555'}
%     {'C06563'}
%     {'C06594'}
%     {'C06597'}
%     {'C06598'}
%     {'C06602'}
%     {'C06620'}
%     {'C06717'}
%     {'C06735'}
%     {'C06986'}
%     {'C07304'}
%     {'C07307'}
%     {'C07490'}
%     {'C07541'}
%     {'C07645'}
%     {'C07647'}
%     {'C07648'}
%     {'C07649'}
%     {'C08325'}
%     {'C08334'}
%     {'C08537'}
%     {'C08540'}
%     {'C08543'}
%     {'C08557'}
%     {'C08565'}
%     {'C09099'}
%     {'C09126'}
%     {'C09315'}
%     {'C09332'}
%     {'C09382'}
%     {'C09440'}
%     {'C10208'}
%     {'C10216'}
%     {'C11149'}
%     {'C11405'}
%     {'C11419'}
%     {'C11633'}
%     {'C11634'}
%     {'C11680'}
%     {'C11713'}
%     {'C11714'}
%     {'C11813'}
%     {'C11814'}
%     {'C11822'}
%     {'C11838'}
%     {'C11887'}
%     {'C11930'}
%     {'C12119'}
%     {'C12214'}
%     {'C12215'}
%     {'C12396'}
%     {'C12397'}
%     {'C12739'}
%     {'C14180'}
%     {'C14786'}
%     {'C14787'}
%     {'C14866'}
%     {'C14909'}
%     {'C15492'}
%     {'C15602'}
%     {'C15603'}
%     {'C15667'}
%     {'C15670'}
%     {'C15809'}
%     {'C15972'}
%     {'C15986'}
%     {'C16075'}
%     {'C16138'}
%     {'C16151'}
%     {'C16152'}
%     {'C16220'}
%     {'C16265'}
%     {'C16392'}
%     {'C16413'}
%     {'C16519'}
%     {'C16556'}
%     {'C16559'}
%     {'C16614'}
%     {'C16615'}
%     {'C16617'}
%     {'C16619'}
%     {'C16634'}
%     {'C16635'}
%     {'C16663'}
%     {'C16664'}
%     {'C16688'}
%     {'C16832'}
%     {'C17204'}
%     {'C17211'}
%     {'C17213'}
%     {'C17216'}
%     {'C17217'}
%     {'C17349'}
%     {'C17751'}
%     {'C17752'}
%     {'C17753'}
%     {'C17754'}
%     {'C17755'}
%     {'C17757'}
%     {'C17758'}
%     {'C18022'}
%     {'C18063'}
%     {'C18064'}
%     {'C18096'}
%     {'C18172'}
%     {'C18174'}
%     {'C18235'}
%     {'C18345'}
%     {'C18796'}
%     {'C18871'}
%     {'C19079'}
%     {'C19084'}
%     {'C19491'}
%     {'C19563'}
%     {'C19564'}
%     {'C19566'}
%     {'C19567'}
%     {'C19568'}
%     {'C19577'}
%     {'C19578'}
%     {'C19580'}
%     {'C19581'}
%     {'C19673'}
%     {'C19714'}
%     {'C19723'}
%     {'C19846'}
%     {'C19875'}
%     {'C19944'}
%     {'C20231'}
%     {'C20247'}
%     {'C20254'}
%     {'C20271'}
%     {'C20279'}
%     {'C20297'}
%     {'C20299'}
%     {'C20312'}
%     {'C20315'}
%     {'C20329'}
%     {'C20330'}
%     {'C20352'}
%     {'C20361'}
%     {'C20373'}
%     {'C20377'}
%     {'C20379'}
%     {'C20409'}
%     {'C20440'}
%     {'C20449'}
%     {'C20451'}
%     {'C20457'}
%     {'C20650'}
%     {'C20729'}
%     {'C20743'}
%     {'C20752'}
%     {'C20758'}
%     {'C20836'}
%     {'C20852'}
%     {'C20853'}
%     {'C20858'}
%     {'C20861'}
%     {'C20887'}
%     {'C20899'}
%     {'C20900'}
%     {'C20901'}
%     {'C20937'}
%     {'C21008'}
%     {'C21026'}
%     {'C21065'}
%     {'C21075'}
%     {'C21113'}
%     {'C21140'}
%     {'C21142'}
%     {'C21154'}
%     {'C21192'}
%     {'C21214'}
%     {'C21334'}
%     {'C21408'}
%     {'C21410'}
%     {'C21412'}
%     {'C21437'}
%     {'C21440'}
%     {'C21442'}
%     {'C21459'}
%     {'C21476'}
%     {'C21582'}
%     {'C21589'}
%     {'C21590'}
%     {'C21599'}
%     {'C21600'}
%     {'C21620'}
%     {'C21622'}
%     {'C21623'}
%     {'C21731'}
%     {'C21751'}
%     {'C21787'}
%     {'C21873'}
%     {'C21897'}
%     {'C21922'}
%     {'C21923'}
%     {'C21930'}
%     {'C21999'}
%     {'C22050'}
%     {'C22051'}
%     {'C22054'}
%     {'C22068'}
%     {'C22070'}
%     {'C22084'}
%     {'C22148'}
%     {'C22149'}
%     {'C22238'}
%     {'C22329'}
%     {'C22331'}
%     {'C22332'}
%     {'C22333'}
%     {'C22334'}
%     {'C22395'}
%     {'C22432'}
%     {'C22442'}
%     {'C22467'}
%     {'C22488'}
%     {'C22624'}
%     {'C22647'}
%     {'C22648'}
%     {'G00092'}
%     {'G00094'}
%     {'G00108'}
%     {'G00109'}
%     {'G00317'}
%     {'G01275'}
%     {'G10504'}
%     {'G10552'}
%     {'G10553'}
%     {'G10555'}
%     {'G10556'}
%     {'G10609'}
%     {'G10665'}
%     {'G11121'}
%     {'G11161'}
%     {'G12336'}
%     {'G13043'}
%     {'G13056'}
%     {'G13061'}
%     {'G13073'}
%     {'G13074'}
%     {'G13163'}
%     {'G13164'}
%     {'G13191'}
%     {'G13199'}
%     {'G13200'}
%     {'C00090'}
%     {'C00145'}
%     {'C00180'}
%     {'C00194'}
%     {'C00203'}
%     {'C00204'}
%     {'C00264'}
%     {'C00282'}
%     {'C00332'}
%     {'C00357'}
%     {'C00491'}
%     {'C00499'}
%     {'C00556'}
%     {'C00683'}
%     {'C00789'}
%     {'C00819'}
%     {'C00894'}
%     {'C01177'}
%     {'C01194'}
%     {'C01467'}
%     {'C01468'}
%     {'C01586'}
%     {'C01962'}
%     {'C02191'}
%     {'C02514'}
%     {'C02923'}
%     {'C02939'}
%     {'C02967'}
%     {'C03345'}
%     {'C03460'}
%     {'C03752'}
%     {'C03892'}
%     {'C04268'}
%     {'C04298'}
%     {'C04334'}
%     {'C04348'}
%     {'C04501'}
%     {'C04570'}
%     {'C04630'}
%     {'C05271'}
%     {'C05696'}
%     {'C05770'}
%     {'C05817'}
%     {'C06041'}
%     {'C06112'}
%     {'C06364'}
%     {'C06508'}
%     {'C09812'}
%     {'C09813'}
%     {'C16154'}
%     {'C16156'}
%     {'C16698'}
%     {'C18055'}
%     {'C19725'}
%     {'C19745'}
%     {'C20239'}
%     {'C20251'}
%     {'C20357'}
%     {'C20395'}
%     {'C20416'}
%     {'C20420'}
%     {'C20427'}
%     {'C20638'}
%     {'C20784'}
%     {'C20897'}
%     {'C20955'}
%     {'C21084'}
%     {'G10558'}
%     {'G10608'}
%     {'G10611'}
%     {'G13119'}
%     {'G13127'}
%     {'G13167'}
%     {'G13170'}
%     {'G13171'}
%     {'G13174'}
%     {'G13175'}
%     {'G13176'}
%     {'G13177'}
%     {'G13178'}
%     {'G13179'}
%     {'G13180'}
%     {'G13182'}
%     {'G13183'}
%     {'G13185'}
%     {'G13186'}
%     {'G13187'}
%     {'G13192'}
%     {'G13193'}
%     {'G13197'}
%     {'G13198'}
% Blocked reactions: 651
%     {'R00022'      }
%     {'R00066'      }
%     {'R00089'      }
%     {'R00104'      }
%     {'R00130'      }
%     {'R00143'      }
%     {'R00161'      }
%     {'R00174'      }
%     {'R00177'      }
%     {'R00188'      }
%     {'R00194'      }
%     {'R00260'      }
%     {'R00274'      }
%     {'R00286'      }
%     {'R00291'      }
%     {'R00336'      }
%     {'R00371'      }
%     {'R00401'      }
%     {'R00405'      }
%     {'R00420'      }
%     {'R00425'      }
%     {'R00429'      }
%     {'R00434'      }
%     {'R00451'      }
%     {'R00480'      }
%     {'R00489'      }
%     {'R00566'      }
%     {'R00597'      }
%     {'R00651'      }
%     {'R00660'      }
%     {'R00691'      }
%     {'R00694'      }
%     {'R00715'      }
%     {'R00717'      }
%     {'R00720'      }
%     {'R00734'      }
%     {'R00847'      }
%     {'R00848'      }
%     {'R00885'      }
%     {'R00888'      }
%     {'R00896_EXP_1'}
%     {'R00899'      }
%     {'R00942'      }
%     {'R00943'      }
%     {'R00945'      }
%     {'R00965'      }
%     {'R01009'      }
%     {'R01054'      }
%     {'R01061'      }
%     {'R01066'      }
%     {'R01072'      }
%     {'R01074'      }
%     {'R01090'      }
%     {'R01092'      }
%     {'R01104'      }
%     {'R01122'      }
%     {'R01127'      }
%     {'R01130'      }
%     {'R01150'      }
%     {'R01152'      }
%     {'R01154'      }
%     {'R01168'      }
%     {'R01194'      }
%     {'R01207'      }
%     {'R01214'      }
%     {'R01220'      }
%     {'R01226'      }
%     {'R01280'      }
%     {'R01291'      }
%     {'R01329'      }
%     {'R01334'      }
%     {'R01373'      }
%     {'R01384'      }
%     {'R01388'      }
%     {'R01397'      }
%     {'R01401'      }
%     {'R01402'      }
%     {'R01445'      }
%     {'R01512'      }
%     {'R01529'      }
%     {'R01530'      }
%     {'R01550'      }
%     {'R01562'      }
%     {'R01625'      }
%     {'R01626'      }
%     {'R01641'      }
%     {'R01655'      }
%     {'R01658'      }
%     {'R01678_EXP_1'}
%     {'R01688'      }
%     {'R01698'      }
%     {'R01714'      }
%     {'R01715_EXP_1'}
%     {'R01716'      }
%     {'R01717'      }
%     {'R01728'      }
%     {'R01736'      }
%     {'R01776'      }
%     {'R01777'      }
%     {'R01799'      }
%     {'R01800'      }
%     {'R01811'      }
%     {'R01818'      }
%     {'R01819'      }
%     {'R01829'      }
%     {'R01856'      }
%     {'R01869'      }
%     {'R01870'      }
%     {'R01877'      }
%     {'R01909'      }
%     {'R01933'      }
%     {'R01942'      }
%     {'R01961'      }
%     {'R01993'      }
%     {'R02003'      }
%     {'R02018'      }
%     {'R02021'      }
%     {'R02025'      }
%     {'R02035'      }
%     {'R02055'      }
%     {'R02061'      }
%     {'R02101_EXP_1'}
%     {'R02110'      }
%     {'R02111'      }
%     {'R02112'      }
%     {'R02148'      }
%     {'R02164'      }
%     {'R02199'      }
%     {'R02237'      }
%     {'R02241'      }
%     {'R02287'      }
%     {'R02288'      }
%     {'R02291'      }
%     {'R02302'      }
%     {'R02320'      }
%     {'R02328'      }
%     {'R02370'      }
%     {'R02404'      }
%     {'R02412'      }
%     {'R02433_EXP_1'}
%     {'R02473'      }
%     {'R02493'      }
%     {'R02530'      }
%     {'R02558'      }
%     {'R02568'      }
%     {'R02619_EXP_1'}
%     {'R02720'      }
%     {'R02748'      }
%     {'R02755'      }
%     {'R02777'      }
%     {'R02783'      }
%     {'R02788'      }
%     {'R02804'      }
%     {'R02914'      }
%     {'R02918'      }
%     {'R02926'      }
%     {'R02971'      }
%     {'R02984'      }
%     {'R02985'      }
%     {'R03018'      }
%     {'R03028'      }
%     {'R03038'      }
%     {'R03083'      }
%     {'R03084'      }
%     {'R03165'      }
%     {'R03189'      }
%     {'R03193'      }
%     {'R03210'      }
%     {'R03223'      }
%     {'R03239'      }
%     {'R03243'      }
%     {'R03254'      }
%     {'R03269'      }
%     {'R03348'      }
%     {'R03350'      }
%     {'R03351'      }
%     {'R03355_EXP_1'}
%     {'R03458'      }
%     {'R03459'      }
%     {'R03460'      }
%     {'R03471'      }
%     {'R03504'      }
%     {'R03509'      }
%     {'R03527'      }
%     {'R03531'      }
%     {'R03537'      }
%     {'R03538'      }
%     {'R03596'      }
%     {'R03599'      }
%     {'R03601'      }
%     {'R03646'      }
%     {'R03648'      }
%     {'R03650'      }
%     {'R03652'      }
%     {'R03654'      }
%     {'R03655'      }
%     {'R03656'      }
%     {'R03657'      }
%     {'R03658'      }
%     {'R03659'      }
%     {'R03660'      }
%     {'R03661'      }
%     {'R03662'      }
%     {'R03663'      }
%     {'R03664'      }
%     {'R03665'      }
%     {'R03921'      }
%     {'R03929'      }
%     {'R03940'      }
%     {'R04018'      }
%     {'R04019'      }
%     {'R04030'      }
%     {'R04112'      }
%     {'R04144'      }
%     {'R04208'      }
%     {'R04231'      }
%     {'R04292'      }
%     {'R04355_EXP_1'}
%     {'R04378'      }
%     {'R04391'      }
%     {'R04405'      }
%     {'R04428'      }
%     {'R04457'      }
%     {'R04463'      }
%     {'R04470'      }
%     {'R04509'      }
%     {'R04533_EXP_1'}
%     {'R04534_EXP_1'}
%     {'R04535'      }
%     {'R04536_EXP_1'}
%     {'R04537'      }
%     {'R04543_EXP_1'}
%     {'R04544'      }
%     {'R04549'      }
%     {'R04550'      }
%     {'R04559'      }
%     {'R04560'      }
%     {'R04566_EXP_1'}
%     {'R04567'      }
%     {'R04568'      }
%     {'R04573'      }
%     {'R04587'      }
%     {'R04591'      }
%     {'R04606'      }
%     {'R04617'      }
%     {'R04657'      }
%     {'R04658'      }
%     {'R04710'      }
%     {'R04726_EXP_1'}
%     {'R04771'      }
%     {'R04773'      }
%     {'R04783_EXP_1'}
%     {'R04949'      }
%     {'R04951'      }
%     {'R04952_EXP_1'}
%     {'R04953_EXP_1'}
%     {'R04954'      }
%     {'R04957_EXP_1'}
%     {'R04960_EXP_1'}
%     {'R04963_EXP_1'}
%     {'R04964_EXP_1'}
%     {'R04965'      }
%     {'R04968_EXP_1'}
%     {'R04998'      }
%     {'R05032'      }
%     {'R05052_EXP_1'}
%     {'R05074'      }
%     {'R05085'      }
%     {'R05135'      }
%     {'R05146'      }
%     {'R05553'      }
%     {'R05577'      }
%     {'R05578'      }
%     {'R05627_EXP_1'}
%     {'R05629'      }
%     {'R05630'      }
%     {'R05633'      }
%     {'R05634'      }
%     {'R05636_EXP_1'}
%     {'R05637'      }
%     {'R05662'      }
%     {'R05688'      }
%     {'R05692'      }
%     {'R05712'      }
%     {'R05884'      }
%     {'R05961'      }
%     {'R05963'      }
%     {'R06004'      }
%     {'R06091'      }
%     {'R06114_EXP_1'}
%     {'R06147'      }
%     {'R06173'      }
%     {'R06174'      }
%     {'R06285'      }
%     {'R06447'      }
%     {'R06513'      }
%     {'R06514'      }
%     {'R06578'      }
%     {'R06590'      }
%     {'R06974'      }
%     {'R06987'      }
%     {'R07136'      }
%     {'R07163'      }
%     {'R07262'      }
%     {'R07263'      }
%     {'R07281'      }
%     {'R07324'      }
%     {'R07390'      }
%     {'R07405'      }
%     {'R07605'      }
%     {'R07613'      }
%     {'R07618'      }
%     {'R07762_EXP_1'}
%     {'R07763_EXP_1'}
%     {'R07765'      }
%     {'R07767'      }
%     {'R07809'      }
%     {'R07810'      }
%     {'R07824'      }
%     {'R07825'      }
%     {'R08165'      }
%     {'R08210'      }
%     {'R08218'      }
%     {'R08221'      }
%     {'R08229'      }
%     {'R08232_EXP_1'}
%     {'R08233'      }
%     {'R08237'      }
%     {'R08238'      }
%     {'R08240'      }
%     {'R08243'      }
%     {'R08244'      }
%     {'R08245'      }
%     {'R08572'      }
%     {'R08622'      }
%     {'R08626'      }
%     {'R08856'      }
%     {'R09030'      }
%     {'R09081'      }
%     {'R09082'      }
%     {'R09099'      }
%     {'R09248'      }
%     {'R09289'      }
%     {'R09365'      }
%     {'R09372'      }
%     {'R09381'      }
%     {'R09597'      }
%     {'R09736'      }
%     {'R09763'      }
%     {'R09764'      }
%     {'R09766'      }
%     {'R09943'      }
%     {'R09978'      }
%     {'R10035'      }
%     {'R10039'      }
%     {'R10040'      }
%     {'R10095'      }
%     {'R10115_EXP_1'}
%     {'R10116_EXP_1'}
%     {'R10118'      }
%     {'R10119_EXP_1'}
%     {'R10120_EXP_1'}
%     {'R10122'      }
%     {'R10124'      }
%     {'R10137'      }
%     {'R10147'      }
%     {'R10205'      }
%     {'R10209'      }
%     {'R10220'      }
%     {'R10223'      }
%     {'R10463'      }
%     {'R10619_EXP_1'}
%     {'R10633'      }
%     {'R10634'      }
%     {'R10649'      }
%     {'R10652'      }
%     {'R10707'      }
%     {'R10712'      }
%     {'R10757'      }
%     {'R10806'      }
%     {'R10810'      }
%     {'R10829'      }
%     {'R10991'      }
%     {'R11025'      }
%     {'R11037'      }
%     {'R11073'      }
%     {'R11104'      }
%     {'R11262'      }
%     {'R11308'      }
%     {'R11316'      }
%     {'R11319'      }
%     {'R11323'      }
%     {'R11396'      }
%     {'R11528'      }
%     {'R11636'      }
%     {'R11671'      }
%     {'R11765'      }
%     {'R11896'      }
%     {'R12049'      }
%     {'R12075'      }
%     {'R12193'      }
%     {'R12423'      }
%     {'R12424'      }
%     {'R12500'      }
%     {'R12768'      }
%     {'R12808'      }
%     {'R12814'      }
%     {'R12821_EXP_1'}
%     {'R12851'      }
%     {'R12852'      }
%     {'R12859'      }
%     {'R12896'      }
%     {'R12958'      }
%     {'R12963'      }
%     {'R13051'      }
%     {'R13052'      }
%     {'R13065'      }
%     {'R13081'      }
%     {'R00647'      }
%     {'R01652'      }
%     {'R02317'      }
%     {'R02962'      }
%     {'R03166'      }
%     {'R03186'      }
%     {'R03445'      }
%     {'R03672'      }
%     {'R03674'      }
%     {'R03954'      }
%     {'R04500'      }
%     {'R04578'      }
%     {'R04701'      }
%     {'R04769'      }
%     {'R05041'      }
%     {'R05098'      }
%     {'R05455'      }
%     {'R05483'      }
%     {'R05484'      }
%     {'R05824'      }
%     {'R05826'      }
%     {'R05844'      }
%     {'R05845'      }
%     {'R05846'      }
%     {'R05887'      }
%     {'R05889'      }
%     {'R06063'      }
%     {'R06064'      }
%     {'R06194'      }
%     {'R06650'      }
%     {'R06830'      }
%     {'R06982'      }
%     {'R07009'      }
%     {'R07010'      }
%     {'R07011'      }
%     {'R07012'      }
%     {'R07198'      }
%     {'R07679'      }
%     {'R07947'      }
%     {'R07948'      }
%     {'R08020'      }
%     {'R08279'      }
%     {'R08289'      }
%     {'R08358'      }
%     {'R08361'      }
%     {'R08372'      }
%     {'R08818'      }
%     {'R08820'      }
%     {'R08821'      }
%     {'R08825'      }
%     {'R08827'      }
%     {'R08829'      }
%     {'R08831'      }
%     {'R08833'      }
%     {'R08834'      }
%     {'R08835'      }
%     {'R08837'      }
%     {'R08976'      }
%     {'R09142'      }
%     {'R09143'      }
%     {'R09144'      }
%     {'R09145'      }
%     {'R09149'      }
%     {'R09274'      }
%     {'R09367'      }
%     {'R09368'      }
%     {'R09391'      }
%     {'R09392'      }
%     {'R09431'      }
%     {'R09432'      }
%     {'R09433'      }
%     {'R09434'      }
%     {'R09885'      }
%     {'R09981'      }
%     {'R10013'      }
%     {'R10018'      }
%     {'R10022'      }
%     {'R10030'      }
%     {'R10034'      }
%     {'R10041'      }
%     {'R10078'      }
%     {'R10082'      }
%     {'R10097'      }
%     {'R10245'      }
%     {'R10302'      }
%     {'R10792'      }
%     {'R10854'      }
%     {'R10856'      }
%     {'R10914'      }
%     {'R11017'      }
%     {'R11034'      }
%     {'R11049'      }
%     {'R11148'      }
%     {'R11176'      }
%     {'R11228'      }
%     {'R11523'      }
%     {'R11550'      }
%     {'R11570'      }
%     {'R11571'      }
%     {'R11572'      }
%     {'R11573'      }
%     {'R11574'      }
%     {'R11575'      }
%     {'R11576'      }
%     {'R11577'      }
%     {'R11691'      }
%     {'R11695'      }
%     {'R11709'      }
%     {'R11736'      }
%     {'R11739'      }
%     {'R11865'      }
%     {'R11947'      }
%     {'R12091'      }
%     {'R12094'      }
%     {'R12132'      }
%     {'R12140'      }
%     {'R12268'      }
%     {'R12274'      }
%     {'R12310'      }
%     {'R12335'      }
%     {'R12421'      }
%     {'R12539'      }
%     {'R12683'      }
%     {'R12686'      }
%     {'R12829'      }
%     {'R12886'      }
%     {'R12910'      }
%     {'R12974'      }
%     {'R13091'      }
%     {'R13113'      }
%     {'R13114'      }
%     {'R13140'      }
%     {'R13144'      }
%     {'R00019'      }
%     {'R00287'      }
%     {'R00362'      }
%     {'R00529'      }
%     {'R00742'      }
%     {'R01073'      }
%     {'R01085'      }
%     {'R01174'      }
%     {'R01175'      }
%     {'R01183'      }
%     {'R01256'      }
%     {'R01416'      }
%     {'R01424'      }
%     {'R01492'      }
%     {'R01544'      }
%     {'R01579'      }
%     {'R01779'      }
%     {'R01859'      }
%     {'R01977'      }
%     {'R02029'      }
%     {'R02240'      }
%     {'R02408'      }
%     {'R02413'      }
%     {'R02425'      }
%     {'R02550'      }
%     {'R02661'      }
%     {'R02773'      }
%     {'R02921'      }
%     {'R03122'      }
%     {'R03172'      }
%     {'R03222'      }
%     {'R03332'      }
%     {'R03472'      }
%     {'R03560'      }
%     {'R03562'      }
%     {'R03608'      }
%     {'R03651'      }
%     {'R04031'      }
%     {'R04178'      }
%     {'R04432'      }
%     {'R04449'      }
%     {'R04529'      }
%     {'R04620'      }
%     {'R04751'      }
%     {'R04858'      }
%     {'R04928'      }
%     {'R04929'      }
%     {'R05081'      }
%     {'R05220'      }
%     {'R05582'      }
%     {'R05666'      }
%     {'R06895'      }
%     {'R07160'      }
%     {'R07268'      }
%     {'R07280'      }
%     {'R07661'      }
%     {'R08555'      }
%     {'R08566'      }
%     {'R08567'      }
%     {'R08962'      }
%     {'R08968'      }
%     {'R09513'      }
%     {'R09600'      }
%     {'R09951'      }
%     {'R10002'      }
%     {'R10042'      }
%     {'R10043'      }
%     {'R10140'      }
%     {'R10175'      }
%     {'R10184'      }
%     {'R10188'      }
%     {'R10266'      }
%     {'R10460'      }
%     {'R10648'      }
%     {'R10702'      }
%     {'R10706'      }
%     {'R10849'      }
%     {'R10850'      }
%     {'R11024'      }
%     {'R11061'      }
%     {'R11130'      }
%     {'R11260'      }
%     {'R12026'      }
%     {'R12077'      }
%     {'R12184'      }
%     {'R12188'      }
%     {'R12316'      }
%     {'R12812'      }
%     {'R12819'      }
%     {'R12863'      }
%     {'R12867'      }
%     {'R12871'      }
%     {'R12873'      }
%     {'R12875'      }
%     {'R12885'      }
%     {'R12900'      }
%     {'R12902'      }
%     {'R12904'      }
%     {'R13050'      }
%     {'BIOMASS_ps'  }

% %% [markdown]
% In order for this to be a functional GEM, exchange reactions need to be added.

% %%
% Setting up the draft GEM base
%PbiviaBiomassDraftModel = importModel('Pbivia_draftGEM_v3.xml');
% create a copy to avoid overwriting
PbiviaExchangeModel = PbiviaBiomassDraftModel;
PbiviaExchangeModel.id = 'PbiviaDraft';

% %% [markdown]
% Perform some cleaning:

% %%
% deal with grRules issues
PbiviaExchangeModel = ensureGrRules(PbiviaExchangeModel);
modelKEGGgr = ensureGrRules(modelKEGG);
% Out:
% Patched grRules to match 11588 rxns

% %%
% further sanitization
modelKEGGgr = padMissingFields(modelKEGGgr, PbiviaExchangeModel);
% Out:
% Added geneMiriams to KEGG
% Added rxnFrom to KEGG
% Added metFrom to KEGG
% Added geneFrom to KEGG
% Added rules to KEGG
% Added equations to KEGG
% Added rxnReferences to KEGG
% Added rxnConfidenceScores to KEGG
% Added metCharges to KEGG
% Added geneNames to KEGG
% Added geneShortNames to KEGG

% %% [markdown]
% Dealing with exchange reactions:

% %%
% getting a cell array of metabolites to create exchange reactions for
biomassMets = getBiomassMets(PbiviaExchangeModel, 'BIOMASS_ps'); % get metabolites involved in the biomass reaction
% Out:
% Biomass reaction: BIOMASS_ps
% Number of metabolites in biomass reaction: 306
%     {'C00001'}
%     {'C00002'}
%     {'C00003'}
%     {'C00004'}
%     {'C00005'}
%     {'C00006'}
%     {'C00007'}
%     {'C00009'}
%     {'C00010'}
%     {'C00011'}
%     {'C00013'}
%     {'C00014'}
%     {'C00016'}
%     {'C00019'}
%     {'C00020'}
%     {'C00022'}
%     {'C00024'}
%     {'C00025'}
%     {'C00026'}
%     {'C00028'}
%     {'C00029'}
%     {'C00030'}
%     {'C00031'}
%     {'C00033'}
%     {'C00036'}
%     {'C00037'}
%     {'C00041'}
%     {'C00042'}
%     {'C00044'}
%     {'C00047'}
%     {'C00049'}
%     {'C00055'}
%     {'C00058'}
%     {'C00061'}
%     {'C00062'}
%     {'C00063'}
%     {'C00064'}
%     {'C00065'}
%     {'C00073'}
%     {'C00075'}
%     {'C00078'}
%     {'C00079'}
%     {'C00080'}
%     {'C00082'}
%     {'C00083'}
%     {'C00085'}
%     {'C00091'}
%     {'C00093'}
%     {'C00095'}
%     {'C00097'}
%     {'C00100'}
%     {'C00101'}
%     {'C00105'}
%     {'C00109'}
%     {'C00116'}
%     {'C00117'}
%     {'C00118'}
%     {'C00120'}
%     {'C00123'}
%     {'C00130'}
%     {'C00131'}
%     {'C00134'}
%     {'C00135'}
%     {'C00137'}
%     {'C00138'}
%     {'C00139'}
%     {'C00140'}
%     {'C00141'}
%     {'C00143'}
%     {'C00144'}
%     {'C00148'}
%     {'C00149'}
%     {'C00155'}
%     {'C00160'}
%     {'C00163'}
%     {'C00169'}
%     {'C00173'}
%     {'C00183'}
%     {'C00188'}
%     {'C00197'}
%     {'C00207'}
%     {'C00214'}
%     {'C00217'}
%     {'C00221'}
%     {'C00224'}
%     {'C00229'}
%     {'C00233'}
%     {'C00239'}
%     {'C00246'}
%     {'C00249'}
%     {'C00250'}
%     {'C00251'}
%     {'C00254'}
%     {'C00255'}
%     {'C00256'}
%     {'C00258'}
%     {'C00263'}
%     {'C00267'}
%     {'C00269'}
%     {'C00272'}
%     {'C00283'}
%     {'C00286'}
%     {'C00288'}
%     {'C00299'}
%     {'C00314'}
%     {'C00320'}
%     {'C00323'}
%     {'C00325'}
%     {'C00329'}
%     {'C00337'}
%     {'C00342'}
%     {'C00343'}
%     {'C00344'}
%     {'C00360'}
%     {'C00362'}
%     {'C00378'}
%     {'C00407'}
%     {'C00415'}
%     {'C00416'}
%     {'C00441'}
%     {'C00449'}
%     {'C00455'}
%     {'C00460'}
%     {'C00463'}
%     {'C00475'}
%     {'C00490'}
%     {'C00493'}
%     {'C00526'}
%     {'C00534'}
%     {'C00559'}
%     {'C00579'}
%     {'C00606'}
%     {'C00636'}
%     {'C00655'}
%     {'C00664'}
%     {'C00671'}
%     {'C00680'}
%     {'C00787'}
%     {'C00826'}
%     {'C00831'}
%     {'C00857'}
%     {'C00864'}
%     {'C00881'}
%     {'C00882'}
%     {'C00921'}
%     {'C00979'}
%     {'C00984'}
%     {'C00993'}
%     {'C01005'}
%     {'C01013'}
%     {'C01050'}
%     {'C01063'}
%     {'C01081'}
%     {'C01097'}
%     {'C01134'}
%     {'C01185'}
%     {'C01187'}
%     {'C01209'}
%     {'C01212'}
%     {'C01279'}
%     {'C01300'}
%     {'C01528'}
%     {'C01563'}
%     {'C01635'}
%     {'C01636'}
%     {'C01638'}
%     {'C01639'}
%     {'C01640'}
%     {'C01641'}
%     {'C01643'}
%     {'C01644'}
%     {'C01645'}
%     {'C01646'}
%     {'C01647'}
%     {'C01648'}
%     {'C01649'}
%     {'C01650'}
%     {'C01651'}
%     {'C01652'}
%     {'C01653'}
%     {'C01847'}
%     {'C01977'}
%     {'C02336'}
%     {'C02411'}
%     {'C02583'}
%     {'C02713'}
%     {'C02730'}
%     {'C02737'}
%     {'C02743'}
%     {'C02869'}
%     {'C02972'}
%     {'C03024'}
%     {'C03160'}
%     {'C03319'}
%     {'C03479'}
%     {'C03492'}
%     {'C03506'}
%     {'C03688'}
%     {'C03972'}
%     {'C04079'}
%     {'C04352'}
%     {'C04376'}
%     {'C04432'}
%     {'C04454'}
%     {'C04489'}
%     {'C04556'}
%     {'C04618'}
%     {'C04619'}
%     {'C04620'}
%     {'C04633'}
%     {'C04646'}
%     {'C04688'}
%     {'C04751'}
%     {'C04932'}
%     {'C05196'}
%     {'C05197'}
%     {'C05223'}
%     {'C05335'}
%     {'C05345'}
%     {'C05519'}
%     {'C05688'}
%     {'C05698'}
%     {'C05745'}
%     {'C05747'}
%     {'C05749'}
%     {'C05752'}
%     {'C05755'}
%     {'C05757'}
%     {'C05761'}
%     {'C05764'}
%     {'C05892'}
%     {'C05983'}
%     {'C05993'}
%     {'C06055'}
%     {'C06153'}
%     {'C09762'}
%     {'C11434'}
%     {'C11435'}
%     {'C11537'}
%     {'C11736'}
%     {'C12203'}
%     {'C15547'}
%     {'C15973'}
%     {'C16221'}
%     {'C16236'}
%     {'C16618'}
%     {'C16633'}
%     {'C16636'}
%     {'C16675'}
%     {'C17023'}
%     {'C18902'}
%     {'C19722'}
%     {'C19845'}
%     {'C20372'}
%     {'C20374'}
%     {'C20376'}
%     {'C20378'}
%     {'C20446'}
%     {'C20751'}
%     {'C20756'}
%     {'C21027'}
%     {'C21333'}
%     {'C22150'}
%     {'C22154'}
%     {'C22159'}
%     {'C22160'}
%     {'C00059'}
%     {'C00136'}
%     {'C00146'}
%     {'C00181'}
%     {'C00186'}
%     {'C00311'}
%     {'C00630'}
%     {'C00641'}
%     {'C00853'}
%     {'C00856'}
%     {'C01068'}
%     {'C01086'}
%     {'C01407'}
%     {'C01455'}
%     {'C01542'}
%     {'C02211'}
%     {'C02882'}
%     {'C03136'}
%     {'C03263'}
%     {'C03561'}
%     {'C04253'}
%     {'C04297'}
%     {'C04573'}
%     {'C05270'}
%     {'C05686'}
%     {'C05697'}
%     {'C05774'}
%     {'C06040'}
%     {'C06365'}
%     {'C06504'}
%     {'C06505'}
%     {'C11145'}
%     {'C13309'}
%     {'C15980'}
%     {'C19078'}
%     {'C19080'}
%     {'C19771'}
%     {'C19891'}
%     {'C20783'}
%     {'C20870'}

% %%
wasteMets = getCommonWasteMets(PbiviaExchangeModel); % get list (cell array) of common waste metabolites
essentialMets = {'C00031','C00014','C00007','C00009','C00036'}; % glucose, ammonium, oxygen, phosphate, sulfate
communityMets = getCommunityExchangeMets(); % metabolites that are likely to be needed in MCMM community exchanges
allExMets = unique([biomassMets(:); wasteMets(:); essentialMets(:); communityMets(:)], 'stable'); % concatenate while avoiding potential duplicates

% add the exchange reactions to the model
PbiviaExchangeModel = addExchangeRxnsForModel(PbiviaExchangeModel, allExMets);
% Out:
% Warning: Metabolite C00469 not found in model, skipping.
% Warning: Metabolite C00086 not found in model, skipping.

% %%
% ensure reversibility of reactions
PbiviaExchangeModel = ensureRevField(PbiviaExchangeModel);
% Out:
% Model already has rev field

% %%
sol3 = solveLP(PbiviaExchangeModel);
disp(sol3.f);
% Out:
%   25.210084033613445

% %% [markdown]
% There is now biomass production!

% %%
% pre-export cleaning
PbiviaExchangeModel = fixSubsystemsField(PbiviaExchangeModel);
PbiviaExchangeModel = sanitizeRxnMiriams(PbiviaExchangeModel);
% Out:
% Sanitized rxnMiriams for 1247 reactions

% %% [markdown]
% Now the model is ready for export:

% %%
% export the current model version
exportModel(PbiviaExchangeModel, 'Pbivia_draftGEM_v4.xml');
% Out:
% WARNING: The following InChI strings are associated to more than one unique metabolite name:
%     1S/C10H20O7P2/c1-9(2)5-4-6-10(3)7-8-16-19(14,15)17-18(11,12)13/h5,7H,4,6,8H2,1-3H3,(H,14,15)(H2,11,12,13)/b10-7+
% Document written

% %%
exportToExcelFormat(PbiviaExchangeModel, 'Pbivia_draftGEM_v4.xlsx');
save('Pbivia_draftGEM_v4.mat', 'PbiviaExchangeModel');

% %% [markdown]
% This will be the version used for the MCMM.
%
% ## Additional tests
%
% A few more sanity checks and tests prior to moving on to gap\-filling.

% %%
% Setting up the draft GEM base
%PbiviaBiomassDraftModel = importModel('Pbivia_draftGEM_v4.xml');
% create a copy to avoid overwriting
PbiviaBiomassObjDraftModel = PbiviaExchangeModel;
PbiviaBiomassObjDraftModel.id = 'PbiviaDraft';

% %% [markdown]
% First, checking for dead\-end metabolites:

% %%
deadMets = quickDeadEnds(PbiviaBiomassObjDraftModel);
fprintf('Dead-end metabolites: %d\n', numel(deadMets));
% Out:
% Dead-end metabolites: 0

% %% [markdown]
% Double\-check that the biomass metabolites are indeed present in the model:

% %%
biomassMets = getBiomassMets(PbiviaBiomassObjDraftModel, 'BIOMASS_ps');
% Out:
% Biomass reaction: BIOMASS_ps
% Number of metabolites in biomass reaction: 306
%     {'C00001'}
%     {'C00002'}
%     {'C00003'}
%     {'C00004'}
%     {'C00005'}
%     {'C00006'}
%     {'C00007'}
%     {'C00009'}
%     {'C00010'}
%     {'C00011'}
%     {'C00013'}
%     {'C00014'}
%     {'C00016'}
%     {'C00019'}
%     {'C00020'}
%     {'C00022'}
%     {'C00024'}
%     {'C00025'}
%     {'C00026'}
%     {'C00028'}
%     {'C00029'}
%     {'C00030'}
%     {'C00031'}
%     {'C00033'}
%     {'C00036'}
%     {'C00037'}
%     {'C00041'}
%     {'C00042'}
%     {'C00044'}
%     {'C00047'}
%     {'C00049'}
%     {'C00055'}
%     {'C00058'}
%     {'C00061'}
%     {'C00062'}
%     {'C00063'}
%     {'C00064'}
%     {'C00065'}
%     {'C00073'}
%     {'C00075'}
%     {'C00078'}
%     {'C00079'}
%     {'C00080'}
%     {'C00082'}
%     {'C00083'}
%     {'C00085'}
%     {'C00091'}
%     {'C00093'}
%     {'C00095'}
%     {'C00097'}
%     {'C00100'}
%     {'C00101'}
%     {'C00105'}
%     {'C00109'}
%     {'C00116'}
%     {'C00117'}
%     {'C00118'}
%     {'C00120'}
%     {'C00123'}
%     {'C00130'}
%     {'C00131'}
%     {'C00134'}
%     {'C00135'}
%     {'C00137'}
%     {'C00138'}
%     {'C00139'}
%     {'C00140'}
%     {'C00141'}
%     {'C00143'}
%     {'C00144'}
%     {'C00148'}
%     {'C00149'}
%     {'C00155'}
%     {'C00160'}
%     {'C00163'}
%     {'C00169'}
%     {'C00173'}
%     {'C00183'}
%     {'C00188'}
%     {'C00197'}
%     {'C00207'}
%     {'C00214'}
%     {'C00217'}
%     {'C00221'}
%     {'C00224'}
%     {'C00229'}
%     {'C00233'}
%     {'C00239'}
%     {'C00246'}
%     {'C00249'}
%     {'C00250'}
%     {'C00251'}
%     {'C00254'}
%     {'C00255'}
%     {'C00256'}
%     {'C00258'}
%     {'C00263'}
%     {'C00267'}
%     {'C00269'}
%     {'C00272'}
%     {'C00283'}
%     {'C00286'}
%     {'C00288'}
%     {'C00299'}
%     {'C00314'}
%     {'C00320'}
%     {'C00323'}
%     {'C00325'}
%     {'C00329'}
%     {'C00337'}
%     {'C00342'}
%     {'C00343'}
%     {'C00344'}
%     {'C00360'}
%     {'C00362'}
%     {'C00378'}
%     {'C00407'}
%     {'C00415'}
%     {'C00416'}
%     {'C00441'}
%     {'C00449'}
%     {'C00455'}
%     {'C00460'}
%     {'C00463'}
%     {'C00475'}
%     {'C00490'}
%     {'C00493'}
%     {'C00526'}
%     {'C00534'}
%     {'C00559'}
%     {'C00579'}
%     {'C00606'}
%     {'C00636'}
%     {'C00655'}
%     {'C00664'}
%     {'C00671'}
%     {'C00680'}
%     {'C00787'}
%     {'C00826'}
%     {'C00831'}
%     {'C00857'}
%     {'C00864'}
%     {'C00881'}
%     {'C00882'}
%     {'C00921'}
%     {'C00979'}
%     {'C00984'}
%     {'C00993'}
%     {'C01005'}
%     {'C01013'}
%     {'C01050'}
%     {'C01063'}
%     {'C01081'}
%     {'C01097'}
%     {'C01134'}
%     {'C01185'}
%     {'C01187'}
%     {'C01209'}
%     {'C01212'}
%     {'C01279'}
%     {'C01300'}
%     {'C01528'}
%     {'C01563'}
%     {'C01635'}
%     {'C01636'}
%     {'C01638'}
%     {'C01639'}
%     {'C01640'}
%     {'C01641'}
%     {'C01643'}
%     {'C01644'}
%     {'C01645'}
%     {'C01646'}
%     {'C01647'}
%     {'C01648'}
%     {'C01649'}
%     {'C01650'}
%     {'C01651'}
%     {'C01652'}
%     {'C01653'}
%     {'C01847'}
%     {'C01977'}
%     {'C02336'}
%     {'C02411'}
%     {'C02583'}
%     {'C02713'}
%     {'C02730'}
%     {'C02737'}
%     {'C02743'}
%     {'C02869'}
%     {'C02972'}
%     {'C03024'}
%     {'C03160'}
%     {'C03319'}
%     {'C03479'}
%     {'C03492'}
%     {'C03506'}
%     {'C03688'}
%     {'C03972'}
%     {'C04079'}
%     {'C04352'}
%     {'C04376'}
%     {'C04432'}
%     {'C04454'}
%     {'C04489'}
%     {'C04556'}
%     {'C04618'}
%     {'C04619'}
%     {'C04620'}
%     {'C04633'}
%     {'C04646'}
%     {'C04688'}
%     {'C04751'}
%     {'C04932'}
%     {'C05196'}
%     {'C05197'}
%     {'C05223'}
%     {'C05335'}
%     {'C05345'}
%     {'C05519'}
%     {'C05688'}
%     {'C05698'}
%     {'C05745'}
%     {'C05747'}
%     {'C05749'}
%     {'C05752'}
%     {'C05755'}
%     {'C05757'}
%     {'C05761'}
%     {'C05764'}
%     {'C05892'}
%     {'C05983'}
%     {'C05993'}
%     {'C06055'}
%     {'C06153'}
%     {'C09762'}
%     {'C11434'}
%     {'C11435'}
%     {'C11537'}
%     {'C11736'}
%     {'C12203'}
%     {'C15547'}
%     {'C15973'}
%     {'C16221'}
%     {'C16236'}
%     {'C16618'}
%     {'C16633'}
%     {'C16636'}
%     {'C16675'}
%     {'C17023'}
%     {'C18902'}
%     {'C19722'}
%     {'C19845'}
%     {'C20372'}
%     {'C20374'}
%     {'C20376'}
%     {'C20378'}
%     {'C20446'}
%     {'C20751'}
%     {'C20756'}
%     {'C21027'}
%     {'C21333'}
%     {'C22150'}
%     {'C22154'}
%     {'C22159'}
%     {'C22160'}
%     {'C00059'}
%     {'C00136'}
%     {'C00146'}
%     {'C00181'}
%     {'C00186'}
%     {'C00311'}
%     {'C00630'}
%     {'C00641'}
%     {'C00853'}
%     {'C00856'}
%     {'C01068'}
%     {'C01086'}
%     {'C01407'}
%     {'C01455'}
%     {'C01542'}
%     {'C02211'}
%     {'C02882'}
%     {'C03136'}
%     {'C03263'}
%     {'C03561'}
%     {'C04253'}
%     {'C04297'}
%     {'C04573'}
%     {'C05270'}
%     {'C05686'}
%     {'C05697'}
%     {'C05774'}
%     {'C06040'}
%     {'C06365'}
%     {'C06504'}
%     {'C06505'}
%     {'C11145'}
%     {'C13309'}
%     {'C15980'}
%     {'C19078'}
%     {'C19080'}
%     {'C19771'}
%     {'C19891'}
%     {'C20783'}
%     {'C20870'}

% %%
missing = setdiff(biomassMets, PbiviaBiomassObjDraftModel.mets);
disp(missing);

% %% [markdown]
% Perform a preliminary test for whether gap\-filling is necessary:

% %%
% block all exchange
PbiviaBiomassObjDraftModel.lb(findExcRxns(PbiviaBiomassObjDraftModel)) = 0;

% reopen minimal medium
allowMets = {'C00031','C00014','C00007','C00009','C00036'}; % glucose, ammonium, oxygen, phosphate, sulfate
for i = 1:numel(allowMets)
    exIdx = find(strcmp(PbiviaBiomassObjDraftModel.mets, allowMets{i}));
    if ~isempty(exIdx)
        rxnIdx = find(PbiviaBiomassObjDraftModel.S(exIdx,:));
        PbiviaBiomassObjDraftModel.lb(rxnIdx) = -1000; % uptake allowed
    end
end

sol4 = solveLP(PbiviaBiomassObjDraftModel);
disp(sol4.f);
% Out:
%   25.210084033613384

% %% [markdown]
% The solution here is the same as before, so this looks good to go.
%
%
% On Ed's recommendation, I will force the biomass flux to be positive:

% %%
% force the biomass flux to be positive
% Set lower and upper bounds of the biomass reaction
rxnID = 'BIOMASS_ps';
biomassIndex = find(ismember(PbiviaBiomassObjDraftModel.rxns, rxnID));

PbiviaBiomassObjDraftModel.lb(biomassIndex) = 0.1;  % minimum growth rate
PbiviaBiomassObjDraftModel.ub(biomassIndex) = 1000; % allow up to 1000

% %% [markdown]
% Finally, run FBA on the new model:

% %%
sol3 = solveLP(PbiviaBiomassObjDraftModel);
disp(sol3.f)
% Out:
%   25.210084033613445

% %% [markdown]
% Export the model:

% %%
exportModel(PbiviaBiomassObjDraftModel, 'Pbivia_draftGEM_v5.xml');
% Out:
% WARNING: The following reactions have lower and upper bounds that indicate reversibility, but are indicated as irreversible in model.rev:
%     R00765
%     R05627_EXP_1
%     R08221
%     R11037
%     R12896
%     R12958
%     R08020
% WARNING: The following InChI strings are associated to more than one unique metabolite name:
%     1S/C10H20O7P2/c1-9(2)5-4-6-10(3)7-8-16-19(14,15)17-18(11,12)13/h5,7H,4,6,8H2,1-3H3,(H,14,15)(H2,11,12,13)/b10-7+
% Document written

% %%
exportToExcelFormat(PbiviaBiomassObjDraftModel, 'Pbivia_draftGEM_v5.xlsx');
save('Pbivia_draftGEM_v5.mat', 'PbiviaBiomassObjDraftModel');

% %% [markdown]
% ## Gap\-filling attempt
%
% On the advice of Ed, I will be doing gap\-filling from the whole of the KEGG database. While the model does technically produce biomass and so therefore is viable, it is better to add more exchanges to ensure as high\-quality of an MCMM as possible.

% %%
% trying gap filling
[Pbivia_filledModel, addedRxns] = fillGaps( ...
    PbiviaBiomassObjDraftModel, ...
    modelKEGGgr, ...
    false, true, true);

% Check the output of fillGaps
if isempty(Pbivia_filledModel)
    disp('fillGaps returned an empty model. Check your input models and required fields.');
elseif iscell(Pbivia_filledModel)
    disp(['fillGaps returned a cell array of size: ', mat2str(size(Pbivia_filledModel))]);
else
    disp('fillGaps returned a valid model struct.');
end
% Out:
% fillGaps returned an empty model. Check your input models and required fields.

% %% [markdown]
% Check the results:

% %%
% Did fillGaps return something valid?
class(Pbivia_filledModel)
% Out:
% ans = 'cell'

% %%
whos Pbivia_filledModel
% Out:
%   Name                    Size            Bytes  Class    Attributes
%   Pbivia_filledModel      0x0                 0  cell

% %% [markdown]
% As before, it appears that gap\-filling is unnecessary in this case.
%
% ## Draft *Trichomonas vaginalis* GEM
%
% Initial GEM creation:

% %%
%clear
%clc

% draft with KEGG
%The organisms with KEGG annotation and their associated ids
%(e.g. 'tva' for Trichomonas vaginalis) can be found from here:
%https://www.kegg.jp/kegg/catalog/org_list.html.
TvaginalisKEGGAnnotation=getKEGGModelForOrganism('tva','','','',1,0,0);
% Out:
% *** The model reconstruction from KEGG based on the annotation available for KEGG Species tva ***
% Importing the global KEGG model from C:/Users/viragv/AppData/Roaming/MathWorks/MATLAB Add-Ons/Collections/RAVEN Toolbox/external/kegg/keggModel.mat... COMPLETE
% Importing the KEGG phylogenetic distance matrix from C:/Users/viragv/AppData/Roaming/MathWorks/MATLAB Add-Ons/Collections/RAVEN Toolbox/external/kegg/keggPhylDist.mat... COMPLETE
% Pruning the model from non-tva genes... COMPLETE
% Removing non-spontaneous reactions without GPR rules... COMPLETE
% Fixing gene names in the model... COMPLETE
% Constructing GPR associations and annotations for the model... COMPLETE
% *** Model reconstruction complete ***

% %%
TvaginalisKEGGHomology=getKEGGModelForOrganism('TvaginalisKEGGHMMs','trichomonas_vaginalis_GCF_026262505-1_prots_edit.fasta','euk90_kegg105','',1,0,0);
% Out:
% *** The model reconstruction from KEGG based on the protein homology search against KEGG Orthology specific HMMs ***
% NOTE: Found euk90_kegg105 directory with pre-trained HMMs, it will therefore be used during reconstruction
% Importing the global KEGG model from C:/Users/viragv/AppData/Roaming/MathWorks/MATLAB Add-Ons/Collections/RAVEN Toolbox/external/kegg/keggModel.mat... COMPLETE
% Removing non-spontaneous reactions without GPR rules... COMPLETE
% Fixing gene names in the model... COMPLETE
% Importing the KEGG phylogenetic distance matrix from C:/Users/viragv/AppData/Roaming/MathWorks/MATLAB Add-Ons/Collections/RAVEN Toolbox/external/kegg/keggPhylDist.mat... COMPLETE
% Generating the KEGG Orthology specific multi-FASTA files... COMPLETE
% Performing clustering and multiple alignment for KEGG Orthology specific protein sets... COMPLETE
% Training the KEGG Orthology specific HMMs... COMPLETE
% Querying the user-specified FASTA file against the KEGG Orthology specific HMMs... COMPLETE
% Parsing the HMM search results... COMPLETE
% Removing gene, KEGG Orthology associations below minScoreRatioKO, minScoreRatioG... COMPLETE
% Adding gene annotations to the model... COMPLETE
% Removing non-spontaneous reactions which after HMM search no longer have GPR rules... COMPLETE
% Constructing GPR rules and finalizing the model... COMPLETE
% *** Model reconstruction complete ***

% %%
% merge models
TvaginalisKEGGDraftModel=mergeModels({TvaginalisKEGGAnnotation TvaginalisKEGGHomology});

% check reaction numbers
disp(numel(TvaginalisKEGGHomology.rxns)+numel(TvaginalisKEGGAnnotation.rxns));
% Out:
%         1490

% %%
disp(numel(TvaginalisKEGGDraftModel.rxns));
% Out:
%         1490

% %%
% further model cleaning
TvaginalisKEGGDraftModel=expandModel(TvaginalisKEGGDraftModel);
TvaginalisKEGGDraftModel=contractModel(TvaginalisKEGGDraftModel);

% %% [markdown]
% At this point, a draft GEM has been created for *T. vaginalis*, merging the information from MetaCyc and KEGG. While it needs to be improved, I'll save it for now in Excel format to avoid having to recreate it each time.

% %%
exportToExcelFormat(TvaginalisKEGGDraftModel, 'Tvaginalis_draftGEM_v1.xlsx');
save('Tvaginalis_draftGEM_v1.mat', 'TvaginalisKEGGDraftModel');

% %% [markdown]
% ## Cleaning *T. vaginalis* draft GEM

% %%
%TvaginalisCombinedDraftModel = load('Tvaginalis_draftGEM_v1.mat');
TvaginalisCleanDraftModel = cleanGrRulesGenes(TvaginalisKEGGDraftModel);
TvaginalisCleanDraftModel = mergeDuplicateMetNames(TvaginalisCleanDraftModel);
TvaginalisCleanDraftModel = mergeDuplicateMetNames2(TvaginalisCleanDraftModel);
TvaginalisCleanDraftModel = fixSubsystemsField(TvaginalisCleanDraftModel);

% %% [markdown]
% The preliminary model should now be ready for export.

% %%
exportModel(TvaginalisCleanDraftModel, 'Tvaginalis_draftGEM_v2.xml');
% Out:
% WARNING: No objective function found. This might be intended, but results in FBCv2 non-compliant SBML file when exported
% WARNING: The composition for the following metabolites could not be parsed:
%     C01977
%     C01978
%     C02031
%     C02100
%     C02339
%     C04157
%     C04802
%     C17324
%     C20458
%     ...and 11 more
% WARNING: The following InChI strings are associated to more than one unique metabolite name:
%     1S/C24H40N7O17P3S/c1-4-15(33)52-8-7-26-14(32)5-6-27-22(36)19(35)24(2,3)10-45-51(42,43)48-50(40,41)44-9-13-18(47-49(37,38)39)17(34)23(46-13)31-12-30-16-20(25)28-11-29-21(16)31/h11-13,17-19,23,34-35H,4-10H2,1-3H3,(H,26,32)(H,27,36)(H,40,41)(H,42,43)(H2,25,28,29)(H2,37,38,39)/t13-,17-,18-,19+,23-/m1/s1
% Document written

% %%
exportToExcelFormat(TvaginalisCleanDraftModel, 'Tvaginalis_draftGEM_v2.xlsx');
save('Tvaginalis_draftGEM_v2.mat', 'TvaginalisCleanDraftModel');

% %% [markdown]
% Saved in SBML standard GEM format.

% %%
% Load the model from SBML (.xml)
%TvaginalisCleanDraftModel = importModel('Tvaginalis_draftGEM_v2.xml');

% %% [markdown]
% Now start quality checks:

% %%
%Check out if the newly generated TvaginalisCombinedDraftModel could grow
sol=solveLP(TvaginalisCleanDraftModel);
disp(sol.f);
% Out:
%      0

% %%
%The results indicate that this new model is non-functional
% ie., biomass = 0, which means there is no growth

% %%
% Look for reactions that produce a "biomass" metabolite
bioMets = find(contains(lower(TvaginalisCleanDraftModel.metNames), 'biomass'));

if isempty(bioMets)
    warning('No metabolites with "biomass" in the name were found.');
else
    % Find reactions involving these metabolites
    [rxnIdx, ~] = find(TvaginalisCleanDraftModel.S(bioMets,:) ~= 0);
    rxnIdx = unique(rxnIdx);
    disp('Potential biomass reactions:');
    disp([rxnIdx, TvaginalisCleanDraftModel.rxns(rxnIdx)', TvaginalisCleanDraftModel.rxnNames(rxnIdx)']);
end
% Out:
% Warning: No metabolites with "biomass" in the name were found.

% %% [markdown]
% ## Adding a biomass reaction
%
% Initial explorations showed that the current preliminary GEM draft doesn't have a biomass reaction. Hence, biomass will always be 0 until this is added. The following code was generated by ChatGPT; it seeds a biomass reaction from common building blocks like amino acids and nucleotides.

% %%
[TvaginalisBiomassDraftModel, biomassRxnID] = addPseudoBiomass_trichomonas( ...
    TvaginalisCleanDraftModel, ...
    'BIOMASS_ps', ...
    [], ...
    true, ...
    'Tvaginalis_biomass_debug.txt', ...
    'Tvaginalis_biomass_metabolites.csv' ...
);
% Out:
% Precursor "L-arginine" → 8 matches found
%     Match: "S-adenosyl-L-methionine:[protein]-L-arginine N-methyltransferase" (ID: R11216)
%         Metabolite: "S-Adenosyl-L-methionine" (ID: C00019)
%         Metabolite: "Protein-L-arginine" (ID: C00613)
%     Match: "S-adenosyl-L-methionine:[protein]-N(omega)-methyl-L-arginine N-methyltransferase ([protein]-N(omega),N(omega)-dimethyl-L-arginine-forming)" (ID: R11217)
%         Metabolite: "S-Adenosyl-L-methionine" (ID: C00019)
%         Metabolite: "Protein N(omega)-methyl-L-arginine" (ID: C04143)
%     Match: "S-adenosyl-L-methionine:[protein]-N(omega)-methyl-L-arginine N-methyltransferase ([protein]-N(omega),N(omega)'-dimethyl-L-arginine-forming)" (ID: R11218)
%         Metabolite: "S-Adenosyl-L-methionine" (ID: C00019)
%         Metabolite: "Protein N(omega)-methyl-L-arginine" (ID: C04143)
%     Match: "S-adenosyl-L-methionine:[protein]-L-arginine N-methyltransferase ([protein]-N(omega),N(omega)-dimethyl-L-arginine-forming)" (ID: R11219)
%         Metabolite: "S-Adenosyl-L-methionine" (ID: C00019)
%         Metabolite: "Protein-L-arginine" (ID: C00613)
%     Match: "S-adenosyl-L-methionine:[protein]-L-arginine N-methyltransferase ([protein]-N(omega),N(omega)'-dimethyl-L-arginine-forming)" (ID: R11220)
%         Metabolite: "S-Adenosyl-L-methionine" (ID: C00019)
%         Metabolite: "Protein-L-arginine" (ID: C00613)
%     Match: "L-arginine,NADPH:oxygen oxidoreductase (nitric-oxide-forming)" (ID: R00557)
%         Metabolite: "NADPH" (ID: C00005)
%         Metabolite: "Oxygen" (ID: C00007)
%         Metabolite: "H+" (ID: C00080)
%         Metabolite: "L-Arginine" (ID: C00062)
%     Match: "L-arginine,NADPH:oxygen oxidoreductase (N-(omega)-hydroxyarginine-forming)" (ID: R00558)
%         Metabolite: "NADPH" (ID: C00005)
%         Metabolite: "Oxygen" (ID: C00007)
%         Metabolite: "H+" (ID: C00080)
%         Metabolite: "L-Arginine" (ID: C00062)
%     Match: "L-Arginine:tRNA(Arg) ligase (AMP-forming)" (ID: R03646)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "L-Arginine" (ID: C00062)
%         Metabolite: "tRNA(Arg)" (ID: C01636)
% Precursor "L-cysteine" → 13 matches found
%     Match: "L-cysteine:2-oxoglutarate aminotransferase" (ID: R00896)
%         Metabolite: "2-Oxoglutarate" (ID: C00026)
%         Metabolite: "L-Cysteine" (ID: C00097)
%     Match: "L-Cysteine:tRNA(Cys) ligase (AMP-forming)" (ID: R03650)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "L-Cysteine" (ID: C00097)
%         Metabolite: "tRNA(Cys)" (ID: C01639)
%     Match: "S-Adenosyl-L-methionine:protein-C-terminal-S-farnesyl-L-cysteine O-methyltransferase" (ID: R04496)
%         Metabolite: "S-Adenosyl-L-methionine" (ID: C00019)
%         Metabolite: "Protein C-terminal S-farnesyl-L-cysteine" (ID: C04506)
%     Match: "L-cysteine:[enzyme]-cysteine sulfurtransferase" (ID: R07460)
%         Metabolite: "L-Cysteine" (ID: C00097)
%         Metabolite: "[Enzyme]-cysteine" (ID: C15811)
%     Match: "L-cysteine:sulfur-acceptor sulfurtransferase" (ID: R11528)
%         Metabolite: "L-Cysteine" (ID: C00097)
%         Metabolite: "[Protein]-L-cysteine" (ID: C02743)
%     Match: "L-cysteine:molybdenum cofactor sulfurtransferase" (ID: R11583)
%         Metabolite: "Reduced acceptor" (ID: C00030)
%         Metabolite: "H+" (ID: C00080)
%         Metabolite: "L-Cysteine" (ID: C00097)
%         Metabolite: "Molybdoenzyme molybdenum cofactor" (ID: C18237)
%     Match: "L-cysteine hydrogen-sulfide-lyase (deaminating; pyruvate-forming)" (ID: R00782)
%         Metabolite: "H2O" (ID: C00001)
%         Metabolite: "L-Cysteine" (ID: C00097)
%     Match: "L-serine hydro-lyase (adding hydrogen sulfide, L-cysteine-forming)" (ID: R00891)
%         Metabolite: "L-Serine" (ID: C00065)
%         Metabolite: "Hydrogen sulfide" (ID: C00283)
%     Match: "N-[(R)-4'-Phosphopantothenoyl]-L-cysteine carboxy-lyase" (ID: R03269)
%         Metabolite: "(R)-4'-Phosphopantothenoyl-L-cysteine" (ID: C04352)
%     Match: "(R)-4'-phosphopantothenate:L-cysteine ligase" (ID: R04231)
%         Metabolite: "CTP" (ID: C00063)
%         Metabolite: "L-Cysteine" (ID: C00097)
%         Metabolite: "D-4'-Phosphopantothenate" (ID: C03492)
%     Match: "O3-acetyl-L-serine:thiosulfate 2-amino-2-carboxyethyltransferase (reducing, L-cysteine-forming);" (ID: R04859)
%         Metabolite: "H+" (ID: C00080)
%         Metabolite: "Thioredoxin" (ID: C00342)
%         Metabolite: "Thiosulfate" (ID: C00320)
%         Metabolite: "O-Acetyl-L-serine" (ID: C00979)
%     Match: "[enzyme]-S-sulfanyl-L-cysteine:adenylyl-[sulfur-carrier protein] sulfurtransferase" (ID: R07461)
%         Metabolite: "Reduced acceptor" (ID: C00030)
%         Metabolite: "[Enzyme]-S-sulfanylcysteine" (ID: C15812)
%         Metabolite: "Adenylyl-[sulfur-carrier protein]" (ID: C15813)
%     Match: "L-cysteine-S-conjugate thiol-lyase (deaminating; 2-aminoprop-2-enoate-forming)" (ID: R12188)
%         Metabolite: "H2O" (ID: C00001)
%         Metabolite: "L-Cysteine-S-conjugate" (ID: C02882)
% Precursor "L-methionine" → 24 matches found
%     Match: "ATP:L-methionine S-adenosyltransferase" (ID: R00177)
%         Metabolite: "Orthophosphate" (ID: C00009)
%         Metabolite: "Diphosphate" (ID: C00013)
%         Metabolite: "S-Adenosyl-L-methionine" (ID: C00019)
%     Match: "S-adenosyl-L-methionine methylthioadenosine-lyase (1-aminocyclopropane-1-carboxylate-forming)" (ID: R00179)
%         Metabolite: "S-Adenosyl-L-methionine" (ID: C00019)
%     Match: "S-adenosyl-L-methionine:tRNA guanine N1-methyltransferase;" (ID: R00597)
%         Metabolite: "S-Adenosyl-L-methionine" (ID: C00019)
%         Metabolite: "tRNA guanine" (ID: C01977)
%     Match: "L-methionine methanethiol-lyase (deaminating;2-oxobutanoate-forming)" (ID: R00654)
%         Metabolite: "H2O" (ID: C00001)
%         Metabolite: "L-Methionine" (ID: C00073)
%     Match: "S-adenosyl-L-methionine:phosphatidyl-N-dimethylethanolamine N-methyltransferase" (ID: R01320)
%         Metabolite: "S-Adenosyl-L-methionine" (ID: C00019)
%         Metabolite: "Phosphatidyl-N-dimethylethanolamine" (ID: C04308)
%     Match: "S-adenosyl-L-methionine:phosphatidylethanolamine N-methyltransferase" (ID: R02056)
%         Metabolite: "S-Adenosyl-L-methionine" (ID: C00019)
%         Metabolite: "Phosphatidylethanolamine" (ID: C00350)
%     Match: "S-adenosyl-L-methionine:carnosine N-methyltransferase" (ID: R02144)
%         Metabolite: "S-Adenosyl-L-methionine" (ID: C00019)
%         Metabolite: "Carnosine" (ID: C00386)
%     Match: "S-adenosyl-L-methionine:phosphatidyl-N-methylethanolamine N-methyltransferase" (ID: R03424)
%         Metabolite: "S-Adenosyl-L-methionine" (ID: C00019)
%         Metabolite: "Phosphatidyl-N-methylethanolamine" (ID: C01241)
%     Match: "L-Methionine:tRNAMet ligase (AMP-forming)" (ID: R03659)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "L-Methionine" (ID: C00073)
%         Metabolite: "tRNA(Met)" (ID: C01647)
%     Match: "S-adenosyl-L-methionine:mRNA (guanine-N7-)-methyltransferase" (ID: R03805)
%         Metabolite: "S-Adenosyl-L-methionine" (ID: C00019)
%         Metabolite: "H+" (ID: C00080)
%         Metabolite: "G(5')pppPur-mRNA" (ID: C02031)
%     Match: "S-adenosyl-L-methionine:5-(N7-methyl 5-triphosphoguanosine)-(purine-ribonucleotide)-[mRNA] 2-O-methyltransferase" (ID: R03922)
%         Metabolite: "S-Adenosyl-L-methionine" (ID: C00019)
%         Metabolite: "m7G(5')pppR-mRNA" (ID: C02339)
%     Match: "S-Adenosyl-L-methionine:protein-C-terminal-S-farnesyl-L-cysteine O-methyltransferase" (ID: R04496)
%         Metabolite: "S-Adenosyl-L-methionine" (ID: C00019)
%         Metabolite: "Protein C-terminal S-farnesyl-L-cysteine" (ID: C04506)
%     Match: "Protein-glycine,dihydroflavodoxin:S-adenosyl-L-methionine oxidoreductase (S-adenosyl-L-methionine cleaving)" (ID: R04710)
%         Metabolite: "S-Adenosyl-L-methionine" (ID: C00019)
%         Metabolite: "Dihydroflavodoxin" (ID: C05196)
%         Metabolite: "Protein glycine" (ID: C05197)
%     Match: "S-adenosyl-L-methionine:cytochrome-c-L-lysine N6-methyltransferase" (ID: R04866)
%         Metabolite: "S-Adenosyl-L-methionine" (ID: C00019)
%         Metabolite: "Protein N6-methyl-L-lysine" (ID: C05544)
%     Match: "S-adenosyl-L-methionine:cytochrome-c-L-lysine N6-methyltransferase" (ID: R04867)
%         Metabolite: "S-Adenosyl-L-methionine" (ID: C00019)
%         Metabolite: "Protein N6,N6-dimethyl-L-lysine" (ID: C05545)
%     Match: "S-adenosyl-L-methionine:[protein]-L-arginine N-methyltransferase" (ID: R11216)
%         Metabolite: "S-Adenosyl-L-methionine" (ID: C00019)
%         Metabolite: "Protein-L-arginine" (ID: C00613)
%     Match: "S-adenosyl-L-methionine:[protein]-N(omega)-methyl-L-arginine N-methyltransferase ([protein]-N(omega),N(omega)-dimethyl-L-arginine-forming)" (ID: R11217)
%         Metabolite: "S-Adenosyl-L-methionine" (ID: C00019)
%         Metabolite: "Protein N(omega)-methyl-L-arginine" (ID: C04143)
%     Match: "S-adenosyl-L-methionine:[protein]-N(omega)-methyl-L-arginine N-methyltransferase ([protein]-N(omega),N(omega)'-dimethyl-L-arginine-forming)" (ID: R11218)
%         Metabolite: "S-Adenosyl-L-methionine" (ID: C00019)
%         Metabolite: "Protein N(omega)-methyl-L-arginine" (ID: C04143)
%     Match: "S-adenosyl-L-methionine:[protein]-L-arginine N-methyltransferase ([protein]-N(omega),N(omega)-dimethyl-L-arginine-forming)" (ID: R11219)
%         Metabolite: "S-Adenosyl-L-methionine" (ID: C00019)
%         Metabolite: "Protein-L-arginine" (ID: C00613)
%     Match: "S-adenosyl-L-methionine:[protein]-L-arginine N-methyltransferase ([protein]-N(omega),N(omega)'-dimethyl-L-arginine-forming)" (ID: R11220)
%         Metabolite: "S-Adenosyl-L-methionine" (ID: C00019)
%         Metabolite: "Protein-L-arginine" (ID: C00613)
%     Match: "S-adenosyl-L-methionine:adenine in mRNA methyltransferase" (ID: R12011)
%         Metabolite: "S-Adenosyl-L-methionine" (ID: C00019)
%         Metabolite: "Adenine in mRNA" (ID: C21844)
%     Match: "S-Adenosyl-L-methionine:8-amino-7-oxononanoate aminotransferase" (ID: R03231)
%         Metabolite: "S-Adenosyl-L-methionine" (ID: C00019)
%         Metabolite: "8-Amino-7-oxononanoate" (ID: C01092)
%     Match: "S-adenosyl-L-methionine:tRNA(Phe) {7-[(3S)-3-amino-3-carboxypropyl]wyosine37-O}-methyltransferase" (ID: R10586)
%         Metabolite: "S-Adenosyl-L-methionine" (ID: C00019)
%         Metabolite: "7-[(3S)-(3-Amino-3-carboxypropyl)]wyosine in tRNA(Phe)" (ID: C20649)
%     Match: "S-adenosyl-L-methionine:tRNA(Phe) {7-[(3S)-3-amino-3-(methoxycarbonyl)propyl]wyosine37-N}-methyltransferase (carbon dioxide-adding)" (ID: R10587)
%         Metabolite: "CO2" (ID: C00011)
%         Metabolite: "S-Adenosyl-L-methionine" (ID: C00019)
%         Metabolite: "7-[(3S)-3-Amino-3-(methoxycarbonyl)propyl]wyosine in tRNA(Phe)" (ID: C20659)
% Precursor "L-serine" → 11 matches found
%     Match: "Palmitoyl-CoA:L-serine C-palmitoyltransferase (decarboxylating)" (ID: R01281)
%         Metabolite: "L-Serine" (ID: C00065)
%         Metabolite: "Palmitoyl-CoA" (ID: C00154)
%     Match: "L-Serine:tRNA(Ser) ligase (AMP-forming)" (ID: R03662)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "L-Serine" (ID: C00065)
%         Metabolite: "tRNA(Ser)" (ID: C01650)
%     Match: "L-serine:tRNASec ligase (AMP-forming)" (ID: R08218)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "L-Serine" (ID: C00065)
%         Metabolite: "tRNA(Sec)" (ID: C16636)
%     Match: "L-serine ammonia-lyase" (ID: R00220)
%         Metabolite: "L-Serine" (ID: C00065)
%     Match: "L-serine hydro-lyase (adding hydrogen sulfide, L-cysteine-forming)" (ID: R00891)
%         Metabolite: "L-Serine" (ID: C00065)
%         Metabolite: "Hydrogen sulfide" (ID: C00283)
%     Match: "O3-acetyl-L-serine:hydrogen-sulfide 2-amino-2-carboxyethyltransferase;" (ID: R00897)
%         Metabolite: "Hydrogen sulfide" (ID: C00283)
%         Metabolite: "O-Acetyl-L-serine" (ID: C00979)
%     Match: "L-serine hydro-lyase (adding homocysteine; L-cystathionine-forming)" (ID: R01290)
%         Metabolite: "L-Serine" (ID: C00065)
%         Metabolite: "L-Homocysteine" (ID: C00155)
%     Match: "O3-Acetyl-L-serine acetate-lyase (adding hydrogen sulfide)" (ID: R03601)
%         Metabolite: "Hydrogen selenide" (ID: C01528)
%         Metabolite: "O-Acetyl-L-serine" (ID: C00979)
%     Match: "O3-acetyl-L-serine:thiosulfate 2-amino-2-carboxyethyltransferase (reducing, L-cysteine-forming);" (ID: R04859)
%         Metabolite: "H+" (ID: C00080)
%         Metabolite: "Thioredoxin" (ID: C00342)
%         Metabolite: "Thiosulfate" (ID: C00320)
%         Metabolite: "O-Acetyl-L-serine" (ID: C00979)
%     Match: "L-Serine hydro-lyase (adding homocysteine)" (ID: R04942)
%         Metabolite: "L-Serine" (ID: C00065)
%         Metabolite: "Selenohomocysteine" (ID: C05698)
%     Match: "O-phospho-L-serine:hydrogen-sulfide 2-amino-2-carboxyethyltransferase" (ID: R07274)
%         Metabolite: "O-Phospho-L-serine" (ID: C01005)
%         Metabolite: "Hydrogen sulfide" (ID: C00283)
% Precursor "L-leucine" → 2 matches found
%     Match: "L-Leucine:tRNA(Leu) ligase (AMP-forming)" (ID: R03657)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "L-Leucine" (ID: C00123)
%         Metabolite: "tRNA(Leu)" (ID: C01645)
%     Match: "L-Leucine:2-oxoglutarate aminotransferase" (ID: R01090)
%         Metabolite: "2-Oxoglutarate" (ID: C00026)
%         Metabolite: "L-Leucine" (ID: C00123)
% Precursor "L-isoleucine" → 2 matches found
%     Match: "L-Isoleucine:tRNA(Ile) ligase (AMP-forming)" (ID: R03656)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "L-Isoleucine" (ID: C00407)
%         Metabolite: "tRNA(Ile)" (ID: C01644)
%     Match: "L-Isoleucine:2-oxoglutarate aminotransferase" (ID: R02199)
%         Metabolite: "2-Oxoglutarate" (ID: C00026)
%         Metabolite: "L-Isoleucine" (ID: C00407)
% Precursor "L-valine" → 2 matches found
%     Match: "L-Valine:2-oxoglutarate aminotransferase" (ID: R01214)
%         Metabolite: "2-Oxoglutarate" (ID: C00026)
%         Metabolite: "L-Valine" (ID: C00183)
%     Match: "L-Valine:tRNAVal ligase (AMP-forming)" (ID: R03665)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "L-Valine" (ID: C00183)
%         Metabolite: "tRNA(Val)" (ID: C01653)
% Precursor "L-histidine" → 1 matches found
%     Match: "L-Histidine:tRNA(His) ligase (AMP-forming)" (ID: R03655)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "L-Histidine" (ID: C00135)
%         Metabolite: "tRNA(His)" (ID: C01643)
% Precursor "L-threonine" → 4 matches found
%     Match: "L-threonine acetaldehyde-lyase (glycine-forming)" (ID: R00751)
%         Metabolite: "L-Threonine" (ID: C00188)
%     Match: "L-Threonine:tRNA(Thr) ligase (AMP-forming)" (ID: R03663)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "L-Threonine" (ID: C00188)
%         Metabolite: "tRNA(Thr)" (ID: C01651)
%     Match: "O-Phospho-4-hydroxy-L-threonine:2-oxoglutarate aminotransferase" (ID: R05085)
%         Metabolite: "2-Oxoglutarate" (ID: C00026)
%         Metabolite: "O-Phospho-4-hydroxy-L-threonine" (ID: C06055)
%     Match: "L-threonine ammonia-lyase (2-oxobutanoate-forming)" (ID: R00996)
%         Metabolite: "L-Threonine" (ID: C00188)
% Precursor "L-lysine" → 7 matches found
%     Match: "S-adenosyl-L-methionine:cytochrome-c-L-lysine N6-methyltransferase" (ID: R04866)
%         Metabolite: "S-Adenosyl-L-methionine" (ID: C00019)
%         Metabolite: "Protein N6-methyl-L-lysine" (ID: C05544)
%     Match: "S-adenosyl-L-methionine:cytochrome-c-L-lysine N6-methyltransferase" (ID: R04867)
%         Metabolite: "S-Adenosyl-L-methionine" (ID: C00019)
%         Metabolite: "Protein N6,N6-dimethyl-L-lysine" (ID: C05545)
%     Match: "[lipoyl-carrier protein]-L-lysine:lipoate ligase (AMP-forming)" (ID: R11143)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "[Lipoyl-carrier protein]-L-lysine" (ID: C16240)
%         Metabolite: "(R)-Lipoate" (ID: C16241)
%     Match: "[lipoyl-carrier protein E2]-L-lysine:octanoate ligase (AMP-forming)" (ID: R12429)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "Octanoic acid" (ID: C06423)
%         Metabolite: "Lipoyl-carrier protein E2" (ID: C22158)
%     Match: "[glycine cleavage system H]-L-lysine:(R)-lipoate ligase (AMP-forming)" (ID: R12433)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "(R)-Lipoate" (ID: C16241)
%         Metabolite: "Glycine cleavage system H" (ID: C22157)
%     Match: "[lipoyl-carrier protein E2]-L-lysine:(R)-lipoate ligase (AMP-forming)" (ID: R12449)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "(R)-Lipoate" (ID: C16241)
%         Metabolite: "Lipoyl-carrier protein E2" (ID: C22158)
%     Match: "L-lysine:tRNALys ligase (AMP-forming)" (ID: R03658)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "L-Lysine" (ID: C00047)
%         Metabolite: "tRNA(Lys)" (ID: C01646)
% Precursor "L-phenylalanine" → 3 matches found
%     Match: "L-Phenylalanine:2-oxoglutarate aminotransferase" (ID: R00694)
%         Metabolite: "2-Oxoglutarate" (ID: C00026)
%         Metabolite: "L-Phenylalanine" (ID: C00079)
%     Match: "L-Phenylalanine:tRNA(Ala) ligase (AMP-forming)" (ID: R03660)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "L-Phenylalanine" (ID: C00079)
%         Metabolite: "tRNA(Phe)" (ID: C01648)
%     Match: "3,4-dihydroxy-L-phenylalanine:oxygen 4,5-oxidoreductase (decyclizing)" (ID: R08836)
%         Metabolite: "Oxygen" (ID: C00007)
%         Metabolite: "3,4-Dihydroxy-L-phenylalanine" (ID: C00355)
% Precursor "L-tyrosine" → 2 matches found
%     Match: "L-tyrosine:2-oxoglutarate aminotransferase" (ID: R00734)
%         Metabolite: "2-Oxoglutarate" (ID: C00026)
%         Metabolite: "L-Tyrosine" (ID: C00082)
%     Match: "L-Tyrosine:tRNA(Tyr) ligase (AMP-forming)" (ID: R02918)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "L-Tyrosine" (ID: C00082)
%         Metabolite: "tRNA(Tyr)" (ID: C00787)
% Precursor "L-tryptophan" → 2 matches found
%     Match: "L-Tryptophan -tRNA(Trp) ligase (AMP-forming)" (ID: R03664_EXP_1)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "L-Tryptophan" (ID: C00078)
%         Metabolite: "tRNA(Trp)" (ID: C01652)
%     Match: "L-tryptophan indole-lyase (deaminating; pyruvate-forming)" (ID: R00673)
%         Metabolite: "H2O" (ID: C00001)
%         Metabolite: "L-Tryptophan" (ID: C00078)
% Precursor "L-glutamine" → 3 matches found
%     Match: "L-glutamine:D-fructose-6-phosphate isomerase (deaminating);" (ID: R00768)
%         Metabolite: "L-Glutamine" (ID: C00064)
%         Metabolite: "D-Fructose 6-phosphate" (ID: C00085)
%     Match: "L-Glutamine:tRNA(Gln) ligase (AMP-forming)" (ID: R03652)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "L-Glutamine" (ID: C00064)
%         Metabolite: "tRNA(Gln)" (ID: C01640)
%     Match: "L-glutamine amidohydrolase" (ID: R00256)
%         Metabolite: "H2O" (ID: C00001)
%         Metabolite: "L-Glutamine" (ID: C00064)
% Precursor "L-glutamate" → 7 matches found
%     Match: "L-glutamate:NADP+ oxidoreductase (deaminating)" (ID: R00248)
%         Metabolite: "H2O" (ID: C00001)
%         Metabolite: "NADP+" (ID: C00006)
%         Metabolite: "L-Glutamate" (ID: C00025)
%     Match: "L-Glutamate:ammonia ligase (ADP-forming)" (ID: R00253)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "Ammonia" (ID: C00014)
%         Metabolite: "L-Glutamate" (ID: C00025)
%     Match: "Tetrahydrofolate:L-glutamate gamma-ligase (ADP-forming)" (ID: R00942)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "L-Glutamate" (ID: C00025)
%         Metabolite: "Tetrahydrofolate" (ID: C00101)
%     Match: "7,8-dihydropteroate:L-glutamate ligase (ADP-forming)" (ID: R02237)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "L-Glutamate" (ID: C00025)
%         Metabolite: "Dihydropteroate" (ID: C00921)
%     Match: "L-Glutamate:tRNA(Gln) ligase (AMP-forming)" (ID: R03651)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "L-Glutamate" (ID: C00025)
%         Metabolite: "tRNA(Gln)" (ID: C01640)
%     Match: "L-glutamate:tRNA(Glu) ligase (AMP-forming)" (ID: R05578)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "L-Glutamate" (ID: C00025)
%         Metabolite: "tRNA(Glu)" (ID: C01641)
%     Match: "L-glutamate 1-carboxy-lyase (4-aminobutanoate-forming)" (ID: R00261)
%         Metabolite: "L-Glutamate" (ID: C00025)
% Precursor "L-asparagine" → 3 matches found
%     Match: "L-asparagine amidohydrolase" (ID: R00485)
%         Metabolite: "H2O" (ID: C00001)
%         Metabolite: "L-Asparagine" (ID: C00152)
%     Match: "L-Asparagine:tRNA(Asn) ligase (AMP-forming)" (ID: R03648)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "L-Asparagine" (ID: C00152)
%         Metabolite: "tRNA(Asn)" (ID: C01637)
%     Match: "dolichyl-diphosphooligosaccharide:protein-L-asparagine oligopolysaccharidotransferase" (ID: R04216)
%         Metabolite: "Protein asparagine" (ID: C03021)
%         Metabolite: "Dolichyl diphosphooligosaccharide" (ID: C04213)
% Precursor "L-aspartate" → 4 matches found
%     Match: "L-Aspartate:2-oxoglutarate aminotransferase" (ID: R00355)
%         Metabolite: "2-Oxoglutarate" (ID: C00026)
%         Metabolite: "L-Aspartate" (ID: C00049)
%     Match: "L-aspartate:ammonia ligase (AMP-forming)" (ID: R00483)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "Ammonia" (ID: C00014)
%         Metabolite: "L-Aspartate" (ID: C00049)
%     Match: "L-Aspartate:tRNA(Asp) ligase (AMP-forming)" (ID: R05577)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "L-Aspartate" (ID: C00049)
%         Metabolite: "tRNA(Asp)" (ID: C01638)
%     Match: "L-aspartate 1-carboxy-lyase (beta-alanine-forming)" (ID: R00489)
%         Metabolite: "L-Aspartate" (ID: C00049)
% Precursor "glycine" → 9 matches found
%     Match: "L-threonine acetaldehyde-lyase (glycine-forming)" (ID: R00751)
%         Metabolite: "L-Threonine" (ID: C00188)
%     Match: "L-cysteinylglycine dipeptidase" (ID: R00899)
%         Metabolite: "H2O" (ID: C00001)
%         Metabolite: "Cys-Gly" (ID: C01419)
%     Match: "5,10-Methylenetetrahydrofolate:glycine hydroxymethyltransferase" (ID: R00945)
%         Metabolite: "H2O" (ID: C00001)
%         Metabolite: "Glycine" (ID: C00037)
%         Metabolite: "5,10-Methylenetetrahydrofolate" (ID: C00143)
%     Match: "glycine:NAD+ 2-oxidoreductase (tetrahydrofolate-methylene-adding);" (ID: R01221)
%         Metabolite: "NAD+" (ID: C00003)
%         Metabolite: "Glycine" (ID: C00037)
%         Metabolite: "Tetrahydrofolate" (ID: C00101)
%     Match: "Protein-glycine,dihydroflavodoxin:S-adenosyl-L-methionine oxidoreductase (S-adenosyl-L-methionine cleaving)" (ID: R04710)
%         Metabolite: "S-Adenosyl-L-methionine" (ID: C00019)
%         Metabolite: "Dihydroflavodoxin" (ID: C05196)
%         Metabolite: "Protein glycine" (ID: C05197)
%     Match: "L-allo-threonine acetaldehyde-lyase (glycine-forming)" (ID: R06171)
%         Metabolite: "L-Allothreonine" (ID: C05519)
%     Match: "5,10-methylenetetrahydromethanopterin:glycine hydroxymethyltransferase" (ID: R09099)
%         Metabolite: "L-Serine" (ID: C00065)
%         Metabolite: "5,6,7,8-Tetrahydromethanopterin" (ID: C01217)
%     Match: "[glycine cleavage system H]-L-lysine:(R)-lipoate ligase (AMP-forming)" (ID: R12433)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "(R)-Lipoate" (ID: C16241)
%         Metabolite: "Glycine cleavage system H" (ID: C22157)
%     Match: "glycine:tRNA(Gly) ligase (AMP-forming)" (ID: R03654)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "Glycine" (ID: C00037)
%         Metabolite: "tRNA(Gly)" (ID: C01642)
% Precursor "ATP" → 104 matches found
%     Match: "ATP phosphohydrolase" (ID: R00086)
%         Metabolite: "H2O" (ID: C00001)
%         Metabolite: "ATP" (ID: C00002)
%     Match: "ATP:NAD+ 2'-phosphotransferase" (ID: R00104)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "NAD+" (ID: C00003)
%     Match: "ADP:ATP adenylyltransferase" (ID: R00126)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "ADP" (ID: C00008)
%     Match: "ATP:AMP phosphotransferase" (ID: R00127)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "AMP" (ID: C00020)
%     Match: "ATP:dephospho-CoA 3'-phosphotransferase" (ID: R00130)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "Dephospho-CoA" (ID: C00882)
%     Match: "ATP:nicotinamide-nucleotide adenylyltransferase" (ID: R00137_EXP_1)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "Nicotinamide D-ribonucleotide" (ID: C00455)
%     Match: "ATP:2'-deoxy-5-hydroxymethylcytidine-5'-diphosphate phosphotransferase" (ID: R00139)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "2'-Deoxy-5-hydroxymethylcytidine-5'-diphosphate" (ID: C11038)
%     Match: "ATP:UDP phosphotransferase" (ID: R00156)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "UDP" (ID: C00015)
%     Match: "ATP:UMP phosphotransferase" (ID: R00158)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "UMP" (ID: C00105)
%     Match: "ATP:FMN adenylyltransferase" (ID: R00161)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "FMN" (ID: C00061)
%     Match: "ATP:pyridoxal 5'-phosphotransferase" (ID: R00174)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "Pyridoxal" (ID: C00250)
%     Match: "ATP:L-methionine S-adenosyltransferase" (ID: R00177)
%         Metabolite: "Orthophosphate" (ID: C00009)
%         Metabolite: "Diphosphate" (ID: C00013)
%         Metabolite: "S-Adenosyl-L-methionine" (ID: C00019)
%     Match: "ATP:D-glucose 6-phosphotransferase" (ID: R00299)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "D-Glucose" (ID: C00031)
%     Match: "ATP:acetate adenylyltransferase" (ID: R00316)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "Acetate" (ID: C00033)
%     Match: "ATP:GDP phosphotransferase" (ID: R00330)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "GDP" (ID: C00035)
%     Match: "ATP:GMP phosphotransferase" (ID: R00332)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "GMP" (ID: C00144)
%     Match: "ATP:CMP phosphotransferase" (ID: R00512)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "CMP" (ID: C00055)
%     Match: "ATP:riboflavin 5'-phosphotransferase" (ID: R00549)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "Riboflavin" (ID: C00255)
%     Match: "ATP:CDP phosphotransferase" (ID: R00570)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "CDP" (ID: C00112)
%     Match: "ATP:thiamine diphosphotransferase" (ID: R00619)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "Thiamine" (ID: C00378)
%     Match: "ATP:IDP phosphotransferase" (ID: R00722)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "IDP" (ID: C00104)
%     Match: "ATP:D-fructose-6-phosphate 1-phosphotransferase" (ID: R00756)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "D-Fructose 6-phosphate" (ID: C00085)
%     Match: "ATP:D-fructose 6-phosphotransferase" (ID: R00760)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "D-Fructose" (ID: C00095)
%     Match: "ATP:glycerol 3-phosphotransferase" (ID: R00847)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "Glycerol" (ID: C00116)
%     Match: "ATP:D-fructose 6-phosphotransferase" (ID: R00867)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "D-Fructose" (ID: C00095)
%     Match: "ATP:D-ribose-5-phosphate diphosphotransferase" (ID: R01049)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "D-Ribose 5-phosphate" (ID: C00117)
%     Match: "ATP:D-ribose 5-phosphotransferase" (ID: R01051)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "D-Ribose" (ID: C00121)
%     Match: "ATP:(R)-5-diphosphomevalonate carboxy-lyase (adding ATP; isopentenyl-diphosphate-forming);" (ID: R01121)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "(R)-5-Diphosphomevalonate" (ID: C01143)
%     Match: "ATP:dADP phosphotransferase" (ID: R01137)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "dADP" (ID: C00206)
%     Match: "ATP:propanoate adenylyltransferase" (ID: R01354)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "Propanoate" (ID: C00163)
%     Match: "ATP:ethanolamine O-phosphotransferase" (ID: R01468)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "Ethanolamine" (ID: C00189)
%     Match: "ATP:cob(I)alamin Co-beta-adenosyltransferase" (ID: R01492)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "Cob(I)alamin" (ID: C00853)
%     Match: "ATP:3-phospho-D-glycerate 1-phosphotransferase" (ID: R01512)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "3-Phospho-D-glycerate" (ID: C00197)
%     Match: "ATP:dAMP phosphotransferase" (ID: R01547)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "dAMP" (ID: C00360)
%     Match: "ATP:thymidine 5'-phosphotransferase" (ID: R01567)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "Thymidine" (ID: C00214)
%     Match: "ATP:beta-D-glucose 6-phosphotransferase" (ID: R01600)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "beta-D-Glucose" (ID: C00221)
%     Match: "APS:ATP adenylyltransferase" (ID: R01618)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "Adenylyl sulfate" (ID: C00224)
%     Match: "ATP:dCMP phosphotransferase" (ID: R01665)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "dCMP" (ID: C00239)
%     Match: "ATP:D-gluconate 6-phosphotransferase" (ID: R01737)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "D-Gluconic acid" (ID: C00257)
%     Match: "ATP:alpha-D-glucose 6-phosphotransferase" (ID: R01786)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "alpha-D-Glucose" (ID: C00267)
%     Match: "ATP:sedoheptulose 7-phosphate" (ID: R01844)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "Sedoheptulose" (ID: C02076)
%     Match: "ATP:dGDP phosphotransferase" (ID: R01857)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "dGDP" (ID: C00361)
%     Match: "ATP:pyridoxine 5'-phosphotransferase" (ID: R01909)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "Pyridoxine" (ID: C00314)
%     Match: "ATP:dGMP phosphotransferase" (ID: R02090)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "dGMP" (ID: C00362)
%     Match: "ATP:dTDP phosphotransferase" (ID: R02093)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "dTDP" (ID: C00363)
%     Match: "ATP:dTMP phosphotransferase" (ID: R02094_EXP_1)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "dTMP" (ID: C00364)
%     Match: "ATP:dUMP phosphotransferase" (ID: R02098_EXP_1)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "dUMP" (ID: C00365)
%     Match: "ATP:deoxyuridine 5'-phosphotransferase" (ID: R02099)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "Deoxyuridine" (ID: C00526)
%     Match: "ATP:1,2-diacylglycerol 3-phosphotransferase" (ID: R02240)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "1,2-Diacyl-sn-glycerol" (ID: C00641)
%     Match: "ATP:(R)-mevalonate 5-phosphotransferase" (ID: R02245)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "(R)-Mevalonate" (ID: C00418)
%     Match: "ATP:N-ribosylnicotinamide 5'-phosphotransferase" (ID: R02324)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "Nicotinamide-beta-riboside" (ID: C03150)
%     Match: "ATP:dCDP phosphotransferase" (ID: R02326)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "dCDP" (ID: C00705)
%     Match: "ATP:dUDP phosphotransferase" (ID: R02331)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "dUDP" (ID: C01346)
%     Match: "ATP:pyridoxal 5'-phosphotransferase" (ID: R02493)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "Pyridoxamine" (ID: C00534)
%     Match: "ATP:2-deoxy-D-ribose 5-phosphotransferase" (ID: R02750)
%         Metabolite: "ADP" (ID: C00008)
%         Metabolite: "2-Deoxy-D-ribose 5-phosphate" (ID: C00673)
%     Match: "ATP:pantothenate 4'-phosphotransferase" (ID: R02971)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "Pantetheine" (ID: C00831)
%     Match: "ATP:nicotinamide-nucleotide adenylyltransferase" (ID: R03005_EXP_1)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "Nicotinate D-ribonucleotide" (ID: C01185)
%     Match: "ATP:pantothenate 4'-phosphotransferase" (ID: R03018)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "Pantothenate" (ID: C00864)
%     Match: "ATP:pantetheine-4'-phosphate adenylyltransferase" (ID: R03035)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "Pantetheine 4'-phosphate" (ID: C01134)
%     Match: "ATP:D-tagatose-6-phosphate 1-phosphotransferase" (ID: R03236)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "D-Tagatose 6-phosphate" (ID: C01097)
%     Match: "ATP:(R)-5-phosphomevalonate phosphotransferase" (ID: R03245)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "(R)-5-Phosphomevalonate" (ID: C01107)
%     Match: "ATP:beta-D-ribosylnicotinate 5-phosphotransferase" (ID: R03347)
%         Metabolite: "ADP" (ID: C00008)
%         Metabolite: "Nicotinate D-ribonucleotide" (ID: C01185)
%     Match: "ATP:1-Phosphatidyl-1D-myo-inositol 4-phosphotransferase" (ID: R03361)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "1-Phosphatidyl-D-myo-inositol" (ID: C01194)
%     Match: "ATP:1-phosphatidyl-1D-myo-inositol 3-phosphotransferase" (ID: R03362)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "1-Phosphatidyl-D-myo-inositol" (ID: C01194)
%     Match: "ATP:1D-myo-inositol-1,3,4-trisphosphate 5-phosphotransferase" (ID: R03428)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "1D-myo-Inositol 1,3,4-trisphosphate" (ID: C01243)
%     Match: "ATP:1D-myo-inositol-1,3,4-trisphosphate 6-phosphotransferase" (ID: R03429)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "1D-myo-Inositol 1,3,4-trisphosphate" (ID: C01243)
%     Match: "ATP:1-phosphatidyl-1D-myo-inositol-4-phosphate 5-phosphotransferase" (ID: R03469)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "1-Phosphatidyl-1D-myo-inositol 4-phosphate" (ID: C01277)
%     Match: "ATP:1D-myo-inositol-1,3,4,6-tetrakisphosphate 5-phosphotransferase" (ID: R03478)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "1D-myo-Inositol 1,3,4,6-tetrakisphosphate" (ID: C04477)
%     Match: "ATP:1D-myo-inositol-3,4,5,6-tetrakisphosphate 1-phosphotransferase" (ID: R03479)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "1D-myo-Inositol 3,4,5,6-tetrakisphosphate" (ID: C04520)
%     Match: "ATP:dIDP phosphotransferase" (ID: R03530)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "dIDP" (ID: C01344)
%     Match: "ATP:D-fructose 6-phosphotransferase" (ID: R03920)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "beta-D-Fructose" (ID: C02336)
%     Match: "ATP:pantothenate 4'-phosphotransferase" (ID: R04391)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "N-((R)-Pantothenoyl)-L-cysteine" (ID: C04079)
%     Match: "ATP:1-phosphatidyl-1D-myo-inositol-4,5-bisphosphate 3-phosphotransferase" (ID: R04545)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "1-Phosphatidyl-D-myo-inositol 4,5-bisphosphate" (ID: C04637)
%     Match: "ATP:L-selenomethione S-adenosyltransferase" (ID: R04771)
%         Metabolite: "H2O" (ID: C00001)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "L-Selenomethionine" (ID: C05335)
%     Match: "ATP:D-fructose-6-phosphate 1-phosphotransferase" (ID: R04779)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "beta-D-Fructose 6-phosphate" (ID: C05345)
%     Match: "ATP:1D-myo-inositol 1,3,4,5,6-pentakisphosphate 2-phosphotransferase" (ID: R05202)
%         Metabolite: "ADP" (ID: C00008)
%         Metabolite: "Phytic acid" (ID: C01204)
%     Match: "ATP:cob(I)yrinic acid-a,c-diamide Cobeta-adenosyltransferase" (ID: R05220)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "Cob(I)yrinate a,c diamide" (ID: C06505)
%     Match: "ATP:1D-myo-inositol-1,4,5-trisphosphate 6-phosphotransferase" (ID: R05800)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "D-myo-Inositol 1,4,5-trisphosphate" (ID: C01245)
%     Match: "ATP:1D-myo-inositol-1,4,5,6-tetrakisphosphate 3-phosphotransferase" (ID: R05801)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "1D-myo-Inositol 1,4,5,6-tetrakisphosphate" (ID: C11555)
%     Match: "ATP:1-phosphatidyl-1D-myo-inositol-3-phosphate 5-phosphotransferase" (ID: R05802)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "1-Phosphatidyl-1D-myo-inositol 3-phosphate" (ID: C04549)
%     Match: "ATP:cobinamide Cobeta-adenosyltransferase" (ID: R07268)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "Cobinamide" (ID: C05774)
%     Match: "ATP:5-fluorodeoxyuridine 5'-phosphotransferase" (ID: R08233)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "5-Fluorodeoxyuridine" (ID: C11736)
%     Match: "ATP:N-acetyl-D-galactosamine 1-phosphotransferase" (ID: R08967)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "N-Acetyl-D-galactosamine" (ID: C01132)
%     Match: "ATP:1D-myo-inositol-hexakisphosphate 5-phosphotransferase" (ID: R09087)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "Phytic acid" (ID: C01204)
%     Match: "CTP,CTP,ATP:tRNA cytidylyl,cytidylyl,adenylyltransferase" (ID: R09382)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "CTP" (ID: C00063)
%         Metabolite: "tRNA precursor" (ID: C02211)
%     Match: "ATP:tRNA adenylyltransferase" (ID: R09386)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "tRNA with a 3' CC end" (ID: C19080)
%     Match: "ATP:1D-myo-inositol-1,4,5-trisphosphate 3,6-phosphotransferase" (ID: R10065)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "D-myo-Inositol 1,4,5-trisphosphate" (ID: C01245)
%     Match: "ATP:L-threonyl,bicarbonate adenylyltransferase" (ID: R10463)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "H+" (ID: C00080)
%         Metabolite: "L-Threonine" (ID: C00188)
%         Metabolite: "HCO3-" (ID: C00288)
%     Match: "ATP:1D-myo-inositol 1-diphosphate 2,3,4,5,6-pentakisphosphate 5-phosphotransferase" (ID: R10548)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "1-Diphosinositol pentakisphosphate" (ID: C11174)
%     Match: "ATP:1-phosphatidyl-1D-myo-inositol 5-phosphotransferase" (ID: R10951)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "1-Phosphatidyl-D-myo-inositol" (ID: C01194)
%     Match: "ATP:1D-myo-inositol-1,3,4,5-tetrakisphosphate 6-phosphotransferase" (ID: R10953)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "1D-myo-Inositol 1,3,4,5-tetrakisphosphate" (ID: C01272)
%     Match: "ATP:5-fluorouridine-monophosphate phosphotransferase" (ID: R11891)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "5-Fluorouridine monophosphate" (ID: C16634)
%     Match: "ATP:5-fluorodeoxyuridine-monophosphate phosphotransferase" (ID: R11892)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "5-Fluorodeoxyuridine monophosphate" (ID: C04242)
%     Match: "ATP:5-fluorouridine-diphosphate phosphotransferase" (ID: R11894)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "5-Fluorouridine diphosphate" (ID: C21748)
%     Match: "ATP:5-fluorodeoxyuridine-diphosphate phosphotransferase" (ID: R11895)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "5-Fluorodeoxyuridine diphosphate" (ID: C21750)
%     Match: "ATP:Cob(II)yrinate diamide Cobeta-adenosyltransferase" (ID: R12184)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "[Reduced NADPH---hemoprotein reductase]" (ID: C03024)
%         Metabolite: "Cob(II)yrinate a,c diamide" (ID: C06504)
%     Match: "ATP diphosphate-lyase (cyclizing; 3',5'-cyclic-AMP-forming)" (ID: R00089)
%         Metabolite: "ATP" (ID: C00002)
%     Match: "ATP:pyruvate 2-O-phosphotransferase" (ID: R00200)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "Pyruvate" (ID: C00022)
%     Match: "ATP:pyruvate,phosphate phosphotransferase" (ID: R00206)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "Orthophosphate" (ID: C00009)
%         Metabolite: "Pyruvate" (ID: C00022)
%     Match: "ATP:alpha-D-galactose 1-phosphotransferase" (ID: R01092)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "alpha-D-Galactose" (ID: C00984)
%     Match: "dATP:pyruvate 2-O-phosphotransferase" (ID: R01138)
%         Metabolite: "Pyruvate" (ID: C00022)
%         Metabolite: "dATP" (ID: C00131)
%     Match: "ATP:D-xylulose 5-phosphotransferase" (ID: R01639)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "D-Xylulose" (ID: C00310)
%     Match: "ATP:[sulfur-carrier protein] adenylyltransferase" (ID: R07459)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "Sulfur-carrier protein" (ID: C15810)
%     Match: "ATP:(R)-glycerate 2-phosphotransferase" (ID: R08572)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "D-Glycerate" (ID: C00258)
% Precursor "GTP" → 7 matches found
%     Match: "GTP phosphohydrolase" (ID: R00335)
%         Metabolite: "H2O" (ID: C00001)
%         Metabolite: "GTP" (ID: C00044)
%     Match: "GTP diphosphate-lyase (cyclizing; 3',5'-cyclic-GMP-forming)" (ID: R00434)
%         Metabolite: "GTP" (ID: C00044)
%     Match: "GTP:alpha-D-mannose-1-phosphate guanylyltransferase" (ID: R00885)
%         Metabolite: "GTP" (ID: C00044)
%         Metabolite: "D-Mannose 1-phosphate" (ID: C00636)
%     Match: "GTP:mRNA guanylyltransferase" (ID: R03828)
%         Metabolite: "GTP" (ID: C00044)
%         Metabolite: "(5')ppPur-mRNA" (ID: C02100)
%     Match: "GTP:pyruvate 2-O-phosphotransferase" (ID: R00430)
%         Metabolite: "Pyruvate" (ID: C00022)
%         Metabolite: "GTP" (ID: C00044)
%     Match: "GTP:oxaloacetate carboxy-lyase (adding GTP;phosphoenolpyruvate-forming);" (ID: R00431)
%         Metabolite: "Oxaloacetate" (ID: C00036)
%         Metabolite: "GTP" (ID: C00044)
%     Match: "dGTP:pyruvate 2-O-phosphotransferase" (ID: R01858)
%         Metabolite: "Pyruvate" (ID: C00022)
%         Metabolite: "dGTP" (ID: C00286)
% Precursor "CTP" → 10 matches found
%     Match: "CTP phosphohydrolase" (ID: R00569)
%         Metabolite: "H2O" (ID: C00001)
%         Metabolite: "CTP" (ID: C00063)
%     Match: "CTP:dolichol O-phosphotransferase" (ID: R01018)
%         Metabolite: "CTP" (ID: C00063)
%         Metabolite: "Dolichol" (ID: C00381)
%     Match: "CTP:phosphatidate cytidyltransferase" (ID: R01799)
%         Metabolite: "CTP" (ID: C00063)
%         Metabolite: "Phosphatidate" (ID: C00416)
%     Match: "CTP:ethanolamine-phosphate cytidylyltransferase" (ID: R02038)
%         Metabolite: "CTP" (ID: C00063)
%         Metabolite: "Ethanolamine phosphate" (ID: C00346)
%     Match: "CTP:ethanolamine-phosphate cytidylyltransferase" (ID: R04247)
%         Metabolite: "CTP" (ID: C00063)
%         Metabolite: "2-Aminoethylphosphonate" (ID: C03557)
%     Match: "CTP,CTP,ATP:tRNA cytidylyl,cytidylyl,adenylyltransferase" (ID: R09382)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "CTP" (ID: C00063)
%         Metabolite: "tRNA precursor" (ID: C02211)
%     Match: "CTP:tRNA cytidylyltransferase" (ID: R09383)
%         Metabolite: "CTP" (ID: C00063)
%         Metabolite: "tRNA precursor" (ID: C02211)
%     Match: "CTP:tRNA cytidylyltransferase" (ID: R09384)
%         Metabolite: "CTP" (ID: C00063)
%         Metabolite: "tRNA with a 3' cytidine" (ID: C19078)
%     Match: "CTP diphosphohydrolase (diphosphate-forming);" (ID: R00515)
%         Metabolite: "H2O" (ID: C00001)
%         Metabolite: "CTP" (ID: C00063)
%     Match: "CTP:D-tagatose 6-phosphate 1-phosphotransferase" (ID: R03237)
%         Metabolite: "CTP" (ID: C00063)
%         Metabolite: "D-Tagatose 6-phosphate" (ID: C01097)
% Precursor "UTP" → 6 matches found
%     Match: "UTP phosphohydrolase" (ID: R00159)
%         Metabolite: "H2O" (ID: C00001)
%         Metabolite: "UTP" (ID: C00075)
%     Match: "UTP:alpha-D-glucose-1-phosphate uridylyltransferase" (ID: R00289)
%         Metabolite: "UTP" (ID: C00075)
%         Metabolite: "D-Glucose 1-phosphate" (ID: C00103)
%     Match: "UTP:N-acetyl-alpha-D-glucosamine-1-phosphate uridylyltransferase" (ID: R00416)
%         Metabolite: "UTP" (ID: C00075)
%         Metabolite: "N-Acetyl-alpha-D-glucosamine 1-phosphate" (ID: C04501)
%     Match: "dUTP nucleotidohydrolase" (ID: R02100)
%         Metabolite: "H2O" (ID: C00001)
%         Metabolite: "dUTP" (ID: C00460)
%     Match: "UTP:N-acetyl-alpha-D-galactosamine-1-phosphate uridylyltransferase" (ID: R10183)
%         Metabolite: "UTP" (ID: C00075)
%         Metabolite: "N-Acetyl-alpha-D-galactosamine 1-phosphate" (ID: C18060)
%     Match: "UTP:D-tagatose 6-phosphate 1-phosphotransferase" (ID: R03238)
%         Metabolite: "UTP" (ID: C00075)
%         Metabolite: "D-Tagatose 6-phosphate" (ID: C01097)
% Precursor "NAD" → 158 matches found
%     Match: "ATP:NAD+ 2'-phosphotransferase" (ID: R00104)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "NAD+" (ID: C00003)
%     Match: "pyruvate:NAD+ 2-oxidoreductase (CoA-acetylating);" (ID: R00209)
%         Metabolite: "NAD+" (ID: C00003)
%         Metabolite: "CoA" (ID: C00010)
%         Metabolite: "Pyruvate" (ID: C00022)
%     Match: "(S)-Malate:NADP+ oxidoreductase(oxaloacetate-decarboxylating)" (ID: R00216)
%         Metabolite: "NADP+" (ID: C00006)
%         Metabolite: "(S)-Malate" (ID: C00149)
%     Match: "L-glutamate:NADP+ oxidoreductase (deaminating)" (ID: R00248)
%         Metabolite: "H2O" (ID: C00001)
%         Metabolite: "NADP+" (ID: C00006)
%         Metabolite: "L-Glutamate" (ID: C00025)
%     Match: "2,5-dioxopentanoate:NADP+ 5-oxidoreductase" (ID: R00264)
%         Metabolite: "H2O" (ID: C00001)
%         Metabolite: "NADP+" (ID: C00006)
%         Metabolite: "2,5-Dioxopentanoate" (ID: C00433)
%     Match: "UDP-glucose:NAD+ 6-oxidoreductase" (ID: R00286)
%         Metabolite: "H2O" (ID: C00001)
%         Metabolite: "NAD+" (ID: C00003)
%         Metabolite: "UDP-glucose" (ID: C00029)
%     Match: "(S)-malate:NAD+ oxidoreductase" (ID: R00342)
%         Metabolite: "NAD+" (ID: C00003)
%         Metabolite: "(S)-Malate" (ID: C00149)
%     Match: "Acetaldehyde:NAD+ oxidoreductase" (ID: R00710)
%         Metabolite: "H2O" (ID: C00001)
%         Metabolite: "NAD+" (ID: C00003)
%         Metabolite: "Acetaldehyde" (ID: C00084)
%     Match: "Ethanol:NADP+ oxidoreductase" (ID: R00746)
%         Metabolite: "NADP+" (ID: C00006)
%         Metabolite: "Ethanol" (ID: C00469)
%     Match: "sn-Glycerol-3-phosphate:NAD+ 2-oxidoreductase" (ID: R00842)
%         Metabolite: "NAD+" (ID: C00003)
%         Metabolite: "sn-Glycerol 3-phosphate" (ID: C00093)
%     Match: "3-aminopropanal:NAD+ oxidoreductase" (ID: R00904)
%         Metabolite: "H2O" (ID: C00001)
%         Metabolite: "NAD+" (ID: C00003)
%         Metabolite: "3-Aminopropanal" (ID: C05665)
%     Match: "5,6-Dihydrouracil:NADP+ oxidoreductase" (ID: R00978)
%         Metabolite: "NADP+" (ID: C00006)
%         Metabolite: "5,6-Dihydrouracil" (ID: C00429)
%     Match: "Glycerol:NAD+ oxidoreductase" (ID: R01036)
%         Metabolite: "NAD+" (ID: C00003)
%         Metabolite: "Glycerol" (ID: C00116)
%     Match: "glycerol:NADP+ oxidoreductase" (ID: R01041)
%         Metabolite: "NADP+" (ID: C00006)
%         Metabolite: "Glycerol" (ID: C00116)
%     Match: "galactitol:NAD+ 1-oxidoreductase" (ID: R01093)
%         Metabolite: "NADH" (ID: C00004)
%         Metabolite: "H+" (ID: C00080)
%         Metabolite: "D-Galactose" (ID: C00124)
%     Match: "galactitol:NADP+ 1-oxidoreductase" (ID: R01095)
%         Metabolite: "NADPH" (ID: C00005)
%         Metabolite: "H+" (ID: C00080)
%         Metabolite: "D-Galactose" (ID: C00124)
%     Match: "glycine:NAD+ 2-oxidoreductase (tetrahydrofolate-methylene-adding);" (ID: R01221)
%         Metabolite: "NAD+" (ID: C00003)
%         Metabolite: "Glycine" (ID: C00037)
%         Metabolite: "Tetrahydrofolate" (ID: C00101)
%     Match: "acyl-[acyl-carrier-protein]:NAD+ oxidoreductase" (ID: R01403)
%         Metabolite: "NAD+" (ID: C00003)
%         Metabolite: "Acyl-[acyl-carrier protein]" (ID: C00173)
%     Match: "5,6-Dihydrothymine:NADP+ oxidoreductase" (ID: R01415)
%         Metabolite: "NADP+" (ID: C00006)
%         Metabolite: "(R)-5,6-Dihydrothymine" (ID: C21028)
%     Match: "xylitol:NADP+ oxidoreductase" (ID: R01431)
%         Metabolite: "NADP+" (ID: C00006)
%         Metabolite: "Xylitol" (ID: C00379)
%     Match: "L-gulonate:NADP+ 6-oxidoreductase" (ID: R01481)
%         Metabolite: "NADP+" (ID: C00006)
%         Metabolite: "L-Gulonate" (ID: C00800)
%     Match: "3-Phospho-D-glycerate:NAD+ 2-oxidoreductase" (ID: R01513)
%         Metabolite: "NAD+" (ID: C00003)
%         Metabolite: "3-Phospho-D-glycerate" (ID: C00197)
%     Match: "6-phospho-D-gluconate:NADP+ 2-oxidoreductase (decarboxylating)" (ID: R01528)
%         Metabolite: "NADP+" (ID: C00006)
% ...
%         Metabolite: "L-Allothreonine" (ID: C05519)
%     Match: "6-(1'-hydroxy-2'-oxopropyl)-tetrahydropterin:NADP+ oxidoreductase" (ID: R11763)
%         Metabolite: "NADP+" (ID: C00006)
%         Metabolite: "6-(1'-Hydroxy-2'-oxopropyl)-tetrahydropterin" (ID: C21640)
% Precursor "FAD" → no matches found
% Precursor "CoA" → 33 matches found
%     Match: "ATP:dephospho-CoA 3'-phosphotransferase" (ID: R00130)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "Dephospho-CoA" (ID: C00882)
%     Match: "pyruvate:NAD+ 2-oxidoreductase (CoA-acetylating);" (ID: R00209)
%         Metabolite: "NAD+" (ID: C00003)
%         Metabolite: "CoA" (ID: C00010)
%         Metabolite: "Pyruvate" (ID: C00022)
%     Match: "Acetyl-CoA hydrolase" (ID: R00227)
%         Metabolite: "H2O" (ID: C00001)
%         Metabolite: "Acetyl-CoA" (ID: C00024)
%     Match: "Acetate:CoA ligase (AMP-forming)" (ID: R00235)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "CoA" (ID: C00010)
%         Metabolite: "Acetate" (ID: C00033)
%     Match: "acetyl adenylate:CoA acetyltransferase" (ID: R00236)
%         Metabolite: "CoA" (ID: C00010)
%         Metabolite: "Acetyl adenylate" (ID: C05993)
%     Match: "acetyl-CoA:acetyl-CoA C-acetyltransferase" (ID: R00238)
%         Metabolite: "Acetyl-CoA" (ID: C00024)
%     Match: "Succinate:CoA ligase (GDP-forming)" (ID: R00432)
%         Metabolite: "CoA" (ID: C00010)
%         Metabolite: "Succinate" (ID: C00042)
%         Metabolite: "GTP" (ID: C00044)
%     Match: "Succinate:CoA ligase (IDP-forming)" (ID: R00727)
%         Metabolite: "CoA" (ID: C00010)
%         Metabolite: "Succinate" (ID: C00042)
%         Metabolite: "ITP" (ID: C00081)
%     Match: "Propanoate:CoA ligase (AMP-forming)" (ID: R00925)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "CoA" (ID: C00010)
%         Metabolite: "Propanoate" (ID: C00163)
%     Match: "Propionyladenylate:CoA propionyltransferase" (ID: R00926)
%         Metabolite: "CoA" (ID: C00010)
%         Metabolite: "Propionyladenylate" (ID: C05983)
%     Match: "butanoyl-CoA:acetyl-CoA C-butanoyltransferase" (ID: R01177)
%         Metabolite: "Acetyl-CoA" (ID: C00024)
%         Metabolite: "Butanoyl-CoA" (ID: C00136)
%     Match: "Palmitate:CoA ligase (AMP-forming)" (ID: R01280)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "CoA" (ID: C00010)
%         Metabolite: "Hexadecanoic acid" (ID: C00249)
%     Match: "Palmitoyl-CoA:L-serine C-palmitoyltransferase (decarboxylating)" (ID: R01281)
%         Metabolite: "L-Serine" (ID: C00065)
%         Metabolite: "Palmitoyl-CoA" (ID: C00154)
%     Match: "Acyl-CoA:1-acyl-sn-glycero-3-phosphocholine O-acyltransferase" (ID: R01318_EXP_1)
%         Metabolite: "Acyl-CoA" (ID: C00040)
%         Metabolite: "1-Acyl-sn-glycero-3-phosphocholine" (ID: C04230)
%     Match: "(S)-3-Hydroxybutanoyl-CoA:NADP+ oxidoreductase" (ID: R01976)
%         Metabolite: "NADP+" (ID: C00006)
%         Metabolite: "(S)-3-Hydroxybutanoyl-CoA" (ID: C01144)
%     Match: "acetyl-CoA:acetoacetyl-CoA C-acetyltransferase (thioester-hydrolysing, carboxymethyl-forming)" (ID: R01978)
%         Metabolite: "CoA" (ID: C00010)
%         Metabolite: "(S)-3-Hydroxy-3-methylglutaryl-CoA" (ID: C00356)
%     Match: "acyl-CoA:1-acyl-sn-glycerol-3-phosphate 2-O-acyltransferase" (ID: R02241_EXP_1)
%         Metabolite: "CoA" (ID: C00010)
%         Metabolite: "Phosphatidate" (ID: C00416)
%     Match: "Methylmalonyl-CoA epimerase" (ID: R02765)
%         Metabolite: "(R)-Methylmalonyl-CoA" (ID: C01213)
%     Match: "Acetyl-CoA:1-alkyl-sn-glycero-3-phosphocholine 2-O-acetyltransferase" (ID: R03437_EXP_1)
%         Metabolite: "Acetyl-CoA" (ID: C00024)
%         Metabolite: "1-Organyl-2-lyso-sn-glycero-3-phosphocholine" (ID: C04317)
%     Match: "Acyl-CoA:1-alkyl-sn-glycero-3-phosphocholine O-acyltransferase" (ID: R03438)
%         Metabolite: "Acyl-CoA" (ID: C00040)
%         Metabolite: "1-Organyl-2-lyso-sn-glycero-3-phosphocholine" (ID: C04317)
%     Match: "Acyl-CoA:1-acyl-sn-glycero-3-phosphoethanolamine O-acyltransferase" (ID: R04480_EXP_1)
%         Metabolite: "Acyl-CoA" (ID: C00040)
%         Metabolite: "1-Acyl-sn-glycero-3-phosphoethanolamine" (ID: C04438)
%     Match: "(S)-3-Hydroxybutanoyl-CoA:NADP+ oxidoreductase" (ID: R05576)
%         Metabolite: "NADP+" (ID: C00006)
%         Metabolite: "3-Hydroxybutanoyl-CoA" (ID: C05116)
%     Match: "(S)-3-hydroxyacyl-CoA:NAD+ oxidoreductase" (ID: R06941)
%         Metabolite: "NAD+" (ID: C00003)
%         Metabolite: "(3S)-3-Hydroxyadipyl-CoA" (ID: C14145)
%     Match: "octadecanoyl-CoA:NADP+ trans-2-oxidoreductase" (ID: R07761)
%         Metabolite: "NADPH" (ID: C00005)
%         Metabolite: "H+" (ID: C00080)
%         Metabolite: "(2E)-Octadecenoyl-CoA" (ID: C16218)
%     Match: "2-oxoglutarate:NAD+ 2-oxidoreductase (CoA-succinylating);" (ID: R08549)
%         Metabolite: "NAD+" (ID: C00003)
%         Metabolite: "CoA" (ID: C00010)
%         Metabolite: "2-Oxoglutarate" (ID: C00026)
%     Match: "acyl-CoA:1-acyl-sn-glycero-3-phosphoinositol O-acyltransferase" (ID: R09034)
%         Metabolite: "Acyl-CoA" (ID: C00040)
%         Metabolite: "1-Acylglycerophosphoinositol" (ID: C03819)
%     Match: "acyl-CoA:1-acyl-sn-glycero-3-phosphoserine O-acyltransferase" (ID: R09035_EXP_1)
%         Metabolite: "Acyl-CoA" (ID: C00040)
%         Metabolite: "1-Acyl-sn-glycero-3-phosphoserine" (ID: C18125)
%     Match: "acyl-CoA:1-acyl-sn-glycero-3-phosphoglycerol O-acyltransferase" (ID: R09036_EXP_1)
%         Metabolite: "Acyl-CoA" (ID: C00040)
%         Metabolite: "1-Acyl-sn-glycero-3-phosphoglycerol" (ID: C18126)
%     Match: "very-long-chain acyl-CoA:NADP+ oxidoreductase" (ID: R09449)
%         Metabolite: "NADPH" (ID: C00005)
%         Metabolite: "H+" (ID: C00080)
%         Metabolite: "trans-2,3-Dehydroacyl-CoA" (ID: C00658)
%     Match: "(2S)-ethylmalonyl-CoA epimerase" (ID: R09979)
%         Metabolite: "(2S)-Ethylmalonyl-CoA" (ID: C18026)
%     Match: "very-long-chain acyl-CoA:NADP+ oxidoreductase" (ID: R10828)
%         Metabolite: "NADP+" (ID: C00006)
%         Metabolite: "Very-long-chain acyl-CoA" (ID: C20876)
%     Match: "acetaldehyde:NAD+ oxidoreductase (CoA-acetylating)" (ID: R00228)
%         Metabolite: "NAD+" (ID: C00003)
%         Metabolite: "CoA" (ID: C00010)
%         Metabolite: "Acetaldehyde" (ID: C00084)
%     Match: "butanal:NAD+ oxidoreductase (CoA-acylating)" (ID: R01172)
%         Metabolite: "NAD+" (ID: C00003)
%         Metabolite: "CoA" (ID: C00010)
%         Metabolite: "Butanal" (ID: C01412)
% Precursor "cholesterol" → no matches found
% Precursor "ergosterol" → no matches found
% Precursor "sterol" → no matches found
% Precursor "phosphatidylcholine" → 4 matches found
%     Match: "ceramide:phosphatidylcholine cholinephosphotransferase" (ID: R08969)
%         Metabolite: "Phosphatidylcholine" (ID: C00157)
%         Metabolite: "N-Acylsphingosine" (ID: C00195)
%     Match: "phosphatidylcholine 2-acylhydrolase" (ID: R01315)
%         Metabolite: "H2O" (ID: C00001)
%         Metabolite: "Phosphatidylcholine" (ID: C00157)
%     Match: "phosphatidylcholine 2-acylhydrolase" (ID: R01317)
%         Metabolite: "H2O" (ID: C00001)
%         Metabolite: "Phosphatidylcholine" (ID: C00157)
%     Match: "phosphatidylcholine 2-acylhydrolase" (ID: R07064)
%         Metabolite: "H2O" (ID: C00001)
%         Metabolite: "Phosphatidylcholine" (ID: C00157)
% Precursor "phosphatidylethanolamine" → 2 matches found
%     Match: "S-adenosyl-L-methionine:phosphatidylethanolamine N-methyltransferase" (ID: R02056)
%         Metabolite: "S-Adenosyl-L-methionine" (ID: C00019)
%         Metabolite: "Phosphatidylethanolamine" (ID: C00350)
%     Match: "phosphatidylethanolamine 2-acylhydrolase" (ID: R02053)
%         Metabolite: "H2O" (ID: C00001)
%         Metabolite: "Phosphatidylethanolamine" (ID: C00350)
% Precursor "phosphatidylserine" → no matches found
% Precursor "sphingolipid" → no matches found
% Precursor "heme" → no matches found
% Precursor "iron" → no matches found
% Precursor "ferredoxin" → no matches found
% Precursor "thiamine" → 1 matches found
%     Match: "ATP:thiamine diphosphotransferase" (ID: R00619)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "Thiamine" (ID: C00378)
% Precursor "riboflavin" → 2 matches found
%     Match: "riboflavin-5-phosphate phosphohydrolase" (ID: R00548_EXP_1)
%         Metabolite: "H2O" (ID: C00001)
%         Metabolite: "FMN" (ID: C00061)
%     Match: "ATP:riboflavin 5'-phosphotransferase" (ID: R00549)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "Riboflavin" (ID: C00255)
% Precursor "biotin" → no matches found
% Precursor "glucose" → 25 matches found
%     Match: "UDP-glucose:NAD+ 6-oxidoreductase" (ID: R00286)
%         Metabolite: "H2O" (ID: C00001)
%         Metabolite: "NAD+" (ID: C00003)
%         Metabolite: "UDP-glucose" (ID: C00029)
%     Match: "UTP:alpha-D-glucose-1-phosphate uridylyltransferase" (ID: R00289)
%         Metabolite: "UTP" (ID: C00075)
%         Metabolite: "D-Glucose 1-phosphate" (ID: C00103)
%     Match: "UDP-glucose 4,6-hydro-lyase (UDP-4-dehydro-6-deoxy-D-glucose-forming)" (ID: R00293)
%         Metabolite: "UDP-glucose" (ID: C00029)
%     Match: "ATP:D-glucose 6-phosphotransferase" (ID: R00299)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "D-Glucose" (ID: C00031)
%     Match: "D-glucose-6-phosphate aldose-ketose-isomerase" (ID: R00771)
%         Metabolite: "D-Glucose 6-phosphate" (ID: C00092)
%     Match: "ADP-glucose glucose-1-phosphohydrolase" (ID: R00951)
%         Metabolite: "H2O" (ID: C00001)
%         Metabolite: "ADP-glucose" (ID: C00498)
%     Match: "alpha-D-Glucose 1-phosphate 1,6-phosphomutase" (ID: R00959)
%         Metabolite: "D-Glucose 1-phosphate" (ID: C00103)
%     Match: "UDPglucose:dolichyl-phosphate beta-D-glucosyltransferase" (ID: R01005)
%         Metabolite: "UDP-glucose" (ID: C00029)
%         Metabolite: "Dolichyl phosphate" (ID: C00110)
%     Match: "ATP:beta-D-glucose 6-phosphotransferase" (ID: R01600)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "beta-D-Glucose" (ID: C00221)
%     Match: "ATP:alpha-D-glucose 6-phosphotransferase" (ID: R01786)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "alpha-D-Glucose" (ID: C00267)
%     Match: "alpha-D-Glucose 6-phosphate ketol-isomerase" (ID: R02739)
%         Metabolite: "alpha-D-Glucose 6-phosphate" (ID: C00668)
%     Match: "alpha-D-Glucose 6-phosphate ketol-isomerase" (ID: R02740)
%         Metabolite: "alpha-D-Glucose 6-phosphate" (ID: C00668)
%     Match: "beta-D-Glucose 6-phosphate ketol-isomerase" (ID: R03321)
%         Metabolite: "beta-D-Glucose 6-phosphate" (ID: C01172)
%     Match: "UDP-alpha-D-glucose:glycogenin alpha-D-glucosyltransferase" (ID: R03681)
%         Metabolite: "UDP-glucose" (ID: C00029)
%         Metabolite: "Glycogenin" (ID: C01702)
%     Match: "alpha-D-glucose 1,6-phosphomutase" (ID: R08639)
%         Metabolite: "D-Glucose 1-phosphate" (ID: C00103)
%     Match: "UDP-4-dehydro-6-deoxy-glucose 3,5-epimerase" (ID: R08704)
%         Metabolite: "UDP-4-dehydro-6-deoxy-D-glucose" (ID: C04089)
%     Match: "UDP-glucose 4-epimerase;" (ID: R00291)
%         Metabolite: "UDP-glucose" (ID: C00029)
%     Match: "D-glucose-6-phosphate:NADP+ 1-oxidoreductase" (ID: R00835)
%         Metabolite: "NADP+" (ID: C00006)
%         Metabolite: "D-Glucose 6-phosphate" (ID: C00092)
%     Match: "D-glucose 1-epimerase" (ID: R01602)
%         Metabolite: "alpha-D-Glucose" (ID: C00267)
%     Match: "beta-D-glucose-6-phosphate:NADP+ 1-oxoreductase" (ID: R02736)
%         Metabolite: "NADP+" (ID: C00006)
%         Metabolite: "beta-D-Glucose 6-phosphate" (ID: C01172)
%     Match: "dTDPglucose 4-epimerase" (ID: R02984)
%         Metabolite: "dTDP-glucose" (ID: C00842)
%     Match: "CDP-4-dehydro-3,6-dideoxy-D-glucose:NAD+ 3-oxydoreductase" (ID: R03391)
%         Metabolite: "H2O" (ID: C00001)
%         Metabolite: "NAD+" (ID: C00003)
%         Metabolite: "CDP-4-dehydro-3,6-dideoxy-D-glucose" (ID: C04297)
%     Match: "CDP-4-dehydro-3,6-dideoxy-D-glucose:NADP+ 3-oxydoreductase" (ID: R03392)
%         Metabolite: "H2O" (ID: C00001)
%         Metabolite: "NADP+" (ID: C00006)
%         Metabolite: "CDP-4-dehydro-3,6-dideoxy-D-glucose" (ID: C04297)
%     Match: "dTDPglucose 4,6-hydro-lyase" (ID: R06513)
%         Metabolite: "dTDP-glucose" (ID: C00842)
%     Match: "beta-D-glucose-6-phosphate:NAD+ 1-oxidoreductase" (ID: R10907)
%         Metabolite: "NAD+" (ID: C00003)
%         Metabolite: "beta-D-Glucose 6-phosphate" (ID: C01172)
% Precursor "pyruvate" → 18 matches found
%     Match: "pyruvate:NAD+ 2-oxidoreductase (CoA-acetylating);" (ID: R00209)
%         Metabolite: "NAD+" (ID: C00003)
%         Metabolite: "CoA" (ID: C00010)
%         Metabolite: "Pyruvate" (ID: C00022)
%     Match: "2-phospho-D-glycerate hydro-lyase (phosphoenolpyruvate-forming)" (ID: R00658)
%         Metabolite: "2-Phospho-D-glycerate" (ID: C00631)
%     Match: "Phenylpyruvate keto-enol-isomerase" (ID: R01378)
%         Metabolite: "Phenylpyruvate" (ID: C00166)
%     Match: "3-(4-Hydroxyphenyl)pyruvate keto-enol-isomerase" (ID: R03342)
%         Metabolite: "3-(4-Hydroxyphenyl)pyruvate" (ID: C01179)
%     Match: "ATP:pyruvate 2-O-phosphotransferase" (ID: R00200)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "Pyruvate" (ID: C00022)
%     Match: "ATP:pyruvate,phosphate phosphotransferase" (ID: R00206)
%         Metabolite: "ATP" (ID: C00002)
%         Metabolite: "Orthophosphate" (ID: C00009)
%         Metabolite: "Pyruvate" (ID: C00022)
%     Match: "GTP:pyruvate 2-O-phosphotransferase" (ID: R00430)
%         Metabolite: "Pyruvate" (ID: C00022)
%         Metabolite: "GTP" (ID: C00044)
%     Match: "GTP:oxaloacetate carboxy-lyase (adding GTP;phosphoenolpyruvate-forming);" (ID: R00431)
%         Metabolite: "Oxaloacetate" (ID: C00036)
%         Metabolite: "GTP" (ID: C00044)
%     Match: "L-tryptophan indole-lyase (deaminating; pyruvate-forming)" (ID: R00673)
%         Metabolite: "H2O" (ID: C00001)
%         Metabolite: "L-Tryptophan" (ID: C00078)
%     Match: "ITP:oxaloacetate carboxy-lyase (adding ITP; phosphoenolpyruvate-forming);" (ID: R00726)
%         Metabolite: "Oxaloacetate" (ID: C00036)
%         Metabolite: "ITP" (ID: C00081)
%     Match: "L-cysteine hydrogen-sulfide-lyase (deaminating; pyruvate-forming)" (ID: R00782)
%         Metabolite: "H2O" (ID: C00001)
%         Metabolite: "L-Cysteine" (ID: C00097)
%     Match: "dATP:pyruvate 2-O-phosphotransferase" (ID: R01138)
%         Metabolite: "Pyruvate" (ID: C00022)
%         Metabolite: "dATP" (ID: C00131)
%     Match: "L-cystathionine L-homocysteine-lyase (deaminating; pyruvate-forming)" (ID: R01286)
%         Metabolite: "H2O" (ID: C00001)
%         Metabolite: "L-Cystathionine" (ID: C02291)
%     Match: "dGTP:pyruvate 2-O-phosphotransferase" (ID: R01858)
%         Metabolite: "Pyruvate" (ID: C00022)
%         Metabolite: "dGTP" (ID: C00286)
%     Match: "NTP:pyruvate O2-phosphotransferase" (ID: R02320)
%         Metabolite: "Pyruvate" (ID: C00022)
%         Metabolite: "Nucleoside triphosphate" (ID: C00201)
%     Match: "L-cystine thiocysteine-lyase (deaminating; pyruvate-forming)" (ID: R02408)
%         Metabolite: "H2O" (ID: C00001)
%         Metabolite: "L-Cystine" (ID: C00491)
%     Match: "3-mercaptopyruvate:sulfide sulfurtransferase" (ID: R03105)
%         Metabolite: "Thioredoxin" (ID: C00342)
%         Metabolite: "Mercaptopyruvate" (ID: C00957)
%     Match: "Se-methyl-L-selenocysteine methaneselenol-lyase (deaminating; pyruvate-forming)" (ID: R09366)
%         Metabolite: "H2O" (ID: C00001)
%         Metabolite: "Se-Methyl-L-selenocysteine" (ID: C05689)
% Precursor "malate" → 3 matches found
%     Match: "(S)-Malate:NADP+ oxidoreductase(oxaloacetate-decarboxylating)" (ID: R00216)
%         Metabolite: "NADP+" (ID: C00006)
%         Metabolite: "(S)-Malate" (ID: C00149)
%     Match: "(S)-malate:NAD+ oxidoreductase" (ID: R00342)
%         Metabolite: "NAD+" (ID: C00003)
%         Metabolite: "(S)-Malate" (ID: C00149)
%     Match: "(S)-malate:NAD+ oxidoreductase (decarboxylating)" (ID: R00214)
%         Metabolite: "NAD+" (ID: C00003)
%         Metabolite: "(S)-Malate" (ID: C00149)
% Warning: Repeated mets in the formula for rxn 'BIOMASS_ps'. Combine the stoichiometry.
% test
% CSV table saved to "Tvaginalis_biomass_metabolites.csv"
% Added biomass reaction "BIOMASS_ps" with 1281 metabolite entries (duplicates kept).

% %% [markdown]
% Quick cleaning to ensure RAVEN structures are correctly kept:

% %%
TvaginalisBiomassDraftModel = syncModelStruct(TvaginalisBiomassDraftModel, 'Tvaginalis_biomass_sync_log.csv');
% Out:
% syncModelStruct: Log saved to "Tvaginalis_biomass_sync_log.csv"

% %%
checkModelCoreConsistency(TvaginalisBiomassDraftModel);
% Out:
% --- BASIC DIMENSION CHECKS ---
% Reactions: 891
% Metabolites: 1160
% Genes: 1734
% Empty grRules in 145 reactions

% %%
TvaginalisBiomassDraftModel = sanitizeGEMforSBML(TvaginalisBiomassDraftModel);
TvaginalisBiomassDraftModel = fixRxnConfidenceScores(TvaginalisBiomassDraftModel);

% %% [markdown]
% I will now save the new model with the biomass reaction included:

% %%
exportModel(TvaginalisBiomassDraftModel, 'Tvaginalis_draftGEM_v3.xml');
% Out:
% WARNING: The following InChI strings are associated to more than one unique metabolite name:
%     1S/C24H40N7O17P3S/c1-4-15(33)52-8-7-26-14(32)5-6-27-22(36)19(35)24(2,3)10-45-51(42,43)48-50(40,41)44-9-13-18(47-49(37,38)39)17(34)23(46-13)31-12-30-16-20(25)28-11-29-21(16)31/h11-13,17-19,23,34-35H,4-10H2,1-3H3,(H,26,32)(H,27,36)(H,40,41)(H,42,43)(H2,25,28,29)(H2,37,38,39)/t13-,17-,18-,19+,23-/m1/s1
% Document written

% %%
exportToExcelFormat(TvaginalisBiomassDraftModel, 'Tvaginalis_draftGEM_v3.xlsx');
save('Tvaginalis_draftGEM_v3.mat', 'TvaginalisBiomassDraftModel');

% %% [markdown]
% Now that a biomass reaction has been added to the model, I will try to solve again:

% %%
%TvaginalisBiomassDraftModel = importModel('Tvaginalis_draftGEM_v3.xml');
sol2 = solveLP(TvaginalisBiomassDraftModel);
disp(sol2.f)
% Out:
%      0

% %% [markdown]
% Still 0, so still no growth.
%
% ## Addition of exchange reactions
%
% The simplified gap report:

% %%
% taking a look at the gap situation
%gapReport(TvaginalisBiomassDraftModel);
gapReport_vSimple(TvaginalisBiomassDraftModel);
% Out:
% Dead-end metabolites: 572
%     {'C00012'}
%     {'C00016'}
%     {'C00018'}
%     {'C00053'}
%     {'C00054'}
%     {'C00058'}
%     {'C00071'}
%     {'C00114'}
%     {'C00134'}
%     {'C00169'}
%     {'C00178'}
%     {'C00190'}
%     {'C00191'}
%     {'C00194'}
%     {'C00203'}
%     {'C00227'}
%     {'C00229'}
%     {'C00237'}
%     {'C00243'}
%     {'C00248'}
%     {'C00263'}
%     {'C00302'}
%     {'C00322'}
%     {'C00344'}
%     {'C00389'}
%     {'C00409'}
%     {'C00412'}
%     {'C00415'}
%     {'C00422'}
%     {'C00427'}
%     {'C00447'}
%     {'C00450'}
%     {'C00458'}
%     {'C00509'}
%     {'C00527'}
%     {'C00561'}
%     {'C00584'}
%     {'C00627'}
%     {'C00647'}
%     {'C00683'}
%     {'C00693'}
%     {'C00700'}
%     {'C00721'}
%     {'C00804'}
%     {'C00818'}
%     {'C00857'}
%     {'C00886'}
%     {'C00940'}
%     {'C00962'}
%     {'C00963'}
%     {'C00988'}
%     {'C01019'}
%     {'C01024'}
%     {'C01041'}
%     {'C01094'}
%     {'C01133'}
%     {'C01168'}
%     {'C01181'}
%     {'C01233'}
%     {'C01234'}
%     {'C01246'}
%     {'C01252'}
%     {'C01262'}
%     {'C01290'}
%     {'C01297'}
%     {'C01367'}
%     {'C01368'}
%     {'C01424'}
%     {'C01449'}
%     {'C01471'}
%     {'C01592'}
%     {'C01594'}
%     {'C01635'}
%     {'C01649'}
%     {'C01674'}
%     {'C01717'}
%     {'C01752'}
%     {'C01801'}
%     {'C01845'}
%     {'C01935'}
%     {'C01978'}
%     {'C01997'}
%     {'C02047'}
%     {'C02067'}
%     {'C02147'}
%     {'C02199'}
%     {'C02232'}
%     {'C02237'}
%     {'C02282'}
%     {'C02348'}
%     {'C02350'}
%     {'C02362'}
%     {'C02380'}
%     {'C02415'}
%     {'C02430'}
%     {'C02470'}
%     {'C02553'}
%     {'C02659'}
%     {'C02687'}
%     {'C02702'}
%     {'C02737'}
%     {'C02763'}
%     {'C02835'}
%     {'C02839'}
%     {'C02843'}
%     {'C02946'}
%     {'C02952'}
%     {'C02962'}
%     {'C02984'}
%     {'C02987'}
%     {'C02988'}
%     {'C02992'}
%     {'C03028'}
%     {'C03089'}
%     {'C03125'}
%     {'C03127'}
%     {'C03160'}
%     {'C03201'}
%     {'C03219'}
%     {'C03241'}
%     {'C03289'}
%     {'C03309'}
%     {'C03313'}
%     {'C03402'}
%     {'C03405'}
%     {'C03454'}
%     {'C03458'}
%     {'C03511'}
%     {'C03512'}
%     {'C03539'}
%     {'C03658'}
%     {'C03671'}
%     {'C03742'}
%     {'C03758'}
%     {'C03771'}
%     {'C03892'}
%     {'C03917'}
%     {'C04076'}
%     {'C04088'}
%     {'C04132'}
%     {'C04157'}
%     {'C04236'}
%     {'C04246'}
%     {'C04377'}
%     {'C04431'}
%     {'C04475'}
%     {'C04522'}
%     {'C04554'}
%     {'C04625'}
%     {'C04646'}
%     {'C04672'}
%     {'C04706'}
%     {'C04718'}
%     {'C04748'}
%     {'C04802'}
%     {'C04895'}
%     {'C05143'}
%     {'C05190'}
%     {'C05191'}
%     {'C05198'}
%     {'C05199'}
%     {'C05269'}
%     {'C05312'}
%     {'C05322'}
%     {'C05336'}
%     {'C05350'}
%     {'C05394'}
%     {'C05403'}
%     {'C05527'}
%     {'C05546'}
%     {'C05570'}
%     {'C05578'}
%     {'C05587'}
%     {'C05623'}
%     {'C05645'}
%     {'C05675'}
%     {'C05691'}
%     {'C05712'}
%     {'C05713'}
%     {'C05726'}
%     {'C05729'}
%     {'C05748'}
%     {'C05751'}
%     {'C05754'}
%     {'C05758'}
%     {'C05760'}
%     {'C05763'}
%     {'C05766'}
%     {'C05819'}
%     {'C05822'}
%     {'C05838'}
%     {'C05839'}
%     {'C05840'}
%     {'C05850'}
%     {'C05914'}
%     {'C05916'}
%     {'C05923'}
%     {'C05946'}
%     {'C05947'}
%     {'C06054'}
%     {'C06066'}
%     {'C06112'}
%     {'C06128'}
%     {'C06173'}
%     {'C06192'}
%     {'C06193'}
%     {'C06197'}
%     {'C06206'}
%     {'C06481'}
%     {'C06508'}
%     {'C06555'}
%     {'C06563'}
%     {'C06594'}
%     {'C06597'}
%     {'C06598'}
%     {'C06602'}
%     {'C06614'}
%     {'C06615'}
%     {'C06620'}
%     {'C06717'}
%     {'C06735'}
%     {'C06755'}
%     {'C06986'}
%     {'C07024'}
%     {'C07304'}
%     {'C07307'}
%     {'C07335'}
%     {'C07480'}
%     {'C07490'}
%     {'C07541'}
%     {'C07647'}
%     {'C08325'}
%     {'C08334'}
%     {'C08537'}
%     {'C08540'}
%     {'C08543'}
%     {'C08557'}
%     {'C08565'}
%     {'C09099'}
%     {'C09126'}
%     {'C09315'}
%     {'C09332'}
%     {'C09382'}
%     {'C09440'}
%     {'C10208'}
%     {'C10216'}
%     {'C11039'}
%     {'C11149'}
%     {'C11405'}
%     {'C11419'}
%     {'C11526'}
%     {'C11572'}
%     {'C11633'}
%     {'C11634'}
%     {'C11638'}
%     {'C11680'}
%     {'C11713'}
%     {'C11714'}
%     {'C11813'}
%     {'C11814'}
%     {'C11822'}
%     {'C11887'}
%     {'C11924'}
%     {'C11930'}
%     {'C12119'}
%     {'C12214'}
%     {'C12215'}
%     {'C12396'}
%     {'C12397'}
%     {'C12739'}
%     {'C13747'}
%     {'C14180'}
%     {'C14786'}
%     {'C14787'}
%     {'C14818'}
%     {'C14819'}
%     {'C14866'}
%     {'C14909'}
%     {'C15670'}
%     {'C15809'}
%     {'C15986'}
%     {'C16075'}
%     {'C16138'}
%     {'C16151'}
%     {'C16152'}
%     {'C16353'}
%     {'C16355'}
%     {'C16356'}
%     {'C16358'}
%     {'C16359'}
%     {'C16360'}
%     {'C16392'}
%     {'C16413'}
%     {'C16502'}
%     {'C16556'}
%     {'C16559'}
%     {'C16613'}
%     {'C16617'}
%     {'C16633'}
%     {'C16682'}
%     {'C17204'}
%     {'C17324'}
%     {'C17349'}
%     {'C17751'}
%     {'C17752'}
%     {'C17753'}
%     {'C17754'}
%     {'C17755'}
%     {'C17757'}
%     {'C18022'}
%     {'C18063'}
%     {'C18064'}
%     {'C18096'}
%     {'C18235'}
%     {'C18345'}
%     {'C18796'}
%     {'C18871'}
%     {'C19079'}
%     {'C19084'}
%     {'C19491'}
%     {'C19563'}
%     {'C19564'}
%     {'C19566'}
%     {'C19567'}
%     {'C19568'}
%     {'C19577'}
%     {'C19578'}
%     {'C19580'}
%     {'C19581'}
%     {'C19714'}
%     {'C19944'}
%     {'C20119'}
%     {'C20183'}
%     {'C20231'}
%     {'C20238'}
%     {'C20254'}
%     {'C20271'}
%     {'C20279'}
%     {'C20297'}
%     {'C20299'}
%     {'C20312'}
%     {'C20315'}
%     {'C20329'}
%     {'C20330'}
%     {'C20361'}
%     {'C20379'}
%     {'C20409'}
%     {'C20449'}
%     {'C20457'}
%     {'C20458'}
%     {'C20459'}
%     {'C20650'}
%     {'C20690'}
%     {'C20729'}
%     {'C20743'}
%     {'C20751'}
%     {'C20836'}
%     {'C20852'}
%     {'C20853'}
%     {'C20863'}
%     {'C20864'}
%     {'C20879'}
%     {'C20899'}
%     {'C20900'}
%     {'C20901'}
%     {'C20937'}
%     {'C21026'}
%     {'C21075'}
%     {'C21140'}
%     {'C21142'}
%     {'C21154'}
%     {'C21192'}
%     {'C21408'}
%     {'C21410'}
%     {'C21412'}
%     {'C21437'}
%     {'C21442'}
%     {'C21459'}
%     {'C21476'}
%     {'C21486'}
%     {'C21582'}
%     {'C21589'}
%     {'C21590'}
%     {'C21599'}
%     {'C21600'}
%     {'C21620'}
%     {'C21622'}
%     {'C21623'}
%     {'C21731'}
%     {'C21749'}
%     {'C21787'}
%     {'C21845'}
%     {'C21897'}
%     {'C21922'}
%     {'C21923'}
%     {'C21930'}
%     {'C22050'}
%     {'C22051'}
%     {'C22054'}
%     {'C22070'}
%     {'C22084'}
%     {'C22131'}
%     {'C22148'}
%     {'C22149'}
%     {'C22160'}
%     {'C22161'}
%     {'C22238'}
%     {'C22329'}
%     {'C22331'}
%     {'C22332'}
%     {'C22333'}
%     {'C22334'}
%     {'C22432'}
%     {'C22438'}
%     {'C22441'}
%     {'C22443'}
%     {'C22467'}
%     {'C22488'}
%     {'C22500'}
%     {'C22624'}
%     {'C22647'}
%     {'C22648'}
%     {'G00006'}
%     {'G00008'}
%     {'G00009'}
%     {'G00012'}
%     {'G00015'}
%     {'G00019'}
%     {'G00023'}
%     {'G00024'}
%     {'G00094'}
%     {'G00108'}
%     {'G00109'}
%     {'G00157'}
%     {'G00162'}
%     {'G00171'}
%     {'G00317'}
%     {'G10504'}
%     {'G10608'}
%     {'G10609'}
%     {'G10665'}
%     {'G10842'}
%     {'G10981'}
%     {'G11055'}
%     {'G11121'}
%     {'G13053'}
%     {'G13056'}
%     {'G13073'}
%     {'G13074'}
%     {'C00052'}
%     {'C00087'}
%     {'C00141'}
%     {'C00145'}
%     {'C00177'}
%     {'C00219'}
%     {'C00222'}
%     {'C00245'}
%     {'C00446'}
%     {'C00454'}
%     {'C00463'}
%     {'C00519'}
%     {'C00588'}
%     {'C00628'}
%     {'C00645'}
%     {'C00671'}
%     {'C00740'}
%     {'C00777'}
%     {'C00819'}
%     {'C00847'}
%     {'C00870'}
%     {'C01037'}
%     {'C01220'}
%     {'C01235'}
%     {'C01416'}
%     {'C01595'}
%     {'C01755'}
%     {'C01825'}
%     {'C01931'}
%     {'C01962'}
%     {'C01996'}
%     {'C02097'}
%     {'C02110'}
%     {'C02163'}
%     {'C02266'}
%     {'C02356'}
%     {'C02412'}
%     {'C02554'}
%     {'C02642'}
%     {'C02863'}
%     {'C03012'}
%     {'C03360'}
%     {'C03546'}
%     {'C03692'}
%     {'C04062'}
%     {'C04425'}
%     {'C04454'}
%     {'C04518'}
%     {'C04635'}
%     {'C04742'}
%     {'C04805'}
%     {'C05102'}
%     {'C05356'}
%     {'C05361'}
%     {'C05399'}
%     {'C05400'}
%     {'C05401'}
%     {'C05585'}
%     {'C05643'}
%     {'C05828'}
%     {'C05842'}
%     {'C05843'}
%     {'C05959'}
%     {'C05965'}
%     {'C05966'}
%     {'C06037'}
%     {'C06082'}
%     {'C06126'}
%     {'C06205'}
%     {'C06427'}
%     {'C06606'}
%     {'C07054'}
%     {'C07446'}
%     {'C07447'}
%     {'C07585'}
%     {'C07646'}
%     {'C08607'}
%     {'C09694'}
%     {'C11150'}
%     {'C11173'}
%     {'C12448'}
%     {'C12650'}
%     {'C13455'}
%     {'C13713'}
%     {'C14090'}
%     {'C14099'}
%     {'C14777'}
%     {'C15493'}
%     {'C15814'}
%     {'C15926'}
%     {'C16453'}
%     {'C16504'}
%     {'C16505'}
%     {'C16506'}
%     {'C16543'}
%     {'C16591'}
%     {'C16610'}
%     {'C16612'}
%     {'C16631'}
%     {'C16641'}
%     {'C16688'}
%     {'C16834'}
%     {'C16836'}
%     {'C16837'}
%     {'C17211'}
%     {'C17213'}
%     {'C17216'}
%     {'C17217'}
%     {'C18042'}
%     {'C18910'}
%     {'C19574'}
%     {'C19803'}
%     {'C20660'}
%     {'C20722'}
%     {'C21029'}
%     {'G00092'}
%     {'G00370'}
%     {'G00711'}
%     {'G01275'}
%     {'G10008'}
%     {'G10617'}
%     {'G10622'}
%     {'G13027'}
% Blocked reactions: 587
%     {'R00022'      }
%     {'R00028'      }
%     {'R00078'      }
%     {'R00104'      }
%     {'R00130'      }
%     {'R00137_EXP_1'}
%     {'R00139'      }
%     {'R00161'      }
%     {'R00174'      }
%     {'R00177'      }
%     {'R00179'      }
%     {'R00187'      }
%     {'R00188'      }
%     {'R00194'      }
%     {'R00238'      }
%     {'R00258'      }
%     {'R00264'      }
%     {'R00269'      }
%     {'R00286'      }
%     {'R00289'      }
%     {'R00293'      }
%     {'R00317'      }
%     {'R00348'      }
%     {'R00355'      }
%     {'R00416'      }
%     {'R00508'      }
%     {'R00597'      }
%     {'R00654'      }
%     {'R00670'      }
%     {'R00694'      }
%     {'R00734'      }
%     {'R00751'      }
%     {'R00885'      }
%     {'R00896'      }
%     {'R00899'      }
%     {'R00904'      }
%     {'R00942'      }
%     {'R00945'      }
%     {'R00951'      }
%     {'R00978'      }
%     {'R01005'      }
%     {'R01018'      }
%     {'R01030'      }
%     {'R01121'      }
%     {'R01123'      }
%     {'R01126'      }
%     {'R01177'      }
%     {'R01221'      }
%     {'R01280'      }
%     {'R01281'      }
%     {'R01320'      }
%     {'R01334'      }
%     {'R01351'      }
%     {'R01378'      }
%     {'R01384'      }
%     {'R01398'      }
%     {'R01401'      }
%     {'R01403'      }
%     {'R01415'      }
%     {'R01421'      }
%     {'R01431'      }
%     {'R01468'      }
%     {'R01470'      }
%     {'R01481'      }
%     {'R01492'      }
%     {'R01498'      }
%     {'R01529'      }
%     {'R01550'      }
%     {'R01562'      }
%     {'R01583'      }
%     {'R01641'      }
%     {'R01658'      }
%     {'R01676'      }
%     {'R01678'      }
%     {'R01698'      }
%     {'R01737'      }
%     {'R01787'      }
%     {'R01801'      }
%     {'R01818'      }
%     {'R01819'      }
%     {'R01829'      }
%     {'R01844'      }
%     {'R01877'      }
%     {'R01885'      }
%     {'R01909'      }
%     {'R01933'      }
%     {'R01976'      }
%     {'R01978'      }
%     {'R02003'      }
%     {'R02038'      }
%     {'R02056'      }
%     {'R02057'      }
%     {'R02110'      }
%     {'R02112'      }
%     {'R02144'      }
%     {'R02148'      }
%     {'R02208'      }
%     {'R02237'      }
%     {'R02245'      }
%     {'R02250'      }
%     {'R02265'      }
%     {'R02297'      }
%     {'R02326'      }
%     {'R02370'      }
%     {'R02433'      }
%     {'R02493'      }
%     {'R02497'      }
%     {'R02531'      }
%     {'R02558'      }
%     {'R02568'      }
%     {'R02577'      }
%     {'R02619'      }
%     {'R02677'      }
%     {'R02719'      }
%     {'R02720'      }
%     {'R02746'      }
%     {'R02750'      }
%     {'R02765'      }
%     {'R02918'      }
%     {'R02940'      }
%     {'R02957'      }
%     {'R02964_EXP_1'}
%     {'R02971'      }
%     {'R02978'      }
%     {'R02985'      }
%     {'R03005_EXP_1'}
%     {'R03018'      }
%     {'R03035'      }
%     {'R03038'      }
%     {'R03245'      }
%     {'R03283'      }
%     {'R03342'      }
%     {'R03355'      }
%     {'R03424'      }
%     {'R03438'      }
%     {'R03479'      }
%     {'R03527'      }
%     {'R03530'      }
%     {'R03531'      }
%     {'R03596'      }
%     {'R03643_EXP_1'}
%     {'R03648'      }
%     {'R03650'      }
%     {'R03651'      }
%     {'R03652'      }
%     {'R03655'      }
%     {'R03656'      }
%     {'R03657'      }
%     {'R03659'      }
%     {'R03660'      }
%     {'R03661'      }
%     {'R03662'      }
%     {'R03663'      }
%     {'R03664_EXP_1'}
%     {'R03681'      }
%     {'R03789'      }
%     {'R03805'      }
%     {'R03815'      }
%     {'R03816_EXP_1'}
%     {'R03828'      }
%     {'R03875'      }
%     {'R03922'      }
%     {'R04018'      }
%     {'R04065'      }
%     {'R04216'      }
%     {'R04247'      }
%     {'R04285'      }
%     {'R04391'      }
%     {'R04429'      }
%     {'R04496'      }
%     {'R04506'      }
%     {'R04710'      }
%     {'R04724'      }
%     {'R04770'      }
%     {'R04771'      }
%     {'R04773'      }
%     {'R04783'      }
%     {'R04866'      }
%     {'R04867'      }
%     {'R04920'      }
%     {'R04949'      }
%     {'R04951'      }
%     {'R04955'      }
%     {'R04958'      }
%     {'R04961'      }
%     {'R04966'      }
%     {'R04969'      }
%     {'R04998'      }
%     {'R05050'      }
%     {'R05052'      }
%     {'R05085'      }
%     {'R05202'      }
%     {'R05220'      }
%     {'R05231'      }
%     {'R05237'      }
%     {'R05238'      }
%     {'R05286'      }
%     {'R05576'      }
%     {'R05577'      }
%     {'R05578'      }
%     {'R05668'      }
%     {'R05908'      }
%     {'R05930'      }
%     {'R05963'      }
%     {'R05969'      }
%     {'R05970_EXP_1'}
%     {'R05972_EXP_1'}
%     {'R05973'      }
%     {'R05976'      }
%     {'R05980'      }
%     {'R05981'      }
%     {'R05986'      }
%     {'R06004'      }
%     {'R06114'      }
%     {'R06127'      }
%     {'R06128'      }
%     {'R06147'      }
%     {'R06171'      }
%     {'R06238'      }
%     {'R06364'      }
%     {'R06366'      }
%     {'R06590'      }
%     {'R06722'      }
%     {'R06941'      }
%     {'R07136'      }
%     {'R07268'      }
%     {'R07324'      }
%     {'R07384'      }
%     {'R07618'      }
%     {'R07761'      }
%     {'R07765'      }
%     {'R07809'      }
%     {'R07810'      }
%     {'R07942'      }
%     {'R07977'      }
%     {'R07978'      }
%     {'R07979'      }
%     {'R08146'      }
%     {'R08218'      }
%     {'R08221_EXP_1'}
%     {'R08226'      }
%     {'R08229'      }
%     {'R08233'      }
%     {'R08235'      }
%     {'R08243'      }
%     {'R08379'      }
%     {'R08383'      }
%     {'R08549'      }
%     {'R08704'      }
%     {'R08705'      }
%     {'R08836'      }
%     {'R08935'      }
%     {'R08954'      }
%     {'R08967'      }
%     {'R08969'      }
%     {'R09030'      }
%     {'R09034'      }
%     {'R09035_EXP_1'}
%     {'R09036_EXP_1'}
%     {'R09087'      }
%     {'R09099'      }
%     {'R09296'      }
%     {'R09302'      }
%     {'R09303'      }
%     {'R09316'      }
%     {'R09372'      }
%     {'R09381_EXP_1'}
%     {'R09449'      }
%     {'R09844'      }
%     {'R09845'      }
%     {'R09979'      }
%     {'R10035'      }
%     {'R10039'      }
%     {'R10040'      }
%     {'R10183'      }
%     {'R10231'      }
%     {'R10242'      }
%     {'R10463'      }
%     {'R10548'      }
%     {'R10633'      }
%     {'R10634'      }
%     {'R10648'      }
%     {'R10814'      }
%     {'R10815'      }
%     {'R10828'      }
%     {'R11180'      }
%     {'R11262'      }
%     {'R11316'      }
%     {'R11319'      }
%     {'R11583'      }
%     {'R11764'      }
%     {'R11891'      }
%     {'R11894'      }
%     {'R12011'      }
%     {'R12184'      }
%     {'R12390'      }
%     {'R12391'      }
%     {'R12429'      }
%     {'R12433'      }
%     {'R12434'      }
%     {'R12449'      }
%     {'R12479'      }
%     {'R12852'      }
%     {'R12853'      }
%     {'R12958'      }
%     {'R12963'      }
%     {'R12987'      }
%     {'R12988'      }
%     {'R12989'      }
%     {'R12990'      }
%     {'R13051'      }
%     {'R13052'      }
%     {'R13065'      }
%     {'R13081'      }
%     {'R00647'      }
%     {'R01652'      }
%     {'R02317'      }
%     {'R02962'      }
%     {'R03166'      }
%     {'R03186'      }
%     {'R03445'      }
%     {'R03672'      }
%     {'R03674'      }
%     {'R03954'      }
%     {'R04500'      }
%     {'R04578'      }
%     {'R04639'      }
%     {'R04701'      }
%     {'R04769'      }
%     {'R05041'      }
%     {'R05048'      }
%     {'R05098'      }
%     {'R05455'      }
%     {'R05483'      }
%     {'R05484'      }
%     {'R05824'      }
%     {'R05826'      }
%     {'R05844'      }
%     {'R05845'      }
%     {'R05846'      }
%     {'R05887'      }
%     {'R05889'      }
%     {'R06063'      }
%     {'R06064'      }
%     {'R06194'      }
%     {'R06650'      }
%     {'R06830'      }
%     {'R06982'      }
%     {'R07009'      }
%     {'R07010'      }
%     {'R07011'      }
%     {'R07012'      }
%     {'R07198'      }
%     {'R07316'      }
%     {'R07406'      }
%     {'R07679'      }
%     {'R07947'      }
%     {'R07948'      }
%     {'R08020'      }
%     {'R08279'      }
%     {'R08289'      }
%     {'R08358'      }
%     {'R08372'      }
%     {'R08818'      }
%     {'R08820'      }
%     {'R08821'      }
%     {'R08825'      }
%     {'R08827'      }
%     {'R08829'      }
%     {'R08831'      }
%     {'R08833'      }
%     {'R08834'      }
%     {'R08835'      }
%     {'R08837'      }
%     {'R08976'      }
%     {'R09142'      }
%     {'R09143'      }
%     {'R09144'      }
%     {'R09145'      }
%     {'R09149'      }
%     {'R09274'      }
%     {'R09367'      }
%     {'R09368'      }
%     {'R09391'      }
%     {'R09392'      }
%     {'R09431'      }
%     {'R09432'      }
%     {'R09433'      }
%     {'R09434'      }
%     {'R09885'      }
%     {'R09981'      }
%     {'R10013'      }
%     {'R10018'      }
%     {'R10022'      }
%     {'R10030'      }
%     {'R10034'      }
%     {'R10041'      }
%     {'R10078'      }
%     {'R10082'      }
%     {'R10097'      }
%     {'R10245'      }
%     {'R10302'      }
%     {'R10792'      }
%     {'R10854'      }
%     {'R10856'      }
%     {'R10914'      }
%     {'R11017'      }
%     {'R11034'      }
%     {'R11049'      }
%     {'R11148'      }
%     {'R11176'      }
%     {'R11228'      }
%     {'R11523'      }
%     {'R11550'      }
%     {'R11570'      }
%     {'R11571'      }
%     {'R11572'      }
%     {'R11573'      }
%     {'R11574'      }
%     {'R11575'      }
%     {'R11576'      }
%     {'R11577'      }
%     {'R11691'      }
%     {'R11695'      }
%     {'R11709'      }
%     {'R11736'      }
%     {'R11739'      }
%     {'R11865'      }
%     {'R11947'      }
%     {'R12091'      }
%     {'R12094'      }
%     {'R12132'      }
%     {'R12140'      }
%     {'R12185'      }
%     {'R12268'      }
%     {'R12274'      }
%     {'R12310'      }
%     {'R12335'      }
%     {'R12421'      }
%     {'R12539'      }
%     {'R12683'      }
%     {'R12686'      }
%     {'R12829'      }
%     {'R12886'      }
%     {'R12910'      }
%     {'R12974'      }
%     {'R13023'      }
%     {'R13091'      }
%     {'R13113'      }
%     {'R13114'      }
%     {'R13140'      }
%     {'R13144'      }
%     {'R00192'      }
%     {'R00261'      }
%     {'R00274'      }
%     {'R00291'      }
%     {'R00465'      }
%     {'R00489'      }
%     {'R00589'      }
%     {'R00673'      }
%     {'R00704'      }
%     {'R00709'      }
%     {'R00858'      }
%     {'R00897'      }
%     {'R00996'      }
%     {'R01001'      }
%     {'R01026'      }
%     {'R01039'      }
%     {'R01090'      }
%     {'R01092'      }
%     {'R01104'      }
%     {'R01172'      }
%     {'R01186'      }
%     {'R01187'      }
%     {'R01194'      }
%     {'R01207'      }
%     {'R01214'      }
%     {'R01268'      }
%     {'R01317'      }
%     {'R01329'      }
%     {'R01430'      }
%     {'R01440'      }
%     {'R01579'      }
%     {'R01639'      }
%     {'R01682'      }
%     {'R01709'      }
%     {'R01827'      }
%     {'R01931'      }
%     {'R02125'      }
%     {'R02199'      }
%     {'R02269'      }
%     {'R02320'      }
%     {'R02408'      }
%     {'R02466'      }
%     {'R02527'      }
%     {'R02541'      }
%     {'R02657'      }
%     {'R02799'      }
%     {'R02926'      }
%     {'R02984'      }
%     {'R03024'      }
%     {'R03055'      }
%     {'R03105'      }
%     {'R03231'      }
%     {'R03269'      }
%     {'R03325'      }
%     {'R03330'      }
%     {'R03394'      }
%     {'R03601'      }
%     {'R03629'      }
%     {'R03646'      }
%     {'R03654'      }
%     {'R03658'      }
%     {'R03665'      }
%     {'R03921'      }
%     {'R04019'      }
%     {'R04072'      }
%     {'R04085'      }
%     {'R04121'      }
%     {'R04231'      }
%     {'R04470'      }
%     {'R04859'      }
%     {'R04880'      }
%     {'R04930'      }
%     {'R04996'      }
%     {'R05233'      }
%     {'R05234'      }
%     {'R05259'      }
%     {'R05961'      }
%     {'R06088'      }
%     {'R06091'      }
%     {'R06513'      }
%     {'R06728'      }
%     {'R06917'      }
%     {'R06927'      }
%     {'R06957'      }
%     {'R07015'      }
%     {'R07034'      }
%     {'R07035'      }
%     {'R07064'      }
%     {'R07104'      }
%     {'R07379'      }
%     {'R07387'      }
%     {'R07459'      }
%     {'R07461'      }
%     {'R07620'      }
%     {'R07674'      }
%     {'R07859'      }
%     {'R08149'      }
%     {'R08150'      }
%     {'R08220'      }
%     {'R08227'      }
%     {'R08249'      }
%     {'R08251'      }
%     {'R08255'      }
%     {'R08258'      }
%     {'R08282'      }
%     {'R08283'      }
%     {'R08307'      }
%     {'R08349'      }
%     {'R08380'      }
%     {'R08384'      }
%     {'R08408'      }
%     {'R08622'      }
%     {'R08626'      }
%     {'R08955'      }
%     {'R08957'      }
%     {'R08958'      }
%     {'R08959'      }
%     {'R08960'      }
%     {'R09289'      }
%     {'R09366'      }
%     {'R09377'      }
%     {'R09420'      }
%     {'R09783'      }
%     {'R10046'      }
%     {'R10586'      }
%     {'R10587'      }
%     {'R10619'      }
%     {'R10831'      }
%     {'R10991'      }
%     {'R11399'      }
%     {'R11763'      }
%     {'R11893'      }
%     {'R12188'      }
%     {'R13043'      }
%     {'BIOMASS_ps'  }

% %% [markdown]
% In order for this to be a functional GEM, exchange reactions need to be added.

% %%
% Setting up the draft GEM base
%TvaginalisBiomassDraftModel = importModel('Tvaginalis_draftGEM_v3.xml');
% create a copy to avoid overwriting
TvaginalisExchangeModel = TvaginalisBiomassDraftModel;
TvaginalisExchangeModel.id = 'TvaginalisDraft';

% %% [markdown]
% Perform some cleaning:

% %%
% deal with grRules issues
TvaginalisExchangeModel = ensureGrRules(TvaginalisExchangeModel);
modelKEGGgr = ensureGrRules(modelKEGG);
% Out:
% Patched grRules to match 11588 rxns

% %%
% further sanitization
modelKEGGgr = padMissingFields(modelKEGGgr, TvaginalisExchangeModel);
% Out:
% Added geneMiriams to KEGG
% Added rxnFrom to KEGG
% Added metFrom to KEGG
% Added geneFrom to KEGG
% Added rules to KEGG
% Added equations to KEGG
% Added rxnReferences to KEGG
% Added rxnConfidenceScores to KEGG
% Added metCharges to KEGG
% Added geneNames to KEGG
% Added geneShortNames to KEGG

% %% [markdown]
% Dealing with exchange reactions:

% %%
% getting a cell array of metabolites to create exchange reactions for
biomassMets = getBiomassMets(TvaginalisExchangeModel, 'BIOMASS_ps'); % get metabolites involved in the biomass reaction
% Out:
% Biomass reaction: BIOMASS_ps
% Number of metabolites in biomass reaction: 358
%     {'C00001'}
%     {'C00002'}
%     {'C00003'}
%     {'C00004'}
%     {'C00005'}
%     {'C00006'}
%     {'C00007'}
%     {'C00008'}
%     {'C00009'}
%     {'C00010'}
%     {'C00011'}
%     {'C00013'}
%     {'C00014'}
%     {'C00015'}
%     {'C00019'}
%     {'C00020'}
%     {'C00022'}
%     {'C00024'}
%     {'C00025'}
%     {'C00026'}
%     {'C00029'}
%     {'C00030'}
%     {'C00031'}
%     {'C00033'}
%     {'C00035'}
%     {'C00036'}
%     {'C00037'}
%     {'C00040'}
%     {'C00042'}
%     {'C00044'}
%     {'C00049'}
%     {'C00055'}
%     {'C00061'}
%     {'C00063'}
%     {'C00064'}
%     {'C00065'}
%     {'C00073'}
%     {'C00075'}
%     {'C00078'}
%     {'C00079'}
%     {'C00080'}
%     {'C00081'}
%     {'C00082'}
%     {'C00084'}
%     {'C00085'}
%     {'C00092'}
%     {'C00093'}
%     {'C00095'}
%     {'C00097'}
%     {'C00101'}
%     {'C00103'}
%     {'C00104'}
%     {'C00105'}
%     {'C00110'}
%     {'C00112'}
%     {'C00116'}
%     {'C00117'}
%     {'C00118'}
%     {'C00121'}
%     {'C00123'}
%     {'C00124'}
%     {'C00131'}
%     {'C00135'}
%     {'C00136'}
%     {'C00143'}
%     {'C00144'}
%     {'C00147'}
%     {'C00148'}
%     {'C00149'}
%     {'C00152'}
%     {'C00154'}
%     {'C00157'}
%     {'C00160'}
%     {'C00163'}
%     {'C00166'}
%     {'C00173'}
%     {'C00181'}
%     {'C00188'}
%     {'C00189'}
%     {'C00195'}
%     {'C00197'}
%     {'C00206'}
%     {'C00207'}
%     {'C00214'}
%     {'C00221'}
%     {'C00224'}
%     {'C00239'}
%     {'C00249'}
%     {'C00250'}
%     {'C00255'}
%     {'C00257'}
%     {'C00258'}
%     {'C00262'}
%     {'C00267'}
%     {'C00272'}
%     {'C00286'}
%     {'C00288'}
%     {'C00314'}
%     {'C00342'}
%     {'C00345'}
%     {'C00346'}
%     {'C00350'}
%     {'C00355'}
%     {'C00356'}
%     {'C00360'}
%     {'C00361'}
%     {'C00362'}
%     {'C00363'}
%     {'C00364'}
%     {'C00365'}
%     {'C00378'}
%     {'C00379'}
%     {'C00381'}
%     {'C00385'}
%     {'C00386'}
%     {'C00407'}
%     {'C00410'}
%     {'C00416'}
%     {'C00418'}
%     {'C00429'}
%     {'C00433'}
%     {'C00455'}
%     {'C00460'}
%     {'C00469'}
%     {'C00473'}
%     {'C00498'}
%     {'C00526'}
%     {'C00532'}
%     {'C00534'}
%     {'C00535'}
%     {'C00555'}
%     {'C00577'}
%     {'C00579'}
%     {'C00583'}
%     {'C00613'}
%     {'C00631'}
%     {'C00636'}
%     {'C00637'}
%     {'C00641'}
%     {'C00658'}
%     {'C00668'}
%     {'C00673'}
%     {'C00674'}
%     {'C00705'}
%     {'C00787'}
%     {'C00794'}
%     {'C00800'}
%     {'C00828'}
%     {'C00831'}
%     {'C00836'}
%     {'C00853'}
%     {'C00864'}
%     {'C00882'}
%     {'C00921'}
%     {'C00957'}
%     {'C01005'}
%     {'C01097'}
%     {'C01107'}
%     {'C01132'}
%     {'C01134'}
%     {'C01143'}
%     {'C01144'}
%     {'C01149'}
%     {'C01172'}
%     {'C01179'}
%     {'C01185'}
%     {'C01194'}
%     {'C01204'}
%     {'C01213'}
%     {'C01217'}
%     {'C01241'}
%     {'C01243'}
%     {'C01245'}
%     {'C01272'}
%     {'C01277'}
%     {'C01344'}
%     {'C01346'}
%     {'C01419'}
%     {'C01528'}
%     {'C01628'}
%     {'C01637'}
%     {'C01638'}
%     {'C01639'}
%     {'C01640'}
%     {'C01641'}
%     {'C01643'}
%     {'C01644'}
%     {'C01645'}
%     {'C01647'}
%     {'C01648'}
%     {'C01650'}
%     {'C01651'}
%     {'C01652'}
%     {'C01702'}
%     {'C01977'}
%     {'C02031'}
%     {'C02059'}
%     {'C02076'}
%     {'C02100'}
%     {'C02211'}
%     {'C02336'}
%     {'C02339'}
%     {'C02576'}
%     {'C02670'}
%     {'C02743'}
%     {'C02972'}
%     {'C03021'}
%     {'C03024'}
%     {'C03150'}
%     {'C03205'}
%     {'C03319'}
%     {'C03461'}
%     {'C03492'}
%     {'C03557'}
%     {'C03681'}
%     {'C03819'}
%     {'C04079'}
%     {'C04089'}
%     {'C04143'}
%     {'C04213'}
%     {'C04230'}
%     {'C04242'}
%     {'C04244'}
%     {'C04308'}
%     {'C04317'}
%     {'C04352'}
%     {'C04438'}
%     {'C04477'}
%     {'C04501'}
%     {'C04506'}
%     {'C04520'}
%     {'C04549'}
%     {'C04637'}
%     {'C05116'}
%     {'C05130'}
%     {'C05196'}
%     {'C05197'}
%     {'C05223'}
%     {'C05335'}
%     {'C05345'}
%     {'C05445'}
%     {'C05519'}
%     {'C05544'}
%     {'C05545'}
%     {'C05634'}
%     {'C05665'}
%     {'C05745'}
%     {'C05749'}
%     {'C05752'}
%     {'C05755'}
%     {'C05761'}
%     {'C05764'}
%     {'C05774'}
%     {'C05936'}
%     {'C05983'}
%     {'C05985'}
%     {'C05993'}
%     {'C05999'}
%     {'C06002'}
%     {'C06055'}
%     {'C06103'}
%     {'C06423'}
%     {'C06504'}
%     {'C06505'}
%     {'C06754'}
%     {'C07645'}
%     {'C07649'}
%     {'C09762'}
%     {'C11038'}
%     {'C11174'}
%     {'C11537'}
%     {'C11555'}
%     {'C11736'}
%     {'C14145'}
%     {'C15811'}
%     {'C15812'}
%     {'C15973'}
%     {'C16218'}
%     {'C16221'}
%     {'C16240'}
%     {'C16241'}
%     {'C16634'}
%     {'C16636'}
%     {'C17328'}
%     {'C18026'}
%     {'C18040'}
%     {'C18060'}
%     {'C18125'}
%     {'C18126'}
%     {'C18237'}
%     {'C18902'}
%     {'C19078'}
%     {'C19080'}
%     {'C20876'}
%     {'C21028'}
%     {'C21640'}
%     {'C21748'}
%     {'C21750'}
%     {'C21844'}
%     {'C22157'}
%     {'C22158'}
%     {'C22499'}
%     {'C00047'}
%     {'C00062'}
%     {'C00155'}
%     {'C00183'}
%     {'C00201'}
%     {'C00256'}
%     {'C00283'}
%     {'C00310'}
%     {'C00311'}
%     {'C00320'}
%     {'C00491'}
%     {'C00601'}
%     {'C00696'}
%     {'C00842'}
%     {'C00899'}
%     {'C00937'}
%     {'C00979'}
%     {'C00984'}
%     {'C01013'}
%     {'C01092'}
%     {'C01157'}
%     {'C01176'}
%     {'C01412'}
%     {'C01598'}
%     {'C01636'}
%     {'C01642'}
%     {'C01646'}
%     {'C01653'}
%     {'C02291'}
%     {'C02882'}
%     {'C02909'}
%     {'C03765'}
%     {'C04042'}
%     {'C04043'}
%     {'C04297'}
%     {'C05576'}
%     {'C05577'}
%     {'C05581'}
%     {'C05583'}
%     {'C05689'}
%     {'C05698'}
%     {'C05827'}
%     {'C05933'}
%     {'C06604'}
%     {'C06611'}
%     {'C06612'}
%     {'C06899'}
%     {'C13712'}
%     {'C14089'}
%     {'C15810'}
%     {'C15813'}
%     {'C16587'}
%     {'C18041'}
%     {'C19892'}
%     {'C20649'}
%     {'C20659'}

% %%
wasteMets = getCommonWasteMets(TvaginalisExchangeModel); % get list (cell array) of common waste metabolites
essentialMets = {'C00031','C00014','C00007','C00009','C00036'}; % glucose, ammonium, oxygen, phosphate, sulfate
communityMets = getCommunityExchangeMets(); % metabolites that are likely to be needed in MCMM community exchanges
allExMets = unique([biomassMets(:); wasteMets(:); essentialMets(:); communityMets(:)], 'stable'); % concatenate while avoiding potential duplicates

% add the exchange reactions to the model
TvaginalisExchangeModel = addExchangeRxnsForModel(TvaginalisExchangeModel, allExMets);
% Out:
% Warning: Metabolite C00186 not found in model, skipping.
% Warning: Metabolite C00086 not found in model, skipping.
% Warning: Metabolite C00282 not found in model, skipping.
% Warning: Metabolite C00246 not found in model, skipping.

% %%
% ensure reversibility of reactions
TvaginalisExchangeModel = ensureRevField(TvaginalisExchangeModel);
% Out:
% Model already has rev field

% %%
sol3 = solveLP(TvaginalisExchangeModel);
disp(sol3.f);
% Out:
%   19.108280254777071

% %% [markdown]
% There is now biomass production!

% %%
% pre-export cleaning
TvaginalisExchangeModel = fixSubsystemsField(TvaginalisExchangeModel);
TvaginalisExchangeModel = sanitizeRxnMiriams(TvaginalisExchangeModel);
% Out:
% Sanitized rxnMiriams for 1251 reactions

% %% [markdown]
% Now the model is ready for export:

% %%
% export the current model version
exportModel(TvaginalisExchangeModel, 'Tvaginalis_draftGEM_v4.xml');
% Out:
% WARNING: The following InChI strings are associated to more than one unique metabolite name:
%     1S/C24H40N7O17P3S/c1-4-15(33)52-8-7-26-14(32)5-6-27-22(36)19(35)24(2,3)10-45-51(42,43)48-50(40,41)44-9-13-18(47-49(37,38)39)17(34)23(46-13)31-12-30-16-20(25)28-11-29-21(16)31/h11-13,17-19,23,34-35H,4-10H2,1-3H3,(H,26,32)(H,27,36)(H,40,41)(H,42,43)(H2,25,28,29)(H2,37,38,39)/t13-,17-,18-,19+,23-/m1/s1
% Document written

% %%
exportToExcelFormat(TvaginalisExchangeModel, 'Tvaginalis_draftGEM_v4.xlsx');
save('Tvaginalis_draftGEM_v4.mat', 'TvaginalisExchangeModel');

% %% [markdown]
% This will be the version used for the MCMM.
%
% ## Additional tests
%
% A few more sanity checks and tests prior to moving on to gap\-filling.

% %%
% Setting up the draft GEM base
%TvaginalisBiomassDraftModel = importModel('Tvaginalis_draftGEM_v4.xml');
% create a copy to avoid overwriting
TvaginalisBiomassObjDraftModel = TvaginalisExchangeModel;
TvaginalisBiomassObjDraftModel.id = 'TvaginalisDraft';

% %% [markdown]
% First, checking for dead\-end metabolites:

% %%
deadMets = quickDeadEnds(TvaginalisBiomassObjDraftModel);
fprintf('Dead-end metabolites: %d\n', numel(deadMets));
% Out:
% Dead-end metabolites: 0

% %% [markdown]
% Double\-check that the biomass metabolites are indeed present in the model:

% %%
biomassMets = getBiomassMets(TvaginalisBiomassObjDraftModel, 'BIOMASS_ps');
% Out:
% Biomass reaction: BIOMASS_ps
% Number of metabolites in biomass reaction: 358
%     {'C00001'}
%     {'C00002'}
%     {'C00003'}
%     {'C00004'}
%     {'C00005'}
%     {'C00006'}
%     {'C00007'}
%     {'C00008'}
%     {'C00009'}
%     {'C00010'}
%     {'C00011'}
%     {'C00013'}
%     {'C00014'}
%     {'C00015'}
%     {'C00019'}
%     {'C00020'}
%     {'C00022'}
%     {'C00024'}
%     {'C00025'}
%     {'C00026'}
%     {'C00029'}
%     {'C00030'}
%     {'C00031'}
%     {'C00033'}
%     {'C00035'}
%     {'C00036'}
%     {'C00037'}
%     {'C00040'}
%     {'C00042'}
%     {'C00044'}
%     {'C00049'}
%     {'C00055'}
%     {'C00061'}
%     {'C00063'}
%     {'C00064'}
%     {'C00065'}
%     {'C00073'}
%     {'C00075'}
%     {'C00078'}
%     {'C00079'}
%     {'C00080'}
%     {'C00081'}
%     {'C00082'}
%     {'C00084'}
%     {'C00085'}
%     {'C00092'}
%     {'C00093'}
%     {'C00095'}
%     {'C00097'}
%     {'C00101'}
%     {'C00103'}
%     {'C00104'}
%     {'C00105'}
%     {'C00110'}
%     {'C00112'}
%     {'C00116'}
%     {'C00117'}
%     {'C00118'}
%     {'C00121'}
%     {'C00123'}
%     {'C00124'}
%     {'C00131'}
%     {'C00135'}
%     {'C00136'}
%     {'C00143'}
%     {'C00144'}
%     {'C00147'}
%     {'C00148'}
%     {'C00149'}
%     {'C00152'}
%     {'C00154'}
%     {'C00157'}
%     {'C00160'}
%     {'C00163'}
%     {'C00166'}
%     {'C00173'}
%     {'C00181'}
%     {'C00188'}
%     {'C00189'}
%     {'C00195'}
%     {'C00197'}
%     {'C00206'}
%     {'C00207'}
%     {'C00214'}
%     {'C00221'}
%     {'C00224'}
%     {'C00239'}
%     {'C00249'}
%     {'C00250'}
%     {'C00255'}
%     {'C00257'}
%     {'C00258'}
%     {'C00262'}
%     {'C00267'}
%     {'C00272'}
%     {'C00286'}
%     {'C00288'}
%     {'C00314'}
%     {'C00342'}
%     {'C00345'}
%     {'C00346'}
%     {'C00350'}
%     {'C00355'}
%     {'C00356'}
%     {'C00360'}
%     {'C00361'}
%     {'C00362'}
%     {'C00363'}
%     {'C00364'}
%     {'C00365'}
%     {'C00378'}
%     {'C00379'}
%     {'C00381'}
%     {'C00385'}
%     {'C00386'}
%     {'C00407'}
%     {'C00410'}
%     {'C00416'}
%     {'C00418'}
%     {'C00429'}
%     {'C00433'}
%     {'C00455'}
%     {'C00460'}
%     {'C00469'}
%     {'C00473'}
%     {'C00498'}
%     {'C00526'}
%     {'C00532'}
%     {'C00534'}
%     {'C00535'}
%     {'C00555'}
%     {'C00577'}
%     {'C00579'}
%     {'C00583'}
%     {'C00613'}
%     {'C00631'}
%     {'C00636'}
%     {'C00637'}
%     {'C00641'}
%     {'C00658'}
%     {'C00668'}
%     {'C00673'}
%     {'C00674'}
%     {'C00705'}
%     {'C00787'}
%     {'C00794'}
%     {'C00800'}
%     {'C00828'}
%     {'C00831'}
%     {'C00836'}
%     {'C00853'}
%     {'C00864'}
%     {'C00882'}
%     {'C00921'}
%     {'C00957'}
%     {'C01005'}
%     {'C01097'}
%     {'C01107'}
%     {'C01132'}
%     {'C01134'}
%     {'C01143'}
%     {'C01144'}
%     {'C01149'}
%     {'C01172'}
%     {'C01179'}
%     {'C01185'}
%     {'C01194'}
%     {'C01204'}
%     {'C01213'}
%     {'C01217'}
%     {'C01241'}
%     {'C01243'}
%     {'C01245'}
%     {'C01272'}
%     {'C01277'}
%     {'C01344'}
%     {'C01346'}
%     {'C01419'}
%     {'C01528'}
%     {'C01628'}
%     {'C01637'}
%     {'C01638'}
%     {'C01639'}
%     {'C01640'}
%     {'C01641'}
%     {'C01643'}
%     {'C01644'}
%     {'C01645'}
%     {'C01647'}
%     {'C01648'}
%     {'C01650'}
%     {'C01651'}
%     {'C01652'}
%     {'C01702'}
%     {'C01977'}
%     {'C02031'}
%     {'C02059'}
%     {'C02076'}
%     {'C02100'}
%     {'C02211'}
%     {'C02336'}
%     {'C02339'}
%     {'C02576'}
%     {'C02670'}
%     {'C02743'}
%     {'C02972'}
%     {'C03021'}
%     {'C03024'}
%     {'C03150'}
%     {'C03205'}
%     {'C03319'}
%     {'C03461'}
%     {'C03492'}
%     {'C03557'}
%     {'C03681'}
%     {'C03819'}
%     {'C04079'}
%     {'C04089'}
%     {'C04143'}
%     {'C04213'}
%     {'C04230'}
%     {'C04242'}
%     {'C04244'}
%     {'C04308'}
%     {'C04317'}
%     {'C04352'}
%     {'C04438'}
%     {'C04477'}
%     {'C04501'}
%     {'C04506'}
%     {'C04520'}
%     {'C04549'}
%     {'C04637'}
%     {'C05116'}
%     {'C05130'}
%     {'C05196'}
%     {'C05197'}
%     {'C05223'}
%     {'C05335'}
%     {'C05345'}
%     {'C05445'}
%     {'C05519'}
%     {'C05544'}
%     {'C05545'}
%     {'C05634'}
%     {'C05665'}
%     {'C05745'}
%     {'C05749'}
%     {'C05752'}
%     {'C05755'}
%     {'C05761'}
%     {'C05764'}
%     {'C05774'}
%     {'C05936'}
%     {'C05983'}
%     {'C05985'}
%     {'C05993'}
%     {'C05999'}
%     {'C06002'}
%     {'C06055'}
%     {'C06103'}
%     {'C06423'}
%     {'C06504'}
%     {'C06505'}
%     {'C06754'}
%     {'C07645'}
%     {'C07649'}
%     {'C09762'}
%     {'C11038'}
%     {'C11174'}
%     {'C11537'}
%     {'C11555'}
%     {'C11736'}
%     {'C14145'}
%     {'C15811'}
%     {'C15812'}
%     {'C15973'}
%     {'C16218'}
%     {'C16221'}
%     {'C16240'}
%     {'C16241'}
%     {'C16634'}
%     {'C16636'}
%     {'C17328'}
%     {'C18026'}
%     {'C18040'}
%     {'C18060'}
%     {'C18125'}
%     {'C18126'}
%     {'C18237'}
%     {'C18902'}
%     {'C19078'}
%     {'C19080'}
%     {'C20876'}
%     {'C21028'}
%     {'C21640'}
%     {'C21748'}
%     {'C21750'}
%     {'C21844'}
%     {'C22157'}
%     {'C22158'}
%     {'C22499'}
%     {'C00047'}
%     {'C00062'}
%     {'C00155'}
%     {'C00183'}
%     {'C00201'}
%     {'C00256'}
%     {'C00283'}
%     {'C00310'}
%     {'C00311'}
%     {'C00320'}
%     {'C00491'}
%     {'C00601'}
%     {'C00696'}
%     {'C00842'}
%     {'C00899'}
%     {'C00937'}
%     {'C00979'}
%     {'C00984'}
%     {'C01013'}
%     {'C01092'}
%     {'C01157'}
%     {'C01176'}
%     {'C01412'}
%     {'C01598'}
%     {'C01636'}
%     {'C01642'}
%     {'C01646'}
%     {'C01653'}
%     {'C02291'}
%     {'C02882'}
%     {'C02909'}
%     {'C03765'}
%     {'C04042'}
%     {'C04043'}
%     {'C04297'}
%     {'C05576'}
%     {'C05577'}
%     {'C05581'}
%     {'C05583'}
%     {'C05689'}
%     {'C05698'}
%     {'C05827'}
%     {'C05933'}
%     {'C06604'}
%     {'C06611'}
%     {'C06612'}
%     {'C06899'}
%     {'C13712'}
%     {'C14089'}
%     {'C15810'}
%     {'C15813'}
%     {'C16587'}
%     {'C18041'}
%     {'C19892'}
%     {'C20649'}
%     {'C20659'}

% %%
missing = setdiff(biomassMets, TvaginalisBiomassObjDraftModel.mets);
disp(missing);

% %% [markdown]
% Perform a preliminary test for whether gap\-filling is necessary:

% %%
% block all exchange
TvaginalisBiomassObjDraftModel.lb(findExcRxns(TvaginalisBiomassObjDraftModel)) = 0;

% reopen minimal medium
allowMets = {'C00031','C00014','C00007','C00009','C00036'}; % glucose, ammonium, oxygen, phosphate, sulfate
for i = 1:numel(allowMets)
    exIdx = find(strcmp(TvaginalisBiomassObjDraftModel.mets, allowMets{i}));
    if ~isempty(exIdx)
        rxnIdx = find(TvaginalisBiomassObjDraftModel.S(exIdx,:));
        TvaginalisBiomassObjDraftModel.lb(rxnIdx) = -1000; % uptake allowed
    end
end

sol4 = solveLP(TvaginalisBiomassObjDraftModel);
disp(sol4.f);
% Out:
%   19.108280254777128

% %% [markdown]
% The solution here is the same as before, so this looks good to go.
%
%
% On Ed's recommendation, I will force the biomass flux to be positive:

% %%
% force the biomass flux to be positive
% Set lower and upper bounds of the biomass reaction
rxnID = 'BIOMASS_ps';
biomassIndex = find(ismember(TvaginalisBiomassObjDraftModel.rxns, rxnID));

TvaginalisBiomassObjDraftModel.lb(biomassIndex) = 0.1;  % minimum growth rate
TvaginalisBiomassObjDraftModel.ub(biomassIndex) = 1000; % allow up to 1000

% %% [markdown]
% Finally, run FBA on the new model:

% %%
sol3 = solveLP(TvaginalisBiomassObjDraftModel);
disp(sol3.f)
% Out:
%   19.108280254777071

% %% [markdown]
% Export the model:

% %%
exportModel(TvaginalisBiomassObjDraftModel, 'Tvaginalis_draftGEM_v5.xml');
% Out:
% WARNING: The following reactions have lower and upper bounds that indicate reversibility, but are indicated as irreversible in model.rev:
%     R00078
%     R00765
%     R07942
%     R07978
%     R07979
%     R08221_EXP_1
%     R08235
%     R12958
%     R12989
%     ...and 6 more
% WARNING: The following InChI strings are associated to more than one unique metabolite name:
%     1S/C24H40N7O17P3S/c1-4-15(33)52-8-7-26-14(32)5-6-27-22(36)19(35)24(2,3)10-45-51(42,43)48-50(40,41)44-9-13-18(47-49(37,38)39)17(34)23(46-13)31-12-30-16-20(25)28-11-29-21(16)31/h11-13,17-19,23,34-35H,4-10H2,1-3H3,(H,26,32)(H,27,36)(H,40,41)(H,42,43)(H2,25,28,29)(H2,37,38,39)/t13-,17-,18-,19+,23-/m1/s1
% Document written

% %%
exportToExcelFormat(TvaginalisBiomassObjDraftModel, 'Tvaginalis_draftGEM_v5.xlsx');
save('Tvaginalis_draftGEM_v5.mat', 'TvaginalisBiomassObjDraftModel');

% %% [markdown]
% ## Gap\-filling attempt
%
% On the advice of Ed, I will be doing gap\-filling from the whole of the KEGG database. While the model does technically produce biomass and so therefore is viable, it is better to add more exchanges to ensure as high\-quality of an MCMM as possible.

% %%
% trying gap filling
[Tvaginalis_filledModel, addedRxns] = fillGaps( ...
    TvaginalisBiomassObjDraftModel, ...
    modelKEGGgr, ...
    false, true, true);

% Check the output of fillGaps
if isempty(Tvaginalis_filledModel)
    disp('fillGaps returned an empty model. Check your input models and required fields.');
elseif iscell(Tvaginalis_filledModel)
    disp(['fillGaps returned a cell array of size: ', mat2str(size(Tvaginalis_filledModel))]);
else
    disp('fillGaps returned a valid model struct.');
end
% Out:
% fillGaps returned an empty model. Check your input models and required fields.

% %% [markdown]
% Check the results:

% %%
% Did fillGaps return something valid?
class(Tvaginalis_filledModel)
% Out:
% ans = 'cell'

% %%
whos Tvaginalis_filledModel
% Out:
%   Name                        Size            Bytes  Class    Attributes
%   Tvaginalis_filledModel      0x0                 0  cell

% %% [markdown]
% As before, it appears that gap\-filling is unnecessary in this case.
%
% ## Human GEM
%
% The human GEM that I will be using was downloaded from GitHub: [https://github.com/SysBioChalmers/Human\-GEM](https://github.com/SysBioChalmers/Human-GEM)
%
%
% The SBML\-formatted version is found at: `Human-GEM/model/Human-GEM.xml`
%
%
% Unfortunately, Human\-GEM uses BIGG reaction and metabolite names, with clashes with the KEGG\-derived draft GEMs created throughout the rest of this workflow. Therefore, prior to constructing the MCMMs, I will create a version of Human\-GEM that uses KEGG reaction and metabolite names.
%
%
% I began by downloading the ChEBI FTP flat files and parsing it to extract ChEBI\-KEGG pairs:
%
%
%  `wget` [`ftp://ftp.ebi.ac.uk/pub/databases/chebi/Flat_file_tab_delimited/database_accession.tsv`](ftp://ftp.ebi.ac.uk/pub/databases/chebi/Flat_file_tab_delimited/database_accession.tsv)
%
%
% `awk -F'\\t' '\$3=="KEGG COMPOUND" && \$4=="KEGG COMPOUND accession" {print "CHEBI:" \$2 "\\t" \$5}' database_accession.tsv > chebi_to_kegg.tsv`
%
%
% Now using this file to create a KEGG version of Human\-GEM:

% %%
%% --- Load Human-GEM XML ---
xmlFile = 'Human-GEM.xml';
xDoc = xmlread(xmlFile);

%% --- Load ChEBI -> KEGG mapping ---
chebiMap = readtable('chebi_to_kegg.tsv','FileType','text','Delimiter','\t',...
    'ReadVariableNames',false);
chebiMap.Properties.VariableNames = {'ChEBI','KEGG'};

%% --- Extract all metabolites ---
metabolites = xDoc.getElementsByTagName('species');
numMets = metabolites.getLength;

% Storage for IDs
metID   = cell(numMets,1);
metName = cell(numMets,1);
keggID  = cell(numMets,1);
chebiID = cell(numMets,1);

for i = 0:numMets-1
    node = metabolites.item(i);
    metID{i+1}   = char(node.getAttribute('id'));
    metName{i+1} = char(node.getAttribute('name'));

    % Extract KEGG and ChEBI URIs
    annotationNode = node.getElementsByTagName('annotation').item(0);
    if ~isempty(annotationNode)
        rdfNode = annotationNode.getElementsByTagName('rdf:RDF').item(0);
        if ~isempty(rdfNode)
            liNodes = rdfNode.getElementsByTagName('rdf:li');
            for j = 0:liNodes.getLength-1
                uri = char(liNodes.item(j).getAttribute('rdf:resource'));
                if contains(uri,'kegg.compound/')
                    keggID{i+1} = extractAfter(uri,'kegg.compound/');
                elseif contains(uri,'chebi/')
                    chebiID{i+1} = extractAfter(uri,'chebi/');
                end
            end
        end
    end
end

%% --- Fill missing KEGG IDs via ChEBI mapping ---
for i = 1:numMets
    if isempty(keggID{i}) && ~isempty(chebiID{i})
        idx = find(strcmp(chebiMap.ChEBI, chebiID{i}));
        if ~isempty(idx)
            keggID{i} = chebiMap.KEGG{idx(1)};
        end
    end
end

%% --- Normalize KEGG IDs to strings ---
% Replace [] with '' and enforce cellstr
for i = 1:numel(keggID)
    if isempty(keggID{i})
        keggID{i} = '';
    else
        keggID{i} = char(keggID{i});
    end
end

%% --- Handle duplicate KEGG IDs: keep first, log others ---
[uniqueKegg, ia, ic] = unique(keggID, 'stable');
dupIdx = setdiff(1:numel(keggID), ia);

if ~isempty(dupIdx)
    dupLog = 'duplicate_metabolites.log';
    fid = fopen(dupLog,'w');
    fprintf(fid,'The following KEGG IDs had multiple matches. First kept, others removed:\n\n');
    dupGroups = accumarray(ic(dupIdx), dupIdx, [], @(x){x});
    for g = 1:numel(dupGroups)
        if isempty(dupGroups{g})
            continue   % skip this group
        end

        idxs = dupGroups{g};   % all indices in this group
        refKegg = keggID{idxs(1)};   % use first as reference

        % Example: check consistency
        if ~all(strcmp(refKegg, keggID(idxs)))
            fprintf('Inconsistent KEGG IDs in group %d\n', g);
        end
    end
    fclose(fid);
    fprintf('Warning: %d duplicate KEGG IDs found. See %s for details.\n', ...
        numel(dupIdx), dupLog);
end
% Out:
% Warning: 6773 duplicate KEGG IDs found. See duplicate_metabolites.log for details.

% %%
% Keep only first occurrence of each KEGG ID
keggID  = uniqueKegg;
metID   = metID(ia);
metName = metName(ia);
chebiID = chebiID(ia);
numMets = numel(metID);

%% --- Build mapping oldID -> KEGG ID (no compartments) ---
validIdx = ~cellfun(@isempty, keggID);
old2kegg = containers.Map(metID(validIdx), keggID(validIdx));

%% --- Update XML species nodes with plain KEGG IDs ---
for i = 0:metabolites.getLength-1
    node = metabolites.item(i);
    oldID = char(node.getAttribute('id'));

    if isKey(old2kegg, oldID) && ~isempty(old2kegg(oldID))
        newKEGG = old2kegg(oldID);

        % Use plain KEGG ID
        node.setAttribute('id', newKEGG);
        node.setAttribute('name', newKEGG);

        % Update RDF annotation with KEGG URI
        annotationNode = node.getElementsByTagName('annotation').item(0);
        if ~isempty(annotationNode)
            rdfNode = annotationNode.getElementsByTagName('rdf:RDF').item(0);
            if ~isempty(rdfNode)
                bagNode = rdfNode.getElementsByTagName('rdf:Bag').item(0);
                liNodes = bagNode.getElementsByTagName('rdf:li');

                % Remove old KEGG URIs
                for j = liNodes.getLength-1:-1:0
                    uri = char(liNodes.item(j).getAttribute('rdf:resource'));
                    if contains(uri,'kegg.compound/')
                        bagNode.removeChild(liNodes.item(j));
                    end
                end

                % Add new KEGG URI
                docNode = xDoc.createElement('rdf:li');
                docNode.setAttribute('rdf:resource', ['https://identifiers.org/kegg.compound/' newKEGG]);
                bagNode.appendChild(docNode);
            end
        end
    end
end

%% --- Update reactions using new KEGG IDs ---
missingMets = {};
reactions = xDoc.getElementsByTagName('reaction');
for i = 0:reactions.getLength-1
    rNode = reactions.item(i);
    speciesRefs = rNode.getElementsByTagName('speciesReference');
    for j = 0:speciesRefs.getLength-1
        sRef = speciesRefs.item(j);
        oldMet = char(sRef.getAttribute('species'));
        if isKey(old2kegg, oldMet) && ~isempty(old2kegg(oldMet))
            sRef.setAttribute('species', old2kegg(oldMet));
        else
            missingMets{end+1,1} = oldMet; %#ok<SAGROW>
        end
    end
end

%% --- Fix exchange reaction IDs ---
for i = 0:reactions.getLength-1
    rNode = reactions.item(i);
    speciesRefs = rNode.getElementsByTagName('speciesReference');

    if speciesRefs.getLength == 1
        sRef = speciesRefs.item(0);
        oldMet = char(sRef.getAttribute('species'));

        if isKey(old2kegg, oldMet)
            newMet = old2kegg(oldMet);

            % Update the metabolite reference
            sRef.setAttribute('species', newMet);

            % Rename the reaction itself: EX_<KEGG>
            newRxnID = ['EX_' newMet];
            rNode.setAttribute('id', newRxnID);
            rNode.setAttribute('name', ['Exchange for ' newMet]);
        end
    end
end

%% --- Write missing metabolites to log file ---
missingMets = unique(missingMets);
if ~isempty(missingMets)
    logFile = 'missing_metabolites.log';
    fid = fopen(logFile,'w');
    fprintf(fid,'The following metabolites were not found in the KEGG mapping:\n');
    fprintf(fid,'%s\n',missingMets{:});
    fclose(fid);
    fprintf('Warning: %d metabolites missing KEGG IDs. See %s for details.\n', ...
        numel(missingMets), logFile);
end
% Out:
% Warning: 6774 metabolites missing KEGG IDs. See missing_metabolites.log for details.

% %%
%% --- Save KEGG XML ---
keggXMLfile = 'Human-GEM_KEGG.xml';
xmlwrite(keggXMLfile, xDoc);

% %% [markdown]
% Finally, ensure compatibility with RAVEN/COBRA:

% %%
%% --- Import back in RAVEN to test ---
model = importModel(keggXMLfile);
% Out:
% The model contains 0 errors and 1 warnings.
% WARNING: The following InChI strings are associated to more than one unique metabolite name:
%     1/C10H12N2O3/c11-7-4-2-1-3-6(7)9(13)5-8(12)10(14)15/h1-4,8H,5,11-12H2,(H,14,15)/t8-/s2
%     1/C10H12N2O4/c11-6(10(15)16)4-8(14)5-2-1-3-7(13)9(5)12/h1-3,6,13H,4,11-12H2,(H,15,16)/t6-/s2
%     1/C10H17NO3/c1-11-6-3-4-7(11)9(8(12)5-6)10(13)14-2/h6-9,12H,3-5H2,1-2H3/t6-,7+,8-,9+/s2
%     1/C10H19NO4/c1-5-10(14)15-8(6-9(12)13)7-11(2,3)4/h8H,5-7H2,1-4H3
%     1/C11H21NO4/c1-5-6-11(15)16-9(7-10(13)14)8-12(2,3)4/h9H,5-8H2,1-4H3
%     1/C14H20N6O5S/c15-6(14(23)24)1-2-26-3-7-9(21)10(22)13(25-7)20-5-19-8-11(16)17-4-18-12(8)20/h4-7,9-10,13,21-22H,1-3,15H2,(H,23,24)(H2,16,17,18)/t6-,7+,9+,10+,13+/s2
%     1/C17H21NO4/c1-18-12-8-9-13(18)15(17(20)21-2)14(10-12)22-16(19)11-6-4-3-5-7-11/h3-7,12-15H,8-10H2,1-2H3/t12-,13+,14-,15+/s2
%     1/C20H12O/c1-2-11-4-5-13-10-14-7-9-16-20(21-16)19(14)15-8-6-12(3-1)17(11)18(13)15/h1-10,16,20H
%     1/C20H12O/c1-2-6-13-12(4-1)10-16-18-14(13)9-8-11-5-3-7-15(17(11)18)19-20(16)21-19/h1-10,19-20H
%     ...and 147 more

% %%
exportModel(model,'Human-GEM_KEGG_test.xml');  % re-export to check formatting
% Out:
% WARNING: The following InChI strings are associated to more than one unique metabolite name:
%     1/C10H12N2O3/c11-7-4-2-1-3-6(7)9(13)5-8(12)10(14)15/h1-4,8H,5,11-12H2,(H,14,15)/t8-/s2
%     1/C10H12N2O4/c11-6(10(15)16)4-8(14)5-2-1-3-7(13)9(5)12/h1-3,6,13H,4,11-12H2,(H,15,16)/t6-/s2
%     1/C10H17NO3/c1-11-6-3-4-7(11)9(8(12)5-6)10(13)14-2/h6-9,12H,3-5H2,1-2H3/t6-,7+,8-,9+/s2
%     1/C10H19NO4/c1-5-10(14)15-8(6-9(12)13)7-11(2,3)4/h8H,5-7H2,1-4H3
%     1/C11H21NO4/c1-5-6-11(15)16-9(7-10(13)14)8-12(2,3)4/h9H,5-8H2,1-4H3
%     1/C14H20N6O5S/c15-6(14(23)24)1-2-26-3-7-9(21)10(22)13(25-7)20-5-19-8-11(16)17-4-18-12(8)20/h4-7,9-10,13,21-22H,1-3,15H2,(H,23,24)(H2,16,17,18)/t6-,7+,9+,10+,13+/s2
%     1/C17H21NO4/c1-18-12-8-9-13(18)15(17(20)21-2)14(10-12)22-16(19)11-6-4-3-5-7-11/h3-7,12-15H,8-10H2,1-2H3/t12-,13+,14-,15+/s2
%     1/C20H12O/c1-2-11-4-5-13-10-14-7-9-16-20(21-16)19(14)15-8-6-12(3-1)17(11)18(13)15/h1-10,16,20H
%     1/C20H12O/c1-2-6-13-12(4-1)10-16-18-14(13)9-8-11-5-3-7-15(17(11)18)19-20(16)21-19/h1-10,19-20H
%     ...and 147 more
% Document written

% %%
disp('Human-GEM KEGG version created and validated with RAVEN import/export.');
% Out:
% Human-GEM KEGG version created and validated with RAVEN import/export.

% %% [markdown]
% ## Conclusions
%
% With this, all preliminary draft GEMs have been generated. The MCMM creation part of the pipeline will be handled in Jupyter. I will be using the \*\_draftGEM\_v4.xml files for the MCMM generation. I will use the KEGG version of the
